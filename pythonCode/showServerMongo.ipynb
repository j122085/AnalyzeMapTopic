# %%
import pymongo
client = pymongo.mongo_client.MongoClient("192.168.1.113", 27017, username='j122085', password='850605')
db = client.rawData

# %%
db.collection_names()
# Out:
# ['MRTinfo',
#  'info3Store',
#  'websites591',
#  'taiwanInfo',
#  'trainStation',
#  'taiwanInfoIta',
#  'eslite',
#  'ipeenInfo',
#  'conStore',
#  'CostPower',
#  'infoClinic',
#  'Watsons',
#  'pxmart',
#  'taiwanInfoSuFood',
#  'busData',
#  'HRdata104',
#  'wowprimediendata',
#  'info591',
#  'departmentStore',
#  'carrefour',
#  'smallStyleCount',
#  'addressCoordinate',
#  'Nhuman',
#  'taiwanInfoStoneTwo',
#  'ipeenWebsite',
#  'realPriceLogin',
#  'canSuMe',
#  'bigStyleCount',
#  'taiwanInfoHot7',
#  'dahu',
#  'primarySchool',
#  'taiwanInfoMaBoss']

# %%
co_names=db.collection_names()
co_names.sort()
for collection_name in co_names:    
    collection=db[collection_name]
    print("collection(table):",collection_name)
    data=collection.find_one()
    for col in data:
        print("\t",col,":",type(data[col]))
# Out:
# collection(table): CostPower
# 	 _id : <class 'str'>
# 	 bigadd : <class 'str'>
# 	 smalladd : <class 'str'>
# 	 costPower : <class 'str'>
# 	 invoice : <class 'str'>
# 	 lat : <class 'float'>
# 	 lng : <class 'float'>
# collection(table): HRdata104
# 	 _id : <class 'bson.objectid.ObjectId'>
# 	 APPEAR_DATE : <class 'str'>
# 	 JOB : <class 'str'>
# 	 JOBCAT_DESCRIPT : <class 'str'>
# 	 JOB_ADDRESS : <class 'str'>
# 	 JOB_ADDR_NO_DESCRIPT : <class 'str'>
# 	 LAT : <class 'float'>
# 	 LON : <class 'float'>
# 	 NAME : <class 'str'>
# 	 PRODUCT : <class 'str'>
# 	 SAL_MONTH_HIGH : <class 'int'>
# 	 SAL_MONTH_LOW : <class 'int'>
# 	 bigadd : <class 'str'>
# 	 smalladd : <class 'str'>
# 	 bigstyle : <class 'str'>
# collection(table): MRTinfo
# 	 _id : <class 'int'>
# 	 項次 : <class 'int'>
# 	 出入口編號 : <class 'str'>
# 	 name : <class 'str'>
# 	 lng : <class 'float'>
# 	 lat : <class 'float'>
# 	 lunch : <class 'int'>
# 	 dinner : <class 'int'>
# collection(table): Nhuman
# ...

# %%
client.close()
