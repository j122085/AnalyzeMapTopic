# %%
import pymongo

# %%
client=pymongo.MongoClient('localhost', 27017,username="j122085",password="850605")

# %%
db=client.rawData

# %%
collection=db.ipeenInfo

# %%
ipeenData=list(collection.find({}))

# %%
macDowload=[i for i in ipeenData if '麥當' in i['name']]

# %%
macDowload
# Out:
# [{'Ncomment': 24,
#   '_id': 33636,
#   'address': '台北市大安區和平東路三段406巷8號',
#   'averagecost': 91,
#   'bigadd': '台北市',
#   'bigstyle': '速食料理',
#   'collecount': 1,
#   'comments': ['http://www.ipeen.com.tw/comment/1471112',
#    'http://www.ipeen.com.tw/comment/1142336',
#    'http://www.ipeen.com.tw/comment/849592',
#    'http://www.ipeen.com.tw/comment/688770',
#    'http://www.ipeen.com.tw/comment/521976'],
#   'ipeenscore': 45,
#   'lat': 25.01832400109,
#   'lng': 121.55799301069,
#   'name': '麥當勞(台北麟光店)',
#   'othername': '台北麟光店',
#   'reviewdate': '2015/05/20',
#   'smalladd': '大安區',
#   'smallstyle': '漢堡、炸雞',
#   'status': '正常營業',
#   'tele': '0223771063',
#   'url': 'http://www.ipeen.com.tw/shop/33636',
#   'viewcount': 93607},
#  {'Ncomment': 17,
#   '_id': 32937,
#   'address': '台北市大安區羅斯福路二段45號',
#   'averagecost': 88,
#   'bigadd': '台北市',
#   'bigstyle': '速食料理',
#   'collecount': 4,
#   'comments': ['http://www.ipeen.com.tw/comment/592218',
# ...
