# %%
import json
import requests
import os
from bs4 import BeautifulSoup as bs

# %%
if not os.path.exists('../data/html'):
    os.makedirs('../data/html')

# %%
with open("../data/WebsiteSet.json","r") as f:
    ipeenWebsite=json.load(f)

# %% [markdown]
# # 第一版-待將存檔名改成id

# %%
# for i in ipeenWebsite:
#     if not os.path.exists('./data/html/'+i+'.html'):
#         res=requests.get(ipeenWebsite[i])
#         if res.status_code==200:
#             with open("./data/html/"+i+".html","w",encoding="utf8") as f:
#                 f.write(res.text)
#                 print(i)
#             res.close()
#         else:
#             print(res.status_code)
#             print(i+"失敗")
#             res.close()
#     else:
#         print(i+"已抓取跳過")

# %%
# 將店名網址改成ID名網址
# n=0
# for i in ipeenWebsite:
#     if n%100==0:
#         print(n)
#     if os.path.exists('./data/html/'+i+'.html'):
#         n+=1
#         with open('./data/html/'+i+'.html',encoding="utf8") as f:
#             with open('./data/html2/'+ipeenWebsite[i].split("/")[-1]+'.html',"w",encoding="utf8") as d:
#                 d.write(f.read())

# %% [markdown]
# # 第二版 直接存ID 資料存於html2資料夾 (目前抓完約需三整天)

# %%
import time
import json
import requests
import os
from bs4 import BeautifulSoup as bs

#建立儲存網址的地方
if not os.path.exists('../data/html2'):
    os.makedirs('../data/html2')
    
#確認共有幾個網址需要抓
with open("../data/WebsiteSet.json","r") as f:
    ipeenWebsite=json.load(f)
    print("共有%s資料要抓取"%len(ipeenWebsite))

n=0
#將每個網址的網頁抓下來，每30頁睡5秒防ban
for i in ipeenWebsite:
    if not os.path.exists('../data/html2/'+ipeenWebsite[i].split("/")[-1]+'.html'):
        n+=1
        if n%15==0:
            time.sleep(5)
            print(n)
        res=requests.get(ipeenWebsite[i])
        if res.status_code==200:
            with open("../data/html2/"+ipeenWebsite[i].split("/")[-1]+".html","w",encoding="utf8") as f:
                f.write(res.text)
                print(i)
            res.close()
        else:
            print(res.status_code)
            print(ipeenWebsite[i].split("/")[-1]+"失敗")
            res.close()
    #過去抓取過的網頁直接跳過
    else:
        print(i+"已抓取跳過")

# %%
with open("../data/WebsiteSet.json","r") as f:
    ipeenWebsite=json.load(f)

# %%
ipeenWebsite

# %% [markdown]
# # try summary

# %%
import json
import requests
import os
from bs4 import BeautifulSoup as bs
if not os.path.exists('../data/html'):
    os.makedirs('../data/html')
with open("../data/WebsiteSet.json","r") as f:
    ipeenWebsite=json.load(f)
    
import time
import json
import requests
import os
from bs4 import BeautifulSoup as bs

#建立儲存網址的地方
if not os.path.exists('../data/html2'):
    os.makedirs('../data/html2')
    
#確認共有幾個網址需要抓
with open("../data/WebsiteSet.json","r") as f:
    ipeenWebsite=json.load(f)
    print("共有%s資料要抓取"%len(ipeenWebsite))

n=0
#將每個網址的網頁抓下來，每30頁睡5秒防ban
for i in ipeenWebsite:
    if not os.path.exists('../data/html2/'+ipeenWebsite[i].split("/")[-1]+'.html'):
        n+=1
        if n%15==0:
            time.sleep(5)
            print(n)
        res=requests.get(ipeenWebsite[i])
        if res.status_code==200:
            with open("../data/html2/"+ipeenWebsite[i].split("/")[-1]+".html","w",encoding="utf8") as f:
                f.write(res.text)
                print(i)
            res.close()
        else:
            print(res.status_code)
            print(ipeenWebsite[i].split("/")[-1]+"失敗")
            res.close()
    #過去抓取過的網頁直接跳過
    else:
        print(i+"已抓取跳過")

# %% [markdown]
# # try summary2

# %%
import json
import requests
import os
from bs4 import BeautifulSoup as bs    
import time
import pymongo
import re
from pymongo import UpdateOne#0125
b=time.time()
    
    
#確認共有幾個網址需要抓
#連Mongodb
client = pymongo.MongoClient('localhost', 27017)
#連DB名
db=client['rawData']
#秀DB內的collection list
print(db.collection_names())
collectionWeb = db.ipeenWebsite
ipeenWebsite={dien['_id']:dien["website"] for dien in list(collectionWeb.find({}))}

print("共有%s資料要抓取"%len(ipeenWebsite))
collectionInfo = db.ipeenInfo
dienInfo=list(collectionInfo.find({}))
client.close()
              
dienset=set()         
if len(dienInfo)!=0:
    dienset=set([dien["_id"] for dien in dienInfo])

n=0
#將每個網址的網頁抓下來，每30頁睡5秒防ban
dienlist=[]
for i in ipeenWebsite:
    if int(i) not in dienset:
#         e=time.time()
#         print(int(e-b))
#         print("連接前")
        try:
            res = None
            while res is None:
                try:
                    res=requests.get(ipeenWebsite[i])
                    while "RedisException" in res.text or "目前系統忙碌中" in res.text:
                        print("requests太頻繁被卡，睡兩分鐘")
                        time.sleep(120)
                        res=requests.get(ipeenWebsite[i])
                except:
                    print("requests逾時，睡兩分鐘")
                    time.sleep(120)
            if "很抱歉，找不到此頁面！" in res.text:
                print("{}，該頁已死".format(i))
                continue
            if res.status_code==200:
                n+=1
    #             e=time.time()
    #             print(int(e-b))
    #             print("已連接")
                if n%20==0:
                    client = pymongo.MongoClient('localhost', 27017)
                    db=client['rawData']
                    collectionInfo = db.ipeenInfo
                    try:
                        #0125----------------------------
                        ids=[data.pop("_id") for data in dienlist]
                        operations=[UpdateOne({"_id":idn},{'$set':data},upsert=True) for idn ,data in zip(ids,dienlist)]
                        collectionInfo.bulk_write(operations)
                        #0125----------------------------
    #                     collectionInfo.insert_many(dienlist,ordered=False)
                    except:
                        print("RRRRRRRRRRRRRRRRRRRRRR")#0125
    #                     print("some data has same _id")
                    dataN=collectionInfo.count()#0125
                    client.close()
                    print("目前有{}筆資料".format(dataN))#0125
    #                 print("目前有{}筆資料".format(len(dienInfo)+n))
                    dienlist=[]
                    time.sleep(10)
                diendata={}
                soup=bs(res.text,"lxml")
                info=soup.select_one("#shop-header > div.info")

                diendata["_id"]=int(i)#id
                diendata["name"]=info.find('span', attrs={'itemprop': 'name'}).text.replace('"',"")
                try:
                    diendata['othername']=re.findall("\((\w*[店|館|門市|百貨|街|夜市|商場|時代|廣場|中心|三越|大學|中|區|高鐵])\)",diendata['name'])[0]
                except:
                    diendata['othername']=0


                diendata["bigstyle"]=soup.find('a', attrs={'data-label': '詳細資訊_大分類'}).text
                diendata["smallstyle"]=info.find('a', attrs={'data-label': '上方小分類'}).text

                try:
                    diendata["averagecost"]=int(re.findall("本店均消 +([0-9]+) +元",info.select_one('p.cost.i').text)[0])
                except:
                    diendata["averagecost"]=0
                try:
                    diendata["tele"]=info.find('a', attrs={'data-label': '上方電話'}).text.replace("-","").replace(")","").replace("(","").replace(" ","")#tele
                except:
                    diendata["tele"]=0
                try:
                    diendata["address"]=info.find('a', attrs={'data-label': '上方地址'}).text.replace("\n"," ").strip()
    #                 diendata["address"]=re.findall("..[市|縣].+[區|市|鎮|鄉].+[路|街|地段|巷|鎮][0-9]+[-|之]?[0-9]*?[號|巷|弄]?[0-9]*[號|巷|弄|樓]",
    #                        info.find('a', attrs={'data-label': '上方地址'}).text)[0]#add
                except:
                    diendata["address"]=0
                #0116新增=================================================
                try:
                    diendata["bigadd"] = re.findall("(..[市|縣])(\w\w?\w?[區|市|鎮|鄉])",diendata["address"])[0][0]
                    diendata["smalladd"] = re.findall("(..[市|縣])(\w\w?\w?[區|市|鎮|鄉])",diendata["address"])[0][1]
                except:
                    diendata["bigadd"]=0
                    diendata["smalladd"]=0
                #0116新增=================================================
                try:
                    diendata["lat"]=float(re.findall("\/c=([0-9]+\.[0-9]+)\,([0-9]+\.[0-9]+)\/z=",
                                                   info.find('a', attrs={'data-label': '上方地址'})["href"])[0][0])#lat.lng
                except:
                    diendata["lat"]=0
                try:
                    diendata["lng"]=float(re.findall("\/c=([0-9]+\.[0-9]+)\,([0-9]+\.[0-9]+)\/z=",
                                                   info.find('a', attrs={'data-label': '上方地址'})["href"])[0][1])#lat.lng
                except:
                    diendata["lng"]=0
                try:
                    diendata["Ncomment"]=int(re.findall("會員分享文 \(([0-9]+)\)",soup.text)[0])#Ncomment
                except:
                    diendata["Ncomment"]=0

                #第四版變更---------------------
                diendata["url"]=ipeenWebsite[i]
    #             commentPage=int(diendata["Ncomment"]/5)+1
    #             peenlist=[]
    #             for i in range(1,commentPage+1):
    #                 url2=diendata["url"]+'/comments?p='+str(i)
    #                 res2=requests.get(url2)
    #                 n+=1
    #                 #每90筆requests資料儲存一次
    #                 if n%90==0:
    #                     with open(savePath,"w") as d:
    #                         json.dump(dienlist,d)
    #                     print("已存%s筆店家資料"%k)
    #                 #每45筆睡5秒，以防ban
    #                 if n%30==0:
    #                     e=time.time()
    #                     print("已執行%s秒"%int(e-b))
    #                     time.sleep(5)
    #                 if k%1000==0:
    #                     with open("..\data\diendataURL2\%s.json"%k,"w") as d:
    #                         json.dump(dienlist,d)
    #                     print("%s筆資料已備分"%k)
    #                 if res2.status_code == 200:
    #                     soup2=bs(res2.text,'lxml')
    #                     res2.close()
    #                     pagepeenlist=['http://www.ipeen.com.tw'+i['href'] for i in soup2.select("p.summary > a") 
    #                                   if "checkin" not in i['href']]
    #                     peenlist+=pagepeenlist
                peenlist=['http://www.ipeen.com.tw'+i['href'] for i in soup.select("p.summary > a") 
                                      if "checkin" not in i['href']]
                diendata["comments"]=peenlist
                #第四版變更---------------------  
                diendata["ipeenscore"]=int(info.select_one("span.score-bar.large > meter")['value'])#ipeenscore
                if "已歇業" in info.select_one("h1").text:
                    diendata["status"]="結束營業"
                elif "已搬遷" in info.select_one("h1").text:
                    diendata["status"]="已搬遷"
                else:
                    diendata["status"]="正常營業"
                diendata["viewcount"]=int(re.findall("共([0-9]+)人瀏覽([0-9]+)人收藏",info.select_one("div.scalar").text.
                           replace(",","").replace("\n","").replace(" ",""))[0][0])#viewcount
                diendata["collecount"]=int(re.findall("共([0-9]+)人瀏覽([0-9]+)人收藏",info.select_one("div.scalar").text.
                           replace(",","").replace("\n","").replace(" ",""))[0][1])#collecount
                diendata["reviewdate"]=re.findall("更新時間(\d{4}\/\d{2}\/\d{2})",soup.select_one("div#shop-details").text.
                           replace("\n","").replace(" ",""))[0]#renewdate
                dienlist.append(diendata)
                res.close()
    #             e=time.time()
    #             print(int(e-b))
    #             print("已爬取")
                print(i)
            else:
                print(res.status_code)
                print(i+"失敗")
                res.close()
                print("request出錯，睡30秒")
                time.sleep(30)
        except:
            continue
    #過去抓取過的網頁直接跳過
    else:
        print(i+"已抓取跳過")
        
client = pymongo.MongoClient('localhost', 27017)
db=client['rawData']
collectionInfo = db.ipeenInfo
try:
    #0125----------------------------
    ids=[data.pop("_id") for data in dienlist]
    operations=[UpdateOne({"_id":idn},{'$set':data},upsert=True) for idn ,data in zip(ids,dienlist)]
    collectionInfo.bulk_write(operations)
    #0125----------------------------
#                     collectionInfo.insert_many(dienlist,ordered=False)
except:
    print("RRRRRRRRRRRRRRRRRRRRRR")#0125
#                     print("some data has same _id")
dataN=collectionInfo.count()#0125
client.close()
print("共有{}筆資料".format(dataN))
# Out:
# ['ipeenWebsite', 'Nhumnan', 'ipeenInfo', 'addressCoordinate', 'HRdata104', 'CostPower', 'Nhuman', 'sample']
# 共有140567資料要抓取
# 597032已抓取跳過
# 81702已抓取跳過
# 57264已抓取跳過
# 95584已抓取跳過
# 976516已抓取跳過
# 66586已抓取跳過
# 979156已抓取跳過
# 600598已抓取跳過
# 88582已抓取跳過
# 110811已抓取跳過
# 49644已抓取跳過
# 590826已抓取跳過
# 7731已抓取跳過
# 635218已抓取跳過
# 16577已抓取跳過
# 31744已抓取跳過
# 6633已抓取跳過
# 94031已抓取跳過
# 36511已抓取跳過
# 948242已抓取跳過
# 17010已抓取跳過
# 121923已抓取跳過
# 145009已抓取跳過
# 155233已抓取跳過
# 6925已抓取跳過
# 7188已抓取跳過
# 43587已抓取跳過
# 67012已抓取跳過
# 33031已抓取跳過
# 38484已抓取跳過
# 3776已抓取跳過
# 141365已抓取跳過
# 47432已抓取跳過
# 108951已抓取跳過
# 578076已抓取跳過
# 39054已抓取跳過
# 39073已抓取跳過
# 992146已抓取跳過
# 10317已抓取跳過
# 22268已抓取跳過
# 40429已抓取跳過
# 108117已抓取跳過
# 23158已抓取跳過
# 987250已抓取跳過
# 615220已抓取跳過
# 6462已抓取跳過
# 43734已抓取跳過
# 479588已抓取跳過
# 44309已抓取跳過
# 584085已抓取跳過
# 132057已抓取跳過
# 600302已抓取跳過
# 134025已抓取跳過
# 42472已抓取跳過
# 8327已抓取跳過
# 1007950已抓取跳過
# 23525已抓取跳過
# 16551已抓取跳過
# 585583已抓取跳過
# 35407已抓取跳過
# 76080已抓取跳過
# 141337已抓取跳過
# 926202已抓取跳過
# 712324已抓取跳過
# 628558已抓取跳過
# 141715已抓取跳過
# 942500已抓取跳過
# 663462已抓取跳過
# 73732已抓取跳過
# 91956已抓取跳過
# 47673已抓取跳過
# 109941已抓取跳過
# 119130已抓取跳過
# 36695已抓取跳過
# 985934已抓取跳過
# 929896已抓取跳過
# 22578已抓取跳過
# 34611已抓取跳過
# 78216已抓取跳過
# 38290已抓取跳過
# 128111已抓取跳過
# 929038已抓取跳過
# 121039已抓取跳過
# 613262已抓取跳過
# 998522已抓取跳過
# 9646已抓取跳過
# 943074已抓取跳過
# 69229已抓取跳過
# 619292已抓取跳過
# 962590已抓取跳過
# 1016990已抓取跳過
# 32721已抓取跳過
# 935604已抓取跳過
# 801718已抓取跳過
# 9274已抓取跳過
# 119175已抓取跳過
# 636252已抓取跳過
# 104402已抓取跳過
# 100314已抓取跳過
# 33714已抓取跳過
# 41688已抓取跳過
# 928780已抓取跳過
# 1042770已抓取跳過
# 592722已抓取跳過
# 30314已抓取跳過
# 148051已抓取跳過
# 22206已抓取跳過
# 35637已抓取跳過
# 59929已抓取跳過
# 8459已抓取跳過
# 148791已抓取跳過
# 28869已抓取跳過
# 632196已抓取跳過
# 37482已抓取跳過
# 40317已抓取跳過
# 22709已抓取跳過
# 68871已抓取跳過
# 31229已抓取跳過
# 22161已抓取跳過
# 30766已抓取跳過
# 85752已抓取跳過
# 37453已抓取跳過
# 33601已抓取跳過
# 40797已抓取跳過
# 106394已抓取跳過
# 37664已抓取跳過
# 150553已抓取跳過
# 66489已抓取跳過
# 9778已抓取跳過
# 43268已抓取跳過
# 1030378已抓取跳過
# 105525已抓取跳過
# 10286已抓取跳過
# 783672已抓取跳過
# 958016已抓取跳過
# 634598已抓取跳過
# 114069已抓取跳過
# 582723已抓取跳過
# 150515已抓取跳過
# 38372已抓取跳過
# 938958已抓取跳過
# 40124已抓取跳過
# 79910已抓取跳過
# 22365已抓取跳過
# 52763已抓取跳過
# 598650已抓取跳過
# 42588已抓取跳過
# 45908已抓取跳過
# 617170已抓取跳過
# 131153已抓取跳過
# 92207已抓取跳過
# 636630已抓取跳過
# 625900已抓取跳過
# 107831已抓取跳過
# 122051已抓取跳過
# 549494已抓取跳過
# 617022已抓取跳過
# 143473已抓取跳過
# 979300已抓取跳過
# 39679已抓取跳過
# 583939已抓取跳過
# 118718已抓取跳過
# 23457已抓取跳過
# 110992已抓取跳過
# 22349已抓取跳過
# 89953已抓取跳過
# 42317已抓取跳過
# 981020已抓取跳過
# 152871已抓取跳過
# 126881已抓取跳過
# 975356已抓取跳過
# 34826已抓取跳過
# 32301已抓取跳過
# 1052706已抓取跳過
# 975520已抓取跳過
# 58530已抓取跳過
# 110119已抓取跳過
# 625604已抓取跳過
# 590224已抓取跳過
# 27429已抓取跳過
# 80788已抓取跳過
# 16548已抓取跳過
# 138215已抓取跳過
# 993224已抓取跳過
# 34770已抓取跳過
# 22545已抓取跳過
# 42835已抓取跳過
# 87992已抓取跳過
# 74600已抓取跳過
# 131861已抓取跳過
# 127071已抓取跳過
# 80786已抓取跳過
# 28053已抓取跳過
# 131363已抓取跳過
# 51701已抓取跳過
# 68884已抓取跳過
# 88583已抓取跳過
# 38252已抓取跳過
# 113457已抓取跳過
# 35880已抓取跳過
# 72245已抓取跳過
# 96784已抓取跳過
# 597140已抓取跳過
# 972684已抓取跳過
# 22355已抓取跳過
# 9623已抓取跳過
# 8700已抓取跳過
# 941562已抓取跳過
# 73423已抓取跳過
# 113524已抓取跳過
# 40893已抓取跳過
# 12670已抓取跳過
# 924678已抓取跳過
# 928572已抓取跳過
# 607602已抓取跳過
# 28297已抓取跳過
# 36330已抓取跳過
# 609164已抓取跳過
# 105233已抓取跳過
# 961204已抓取跳過
# 622512已抓取跳過
# 84365已抓取跳過
# 589166已抓取跳過
# 16629已抓取跳過
# 68248已抓取跳過
# 135709已抓取跳過
# 107209已抓取跳過
# 105851已抓取跳過
# 88469已抓取跳過
# 968688已抓取跳過
# 95458已抓取跳過
# 80894已抓取跳過
# 82595已抓取跳過
# 45130已抓取跳過
# 6500已抓取跳過
# 971084已抓取跳過
# 9014已抓取跳過
# 1041066已抓取跳過
# 1077648已抓取跳過
# 879994已抓取跳過
# 115646已抓取跳過
# 42367已抓取跳過
# 109903已抓取跳過
# 934924已抓取跳過
# 30236已抓取跳過
# 18936已抓取跳過
# 110859已抓取跳過
# 72317已抓取跳過
# 93716已抓取跳過
# 28428已抓取跳過
# 141841已抓取跳過
# 34638已抓取跳過
# 66537已抓取跳過
# 88698已抓取跳過
# 956260已抓取跳過
# 29872已抓取跳過
# 53081已抓取跳過
# 1018570已抓取跳過
# 961112已抓取跳過
# 15851已抓取跳過
# 945322已抓取跳過
# 47480已抓取跳過
# 102574已抓取跳過
# 255075已抓取跳過
# 9176已抓取跳過
# 28880已抓取跳過
# 91920已抓取跳過
# 50731已抓取跳過
# 69430已抓取跳過
# 45152已抓取跳過
# 22440已抓取跳過
# 148525已抓取跳過
# 28239已抓取跳過
# 85381已抓取跳過
# 8326已抓取跳過
# 110374已抓取跳過
# 608154已抓取跳過
# 8940已抓取跳過
# 45137已抓取跳過
# 4183已抓取跳過
# 985364已抓取跳過
# 35718已抓取跳過
# 153377已抓取跳過
# 85388已抓取跳過
# 6506已抓取跳過
# 79297已抓取跳過
# 971566已抓取跳過
# 155161已抓取跳過
# 592328已抓取跳過
# 965236已抓取跳過
# 596256已抓取跳過
# 30222已抓取跳過
# 157109已抓取跳過
# 93186已抓取跳過
# 120607已抓取跳過
# 16745已抓取跳過
# 996296已抓取跳過
# 119917已抓取跳過
# 93925已抓取跳過
# 28371已抓取跳過
# 125235已抓取跳過
# 658262已抓取跳過
# 999524已抓取跳過
# 151317已抓取跳過
# 104473已抓取跳過
# 54246已抓取跳過
# 56007已抓取跳過
# 596838已抓取跳過
# 22246已抓取跳過
# 9037已抓取跳過
# 155787已抓取跳過
# 45454已抓取跳過
# 41046已抓取跳過
# 155349已抓取跳過
# 136069已抓取跳過
# 91210已抓取跳過
# 107516已抓取跳過
# 151219已抓取跳過
# 76489已抓取跳過
# 119679已抓取跳過
# 37507已抓取跳過
# 123235已抓取跳過
# 65108已抓取跳過
# 43341已抓取跳過
# 31381已抓取跳過
# 29120已抓取跳過
# 984880已抓取跳過
# 1025546已抓取跳過
# 31370已抓取跳過
# 592442已抓取跳過
# 28807已抓取跳過
# 584421已抓取跳過
# 16572已抓取跳過
# 28411已抓取跳過
# 75200已抓取跳過
# 85430已抓取跳過
# 612904已抓取跳過
# 14745已抓取跳過
# 608946已抓取跳過
# 1028862已抓取跳過
# 38304已抓取跳過
# 13383已抓取跳過
# 580527已抓取跳過
# 155531已抓取跳過
# 600556已抓取跳過
# 43082已抓取跳過
# 929478已抓取跳過
# 115450已抓取跳過
# 581453已抓取跳過
# 937878已抓取跳過
# 53549已抓取跳過
# 117565已抓取跳過
# 153141已抓取跳過
# 28661已抓取跳過
# 107042已抓取跳過
# 617400已抓取跳過
# 36053已抓取跳過
# 31771已抓取跳過
# 590136已抓取跳過
# 92695已抓取跳過
# 143715已抓取跳過
# 615476已抓取跳過
# 41645已抓取跳過
# 48113已抓取跳過
# 22383已抓取跳過
# 22211已抓取跳過
# 106083已抓取跳過
# 70952已抓取跳過
# 1035424已抓取跳過
# 60581已抓取跳過
# 139031已抓取跳過
# 100319已抓取跳過
# 632396已抓取跳過
# 107143已抓取跳過
# 40659已抓取跳過
# 554804已抓取跳過
# 587282已抓取跳過
# 103051已抓取跳過
# 29939已抓取跳過
# 147175已抓取跳過
# 988522已抓取跳過
# 140729已抓取跳過
# 960572已抓取跳過
# 36664已抓取跳過
# 29744已抓取跳過
# 118974已抓取跳過
# 625832已抓取跳過
# 31929已抓取跳過
# 1026808已抓取跳過
# 46211已抓取跳過
# 28362已抓取跳過
# 597322已抓取跳過
# 72446已抓取跳過
# 1036424已抓取跳過
# 41505已抓取跳過
# 205309已抓取跳過
# 58381已抓取跳過
# 1043448已抓取跳過
# 61065已抓取跳過
# 611652已抓取跳過
# 113531已抓取跳過
# 28836已抓取跳過
# 596244已抓取跳過
# 143005已抓取跳過
# 28413已抓取跳過
# 1023222已抓取跳過
# 105935已抓取跳過
# 30424已抓取跳過
# 54719已抓取跳過
# 20510已抓取跳過
# 102271已抓取跳過
# 9614已抓取跳過
# 40863已抓取跳過
# 982570已抓取跳過
# 27702已抓取跳過
# 31766已抓取跳過
# 657442已抓取跳過
# 137815已抓取跳過
# 1021146已抓取跳過
# 979798已抓取跳過
# 99129已抓取跳過
# 609702已抓取跳過
# 39670已抓取跳過
# 74241已抓取跳過
# 122483已抓取跳過
# 83250已抓取跳過
# 33610已抓取跳過
# 78277已抓取跳過
# 636234已抓取跳過
# 587120已抓取跳過
# 589092已抓取跳過
# 778968已抓取跳過
# 141831已抓取跳過
# 41690已抓取跳過
# 41178已抓取跳過
# 994124已抓取跳過
# 972732已抓取跳過
# 35355已抓取跳過
# 582769已抓取跳過
# 1004278已抓取跳過
# 44761已抓取跳過
# 581595已抓取跳過
# 138027已抓取跳過
# 83993已抓取跳過
# 16804已抓取跳過
# 16725已抓取跳過
# 27656已抓取跳過
# 35786已抓取跳過
# 147627已抓取跳過
# 71362已抓取跳過
# 8749已抓取跳過
# 73881已抓取跳過
# 995352已抓取跳過
# 127477已抓取跳過
# 1032262已抓取跳過
# 33353已抓取跳過
# 43549已抓取跳過
# 582461已抓取跳過
# 626512已抓取跳過
# 118822已抓取跳過
# 49280已抓取跳過
# 70926已抓取跳過
# 41460已抓取跳過
# 149411已抓取跳過
# 56199已抓取跳過
# 101754已抓取跳過
# 44942已抓取跳過
# 651874已抓取跳過
# 581493已抓取跳過
# 6277已抓取跳過
# 7468已抓取跳過
# 94306已抓取跳過
# 95838已抓取跳過
# 1013818已抓取跳過
# 118297已抓取跳過
# 42192已抓取跳過
# 1015196已抓取跳過
# 782276已抓取跳過
# 617720已抓取跳過
# 47162已抓取跳過
# 4543已抓取跳過
# 1176065已抓取跳過
# 624434已抓取跳過
# 40968已抓取跳過
# 47133已抓取跳過
# 619684已抓取跳過
# 81179已抓取跳過
# 596048已抓取跳過
# 20191已抓取跳過
# 22402已抓取跳過
# 1046906已抓取跳過
# 1031302已抓取跳過
# 120467已抓取跳過
# 604724已抓取跳過
# 627284已抓取跳過
# 27754已抓取跳過
# 119635已抓取跳過
# 121983已抓取跳過
# 967204已抓取跳過
# 630326已抓取跳過
# 620974已抓取跳過
# 949014已抓取跳過
# 51302已抓取跳過
# 64284已抓取跳過
# 30933已抓取跳過
# 34080已抓取跳過
# 604098已抓取跳過
# 43355已抓取跳過
# 4010已抓取跳過
# 964638已抓取跳過
# 16546已抓取跳過
# 38100已抓取跳過
# 57220已抓取跳過
# 950754已抓取跳過
# 54127已抓取跳過
# 970256已抓取跳過
# 1064204已抓取跳過
# 30460已抓取跳過
# 993228已抓取跳過
# 50491已抓取跳過
# 1026374已抓取跳過
# 43598已抓取跳過
# 75550已抓取跳過
# 86390已抓取跳過
# 14708已抓取跳過
# 66435已抓取跳過
# 947880已抓取跳過
# 27738已抓取跳過
# 35266已抓取跳過
# 148637已抓取跳過
# 81786已抓取跳過
# 7437已抓取跳過
# 970224已抓取跳過
# 149053已抓取跳過
# 39701已抓取跳過
# 1013648已抓取跳過
# 16747已抓取跳過
# 88650已抓取跳過
# 1009622已抓取跳過
# 28079已抓取跳過
# 984356已抓取跳過
# 939878已抓取跳過
# 110026已抓取跳過
# 84882已抓取跳過
# 58759已抓取跳過
# 118788已抓取跳過
# 83720已抓取跳過
# 568364已抓取跳過
# 73367已抓取跳過
# 72528已抓取跳過
# 119674已抓取跳過
# 11086已抓取跳過
# 583015已抓取跳過
# 57182已抓取跳過
# 6578已抓取跳過
# 44415已抓取跳過
# 611800已抓取跳過
# 985156已抓取跳過
# 9798已抓取跳過
# 106307已抓取跳過
# 103857已抓取跳過
# 134761已抓取跳過
# 71923已抓取跳過
# 47122已抓取跳過
# 45767已抓取跳過
# 926206已抓取跳過
# 1006766已抓取跳過
# 17859已抓取跳過
# 1030860已抓取跳過
# 22588已抓取跳過
# 7573已抓取跳過
# 22567已抓取跳過
# 88024已抓取跳過
# 929716已抓取跳過
# 1065482已抓取跳過
# 94032已抓取跳過
# 72632已抓取跳過
# 8210已抓取跳過
# 1010728已抓取跳過
# 93093已抓取跳過
# 22214已抓取跳過
# 28040已抓取跳過
# 1028288已抓取跳過
# 1019530已抓取跳過
# 137217已抓取跳過
# 26679已抓取跳過
# 992632已抓取跳過
# 14640已抓取跳過
# 45854已抓取跳過
# 115722已抓取跳過
# 982460已抓取跳過
# 87794已抓取跳過
# 60321已抓取跳過
# 56004已抓取跳過
# 568646已抓取跳過
# 119552已抓取跳過
# 157217已抓取跳過
# 154163已抓取跳過
# 89330已抓取跳過
# 936092已抓取跳過
# 589574已抓取跳過
# 42757已抓取跳過
# 40082已抓取跳過
# 144409已抓取跳過
# 598300已抓取跳過
# 143331已抓取跳過
# 79436已抓取跳過
# 615154已抓取跳過
# 78367已抓取跳過
# 32054已抓取跳過
# 41406已抓取跳過
# 602480已抓取跳過
# 145851已抓取跳過
# 1043298已抓取跳過
# 155297已抓取跳過
# 30886已抓取跳過
# 144543已抓取跳過
# 31032已抓取跳過
# 30526已抓取跳過
# 8947已抓取跳過
# 60485已抓取跳過
# 34671已抓取跳過
# 588192已抓取跳過
# 6287已抓取跳過
# 589794已抓取跳過
# 34900已抓取跳過
# 118487已抓取跳過
# 75787已抓取跳過
# 1054678已抓取跳過
# 30147已抓取跳過
# 33709已抓取跳過
# 1046058已抓取跳過
# 604168已抓取跳過
# 1032402已抓取跳過
# 42423已抓取跳過
# 590112已抓取跳過
# 956512已抓取跳過
# 154203已抓取跳過
# 42579已抓取跳過
# 948182已抓取跳過
# 7025已抓取跳過
# 35284已抓取跳過
# 70525已抓取跳過
# 22550已抓取跳過
# 7406已抓取跳過
# 61077已抓取跳過
# 607566已抓取跳過
# 22741已抓取跳過
# 59780已抓取跳過
# 601380已抓取跳過
# 23417已抓取跳過
# 27410已抓取跳過
# 984250已抓取跳過
# 109244已抓取跳過
# 147已抓取跳過
# 113936已抓取跳過
# 27706已抓取跳過
# 8303已抓取跳過
# 23325已抓取跳過
# 45865已抓取跳過
# 592652已抓取跳過
# 57887已抓取跳過
# 22264已抓取跳過
# 7002已抓取跳過
# 32494已抓取跳過
# 93973已抓取跳過
# 580483已抓取跳過
# 49390已抓取跳過
# 78338已抓取跳過
# 30300已抓取跳過
# 634584已抓取跳過
# 606308已抓取跳過
# 29213已抓取跳過
# 62421已抓取跳過
# 53812已抓取跳過
# 66103已抓取跳過
# 751250已抓取跳過
# 595048已抓取跳過
# 968384已抓取跳過
# 6635已抓取跳過
# 109443已抓取跳過
# 592032已抓取跳過
# 95242已抓取跳過
# 31190已抓取跳過
# 37826已抓取跳過
# 40870已抓取跳過
# 619070已抓取跳過
# 85815已抓取跳過
# 16736已抓取跳過
# 987370已抓取跳過
# 39367已抓取跳過
# 44874已抓取跳過
# 53693已抓取跳過
# 85187已抓取跳過
# 89193已抓取跳過
# 59055已抓取跳過
# 773918已抓取跳過
# 32052已抓取跳過
# 35898已抓取跳過
# 86977已抓取跳過
# 46503已抓取跳過
# 32273已抓取跳過
# 920820已抓取跳過
# 71176已抓取跳過
# 72255已抓取跳過
# 35368已抓取跳過
# 32491已抓取跳過
# 137151已抓取跳過
# 27709已抓取跳過
# 627192已抓取跳過
# 622190已抓取跳過
# 27758已抓取跳過
# 1000654已抓取跳過
# 34956已抓取跳過
# 958832已抓取跳過
# 44312已抓取跳過
# 42778已抓取跳過
# 76186已抓取跳過
# 36385已抓取跳過
# 975994已抓取跳過
# 626574已抓取跳過
# 94998已抓取跳過
# 33352已抓取跳過
# 90619已抓取跳過
# 27560已抓取跳過
# 9181已抓取跳過
# 1025128已抓取跳過
# 40801已抓取跳過
# 842220已抓取跳過
# 33324已抓取跳過
# 44378已抓取跳過
# 6220已抓取跳過
# 4685已抓取跳過
# 54180已抓取跳過
# 651312已抓取跳過
# 77401已抓取跳過
# 996168已抓取跳過
# 138837已抓取跳過
# 28064已抓取跳過
# 1058216已抓取跳過
# 28314已抓取跳過
# 602520已抓取跳過
# 595038已抓取跳過
# 43825已抓取跳過
# 87231已抓取跳過
# 954168已抓取跳過
# 22283已抓取跳過
# 885368已抓取跳過
# 149841已抓取跳過
# 27511已抓取跳過
# 94677已抓取跳過
# 31110已抓取跳過
# 104164已抓取跳過
# 48669已抓取跳過
# 33930已抓取跳過
# 592436已抓取跳過
# 580935已抓取跳過
# 63912已抓取跳過
# 598086已抓取跳過
# 985712已抓取跳過
# 75442已抓取跳過
# 108850已抓取跳過
# 614612已抓取跳過
# 635622已抓取跳過
# 152433已抓取跳過
# 85574已抓取跳過
# 134545已抓取跳過
# 1046690已抓取跳過
# 593256已抓取跳過
# 38896已抓取跳過
# 45069已抓取跳過
# 985632已抓取跳過
# 55825已抓取跳過
# 57140已抓取跳過
# 97572已抓取跳過
# 22680已抓取跳過
# 579014已抓取跳過
# 809504已抓取跳過
# 90692已抓取跳過
# 626890已抓取跳過
# 9226已抓取跳過
# 27360已抓取跳過
# 27642已抓取跳過
# 86266已抓取跳過
# 22208已抓取跳過
# 65339已抓取跳過
# 1084403已抓取跳過
# 18536已抓取跳過
# 34605已抓取跳過
# 1144274已抓取跳過
# 4452已抓取跳過
# 30942已抓取跳過
# 970322已抓取跳過
# 627878已抓取跳過
# 121497已抓取跳過
# 49166已抓取跳過
# 102626已抓取跳過
# 590512已抓取跳過
# 69151已抓取跳過
# 45747已抓取跳過
# 37921已抓取跳過
# 1008228已抓取跳過
# 8404已抓取跳過
# 139253已抓取跳過
# 103700已抓取跳過
# 110064已抓取跳過
# 1054418已抓取跳過
# 622168已抓取跳過
# 12796已抓取跳過
# 921008已抓取跳過
# 34725已抓取跳過
# 3927已抓取跳過
# 586461已抓取跳過
# 971646已抓取跳過
# 4186已抓取跳過
# 114204已抓取跳過
# 927386已抓取跳過
# 76875已抓取跳過
# 30982已抓取跳過
# 143415已抓取跳過
# 636800已抓取跳過
# 3989已抓取跳過
# 83991已抓取跳過
# 32252已抓取跳過
# 9060已抓取跳過
# 145157已抓取跳過
# 953866已抓取跳過
# 93551已抓取跳過
# 118044已抓取跳過
# 960634已抓取跳過
# 1030872已抓取跳過
# 94190已抓取跳過
# 972138已抓取跳過
# 27537已抓取跳過
# 114853已抓取跳過
# 42496已抓取跳過
# 151929已抓取跳過
# 27359已抓取跳過
# 946734已抓取跳過
# 138891已抓取跳過
# 148619已抓取跳過
# 22202已抓取跳過
# 981660已抓取跳過
# 144247已抓取跳過
# 629742已抓取跳過
# 922074已抓取跳過
# 35516已抓取跳過
# 69464已抓取跳過
# 27479已抓取跳過
# 634944已抓取跳過
# 625834已抓取跳過
# 28113已抓取跳過
# 151939已抓取跳過
# 16322已抓取跳過
# 39971已抓取跳過
# 76325已抓取跳過
# 70193已抓取跳過
# 44771已抓取跳過
# 3949已抓取跳過
# 8840已抓取跳過
# 44465已抓取跳過
# 31702已抓取跳過
# 939184已抓取跳過
# 617544已抓取跳過
# 85271已抓取跳過
# 44642已抓取跳過
# 819678已抓取跳過
# 109995已抓取跳過
# 31223已抓取跳過
# 1009086已抓取跳過
# 110780已抓取跳過
# 974090已抓取跳過
# 36443已抓取跳過
# 925258已抓取跳過
# 27481已抓取跳過
# 41679已抓取跳過
# 8690已抓取跳過
# 947042已抓取跳過
# 339588已抓取跳過
# 38704已抓取跳過
# 62782已抓取跳過
# 10272已抓取跳過
# 927974已抓取跳過
# 1100240已抓取跳過
# 40058已抓取跳過
# 40934已抓取跳過
# 116687已抓取跳過
# 968598已抓取跳過
# 39097已抓取跳過
# 150979已抓取跳過
# 586890已抓取跳過
# 3893已抓取跳過
# 1030290已抓取跳過
# 150131已抓取跳過
# 119466已抓取跳過
# 599290已抓取跳過
# 42711已抓取跳過
# 15184已抓取跳過
# 89822已抓取跳過
# 590516已抓取跳過
# 93190已抓取跳過
# 150569已抓取跳過
# 997022已抓取跳過
# 29332已抓取跳過
# 611068已抓取跳過
# 18747已抓取跳過
# 991156已抓取跳過
# 30365已抓取跳過
# 32496已抓取跳過
# 15778已抓取跳過
# 1009268已抓取跳過
# 37667已抓取跳過
# 618036已抓取跳過
# 17687已抓取跳過
# 120755已抓取跳過
# 951482已抓取跳過
# 996374已抓取跳過
# 1061576已抓取跳過
# 121825已抓取跳過
# 964006已抓取跳過
# 32083已抓取跳過
# 50677已抓取跳過
# 1061828已抓取跳過
# 79290已抓取跳過
# 51142已抓取跳過
# 475312已抓取跳過
# 82439已抓取跳過
# 989628已抓取跳過
# 81040已抓取跳過
# 51904已抓取跳過
# 47018已抓取跳過
# 965242已抓取跳過
# 552860已抓取跳過
# 22712已抓取跳過
# 979046已抓取跳過
# 109190已抓取跳過
# 615462已抓取跳過
# 128127已抓取跳過
# 606496已抓取跳過
# 44889已抓取跳過
# 33901已抓取跳過
# 22633已抓取跳過
# 31940已抓取跳過
# 949490已抓取跳過
# 936260已抓取跳過
# 969078已抓取跳過
# 88653已抓取跳過
# 4329已抓取跳過
# 629870已抓取跳過
# 30364已抓取跳過
# 65647已抓取跳過
# 27682已抓取跳過
# 595516已抓取跳過
# 38285已抓取跳過
# 1104071已抓取跳過
# 46666已抓取跳過
# 23269已抓取跳過
# 966300已抓取跳過
# 975640已抓取跳過
# 49358已抓取跳過
# 22303已抓取跳過
# 924792已抓取跳過
# 965190已抓取跳過
# 63086已抓取跳過
# 32451已抓取跳過
# 36533已抓取跳過
# 53578已抓取跳過
# 85513已抓取跳過
# 146073已抓取跳過
# 138933已抓取跳過
# 1118051已抓取跳過
# 7261已抓取跳過
# 48755已抓取跳過
# 580829已抓取跳過
# 82293已抓取跳過
# 470404已抓取跳過
# 622048已抓取跳過
# 19699已抓取跳過
# 617568已抓取跳過
# 580163已抓取跳過
# 1022258已抓取跳過
# 37680已抓取跳過
# 10492已抓取跳過
# 958360已抓取跳過
# 44319已抓取跳過
# 946534已抓取跳過
# 8678已抓取跳過
# 22773已抓取跳過
# 997662已抓取跳過
# 88645已抓取跳過
# 586111已抓取跳過
# 53263已抓取跳過
# 920770已抓取跳過
# 958862已抓取跳過
# 627400已抓取跳過
# 16759已抓取跳過
# 123301已抓取跳過
# 25294已抓取跳過
# 88095已抓取跳過
# 1055732已抓取跳過
# 631702已抓取跳過
# 960104已抓取跳過
# 985882已抓取跳過
# 86775已抓取跳過
# 8315已抓取跳過
# 32889已抓取跳過
# 637248已抓取跳過
# 113353已抓取跳過
# 1022456已抓取跳過
# 981454已抓取跳過
# 615228已抓取跳過
# 19475已抓取跳過
# 22462已抓取跳過
# 663184已抓取跳過
# 37852已抓取跳過
# 937730已抓取跳過
# 1014074已抓取跳過
# 44653已抓取跳過
# 134397已抓取跳過
# 1002774已抓取跳過
# 146497已抓取跳過
# 604194已抓取跳過
# 578802已抓取跳過
# 1139699已抓取跳過
# 972998已抓取跳過
# 58222已抓取跳過
# 139585已抓取跳過
# 22724已抓取跳過
# 21234已抓取跳過
# 94816已抓取跳過
# 622432已抓取跳過
# 55802已抓取跳過
# 36565已抓取跳過
# 67152已抓取跳過
# 155813已抓取跳過
# 22401已抓取跳過
# 74547已抓取跳過
# 949422已抓取跳過
# 627006已抓取跳過
# 601130已抓取跳過
# 1183859已抓取跳過
# 596992已抓取跳過
# 14863已抓取跳過
# 60867已抓取跳過
# 151691已抓取跳過
# 31205已抓取跳過
# 6320已抓取跳過
# 624322已抓取跳過
# 109927已抓取跳過
# 29864已抓取跳過
# 82192已抓取跳過
# 41812已抓取跳過
# 115083已抓取跳過
# 77161已抓取跳過
# 80399已抓取跳過
# 1015624已抓取跳過
# 39227已抓取跳過
# 31738已抓取跳過
# 113130已抓取跳過
# 59882已抓取跳過
# 613984已抓取跳過
# 998614已抓取跳過
# 950464已抓取跳過
# 108072已抓取跳過
# 27826已抓取跳過
# 1002984已抓取跳過
# 32012已抓取跳過
# 10794已抓取跳過
# 585883已抓取跳過
# 31168已抓取跳過
# 1070502已抓取跳過
# 925472已抓取跳過
# 70566已抓取跳過
# 1050066已抓取跳過
# 8862已抓取跳過
# 1165892已抓取跳過
# 69622已抓取跳過
# 39873已抓取跳過
# 925556已抓取跳過
# 14698已抓取跳過
# 22651已抓取跳過
# 996984已抓取跳過
# 995912已抓取跳過
# 161141已抓取跳過
# 615454已抓取跳過
# 1050386已抓取跳過
# 928694已抓取跳過
# 65928已抓取跳過
# 965976已抓取跳過
# 1009674已抓取跳過
# 717310已抓取跳過
# 1001820已抓取跳過
# 6513已抓取跳過
# 51921已抓取跳過
# 27380已抓取跳過
# 8279已抓取跳過
# 33033已抓取跳過
# 70746已抓取跳過
# 990720已抓取跳過
# 110589已抓取跳過
# 22390已抓取跳過
# 131271已抓取跳過
# 39237已抓取跳過
# 73678已抓取跳過
# 107929已抓取跳過
# 35465已抓取跳過
# 45303已抓取跳過
# 6545已抓取跳過
# 16792已抓取跳過
# 940526已抓取跳過
# 608778已抓取跳過
# 71527已抓取跳過
# 28273已抓取跳過
# 14755已抓取跳過
# 109698已抓取跳過
# 27648已抓取跳過
# 590076已抓取跳過
# 30455已抓取跳過
# 89528已抓取跳過
# 88412已抓取跳過
# 98031已抓取跳過
# 31796已抓取跳過
# 592396已抓取跳過
# 614452已抓取跳過
# 22411已抓取跳過
# 30116已抓取跳過
# 35084已抓取跳過
# 8133已抓取跳過
# 33891已抓取跳過
# 590042已抓取跳過
# 255079已抓取跳過
# 29350已抓取跳過
# 22810已抓取跳過
# 66243已抓取跳過
# 630250已抓取跳過
# 31193已抓取跳過
# 47391已抓取跳過
# 42418已抓取跳過
# 95556已抓取跳過
# 88377已抓取跳過
# 4213已抓取跳過
# 15615已抓取跳過
# 22671已抓取跳過
# 119257已抓取跳過
# 27659已抓取跳過
# 568344已抓取跳過
# 30073已抓取跳過
# 46598已抓取跳過
# 80935已抓取跳過
# 22571已抓取跳過
# 80497已抓取跳過
# 93259已抓取跳過
# 77563已抓取跳過
# 40754已抓取跳過
# 118已抓取跳過
# 42170已抓取跳過
# 35242已抓取跳過
# 95798已抓取跳過
# 45562已抓取跳過
# 937868已抓取跳過
# 23214已抓取跳過
# 1032652已抓取跳過
# 143655已抓取跳過
# 41911已抓取跳過
# 414472已抓取跳過
# 51778已抓取跳過
# 53218已抓取跳過
# 438322已抓取跳過
# 30865已抓取跳過
# 618318已抓取跳過
# 39936已抓取跳過
# 31477已抓取跳過
# 27565已抓取跳過
# 16638已抓取跳過
# 934246已抓取跳過
# 46779已抓取跳過
# 927064已抓取跳過
# 597760已抓取跳過
# 1026818已抓取跳過
# 105464已抓取跳過
# 28887已抓取跳過
# 68567已抓取跳過
# 22438已抓取跳過
# 42111已抓取跳過
# 1010250已抓取跳過
# 40094已抓取跳過
# 9208已抓取跳過
# 142339已抓取跳過
# 38707已抓取跳過
# 50003已抓取跳過
# 10432已抓取跳過
# 153949已抓取跳過
# 30877已抓取跳過
# 973542已抓取跳過
# 49555已抓取跳過
# 95799已抓取跳過
# 109420已抓取跳過
# 37846已抓取跳過
# 27567已抓取跳過
# 96079已抓取跳過
# 46746已抓取跳過
# 81540已抓取跳過
# 76542已抓取跳過
# 1017628已抓取跳過
# 31396已抓取跳過
# 27637已抓取跳過
# 87285已抓取跳過
# 964678已抓取跳過
# 1042278已抓取跳過
# 1036648已抓取跳過
# 23430已抓取跳過
# 31778已抓取跳過
# 590014已抓取跳過
# 1138883已抓取跳過
# 943996已抓取跳過
# 36793已抓取跳過
# 611194已抓取跳過
# 36224已抓取跳過
# 17195已抓取跳過
# 34381已抓取跳過
# 1046380已抓取跳過
# 92430已抓取跳過
# 109759已抓取跳過
# 1026026已抓取跳過
# 39351已抓取跳過
# 30830已抓取跳過
# 107997已抓取跳過
# 1065472已抓取跳過
# 1020182已抓取跳過
# 992196已抓取跳過
# 34160已抓取跳過
# 630166已抓取跳過
# 9903已抓取跳過
# 113839已抓取跳過
# 983154已抓取跳過
# 152895已抓取跳過
# 1011360已抓取跳過
# 6433已抓取跳過
# 108849已抓取跳過
# 588820已抓取跳過
# 37819已抓取跳過
# 1013958已抓取跳過
# 1036732已抓取跳過
# 100609已抓取跳過
# 1095674已抓取跳過
# 37382已抓取跳過
# 592370已抓取跳過
# 35432已抓取跳過
# 1019532已抓取跳過
# 28329已抓取跳過
# 28660已抓取跳過
# 38253已抓取跳過
# 30839已抓取跳過
# 38654已抓取跳過
# 596754已抓取跳過
# 150049已抓取跳過
# 78133已抓取跳過
# 41276已抓取跳過
# 38420已抓取跳過
# 628538已抓取跳過
# 1030122已抓取跳過
# 1014232已抓取跳過
# 110120已抓取跳過
# 1011578已抓取跳過
# 136651已抓取跳過
# 590376已抓取跳過
# 91877已抓取跳過
# 28291已抓取跳過
# 17360已抓取跳過
# 1028406已抓取跳過
# 97194已抓取跳過
# 636230已抓取跳過
# 52232已抓取跳過
# 70578已抓取跳過
# 978850已抓取跳過
# 31096已抓取跳過
# 30411已抓取跳過
# 55497已抓取跳過
# 1044372已抓取跳過
# 116479已抓取跳過
# 46149已抓取跳過
# 32734已抓取跳過
# 27746已抓取跳過
# 908954已抓取跳過
# 825726已抓取跳過
# 985880已抓取跳過
# 979534已抓取跳過
# 31472已抓取跳過
# 636120已抓取跳過
# 31492已抓取跳過
# 10089已抓取跳過
# 977614已抓取跳過
# 470936已抓取跳過
# 81675已抓取跳過
# 8945已抓取跳過
# 94724已抓取跳過
# 989858已抓取跳過
# 925792已抓取跳過
# 28895已抓取跳過
# 925264已抓取跳過
# 142559已抓取跳過
# 155601已抓取跳過
# 14949已抓取跳過
# 37661已抓取跳過
# 124677已抓取跳過
# 601844已抓取跳過
# 799772已抓取跳過
# 31087已抓取跳過
# 979926已抓取跳過
# 936532已抓取跳過
# 34624已抓取跳過
# 104919已抓取跳過
# 597812已抓取跳過
# 52461已抓取跳過
# 36078已抓取跳過
# 122277已抓取跳過
# 6461已抓取跳過
# 66760已抓取跳過
# 30818已抓取跳過
# 31500已抓取跳過
# 93758已抓取跳過
# 118069已抓取跳過
# 105873已抓取跳過
# 22247已抓取跳過
# 636218已抓取跳過
# 42867已抓取跳過
# 1066964已抓取跳過
# 931344已抓取跳過
# 22617已抓取跳過
# 938478已抓取跳過
# 28928已抓取跳過
# 945136已抓取跳過
# 142397已抓取跳過
# 24839已抓取跳過
# 596460已抓取跳過
# 996776已抓取跳過
# 987810已抓取跳過
# 1033638已抓取跳過
# 998628已抓取跳過
# 35689已抓取跳過
# 990408已抓取跳過
# 880246已抓取跳過
# 616740已抓取跳過
# 6889已抓取跳過
# 45308已抓取跳過
# 600980已抓取跳過
# 22746已抓取跳過
# 44148已抓取跳過
# 1058968已抓取跳過
# 956158已抓取跳過
# 68016已抓取跳過
# 36796已抓取跳過
# 31524已抓取跳過
# 120907已抓取跳過
# 30419已抓取跳過
# 76444已抓取跳過
# 28035已抓取跳過
# 961570已抓取跳過
# 118653已抓取跳過
# 52988已抓取跳過
# 33220已抓取跳過
# 42852已抓取跳過
# 31481已抓取跳過
# 966368已抓取跳過
# 27697已抓取跳過
# 43646已抓取跳過
# 95022已抓取跳過
# 32493已抓取跳過
# 55675已抓取跳過
# 36339已抓取跳過
# 99946已抓取跳過
# 1014470已抓取跳過
# 966920已抓取跳過
# 32289已抓取跳過
# 67521已抓取跳過
# 594482已抓取跳過
# 28087已抓取跳過
# 77302已抓取跳過
# 45185已抓取跳過
# 16614已抓取跳過
# 27645已抓取跳過
# 945512已抓取跳過
# 44120已抓取跳過
# 41699已抓取跳過
# 94414已抓取跳過
# 113859已抓取跳過
# 1037880已抓取跳過
# 585983已抓取跳過
# 969088已抓取跳過
# 594302已抓取跳過
# 626724已抓取跳過
# 7623已抓取跳過
# 940386已抓取跳過
# 20264已抓取跳過
# 987312已抓取跳過
# 30479已抓取跳過
# 38494已抓取跳過
# 1031202已抓取跳過
# 31485已抓取跳過
# 35604已抓取跳過
# 15486已抓取跳過
# 38852已抓取跳過
# 28579已抓取跳過
# 968186已抓取跳過
# 84240已抓取跳過
# 47866已抓取跳過
# 960854已抓取跳過
# 152869已抓取跳過
# 15178已抓取跳過
# 76406已抓取跳過
# 27334已抓取跳過
# 35464已抓取跳過
# 138103已抓取跳過
# 592486已抓取跳過
# 133841已抓取跳過
# 106246已抓取跳過
# 21260已抓取跳過
# 967876已抓取跳過
# 1042746已抓取跳過
# 157203已抓取跳過
# 124853已抓取跳過
# 886964已抓取跳過
# 22327已抓取跳過
# 119513已抓取跳過
# 52084已抓取跳過
# 588508已抓取跳過
# 98229已抓取跳過
# 975058已抓取跳過
# 12739已抓取跳過
# 1018078已抓取跳過
# 41082已抓取跳過
# 39422已抓取跳過
# 22351已抓取跳過
# 90821已抓取跳過
# 920480已抓取跳過
# 26825已抓取跳過
# 996592已抓取跳過
# 966592已抓取跳過
# 6321已抓取跳過
# 45774已抓取跳過
# 44787已抓取跳過
# 1054420已抓取跳過
# 48653已抓取跳過
# 36250已抓取跳過
# 27755已抓取跳過
# 51075已抓取跳過
# 30408已抓取跳過
# 35353已抓取跳過
# 935662已抓取跳過
# 35308已抓取跳過
# 989838已抓取跳過
# 28863已抓取跳過
# 40854已抓取跳過
# 1018482已抓取跳過
# 72011已抓取跳過
# 958174已抓取跳過
# 85661已抓取跳過
# 38366已抓取跳過
# 972686已抓取跳過
# 619296已抓取跳過
# 29645已抓取跳過
# 967788已抓取跳過
# 931746已抓取跳過
# 17021已抓取跳過
# 582945已抓取跳過
# 33719已抓取跳過
# 602956已抓取跳過
# 49391已抓取跳過
# 951806已抓取跳過
# 1042226已抓取跳過
# 637322已抓取跳過
# 70154已抓取跳過
# 119512已抓取跳過
# 21359已抓取跳過
# 600222已抓取跳過
# 986544已抓取跳過
# 45336已抓取跳過
# 927682已抓取跳過
# 154107已抓取跳過
# 30806已抓取跳過
# 37233已抓取跳過
# 4499已抓取跳過
# 36794已抓取跳過
# 72239已抓取跳過
# 154255已抓取跳過
# 46192已抓取跳過
# 963938已抓取跳過
# 849518已抓取跳過
# 36720已抓取跳過
# 753364已抓取跳過
# 115624已抓取跳過
# 35533已抓取跳過
# 1057318已抓取跳過
# 1013032已抓取跳過
# 17595已抓取跳過
# 105134已抓取跳過
# 35279已抓取跳過
# 627454已抓取跳過
# 114491已抓取跳過
# 624114已抓取跳過
# 609932已抓取跳過
# 122817已抓取跳過
# 884100已抓取跳過
# 28931已抓取跳過
# 978106已抓取跳過
# 1022568已抓取跳過
# 618694已抓取跳過
# 51270已抓取跳過
# 619866已抓取跳過
# 38430已抓取跳過
# 36645已抓取跳過
# 954500已抓取跳過
# 6600已抓取跳過
# 936550已抓取跳過
# 42070已抓取跳過
# 6281已抓取跳過
# 614652已抓取跳過
# 52426已抓取跳過
# 618312已抓取跳過
# 22782已抓取跳過
# 55210已抓取跳過
# 629510已抓取跳過
# 61188已抓取跳過
# 926384已抓取跳過
# 34802已抓取跳過
# 990666已抓取跳過
# 926690已抓取跳過
# 6487已抓取跳過
# 10666已抓取跳過
# 972680已抓取跳過
# 14924已抓取跳過
# 62758已抓取跳過
# 90086已抓取跳過
# 33914已抓取跳過
# 120703已抓取跳過
# 41348已抓取跳過
# 1072590已抓取跳過
# 61009已抓取跳過
# 30146已抓取跳過
# 22668已抓取跳過
# 38231已抓取跳過
# 1027220已抓取跳過
# 1009008已抓取跳過
# 626156已抓取跳過
# 122313已抓取跳過
# 592372已抓取跳過
# 37519已抓取跳過
# 50803已抓取跳過
# 1022210已抓取跳過
# 586179已抓取跳過
# 1021896已抓取跳過
# 32310已抓取跳過
# 1033602已抓取跳過
# 77408已抓取跳過
# 1034706已抓取跳過
# 73645已抓取跳過
# 946810已抓取跳過
# 33327已抓取跳過
# 40853已抓取跳過
# 993748已抓取跳過
# 8284已抓取跳過
# 31733已抓取跳過
# 972038已抓取跳過
# 125017已抓取跳過
# 43757已抓取跳過
# 12908已抓取跳過
# 31750已抓取跳過
# 44540已抓取跳過
# 42796已抓取跳過
# 34195已抓取跳過
# 1023968已抓取跳過
# 96387已抓取跳過
# 39855已抓取跳過
# 68388已抓取跳過
# 46560已抓取跳過
# 157377已抓取跳過
# 27874已抓取跳過
# 988474已抓取跳過
# 22730已抓取跳過
# 1051492已抓取跳過
# 33313已抓取跳過
# 147223已抓取跳過
# 48074已抓取跳過
# 97080已抓取跳過
# 38894已抓取跳過
# 923844已抓取跳過
# 46169已抓取跳過
# 35697已抓取跳過
# 151395已抓取跳過
# 152579已抓取跳過
# 1069758已抓取跳過
# 968550已抓取跳過
# 149231已抓取跳過
# 38655已抓取跳過
# 47905已抓取跳過
# 81431已抓取跳過
# 73969已抓取跳過
# 615946已抓取跳過
# 30622已抓取跳過
# 601960已抓取跳過
# 116107已抓取跳過
# 597198已抓取跳過
# 47397已抓取跳過
# 40984已抓取跳過
# 28506已抓取跳過
# 598834已抓取跳過
# 631240已抓取跳過
# 964564已抓取跳過
# 94302已抓取跳過
# 56202已抓取跳過
# 74855已抓取跳過
# 1012266已抓取跳過
# 969586已抓取跳過
# 4566已抓取跳過
# 29946已抓取跳過
# 31130已抓取跳過
# 627618已抓取跳過
# 4431已抓取跳過
# 37965已抓取跳過
# 959550已抓取跳過
# 38225已抓取跳過
# 42234已抓取跳過
# 593352已抓取跳過
# 1051188已抓取跳過
# 94336已抓取跳過
# 1013638已抓取跳過
# 787658已抓取跳過
# 634068已抓取跳過
# 1030936已抓取跳過
# 56618已抓取跳過
# 39135已抓取跳過
# 604000已抓取跳過
# 110904已抓取跳過
# 631154已抓取跳過
# 38834已抓取跳過
# 28228已抓取跳過
# 78945已抓取跳過
# 938794已抓取跳過
# 90289已抓取跳過
# 22539已抓取跳過
# 39606已抓取跳過
# 133713已抓取跳過
# 107068已抓取跳過
# 1042144已抓取跳過
# 91295已抓取跳過
# 1045752已抓取跳過
# 595788已抓取跳過
# 41224已抓取跳過
# 27470已抓取跳過
# 42112已抓取跳過
# 601178已抓取跳過
# 595512已抓取跳過
# 27368已抓取跳過
# 48285已抓取跳過
# 965342已抓取跳過
# 977060已抓取跳過
# 63721已抓取跳過
# 31086已抓取跳過
# 745754已抓取跳過
# 129811已抓取跳過
# 1017400已抓取跳過
# 21346已抓取跳過
# 1002434已抓取跳過
# 51717已抓取跳過
# 1002264已抓取跳過
# 22750已抓取跳過
# 595666已抓取跳過
# 31713已抓取跳過
# 949370已抓取跳過
# 602770已抓取跳過
# 962932已抓取跳過
# 50320已抓取跳過
# 34340已抓取跳過
# 946748已抓取跳過
# 32028已抓取跳過
# 582603已抓取跳過
# 154405已抓取跳過
# 29957已抓取跳過
# 30544已抓取跳過
# 47335已抓取跳過
# 1026558已抓取跳過
# 954278已抓取跳過
# 93676已抓取跳過
# 38730已抓取跳過
# 920592已抓取跳過
# 618000已抓取跳過
# 577660已抓取跳過
# 1014078已抓取跳過
# 626166已抓取跳過
# 25257已抓取跳過
# 928848已抓取跳過
# 58637已抓取跳過
# 117221已抓取跳過
# 37014已抓取跳過
# 593994已抓取跳過
# 116301已抓取跳過
# 65974已抓取跳過
# 995844已抓取跳過
# 73465已抓取跳過
# 27664已抓取跳過
# 157339已抓取跳過
# 1009106已抓取跳過
# 27420已抓取跳過
# 8890已抓取跳過
# 66683已抓取跳過
# 1025588已抓取跳過
# 41856已抓取跳過
# 9805已抓取跳過
# 101241已抓取跳過
# 1200026已抓取跳過
# 40487已抓取跳過
# 946154已抓取跳過
# 7074已抓取跳過
# 22203已抓取跳過
# 994478已抓取跳過
# 40345已抓取跳過
# 58541已抓取跳過
# 89703已抓取跳過
# 38424已抓取跳過
# 1069226已抓取跳過
# 38191已抓取跳過
# 23295已抓取跳過
# 105077已抓取跳過
# 937394已抓取跳過
# 582343已抓取跳過
# 950770已抓取跳過
# 64737已抓取跳過
# 3800已抓取跳過
# 2919已抓取跳過
# 637610已抓取跳過
# 97783已抓取跳過
# 1074904已抓取跳過
# 28057已抓取跳過
# 929882已抓取跳過
# 60044已抓取跳過
# 15485已抓取跳過
# 28959已抓取跳過
# 976526已抓取跳過
# 27582已抓取跳過
# 23352已抓取跳過
# 42100已抓取跳過
# 12990已抓取跳過
# 41142已抓取跳過
# 591856已抓取跳過
# 622376已抓取跳過
# 48844已抓取跳過
# 39870已抓取跳過
# 28088已抓取跳過
# 87008已抓取跳過
# 234439已抓取跳過
# 23060已抓取跳過
# 824072已抓取跳過
# 32938已抓取跳過
# 607622已抓取跳過
# 22288已抓取跳過
# 623212已抓取跳過
# 128087已抓取跳過
# 598932已抓取跳過
# 92657已抓取跳過
# 601240已抓取跳過
# 588442已抓取跳過
# 7234已抓取跳過
# 117735已抓取跳過
# 14696已抓取跳過
# 46735已抓取跳過
# 1041796已抓取跳過
# 927762已抓取跳過
# 41257已抓取跳過
# 52323已抓取跳過
# 31774已抓取跳過
# 1014154已抓取跳過
# 27522已抓取跳過
# 608136已抓取跳過
# 57925已抓取跳過
# 510948已抓取跳過
# 50492已抓取跳過
# 30888已抓取跳過
# 588502已抓取跳過
# 1009504已抓取跳過
# 608816已抓取跳過
# 985370已抓取跳過
# 999620已抓取跳過
# 35991已抓取跳過
# 75597已抓取跳過
# 102551已抓取跳過
# 625594已抓取跳過
# 623204已抓取跳過
# 60715已抓取跳過
# 108189已抓取跳過
# 41797已抓取跳過
# 39684已抓取跳過
# 1009608已抓取跳過
# 27529已抓取跳過
# 1078298已抓取跳過
# 40675已抓取跳過
# 28116已抓取跳過
# 588618已抓取跳過
# 138001已抓取跳過
# 30329已抓取跳過
# 22164已抓取跳過
# 21256已抓取跳過
# 43322已抓取跳過
# 585789已抓取跳過
# 32941已抓取跳過
# 48990已抓取跳過
# 60098已抓取跳過
# 77706已抓取跳過
# 43301已抓取跳過
# 60328已抓取跳過
# 119643已抓取跳過
# 632642已抓取跳過
# 118414已抓取跳過
# 629982已抓取跳過
# 31174已抓取跳過
# 969946已抓取跳過
# 937902已抓取跳過
# 595704已抓取跳過
# 44482已抓取跳過
# 590028已抓取跳過
# 581161已抓取跳過
# 49213已抓取跳過
# 6596已抓取跳過
# 38377已抓取跳過
# 153087已抓取跳過
# 20261已抓取跳過
# 8640已抓取跳過
# 8904已抓取跳過
# 37875已抓取跳過
# 153795已抓取跳過
# 36463已抓取跳過
# 8969已抓取跳過
# 8366已抓取跳過
# 45445已抓取跳過
# 1022934已抓取跳過
# 120317已抓取跳過
# 50221已抓取跳過
# 23268已抓取跳過
# 44927已抓取跳過
# 6152已抓取跳過
# 227679已抓取跳過
# 31659已抓取跳過
# 618422已抓取跳過
# 615210已抓取跳過
# 926968已抓取跳過
# 27551已抓取跳過
# 38137已抓取跳過
# 85961已抓取跳過
# 34874已抓取跳過
# 9018已抓取跳過
# 95582已抓取跳過
# 1022168已抓取跳過
# 36982已抓取跳過
# 1012422已抓取跳過
# 140449已抓取跳過
# 628600已抓取跳過
# 27345已抓取跳過
# 36459已抓取跳過
# 599358已抓取跳過
# 1093862已抓取跳過
# 947666已抓取跳過
# 927832已抓取跳過
# 23287已抓取跳過
# 57419已抓取跳過
# 94028已抓取跳過
# 1025958已抓取跳過
# 45250已抓取跳過
# 959530已抓取跳過
# 36717已抓取跳過
# 104051已抓取跳過
# 12709已抓取跳過
# 1127090已抓取跳過
# 950640已抓取跳過
# 1043716已抓取跳過
# 22534已抓取跳過
# 594658已抓取跳過
# 129083已抓取跳過
# 586255已抓取跳過
# 965500已抓取跳過
# 580317已抓取跳過
# 142139已抓取跳過
# 16662已抓取跳過
# 13387已抓取跳過
# 51821已抓取跳過
# 9846已抓取跳過
# 72380已抓取跳過
# 941836已抓取跳過
# 965450已抓取跳過
# 1035822已抓取跳過
# 148427已抓取跳過
# 92859已抓取跳過
# 89052已抓取跳過
# 25047已抓取跳過
# 1046928已抓取跳過
# 1009140已抓取跳過
# 73704已抓取跳過
# 974064已抓取跳過
# 96306已抓取跳過
# 578912已抓取跳過
# 147015已抓取跳過
# 633064已抓取跳過
# 36445已抓取跳過
# 1040188已抓取跳過
# 121867已抓取跳過
# 1020138已抓取跳過
# 745714已抓取跳過
# 1009640已抓取跳過
# 1005750已抓取跳過
# 958020已抓取跳過
# 589054已抓取跳過
# 611538已抓取跳過
# 82639已抓取跳過
# 8828已抓取跳過
# 42525已抓取跳過
# 81400已抓取跳過
# 63329已抓取跳過
# 44453已抓取跳過
# 582405已抓取跳過
# 1012336已抓取跳過
# 625812已抓取跳過
# 149已抓取跳過
# 32920已抓取跳過
# 998218已抓取跳過
# 34933已抓取跳過
# 139019已抓取跳過
# 106734已抓取跳過
# 86326已抓取跳過
# 589416已抓取跳過
# 622520已抓取跳過
# 20179已抓取跳過
# 1017982已抓取跳過
# 1009868已抓取跳過
# 28933已抓取跳過
# 941102已抓取跳過
# 135691已抓取跳過
# 42790已抓取跳過
# 81080已抓取跳過
# 56709已抓取跳過
# 23557已抓取跳過
# 29855已抓取跳過
# 1036772已抓取跳過
# 1031420已抓取跳過
# 43659已抓取跳過
# 43972已抓取跳過
# 636220已抓取跳過
# 80206已抓取跳過
# 23372已抓取跳過
# 101429已抓取跳過
# 956424已抓取跳過
# 583587已抓取跳過
# 1010598已抓取跳過
# 636446已抓取跳過
# 30782已抓取跳過
# 827482已抓取跳過
# 1013074已抓取跳過
# 35490已抓取跳過
# 1202804已抓取跳過
# 464570已抓取跳過
# 50152已抓取跳過
# 948388已抓取跳過
# 608138已抓取跳過
# 579494已抓取跳過
# 6576已抓取跳過
# 945256已抓取跳過
# 9293已抓取跳過
# 920472已抓取跳過
# 1009628已抓取跳過
# 593680已抓取跳過
# 995070已抓取跳過
# 4055已抓取跳過
# 1027652已抓取跳過
# 1028506已抓取跳過
# 46538已抓取跳過
# 108601已抓取跳過
# 68095已抓取跳過
# 963956已抓取跳過
# 41315已抓取跳過
# 34914已抓取跳過
# 599654已抓取跳過
# 1004372已抓取跳過
# 28840已抓取跳過
# 38066已抓取跳過
# 1016138已抓取跳過
# 36364已抓取跳過
# 36622已抓取跳過
# 17037已抓取跳過
# 154457已抓取跳過
# 597976已抓取跳過
# 11198已抓取跳過
# 947676已抓取跳過
# 153093已抓取跳過
# 110030已抓取跳過
# 1011334已抓取跳過
# 93156已抓取跳過
# 934468已抓取跳過
# 703602已抓取跳過
# 2903已抓取跳過
# 61507已抓取跳過
# 813454已抓取跳過
# 23323已抓取跳過
# 8018已抓取跳過
# 633790已抓取跳過
# 55719已抓取跳過
# 137947已抓取跳過
# 44323已抓取跳過
# 40205已抓取跳過
# 85786已抓取跳過
# 635076已抓取跳過
# 621798已抓取跳過
# 264597已抓取跳過
# 27473已抓取跳過
# 997472已抓取跳過
# 83426已抓取跳過
# 78596已抓取跳過
# 42362已抓取跳過
# 960932已抓取跳過
# 70319已抓取跳過
# 71470已抓取跳過
# 933172已抓取跳過
# 39966已抓取跳過
# 13954已抓取跳過
# 154487已抓取跳過
# 976324已抓取跳過
# 47425已抓取跳過
# 1018588已抓取跳過
# 30238已抓取跳過
# 32767已抓取跳過
# 48553已抓取跳過
# 1111520已抓取跳過
# 29023已抓取跳過
# 1232714已抓取跳過
# 59924已抓取跳過
# 1032100已抓取跳過
# 90598已抓取跳過
# 67841已抓取跳過
# 986974已抓取跳過
# 46613已抓取跳過
# 993282已抓取跳過
# 979480已抓取跳過
# 595344已抓取跳過
# 1011168已抓取跳過
# 46201已抓取跳過
# 791162已抓取跳過
# 70338已抓取跳過
# 32234已抓取跳過
# 110246已抓取跳過
# 52329已抓取跳過
# 959116已抓取跳過
# 37835已抓取跳過
# 91120已抓取跳過
# 600544已抓取跳過
# 632140已抓取跳過
# 16831已抓取跳過
# 39451已抓取跳過
# 593212已抓取跳過
# 1064570已抓取跳過
# 1027944已抓取跳過
# 1064698已抓取跳過
# 74454已抓取跳過
# 117889已抓取跳過
# 48961已抓取跳過
# 1129316已抓取跳過
# 124069已抓取跳過
# 22837已抓取跳過
# 65063已抓取跳過
# 113798已抓取跳過
# 1011074已抓取跳過
# 54554已抓取跳過
# 144337已抓取跳過
# 33335已抓取跳過
# 86099已抓取跳過
# 771678已抓取跳過
# 991728已抓取跳過
# 623566已抓取跳過
# 8710已抓取跳過
# 28470已抓取跳過
# 1020014已抓取跳過
# 1033410已抓取跳過
# 1018644已抓取跳過
# 1017876已抓取跳過
# 608812已抓取跳過
# 148089已抓取跳過
# 8168已抓取跳過
# 15569已抓取跳過
# 1051366已抓取跳過
# 925530已抓取跳過
# 20041已抓取跳過
# 94614已抓取跳過
# 1009702已抓取跳過
# 942056已抓取跳過
# 30504已抓取跳過
# 934146已抓取跳過
# 32203已抓取跳過
# 1111121已抓取跳過
# 943680已抓取跳過
# 961038已抓取跳過
# 631564已抓取跳過
# 28706已抓取跳過
# 51052已抓取跳過
# 989898已抓取跳過
# 114792已抓取跳過
# 30405已抓取跳過
# 1036968已抓取跳過
# 119060已抓取跳過
# 34878已抓取跳過
# 37049已抓取跳過
# 148371已抓取跳過
# 49519已抓取跳過
# 110937已抓取跳過
# 116977已抓取跳過
# 641140已抓取跳過
# 953572已抓取跳過
# 1042506已抓取跳過
# 1008446已抓取跳過
# 966306已抓取跳過
# 73081已抓取跳過
# 978872已抓取跳過
# 36884已抓取跳過
# 1005728已抓取跳過
# 52468已抓取跳過
# 58923已抓取跳過
# 13375已抓取跳過
# 932182已抓取跳過
# 599490已抓取跳過
# 11654已抓取跳過
# 51103已抓取跳過
# 29127已抓取跳過
# 118650已抓取跳過
# 72489已抓取跳過
# 926824已抓取跳過
# 38437已抓取跳過
# 989286已抓取跳過
# 40760已抓取跳過
# 1192已抓取跳過
# 1035062已抓取跳過
# 93653已抓取跳過
# 124625已抓取跳過
# 67851已抓取跳過
# 995706已抓取跳過
# 27807已抓取跳過
# 7598已抓取跳過
# 596544已抓取跳過
# 79112已抓取跳過
# 1025392已抓取跳過
# 970034已抓取跳過
# 25204已抓取跳過
# 607138已抓取跳過
# 920890已抓取跳過
# 50941已抓取跳過
# 1080080已抓取跳過
# 822072已抓取跳過
# 1013906已抓取跳過
# 16695已抓取跳過
# 1029044已抓取跳過
# 91459已抓取跳過
# 804664已抓取跳過
# 33892已抓取跳過
# 607922已抓取跳過
# 1141490已抓取跳過
# 39222已抓取跳過
# 97708已抓取跳過
# 30983已抓取跳過
# 95448已抓取跳過
# 40311已抓取跳過
# 1019970已抓取跳過
# 610790已抓取跳過
# 40476已抓取跳過
# 34629已抓取跳過
# 19048已抓取跳過
# 46998已抓取跳過
# 47307已抓取跳過
# 94913已抓取跳過
# 619388已抓取跳過
# 107646已抓取跳過
# 1029178已抓取跳過
# 69155已抓取跳過
# 602844已抓取跳過
# 40669已抓取跳過
# 717768已抓取跳過
# 72369已抓取跳過
# 42088已抓取跳過
# 696676已抓取跳過
# 72362已抓取跳過
# 605232已抓取跳過
# 51627已抓取跳過
# 578610已抓取跳過
# 16550已抓取跳過
# 92330已抓取跳過
# 117537已抓取跳過
# 625930已抓取跳過
# 580913已抓取跳過
# 1023008已抓取跳過
# 1030712已抓取跳過
# 32610已抓取跳過
# 127457已抓取跳過
# 605156已抓取跳過
# 24627已抓取跳過
# 939576已抓取跳過
# 31191已抓取跳過
# 51878已抓取跳過
# 605876已抓取跳過
# 625534已抓取跳過
# 932544已抓取跳過
# 7407已抓取跳過
# 48959已抓取跳過
# 1039090已抓取跳過
# 33955已抓取跳過
# 987984已抓取跳過
# 42176已抓取跳過
# 1016202已抓取跳過
# 1067064已抓取跳過
# 93319已抓取跳過
# 1013110已抓取跳過
# 49761已抓取跳過
# 970810已抓取跳過
# 34154已抓取跳過
# 69096已抓取跳過
# 34128已抓取跳過
# 37271已抓取跳過
# 118963已抓取跳過
# 1005032已抓取跳過
# 23465已抓取跳過
# 22181已抓取跳過
# 1021052已抓取跳過
# 105028已抓取跳過
# 57005已抓取跳過
# 37926已抓取跳過
# 81414已抓取跳過
# 142715已抓取跳過
# 94793已抓取跳過
# 8308已抓取跳過
# 36787已抓取跳過
# 997060已抓取跳過
# 101676已抓取跳過
# 636784已抓取跳過
# 636060已抓取跳過
# 122345已抓取跳過
# 591684已抓取跳過
# 88568已抓取跳過
# 128787已抓取跳過
# 97664已抓取跳過
# 31002已抓取跳過
# 42450已抓取跳過
# 40481已抓取跳過
# 61745已抓取跳過
# 537738已抓取跳過
# 965218已抓取跳過
# 9027已抓取跳過
# 3792已抓取跳過
# 51453已抓取跳過
# 1045670已抓取跳過
# 42398已抓取跳過
# 53682已抓取跳過
# 59981已抓取跳過
# 1008716已抓取跳過
# 3924已抓取跳過
# 590688已抓取跳過
# 623144已抓取跳過
# 46775已抓取跳過
# 992888已抓取跳過
# 948450已抓取跳過
# 979440已抓取跳過
# 149463已抓取跳過
# 619130已抓取跳過
# 922240已抓取跳過
# 123343已抓取跳過
# 597634已抓取跳過
# 9002已抓取跳過
# 9532已抓取跳過
# 34394已抓取跳過
# 31865已抓取跳過
# 141153已抓取跳過
# 2767已抓取跳過
# 18395已抓取跳過
# 1043892已抓取跳過
# 38603已抓取跳過
# 967930已抓取跳過
# 1015106已抓取跳過
# 40365已抓取跳過
# 1046502已抓取跳過
# 27815已抓取跳過
# 34406已抓取跳過
# 9621已抓取跳過
# 1018976已抓取跳過
# 935954已抓取跳過
# 128915已抓取跳過
# 3808已抓取跳過
# 41301已抓取跳過
# 152013已抓取跳過
# 587802已抓取跳過
# 581099已抓取跳過
# 31495已抓取跳過
# 952644已抓取跳過
# 30546已抓取跳過
# 1000170已抓取跳過
# 1127930已抓取跳過
# 42983已抓取跳過
# 36714已抓取跳過
# 42854已抓取跳過
# 6575已抓取跳過
# 35360已抓取跳過
# 63916已抓取跳過
# 932238已抓取跳過
# 949480已抓取跳過
# 951810已抓取跳過
# 1023746已抓取跳過
# 1052240已抓取跳過
# 1024342已抓取跳過
# 926148已抓取跳過
# 996638已抓取跳過
# 92983已抓取跳過
# 36046已抓取跳過
# 164已抓取跳過
# 614670已抓取跳過
# 592346已抓取跳過
# 1043580已抓取跳過
# 962420已抓取跳過
# 31148已抓取跳過
# 72535已抓取跳過
# 49905已抓取跳過
# 68411已抓取跳過
# 618568已抓取跳過
# 998236已抓取跳過
# 901444已抓取跳過
# 980536已抓取跳過
# 1068326已抓取跳過
# 35864已抓取跳過
# 50607已抓取跳過
# 813808已抓取跳過
# 626808已抓取跳過
# 34628已抓取跳過
# 30062已抓取跳過
# 48624已抓取跳過
# 31181已抓取跳過
# 647090已抓取跳過
# 86789已抓取跳過
# 23141已抓取跳過
# 75779已抓取跳過
# 56931已抓取跳過
# 1041808已抓取跳過
# 950648已抓取跳過
# 1141352已抓取跳過
# 10873已抓取跳過
# 4315已抓取跳過
# 93943已抓取跳過
# 106913已抓取跳過
# 1011376已抓取跳過
# 10073已抓取跳過
# 1053842已抓取跳過
# 41574已抓取跳過
# 1036456已抓取跳過
# 30050已抓取跳過
# 1119206已抓取跳過
# 1038702已抓取跳過
# 47137已抓取跳過
# 772966已抓取跳過
# 1070130已抓取跳過
# 140561已抓取跳過
# 56143已抓取跳過
# 154893已抓取跳過
# 107447已抓取跳過
# 37383已抓取跳過
# 50791已抓取跳過
# 114788已抓取跳過
# 1054548已抓取跳過
# 958844已抓取跳過
# 105648已抓取跳過
# 966492已抓取跳過
# 78037已抓取跳過
# 113099已抓取跳過
# 27841已抓取跳過
# 665512已抓取跳過
# 1067564已抓取跳過
# 27745已抓取跳過
# 42781已抓取跳過
# 128355已抓取跳過
# 115329已抓取跳過
# 22291已抓取跳過
# 43766已抓取跳過
# 103311已抓取跳過
# 930990已抓取跳過
# 956216已抓取跳過
# 623644已抓取跳過
# 23203已抓取跳過
# 973396已抓取跳過
# 607264已抓取跳過
# 146849已抓取跳過
# 44934已抓取跳過
# 131601已抓取跳過
# 581119已抓取跳過
# 31026已抓取跳過
# 120123已抓取跳過
# 35765已抓取跳過
# 86349已抓取跳過
# 1043228已抓取跳過
# 30344已抓取跳過
# 49320已抓取跳過
# 31934已抓取跳過
# 44242已抓取跳過
# 1050422已抓取跳過
# 37435已抓取跳過
# 7075已抓取跳過
# 70330已抓取跳過
# 1127810已抓取跳過
# 14982已抓取跳過
# 27219已抓取跳過
# 627202已抓取跳過
# 124865已抓取跳過
# 52668已抓取跳過
# 150185已抓取跳過
# 49728已抓取跳過
# 105874已抓取跳過
# 95786已抓取跳過
# 22553已抓取跳過
# 7071已抓取跳過
# 1144589已抓取跳過
# 44582已抓取跳過
# 89639已抓取跳過
# 72725已抓取跳過
# 45143已抓取跳過
# 118188已抓取跳過
# 35160已抓取跳過
# 629222已抓取跳過
# 935832已抓取跳過
# 1029268已抓取跳過
# 941186已抓取跳過
# 27367已抓取跳過
# 981402已抓取跳過
# 96607已抓取跳過
# 39057已抓取跳過
# 38920已抓取跳過
# 7080已抓取跳過
# 1027920已抓取跳過
# 1230032已抓取跳過
# 144289已抓取跳過
# 83576已抓取跳過
# 92897已抓取跳過
# 22180已抓取跳過
# 51784已抓取跳過
# 15503已抓取跳過
# 37962已抓取跳過
# 971078已抓取跳過
# 996848已抓取跳過
# 1045352已抓取跳過
# 34457已抓取跳過
# 10939已抓取跳過
# 22554已抓取跳過
# 18299已抓取跳過
# 42952已抓取跳過
# 33386已抓取跳過
# 22153已抓取跳過
# 48710已抓取跳過
# 618058已抓取跳過
# 131193已抓取跳過
# 630182已抓取跳過
# 22653已抓取跳過
# 72512已抓取跳過
# 29428已抓取跳過
# 35511已抓取跳過
# 9125已抓取跳過
# 6569已抓取跳過
# 939338已抓取跳過
# 78242已抓取跳過
# 27881已抓取跳過
# 68954已抓取跳過
# 36937已抓取跳過
# 119851已抓取跳過
# 7955已抓取跳過
# 981368已抓取跳過
# 948464已抓取跳過
# 81083已抓取跳過
# 608794已抓取跳過
# 1054114已抓取跳過
# 190037已抓取跳過
# 53006已抓取跳過
# 937772已抓取跳過
# 47965已抓取跳過
# 1141658已抓取跳過
# 980762已抓取跳過
# 146797已抓取跳過
# 1052808已抓取跳過
# 64100已抓取跳過
# 52254已抓取跳過
# 932136已抓取跳過
# 119243已抓取跳過
# 8903已抓取跳過
# 1028014已抓取跳過
# 992788已抓取跳過
# 104297已抓取跳過
# 996968已抓取跳過
# 152285已抓取跳過
# 989948已抓取跳過
# 2363已抓取跳過
# 149669已抓取跳過
# 144925已抓取跳過
# 93604已抓取跳過
# 47406已抓取跳過
# 14855已抓取跳過
# 1053692已抓取跳過
# 955886已抓取跳過
# 102539已抓取跳過
# 19783已抓取跳過
# 642088已抓取跳過
# 42162已抓取跳過
# 27930已抓取跳過
# 951332已抓取跳過
# 999758已抓取跳過
# 628197已抓取跳過
# 642874已抓取跳過
# 45117已抓取跳過
# 46016已抓取跳過
# 1051132已抓取跳過
# 94599已抓取跳過
# 941224已抓取跳過
# 992958已抓取跳過
# 33818已抓取跳過
# 109307已抓取跳過
# 64248已抓取跳過
# 1040272已抓取跳過
# 32615已抓取跳過
# 8503已抓取跳過
# 44254已抓取跳過
# 582905已抓取跳過
# 997872已抓取跳過
# 1029248已抓取跳過
# 34952已抓取跳過
# 956542已抓取跳過
# 23564已抓取跳過
# 91099已抓取跳過
# 13388已抓取跳過
# 48891已抓取跳過
# 1032864已抓取跳過
# 1031390已抓取跳過
# 148185已抓取跳過
# 951824已抓取跳過
# 1009394已抓取跳過
# 86795已抓取跳過
# 982209已抓取跳過
# 607640已抓取跳過
# 1063968已抓取跳過
# 12056已抓取跳過
# 62924已抓取跳過
# 110728已抓取跳過
# 51491已抓取跳過
# 38851已抓取跳過
# 1150079已抓取跳過
# 95889已抓取跳過
# 586998已抓取跳過
# 1020194已抓取跳過
# 1119026已抓取跳過
# 1033784已抓取跳過
# 28975已抓取跳過
# 43934已抓取跳過
# 7065已抓取跳過
# 27507已抓取跳過
# 41604已抓取跳過
# 81087已抓取跳過
# 37128已抓取跳過
# 623358已抓取跳過
# 86341已抓取跳過
# 31639已抓取跳過
# 35839已抓取跳過
# 1037010已抓取跳過
# 29814已抓取跳過
# 33947已抓取跳過
# 378384已抓取跳過
# 38515已抓取跳過
# 1023560已抓取跳過
# 28172已抓取跳過
# 1031314已抓取跳過
# 77166已抓取跳過
# 6140已抓取跳過
# 619538已抓取跳過
# 54898已抓取跳過
# 964874已抓取跳過
# 22713已抓取跳過
# 16271已抓取跳過
# 980684已抓取跳過
# 16690已抓取跳過
# 958348已抓取跳過
# 1006578已抓取跳過
# 937646已抓取跳過
# 103058已抓取跳過
# 932404已抓取跳過
# 41320已抓取跳過
# 6985已抓取跳過
# 1051194已抓取跳過
# 47110已抓取跳過
# 49757已抓取跳過
# 76238已抓取跳過
# 106034已抓取跳過
# 607132已抓取跳過
# 1039602已抓取跳過
# 31777已抓取跳過
# 7460已抓取跳過
# 1033756已抓取跳過
# 1027148已抓取跳過
# 35535已抓取跳過
# 39557已抓取跳過
# 617926已抓取跳過
# 41248已抓取跳過
# 1021696已抓取跳過
# 30992已抓取跳過
# 36991已抓取跳過
# 39750已抓取跳過
# 10280已抓取跳過
# 27388已抓取跳過
# 27901已抓取跳過
# 63783已抓取跳過
# 926734已抓取跳過
# 34667已抓取跳過
# 1203548已抓取跳過
# 990142已抓取跳過
# 109424已抓取跳過
# 583375已抓取跳過
# 59651已抓取跳過
# 1053108已抓取跳過
# 953012已抓取跳過
# 1059148已抓取跳過
# 601278已抓取跳過
# 781280已抓取跳過
# 154117已抓取跳過
# 937776已抓取跳過
# 627072已抓取跳過
# 961516已抓取跳過
# 939648已抓取跳過
# 70904已抓取跳過
# 75496已抓取跳過
# 101666已抓取跳過
# 53508已抓取跳過
# 1039814已抓取跳過
# 1065088已抓取跳過
# 992806已抓取跳過
# 77330已抓取跳過
# 1171103已抓取跳過
# 31930已抓取跳過
# 590628已抓取跳過
# 22506已抓取跳過
# 49416已抓取跳過
# 37939已抓取跳過
# 69374已抓取跳過
# 12040已抓取跳過
# 16136已抓取跳過
# 38256已抓取跳過
# 1058254已抓取跳過
# 15781已抓取跳過
# 1001510已抓取跳過
# 51643已抓取跳過
# 1046420已抓取跳過
# 1037636已抓取跳過
# 114486已抓取跳過
# 36223已抓取跳過
# 22505已抓取跳過
# 37633已抓取跳過
# 975372已抓取跳過
# 38830已抓取跳過
# 116153已抓取跳過
# 64172已抓取跳過
# 1003954已抓取跳過
# 988804已抓取跳過
# 120809已抓取跳過
# 57124已抓取跳過
# 1010944已抓取跳過
# 153043已抓取跳過
# 14867已抓取跳過
# 103393已抓取跳過
# 12516已抓取跳過
# 10155已抓取跳過
# 613934已抓取跳過
# 42106已抓取跳過
# 622650已抓取跳過
# 1208465已抓取跳過
# 83235已抓取跳過
# 1033118已抓取跳過
# 597622已抓取跳過
# 27572已抓取跳過
# 94885已抓取跳過
# 34059已抓取跳過
# 137755已抓取跳過
# 933338已抓取跳過
# 49976已抓取跳過
# 615404已抓取跳過
# 46317已抓取跳過
# 947330已抓取跳過
# 22358已抓取跳過
# 94999已抓取跳過
# 47824已抓取跳過
# 14369已抓取跳過
# 628288已抓取跳過
# 22243已抓取跳過
# 617848已抓取跳過
# 40376已抓取跳過
# 38789已抓取跳過
# 38863已抓取跳過
# 618274已抓取跳過
# 62153已抓取跳過
# 44289已抓取跳過
# 31554已抓取跳過
# 23539已抓取跳過
# 596310已抓取跳過
# 22537已抓取跳過
# 972814已抓取跳過
# 17433已抓取跳過
# 29513已抓取跳過
# 1010566已抓取跳過
# 14799已抓取跳過
# 1010124已抓取跳過
# 1048884已抓取跳過
# 47362已抓取跳過
# 969366已抓取跳過
# 622660已抓取跳過
# 937720已抓取跳過
# 62115已抓取跳過
# 1009074已抓取跳過
# 96451已抓取跳過
# 986788已抓取跳過
# 1007698已抓取跳過
# 28130已抓取跳過
# 634830已抓取跳過
# 38914已抓取跳過
# 1006756已抓取跳過
# 734826已抓取跳過
# 119306已抓取跳過
# 996438已抓取跳過
# 933326已抓取跳過
# 35033已抓取跳過
# 106320已抓取跳過
# 16683已抓取跳過
# 39914已抓取跳過
# 23202已抓取跳過
# 81107已抓取跳過
# 92839已抓取跳過
# 31215已抓取跳過
# 32955已抓取跳過
# 991086已抓取跳過
# 1033648已抓取跳過
# 953148已抓取跳過
# 42396已抓取跳過
# 1067860已抓取跳過
# 16147已抓取跳過
# 590514已抓取跳過
# 982203已抓取跳過
# 599612已抓取跳過
# 55538已抓取跳過
# 149551已抓取跳過
# 22603已抓取跳過
# 627294已抓取跳過
# 1067034已抓取跳過
# 929718已抓取跳過
# 593076已抓取跳過
# 44124已抓取跳過
# 633204已抓取跳過
# 978574已抓取跳過
# 40138已抓取跳過
# 35086已抓取跳過
# 43068已抓取跳過
# 9691已抓取跳過
# 114667已抓取跳過
# 625232已抓取跳過
# 29219已抓取跳過
# 635974已抓取跳過
# 779770已抓取跳過
# 114843已抓取跳過
# 1101431已抓取跳過
# 1017792已抓取跳過
# 29211已抓取跳過
# 46007已抓取跳過
# 122167已抓取跳過
# 10439已抓取跳過
# 40634已抓取跳過
# 944126已抓取跳過
# 122833已抓取跳過
# 17814已抓取跳過
# 35150已抓取跳過
# 975574已抓取跳過
# 1019384已抓取跳過
# 632260已抓取跳過
# 998346已抓取跳過
# 77021已抓取跳過
# 144361已抓取跳過
# 595338已抓取跳過
# 24678已抓取跳過
# 144783已抓取跳過
# 1056292已抓取跳過
# 94873已抓取跳過
# 30937已抓取跳過
# 8206已抓取跳過
# 22326已抓取跳過
# 1016608已抓取跳過
# 59402已抓取跳過
# 47333已抓取跳過
# 1052236已抓取跳過
# 965326已抓取跳過
# 7125已抓取跳過
# 1061552已抓取跳過
# 33705已抓取跳過
# 22280已抓取跳過
# 35570已抓取跳過
# 11630已抓取跳過
# 14984已抓取跳過
# 33827已抓取跳過
# 30299已抓取跳過
# 621884已抓取跳過
# 42615已抓取跳過
# 618706已抓取跳過
# 615364已抓取跳過
# 999752已抓取跳過
# 1051824已抓取跳過
# 42718已抓取跳過
# 62125已抓取跳過
# 1037248已抓取跳過
# 113695已抓取跳過
# 929568已抓取跳過
# 119503已抓取跳過
# 57472已抓取跳過
# 934972已抓取跳過
# 97567已抓取跳過
# 619148已抓取跳過
# 150809已抓取跳過
# 115420已抓取跳過
# 79833已抓取跳過
# 44324已抓取跳過
# 1037964已抓取跳過
# 631156已抓取跳過
# 31722已抓取跳過
# 585241已抓取跳過
# 40179已抓取跳過
# 30027已抓取跳過
# 629680已抓取跳過
# 1059490已抓取跳過
# 1014492已抓取跳過
# 39220已抓取跳過
# 17749已抓取跳過
# 21420已抓取跳過
# 1057724已抓取跳過
# 608670已抓取跳過
# 10266已抓取跳過
# 22767已抓取跳過
# 980924已抓取跳過
# 37600已抓取跳過
# 1000080已抓取跳過
# 4348已抓取跳過
# 1135337已抓取跳過
# 989546已抓取跳過
# 125493已抓取跳過
# 1006230已抓取跳過
# 118088已抓取跳過
# 1028200已抓取跳過
# 69134已抓取跳過
# 927750已抓取跳過
# 93806已抓取跳過
# 72683已抓取跳過
# 50197已抓取跳過
# 64406已抓取跳過
# 34571已抓取跳過
# 978078已抓取跳過
# 38618已抓取跳過
# 44923已抓取跳過
# 920814已抓取跳過
# 606814已抓取跳過
# 33747已抓取跳過
# 10144已抓取跳過
# 31540已抓取跳過
# 705282已抓取跳過
# 1069068已抓取跳過
# 28436已抓取跳過
# 147881已抓取跳過
# 94820已抓取跳過
# 944700已抓取跳過
# 87067已抓取跳過
# 109040已抓取跳過
# 925578已抓取跳過
# 1067606已抓取跳過
# 938680已抓取跳過
# 119449已抓取跳過
# 721402已抓取跳過
# 29015已抓取跳過
# 1075246已抓取跳過
# 626346已抓取跳過
# 950476已抓取跳過
# 949570已抓取跳過
# 1065732已抓取跳過
# 1061824已抓取跳過
# 635208已抓取跳過
# 108276已抓取跳過
# 1042882已抓取跳過
# 617214已抓取跳過
# 138909已抓取跳過
# 101703已抓取跳過
# 580461已抓取跳過
# 20221已抓取跳過
# 65115已抓取跳過
# 128443已抓取跳過
# 41026已抓取跳過
# 143487已抓取跳過
# 589132已抓取跳過
# 22679已抓取跳過
# 120625已抓取跳過
# 933400已抓取跳過
# 987812已抓取跳過
# 70824已抓取跳過
# 118261已抓取跳過
# 50191已抓取跳過
# 30119已抓取跳過
# 43030已抓取跳過
# 1038562已抓取跳過
# 17437已抓取跳過
# 29739已抓取跳過
# 77732已抓取跳過
# 50195已抓取跳過
# 39053已抓取跳過
# 119379已抓取跳過
# 1003970已抓取跳過
# 1012974已抓取跳過
# 31296已抓取跳過
# 48276已抓取跳過
# 8963已抓取跳過
# 53796已抓取跳過
# 133649已抓取跳過
# 90988已抓取跳過
# 623828已抓取跳過
# 75712已抓取跳過
# 35473已抓取跳過
# 30141已抓取跳過
# 119395已抓取跳過
# 118157已抓取跳過
# 1019040已抓取跳過
# 46184已抓取跳過
# 28871已抓取跳過
# 947882已抓取跳過
# 16624已抓取跳過
# 587834已抓取跳過
# 965550已抓取跳過
# 1012432已抓取跳過
# 109452已抓取跳過
# 29721已抓取跳過
# 929402已抓取跳過
# 22186已抓取跳過
# 10171已抓取跳過
# 106615已抓取跳過
# 18890已抓取跳過
# 47800已抓取跳過
# 987386已抓取跳過
# 97906已抓取跳過
# 16703已抓取跳過
# 15030已抓取跳過
# 58023已抓取跳過
# 968824已抓取跳過
# 3904已抓取跳過
# 996264已抓取跳過
# 586699已抓取跳過
# 980710已抓取跳過
# 947378已抓取跳過
# 30988已抓取跳過
# 9127已抓取跳過
# 1068508已抓取跳過
# 8626已抓取跳過
# 1053482已抓取跳過
# 1056154已抓取跳過
# 618190已抓取跳過
# 79599已抓取跳過
# 624036已抓取跳過
# 124077已抓取跳過
# 110024已抓取跳過
# 584741已抓取跳過
# 80928已抓取跳過
# 76695已抓取跳過
# 31362已抓取跳過
# 964484已抓取跳過
# 627170已抓取跳過
# 1041864已抓取跳過
# 71201已抓取跳過
# 621248已抓取跳過
# 624870已抓取跳過
# 1003952已抓取跳過
# 50497已抓取跳過
# 87969已抓取跳過
# 592210已抓取跳過
# 67109已抓取跳過
# 1051786已抓取跳過
# 26806已抓取跳過
# 92851已抓取跳過
# 50729已抓取跳過
# 117258已抓取跳過
# 1205180已抓取跳過
# 52049已抓取跳過
# 636048已抓取跳過
# 117910已抓取跳過
# 6325已抓取跳過
# 46387已抓取跳過
# 60048已抓取跳過
# 36616已抓取跳過
# 95503已抓取跳過
# 989006已抓取跳過
# 1141865已抓取跳過
# 36106已抓取跳過
# 64166已抓取跳過
# 8671已抓取跳過
# 27377已抓取跳過
# 9591已抓取跳過
# 150005已抓取跳過
# 28567已抓取跳過
# 36291已抓取跳過
# 993208已抓取跳過
# 1029114已抓取跳過
# 15665已抓取跳過
# 72073已抓取跳過
# 144949已抓取跳過
# 1031818已抓取跳過
# 982678已抓取跳過
# 122319已抓取跳過
# 959102已抓取跳過
# 1028280已抓取跳過
# 28423已抓取跳過
# 970222已抓取跳過
# 878426已抓取跳過
# 47231已抓取跳過
# 942194已抓取跳過
# 92048已抓取跳過
# 38320已抓取跳過
# 55827已抓取跳過
# 1055308已抓取跳過
# 1006930已抓取跳過
# 1044374已抓取跳過
# 957640已抓取跳過
# 6234已抓取跳過
# 88573已抓取跳過
# 33316已抓取跳過
# 1011668已抓取跳過
# 45978已抓取跳過
# 92531已抓取跳過
# 1053782已抓取跳過
# 56304已抓取跳過
# 1040162已抓取跳過
# 124791已抓取跳過
# 30208已抓取跳過
# 1018632已抓取跳過
# 40232已抓取跳過
# 482630已抓取跳過
# 63786已抓取跳過
# 951614已抓取跳過
# 39938已抓取跳過
# 1015930已抓取跳過
# 61123已抓取跳過
# 1033812已抓取跳過
# 627662已抓取跳過
# 44611已抓取跳過
# 84242已抓取跳過
# 995046已抓取跳過
# 1068136已抓取跳過
# 141945已抓取跳過
# 153025已抓取跳過
# 22207已抓取跳過
# 44890已抓取跳過
# 4643已抓取跳過
# 1028260已抓取跳過
# 44433已抓取跳過
# 1120838已抓取跳過
# 15749已抓取跳過
# 83928已抓取跳過
# 591096已抓取跳過
# 20223已抓取跳過
# 1043052已抓取跳過
# 627550已抓取跳過
# 83536已抓取跳過
# 42940已抓取跳過
# 47456已抓取跳過
# 615240已抓取跳過
# 1002824已抓取跳過
# 986154已抓取跳過
# 698254已抓取跳過
# 1127684已抓取跳過
# 46281已抓取跳過
# 39130已抓取跳過
# 84782已抓取跳過
# 22748已抓取跳過
# 22640已抓取跳過
# 1035222已抓取跳過
# 22536已抓取跳過
# 113429已抓取跳過
# 1077044已抓取跳過
# 1052182已抓取跳過
# 28029已抓取跳過
# 943190已抓取跳過
# 76795已抓取跳過
# 8283已抓取跳過
# 931008已抓取跳過
# 610416已抓取跳過
# 9090已抓取跳過
# 14305已抓取跳過
# 1034880已抓取跳過
# 580285已抓取跳過
# 611260已抓取跳過
# 1110452已抓取跳過
# 597130已抓取跳過
# 1066392已抓取跳過
# 933146已抓取跳過
# 108093已抓取跳過
# 1051872已抓取跳過
# 49344已抓取跳過
# 149267已抓取跳過
# 46529已抓取跳過
# 34712已抓取跳過
# 44368已抓取跳過
# 1029644已抓取跳過
# 41212已抓取跳過
# 3981已抓取跳過
# 94947已抓取跳過
# 61876已抓取跳過
# 983450已抓取跳過
# 634284已抓取跳過
# 699090已抓取跳過
# 93622已抓取跳過
# 39678已抓取跳過
# 960842已抓取跳過
# 4295已抓取跳過
# 105644已抓取跳過
# 55036已抓取跳過
# 107558已抓取跳過
# 48468已抓取跳過
# 14298已抓取跳過
# 629638已抓取跳過
# 93058已抓取跳過
# 118629已抓取跳過
# 34954已抓取跳過
# 851448已抓取跳過
# 140057已抓取跳過
# 120839已抓取跳過
# 609812已抓取跳過
# 83524已抓取跳過
# 634866已抓取跳過
# 997546已抓取跳過
# 1031424已抓取跳過
# 630670已抓取跳過
# 11431已抓取跳過
# 603396已抓取跳過
# 27612已抓取跳過
# 43601已抓取跳過
# 132143已抓取跳過
# 28862已抓取跳過
# 1028782已抓取跳過
# 637060已抓取跳過
# 974376已抓取跳過
# 1053964已抓取跳過
# 596180已抓取跳過
# 932996已抓取跳過
# 110922已抓取跳過
# 27876已抓取跳過
# 41576已抓取跳過
# 1050924已抓取跳過
# 22693已抓取跳過
# 49672已抓取跳過
# 27517已抓取跳過
# 8966已抓取跳過
# 146017已抓取跳過
# 1064744已抓取跳過
# 47822已抓取跳過
# 612332已抓取跳過
# 10293已抓取跳過
# 617782已抓取跳過
# 1025422已抓取跳過
# 1041498已抓取跳過
# 105063已抓取跳過
# 1135082已抓取跳過
# 60311已抓取跳過
# 22660已抓取跳過
# 51949已抓取跳過
# 31667已抓取跳過
# 582959已抓取跳過
# 1073616已抓取跳過
# 946500已抓取跳過
# 60266已抓取跳過
# 1047212已抓取跳過
# 120829已抓取跳過
# 150875已抓取跳過
# 572320已抓取跳過
# 41379已抓取跳過
# 46739已抓取跳過
# 103307已抓取跳過
# 631842已抓取跳過
# 156201已抓取跳過
# 974470已抓取跳過
# 1066080已抓取跳過
# 1028196已抓取跳過
# 7199已抓取跳過
# 754272已抓取跳過
# 44014已抓取跳過
# 6952已抓取跳過
# 952212已抓取跳過
# 952270已抓取跳過
# 87271已抓取跳過
# 66492已抓取跳過
# 1064042已抓取跳過
# 40026已抓取跳過
# 956152已抓取跳過
# 42870已抓取跳過
# 599306已抓取跳過
# 1047736已抓取跳過
# 974542已抓取跳過
# 50014已抓取跳過
# 927452已抓取跳過
# 617594已抓取跳過
# 1021568已抓取跳過
# 579052已抓取跳過
# 154505已抓取跳過
# 87923已抓取跳過
# 952224已抓取跳過
# 129727已抓取跳過
# 1035264已抓取跳過
# 44728已抓取跳過
# 932306已抓取跳過
# 651318已抓取跳過
# 580185已抓取跳過
# 50336已抓取跳過
# 1073358已抓取跳過
# 104680已抓取跳過
# 30758已抓取跳過
# 1033862已抓取跳過
# 37935已抓取跳過
# 62792已抓取跳過
# 1012856已抓取跳過
# 150937已抓取跳過
# 595236已抓取跳過
# 72366已抓取跳過
# 114907已抓取跳過
# 82649已抓取跳過
# 105910已抓取跳過
# 1054080已抓取跳過
# 975518已抓取跳過
# 583039已抓取跳過
# 1199168已抓取跳過
# 603030已抓取跳過
# 16694已抓取跳過
# 116295已抓取跳過
# 23034已抓取跳過
# 995042已抓取跳過
# 82179已抓取跳過
# 1003032已抓取跳過
# 15491已抓取跳過
# 33306已抓取跳過
# 1067688已抓取跳過
# 1076022已抓取跳過
# 699078已抓取跳過
# 598018已抓取跳過
# 1084670已抓取跳過
# 39069已抓取跳過
# 30883已抓取跳過
# 1048428已抓取跳過
# 1029256已抓取跳過
# 47482已抓取跳過
# 916424已抓取跳過
# 1048768已抓取跳過
# 974744已抓取跳過
# 973636已抓取跳過
# 627102已抓取跳過
# 29964已抓取跳過
# 1049148已抓取跳過
# 52978已抓取跳過
# 1033594已抓取跳過
# 71655已抓取跳過
# 76132已抓取跳過
# 92888已抓取跳過
# 7079已抓取跳過
# 153385已抓取跳過
# 966984已抓取跳過
# 59395已抓取跳過
# 76791已抓取跳過
# 131585已抓取跳過
# 964504已抓取跳過
# 43534已抓取跳過
# 982442已抓取跳過
# 586149已抓取跳過
# 982310已抓取跳過
# 110967已抓取跳過
# 41568已抓取跳過
# 119496已抓取跳過
# 1043622已抓取跳過
# 1058044已抓取跳過
# 47342已抓取跳過
# 991330已抓取跳過
# 636224已抓取跳過
# 29340已抓取跳過
# 1068982已抓取跳過
# 929958已抓取跳過
# 604842已抓取跳過
# 1149776已抓取跳過
# 973226已抓取跳過
# 996928已抓取跳過
# 29100已抓取跳過
# 6534已抓取跳過
# 41376已抓取跳過
# 583157已抓取跳過
# 992182已抓取跳過
# 23281已抓取跳過
# 81782已抓取跳過
# 37183已抓取跳過
# 43722已抓取跳過
# 68757已抓取跳過
# 43278已抓取跳過
# 34814已抓取跳過
# 107577已抓取跳過
# 1086944已抓取跳過
# 940024已抓取跳過
# 11408已抓取跳過
# 583865已抓取跳過
# 32501已抓取跳過
# 33351已抓取跳過
# 1016922已抓取跳過
# 38217已抓取跳過
# 58388已抓取跳過
# 79649已抓取跳過
# 113897已抓取跳過
# 47087已抓取跳過
# 27376已抓取跳過
# 829326已抓取跳過
# 736996已抓取跳過
# 939938已抓取跳過
# 6587已抓取跳過
# 43330已抓取跳過
# 47594已抓取跳過
# 22301已抓取跳過
# 34276已抓取跳過
# 119337已抓取跳過
# 1033232已抓取跳過
# 1010312已抓取跳過
# 1014824已抓取跳過
# 1022738已抓取跳過
# 590288已抓取跳過
# 34877已抓取跳過
# 604930已抓取跳過
# 973036已抓取跳過
# 1054760已抓取跳過
# 584743已抓取跳過
# 6953已抓取跳過
# 84056已抓取跳過
# 9096已抓取跳過
# 32997已抓取跳過
# 937152已抓取跳過
# 960724已抓取跳過
# 1050030已抓取跳過
# 46272已抓取跳過
# 52744已抓取跳過
# 969834已抓取跳過
# 994406已抓取跳過
# 986790已抓取跳過
# 975312已抓取跳過
# 976518已抓取跳過
# 38877已抓取跳過
# 7630已抓取跳過
# 59525已抓取跳過
# 119761已抓取跳過
# 1025916已抓取跳過
# 104364已抓取跳過
# 1006768已抓取跳過
# 1023318已抓取跳過
# 935360已抓取跳過
# 32280已抓取跳過
# 986012已抓取跳過
# 930066已抓取跳過
# 46813已抓取跳過
# 961568已抓取跳過
# 581831已抓取跳過
# 1019804已抓取跳過
# 39433已抓取跳過
# 1053560已抓取跳過
# 102593已抓取跳過
# 587088已抓取跳過
# 42138已抓取跳過
# 616012已抓取跳過
# 58707已抓取跳過
# 1016106已抓取跳過
# 31306已抓取跳過
# 952194已抓取跳過
# 8674已抓取跳過
# 9150已抓取跳過
# 615586已抓取跳過
# 1023538已抓取跳過
# 976578已抓取跳過
# 125911已抓取跳過
# 1160405已抓取跳過
# 933794已抓取跳過
# 40197已抓取跳過
# 977150已抓取跳過
# 44427已抓取跳過
# 940966已抓取跳過
# 1085144已抓取跳過
# 73436已抓取跳過
# 30278已抓取跳過
# 607194已抓取跳過
# 35076已抓取跳過
# 938966已抓取跳過
# 965038已抓取跳過
# 49922已抓取跳過
# 616728已抓取跳過
# 1011044已抓取跳過
# 1036610已抓取跳過
# 52538已抓取跳過
# 22441已抓取跳過
# 1062960已抓取跳過
# 736750已抓取跳過
# 554942已抓取跳過
# 146207已抓取跳過
# 64853已抓取跳過
# 930038已抓取跳過
# 599976已抓取跳過
# 1046222已抓取跳過
# 38950已抓取跳過
# 47760已抓取跳過
# 29951已抓取跳過
# 41982已抓取跳過
# 953536已抓取跳過
# 987898已抓取跳過
# 102209已抓取跳過
# 929232已抓取跳過
# 26629已抓取跳過
# 992952已抓取跳過
# 981114已抓取跳過
# 958210已抓取跳過
# 954774已抓取跳過
# 598768已抓取跳過
# 28533已抓取跳過
# 30833已抓取跳過
# 935810已抓取跳過
# 34862已抓取跳過
# 987650已抓取跳過
# 1068988已抓取跳過
# 109851已抓取跳過
# 998044已抓取跳過
# 964102已抓取跳過
# 94756已抓取跳過
# 45237已抓取跳過
# 1054846已抓取跳過
# 1145282已抓取跳過
# 979940已抓取跳過
# 63728已抓取跳過
# 28589已抓取跳過
# 40917已抓取跳過
# 121955已抓取跳過
# 1006514已抓取跳過
# 114254已抓取跳過
# 962962已抓取跳過
# 1038888已抓取跳過
# 88526已抓取跳過
# 581175已抓取跳過
# 108267已抓取跳過
# 8620已抓取跳過
# 58386已抓取跳過
# 1046546已抓取跳過
# 36438已抓取跳過
# 144379已抓取跳過
# 1043958已抓取跳過
# 962182已抓取跳過
# 27459已抓取跳過
# 40850已抓取跳過
# 1170893已抓取跳過
# 119167已抓取跳過
# 992736已抓取跳過
# 920620已抓取跳過
# 1025758已抓取跳過
# 1028790已抓取跳過
# 920776已抓取跳過
# 16770已抓取跳過
# 33321已抓取跳過
# 8648已抓取跳過
# 1048900已抓取跳過
# 43942已抓取跳過
# 1012574已抓取跳過
# 94292已抓取跳過
# 1046676已抓取跳過
# 933020已抓取跳過
# 936968已抓取跳過
# 67679已抓取跳過
# 118252已抓取跳過
# 1029812已抓取跳過
# 939494已抓取跳過
# 1050496已抓取跳過
# 87883已抓取跳過
# 88391已抓取跳過
# 472450已抓取跳過
# 30812已抓取跳過
# 1046750已抓取跳過
# 625654已抓取跳過
# 122995已抓取跳過
# 29202已抓取跳過
# 23568已抓取跳過
# 19242已抓取跳過
# 49935已抓取跳過
# 583209已抓取跳過
# 53011已抓取跳過
# 145413已抓取跳過
# 17690已抓取跳過
# 3805已抓取跳過
# 636942已抓取跳過
# 62064已抓取跳過
# 1034384已抓取跳過
# 74732已抓取跳過
# 978820已抓取跳過
# 1050006已抓取跳過
# 975576已抓取跳過
# 47471已抓取跳過
# 1072880已抓取跳過
# 1010370已抓取跳過
# 7053已抓取跳過
# 66111已抓取跳過
# 110118已抓取跳過
# 1077560已抓取跳過
# 1201142已抓取跳過
# 994838已抓取跳過
# 1013036已抓取跳過
# 67651已抓取跳過
# 27487已抓取跳過
# 600940已抓取跳過
# 152309已抓取跳過
# 1129079已抓取跳過
# 955338已抓取跳過
# 35461已抓取跳過
# 115344已抓取跳過
# 945624已抓取跳過
# 578450已抓取跳過
# 1018370已抓取跳過
# 50964已抓取跳過
# 21338已抓取跳過
# 11067已抓取跳過
# 605164已抓取跳過
# 87473已抓取跳過
# 80387已抓取跳過
# 1006778已抓取跳過
# 619936已抓取跳過
# 22533已抓取跳過
# 599742已抓取跳過
# 123961已抓取跳過
# 953980已抓取跳過
# 98765已抓取跳過
# 31515已抓取跳過
# 1017526已抓取跳過
# 43782已抓取跳過
# 48118已抓取跳過
# 65940已抓取跳過
# 67838已抓取跳過
# 991658已抓取跳過
# 74444已抓取跳過
# 989792已抓取跳過
# 938398已抓取跳過
# 107121已抓取跳過
# 1029988已抓取跳過
# 6585已抓取跳過
# 28481已抓取跳過
# 51128已抓取跳過
# 138867已抓取跳過
# 35820已抓取跳過
# 26379已抓取跳過
# 68439已抓取跳過
# 1017464已抓取跳過
# 54679已抓取跳過
# 1135574已抓取跳過
# 44089已抓取跳過
# 987024已抓取跳過
# 615158已抓取跳過
# 599302已抓取跳過
# 37367已抓取跳過
# 32154已抓取跳過
# 578122已抓取跳過
# 929388已抓取跳過
# 3897已抓取跳過
# 3777已抓取跳過
# 18908已抓取跳過
# 1020140已抓取跳過
# 55433已抓取跳過
# 18446已抓取跳過
# 23277已抓取跳過
# 44610已抓取跳過
# 1090787已抓取跳過
# 38064已抓取跳過
# 15187已抓取跳過
# 28109已抓取跳過
# 140955已抓取跳過
# 120457已抓取跳過
# 96048已抓取跳過
# 90085已抓取跳過
# 119163已抓取跳過
# 144545已抓取跳過
# 958570已抓取跳過
# 36904已抓取跳過
# 29992已抓取跳過
# 931712已抓取跳過
# 150729已抓取跳過
# 1054138已抓取跳過
# 64347已抓取跳過
# 48139已抓取跳過
# 1061234已抓取跳過
# 1051810已抓取跳過
# 8313已抓取跳過
# 28253已抓取跳過
# 74985已抓取跳過
# 35558已抓取跳過
# 988464已抓取跳過
# 44785已抓取跳過
# 23369已抓取跳過
# 585429已抓取跳過
# 1120478已抓取跳過
# 976494已抓取跳過
# 1027818已抓取跳過
# 27679已抓取跳過
# 152865已抓取跳過
# 1016108已抓取跳過
# 33957已抓取跳過
# 968916已抓取跳過
# 992710已抓取跳過
# 34360已抓取跳過
# 973312已抓取跳過
# 950750已抓取跳過
# 681068已抓取跳過
# 58684已抓取跳過
# 1046760已抓取跳過
# 13180已抓取跳過
# 991512已抓取跳過
# 30777已抓取跳過
# 1143908已抓取跳過
# 84178已抓取跳過
# 7980已抓取跳過
# 29900已抓取跳過
# 606578已抓取跳過
# 1021140已抓取跳過
# 31927已抓取跳過
# 89466已抓取跳過
# 11043已抓取跳過
# 64120已抓取跳過
# 117229已抓取跳過
# 34144已抓取跳過
# 70941已抓取跳過
# 107490已抓取跳過
# 150821已抓取跳過
# 18549已抓取跳過
# 589308已抓取跳過
# 935648已抓取跳過
# 106622已抓取跳過
# 28210已抓取跳過
# 957972已抓取跳過
# 32737已抓取跳過
# 140925已抓取跳過
# 972882已抓取跳過
# 38469已抓取跳過
# 78472已抓取跳過
# 91054已抓取跳過
# 608260已抓取跳過
# 28951已抓取跳過
# 633676已抓取跳過
# 126113已抓取跳過
# 52100已抓取跳過
# 1039754已抓取跳過
# 78531已抓取跳過
# 1112750已抓取跳過
# 95524已抓取跳過
# 39435已抓取跳過
# 8123已抓取跳過
# 137687已抓取跳過
# 961094已抓取跳過
# 568412已抓取跳過
# 984632已抓取跳過
# 12892已抓取跳過
# 981214已抓取跳過
# 1165268已抓取跳過
# 37381已抓取跳過
# 31102已抓取跳過
# 80100已抓取跳過
# 33962已抓取跳過
# 984418已抓取跳過
# 107601已抓取跳過
# 107431已抓取跳過
# 44109已抓取跳過
# 1109843已抓取跳過
# 697330已抓取跳過
# 30975已抓取跳過
# 1130456已抓取跳過
# 9276已抓取跳過
# 994728已抓取跳過
# 973314已抓取跳過
# 1077266已抓取跳過
# 138987已抓取跳過
# 149843已抓取跳過
# 626806已抓取跳過
# 937668已抓取跳過
# 28231已抓取跳過
# 39869已抓取跳過
# 1021410已抓取跳過
# 151471已抓取跳過
# 148955已抓取跳過
# 9541已抓取跳過
# 920670已抓取跳過
# 27835已抓取跳過
# 930600已抓取跳過
# 29414已抓取跳過
# 1061838已抓取跳過
# 4694已抓取跳過
# 93993已抓取跳過
# 61275已抓取跳過
# 978812已抓取跳過
# 1014496已抓取跳過
# 1021850已抓取跳過
# 34104已抓取跳過
# 1081112已抓取跳過
# 137319已抓取跳過
# 30122已抓取跳過
# 97327已抓取跳過
# 959940已抓取跳過
# 949640已抓取跳過
# 79163已抓取跳過
# 963718已抓取跳過
# 134893已抓取跳過
# 71490已抓取跳過
# 606668已抓取跳過
# 76881已抓取跳過
# 981889已抓取跳過
# 123295已抓取跳過
# 15675已抓取跳過
# 1157372已抓取跳過
# 116569已抓取跳過
# 104319已抓取跳過
# 44306已抓取跳過
# 960086已抓取跳過
# 1018232已抓取跳過
# 1076698已抓取跳過
# 633830已抓取跳過
# 608804已抓取跳過
# 1055854已抓取跳過
# 1037260已抓取跳過
# 1046346已抓取跳過
# 41403已抓取跳過
# 978814已抓取跳過
# 27563已抓取跳過
# 1177295已抓取跳過
# 973550已抓取跳過
# 116289已抓取跳過
# 978360已抓取跳過
# 971636已抓取跳過
# 587044已抓取跳過
# 60782已抓取跳過
# 1038720已抓取跳過
# 53110已抓取跳過
# 56341已抓取跳過
# 955924已抓取跳過
# 1157642已抓取跳過
# 1063590已抓取跳過
# 9025已抓取跳過
# 618676已抓取跳過
# 593252已抓取跳過
# 1064994已抓取跳過
# 9871已抓取跳過
# 97032已抓取跳過
# 1021248已抓取跳過
# 1070796已抓取跳過
# 607664已抓取跳過
# 41532已抓取跳過
# 50106已抓取跳過
# 97059已抓取跳過
# 984002已抓取跳過
# 72566已抓取跳過
# 617222已抓取跳過
# 75513已抓取跳過
# 1049084已抓取跳過
# 27366已抓取跳過
# 936400已抓取跳過
# 1047300已抓取跳過
# 1044232已抓取跳過
# 2938已抓取跳過
# 43809已抓取跳過
# 38882已抓取跳過
# 53719已抓取跳過
# 945600已抓取跳過
# 1025384已抓取跳過
# 115153已抓取跳過
# 679674已抓取跳過
# 34358已抓取跳過
# 114603已抓取跳過
# 1098641已抓取跳過
# 65454已抓取跳過
# 8722已抓取跳過
# 60915已抓取跳過
# 580030已抓取跳過
# 939886已抓取跳過
# 779372已抓取跳過
# 33341已抓取跳過
# 55510已抓取跳過
# 16793已抓取跳過
# 34754已抓取跳過
# 988236已抓取跳過
# 935160已抓取跳過
# 959982已抓取跳過
# 602132已抓取跳過
# 989842已抓取跳過
# 925164已抓取跳過
# 1031736已抓取跳過
# 144199已抓取跳過
# 70908已抓取跳過
# 41225已抓取跳過
# 607700已抓取跳過
# 80824已抓取跳過
# 960528已抓取跳過
# 45170已抓取跳過
# 43621已抓取跳過
# 23143已抓取跳過
# 1184888已抓取跳過
# 35680已抓取跳過
# 35454已抓取跳過
# 1168130已抓取跳過
# 619254已抓取跳過
# 70321已抓取跳過
# 59749已抓取跳過
# 973412已抓取跳過
# 586823已抓取跳過
# 1055712已抓取跳過
# 100567已抓取跳過
# 119391已抓取跳過
# 1004616已抓取跳過
# 937406已抓取跳過
# 28897已抓取跳過
# 1046472已抓取跳過
# 974246已抓取跳過
# 983908已抓取跳過
# 36776已抓取跳過
# 41398已抓取跳過
# 1001742已抓取跳過
# 607456已抓取跳過
# 1095491已抓取跳過
# 1075058已抓取跳過
# 937816已抓取跳過
# 1012376已抓取跳過
# 963884已抓取跳過
# 1007688已抓取跳過
# 973424已抓取跳過
# 981929已抓取跳過
# 1034230已抓取跳過
# 951224已抓取跳過
# 1057882已抓取跳過
# 81072已抓取跳過
# 958784已抓取跳過
# 594118已抓取跳過
# 1072706已抓取跳過
# 944678已抓取跳過
# 9219已抓取跳過
# 30148已抓取跳過
# 9109已抓取跳過
# 1031670已抓取跳過
# 964082已抓取跳過
# 8977已抓取跳過
# 108091已抓取跳過
# 106012已抓取跳過
# 21571已抓取跳過
# 33954已抓取跳過
# 17386已抓取跳過
# 44801已抓取跳過
# 1127780已抓取跳過
# 935610已抓取跳過
# 22694已抓取跳過
# 46216已抓取跳過
# 947844已抓取跳過
# 1177661已抓取跳過
# 6580已抓取跳過
# 603346已抓取跳過
# 85928已抓取跳過
# 80144已抓取跳過
# 1068694已抓取跳過
# 594148已抓取跳過
# 43248已抓取跳過
# 1068250已抓取跳過
# 42546已抓取跳過
# 904994已抓取跳過
# 17423已抓取跳過
# 27506已抓取跳過
# 27759已抓取跳過
# 110746已抓取跳過
# 15687已抓取跳過
# 29145已抓取跳過
# 41439已抓取跳過
# 119579已抓取跳過
# 980456已抓取跳過
# 936732已抓取跳過
# 590982已抓取跳過
# 993040已抓取跳過
# 16382已抓取跳過
# 956242已抓取跳過
# 1007940已抓取跳過
# 1074962已抓取跳過
# 973256已抓取跳過
# 936272已抓取跳過
# 4916已抓取跳過
# 1050094已抓取跳過
# 606056已抓取跳過
# 57324已抓取跳過
# 1039054已抓取跳過
# 614304已抓取跳過
# 1038430已抓取跳過
# 9169已抓取跳過
# 1042912已抓取跳過
# 1068400已抓取跳過
# 29860已抓取跳過
# 50130已抓取跳過
# 33636已抓取跳過
# 36469已抓取跳過
# 89176已抓取跳過
# 934472已抓取跳過
# 47952已抓取跳過
# 128055已抓取跳過
# 1038860已抓取跳過
# 29974已抓取跳過
# 56208已抓取跳過
# 1040598已抓取跳過
# 53523已抓取跳過
# 947948已抓取跳過
# 28789已抓取跳過
# 1015422已抓取跳過
# 22287已抓取跳過
# 45078已抓取跳過
# 926692已抓取跳過
# 1044096已抓取跳過
# 953810已抓取跳過
# 59794已抓取跳過
# 1127993已抓取跳過
# 941010已抓取跳過
# 632326已抓取跳過
# 78795已抓取跳過
# 70378已抓取跳過
# 98513已抓取跳過
# 30151已抓取跳過
# 966344已抓取跳過
# 94681已抓取跳過
# 47961已抓取跳過
# 995052已抓取跳過
# 1194380已抓取跳過
# 978904已抓取跳過
# 952434已抓取跳過
# 34962已抓取跳過
# 17275已抓取跳過
# 8374已抓取跳過
# 40663已抓取跳過
# 37426已抓取跳過
# 45976已抓取跳過
# 8665已抓取跳過
# 40921已抓取跳過
# 984832已抓取跳過
# 629328已抓取跳過
# 20803已抓取跳過
# 966172已抓取跳過
# 34776已抓取跳過
# 1059498已抓取跳過
# 22682已抓取跳過
# 1156187已抓取跳過
# 61357已抓取跳過
# 1057904已抓取跳過
# 1028802已抓取跳過
# 16839已抓取跳過
# 33707已抓取跳過
# 44798已抓取跳過
# 934088已抓取跳過
# 1166186已抓取跳過
# 1018016已抓取跳過
# 1043572已抓取跳過
# 930840已抓取跳過
# 84096已抓取跳過
# 607992已抓取跳過
# 988540已抓取跳過
# 1113已抓取跳過
# 31521已抓取跳過
# 114872已抓取跳過
# 982344已抓取跳過
# 12217已抓取跳過
# 133301已抓取跳過
# 934320已抓取跳過
# 95807已抓取跳過
# 946992已抓取跳過
# 48643已抓取跳過
# 22626已抓取跳過
# 30845已抓取跳過
# 1004028已抓取跳過
# 108068已抓取跳過
# 1067964已抓取跳過
# 1075626已抓取跳過
# 46630已抓取跳過
# 39745已抓取跳過
# 68195已抓取跳過
# 3901已抓取跳過
# 35844已抓取跳過
# 1027882已抓取跳過
# 49227已抓取跳過
# 1079062已抓取跳過
# 1059088已抓取跳過
# 65582已抓取跳過
# 967524已抓取跳過
# 44192已抓取跳過
# 470854已抓取跳過
# 712070已抓取跳過
# 39541已抓取跳過
# 971810已抓取跳過
# 41496已抓取跳過
# 1050456已抓取跳過
# 591388已抓取跳過
# 1162679已抓取跳過
# 29815已抓取跳過
# 9558已抓取跳過
# 1015326已抓取跳過
# 1016728已抓取跳過
# 1063474已抓取跳過
# 42325已抓取跳過
# 1056378已抓取跳過
# 1014760已抓取跳過
# 41446已抓取跳過
# 1063976已抓取跳過
# 91616已抓取跳過
# 96729已抓取跳過
# 583877已抓取跳過
# 585231已抓取跳過
# 1142720已抓取跳過
# 35474已抓取跳過
# 1017576已抓取跳過
# 77724已抓取跳過
# 1902已抓取跳過
# 1002628已抓取跳過
# 79156已抓取跳過
# 70572已抓取跳過
# 31535已抓取跳過
# 1054670已抓取跳過
# 40906已抓取跳過
# 1155245已抓取跳過
# 62819已抓取跳過
# 1162301已抓取跳過
# 93742已抓取跳過
# 41317已抓取跳過
# 36669已抓取跳過
# 594396已抓取跳過
# 1081976已抓取跳過
# 38517已抓取跳過
# 607452已抓取跳過
# 61719已抓取跳過
# 1060006已抓取跳過
# 1054470已抓取跳過
# 31285已抓取跳過
# 974722已抓取跳過
# 38462已抓取跳過
# 1001710已抓取跳過
# 34110已抓取跳過
# 1076456已抓取跳過
# 43743已抓取跳過
# 48960已抓取跳過
# 1090382已抓取跳過
# 22254已抓取跳過
# 36491已抓取跳過
# 16114已抓取跳過
# 150113已抓取跳過
# 116116已抓取跳過
# 631724已抓取跳過
# 61845已抓取跳過
# 1040074已抓取跳過
# 52207已抓取跳過
# 96756已抓取跳過
# 944116已抓取跳過
# 67718已抓取跳過
# 28278已抓取跳過
# 70323已抓取跳過
# 52192已抓取跳過
# 119146已抓取跳過
# 939804已抓取跳過
# 1070842已抓取跳過
# 35920已抓取跳過
# 959306已抓取跳過
# 59822已抓取跳過
# 985468已抓取跳過
# 1076560已抓取跳過
# 971908已抓取跳過
# 33706已抓取跳過
# 39500已抓取跳過
# 925已抓取跳過
# 1119470已抓取跳過
# 972696已抓取跳過
# 1015672已抓取跳過
# 76902已抓取跳過
# 75546已抓取跳過
# 629050已抓取跳過
# 40461已抓取跳過
# 153803已抓取跳過
# 59573已抓取跳過
# 34743已抓取跳過
# 974026已抓取跳過
# 1021394已抓取跳過
# 1129109已抓取跳過
# 37328已抓取跳過
# 75788已抓取跳過
# 954538已抓取跳過
# 921928已抓取跳過
# 89126已抓取跳過
# 1068348已抓取跳過
# 31633已抓取跳過
# 940610已抓取跳過
# 51815已抓取跳過
# 948460已抓取跳過
# 38606已抓取跳過
# 117121已抓取跳過
# 41284已抓取跳過
# 975698已抓取跳過
# 38966已抓取跳過
# 22472已抓取跳過
# 41106已抓取跳過
# 1130534已抓取跳過
# 1192400已抓取跳過
# 981624已抓取跳過
# 76335已抓取跳過
# 988276已抓取跳過
# 1148783已抓取跳過
# 597564已抓取跳過
# 23585已抓取跳過
# 635276已抓取跳過
# 50563已抓取跳過
# 84634已抓取跳過
# 1022094已抓取跳過
# 1071274已抓取跳過
# 34792已抓取跳過
# 1002830已抓取跳過
# 33177已抓取跳過
# 977196已抓取跳過
# 52879已抓取跳過
# 27622已抓取跳過
# 995138已抓取跳過
# 50822已抓取跳過
# 1021144已抓取跳過
# 1052484已抓取跳過
# 34382已抓取跳過
# 988512已抓取跳過
# 631206已抓取跳過
# 90152已抓取跳過
# 1040766已抓取跳過
# ...
# 1140146已抓取跳過
# 1211129已抓取跳過
# 1198382已抓取跳過
# 1211990已抓取跳過
# 1214081已抓取跳過
# 1211201已抓取跳過
# 1211936已抓取跳過
# 1186253已抓取跳過
# 1193579已抓取跳過
# 1211219已抓取跳過
# 1213274已抓取跳過
# 1212713已抓取跳過
# 1126157已抓取跳過
# 1211018已抓取跳過
# 1213412已抓取跳過
# 1212185已抓取跳過
# 1212743已抓取跳過
# 1213238已抓取跳過
# 1213895已抓取跳過
# 1213583已抓取跳過
# 1212047已抓取跳過
# 1213490已抓取跳過
# 1214021已抓取跳過
# 1213871已抓取跳過
# 1211633已抓取跳過
# 1213667已抓取跳過
# 1212470已抓取跳過
# 1212605已抓取跳過
# 1212476已抓取跳過
# 1212314已抓取跳過
# 1212218已抓取跳過
# 1212953已抓取跳過
# 1213733已抓取跳過
# 1213154已抓取跳過
# 1201301已抓取跳過
# 1213118已抓取跳過
# 1212581已抓取跳過
# 1213607已抓取跳過
# 1214051已抓取跳過
# 1212809已抓取跳過
# 1213130已抓取跳過
# 1213799已抓取跳過
# 1213541已抓取跳過
# 1210970已抓取跳過
# 1209518已抓取跳過
# 1212503已抓取跳過
# 1210661已抓取跳過
# 1211822已抓取跳過
# 1212791已抓取跳過
# 1211450已抓取跳過
# 1212191已抓取跳過
# 1211171已抓取跳過
# 1212464已抓取跳過
# 1212887已抓取跳過
# 1165379已抓取跳過
# 1211639已抓取跳過
# 1211624已抓取跳過
# 1212551已抓取跳過
# 1212719已抓取跳過
# 1098569已抓取跳過
# 1214015已抓取跳過
# 1211942已抓取跳過
# 1212749已抓取跳過
# 1211462已抓取跳過
# 1212428已抓取跳過
# 1211798已抓取跳過
# 1212803已抓取跳過
# 1211693已抓取跳過
# 1183943已抓取跳過
# 1212617已抓取跳過
# 1211000已抓取跳過
# 1212959已抓取跳過
# 1213232已抓取跳過
# 1213250已抓取跳過
# 1211540已抓取跳過
# 1211135已抓取跳過
# 1214057已抓取跳過
# 1182269已抓取跳過
# 1212863已抓取跳過
# 1211279已抓取跳過
# 1211663已抓取跳過
# 1214225已抓取跳過
# 1092524已抓取跳過
# 1213094已抓取跳過
# 1211657已抓取跳過
# 1211588已抓取跳過
# 1211948已抓取跳過
# 1212641已抓取跳過
# 1214267已抓取跳過
# 1211735已抓取跳過
# 1212539已抓取跳過
# 1212857已抓取跳過
# 1211888已抓取跳過
# 1212869已抓取跳過
# 1207430已抓取跳過
# 1213559已抓取跳過
# 1211924已抓取跳過
# 1213304已抓取跳過
# 1212629已抓取跳過
# 1213727已抓取跳過
# 1212593已抓取跳過
# 1145744已抓取跳過
# 1212557已抓取跳過
# 1211351已抓取跳過
# 1214297已抓取跳過
# 1211966已抓取跳過
# 1212095已抓取跳過
# 1212545已抓取跳過
# 1212917已抓取跳過
# 1207664已抓取跳過
# 1211024已抓取跳過
# 1213889已抓取跳過
# 1214117已抓取跳過
# 1211369已抓取跳過
# 1213394已抓取跳過
# 1213220已抓取跳過
# 1213943已抓取跳過
# 1214153已抓取跳過
# 1212785已抓取跳過
# 1211153已抓取跳過
# 1076326已抓取跳過
# 1212137已抓取跳過
# 1211315已抓取跳過
# 1212422已抓取跳過
# 1213001已抓取跳過
# 1211327已抓取跳過
# 1213745已抓取跳過
# 1213883已抓取跳過
# 1212023已抓取跳過
# 1214183已抓取跳過
# 1214285已抓取跳過
# 1212737已抓取跳過
# 1211699已抓取跳過
# 1213388已抓取跳過
# 1211285已抓取跳過
# 1213937已抓取跳過
# 1098581已抓取跳過
# 1211048已抓取跳過
# 1211123已抓取跳過
# 1213991已抓取跳過
# 1211207已抓取跳過
# 1211030已抓取跳過
# 1131989已抓取跳過
# 1211105已抓取跳過
# 1206119已抓取跳過
# 1213184已抓取跳過
# 1212107已抓取跳過
# 1213553已抓取跳過
# 1211681已抓取跳過
# 1213040已抓取跳過
# 1212071已抓取跳過
# 1213763已抓取跳過
# 1211645已抓取跳過
# 1211321已抓取跳過
# 1100525已抓取跳過
# 1212131已抓取跳過
# 1212398已抓取跳過
# 1212569已抓取跳過
# 1213052已抓取跳過
# 1211996已抓取跳過
# 1213877已抓取跳過
# 1211066已抓取跳過
# 1212935已抓取跳過
# 1211786已抓取跳過
# 1212179已抓取跳過
# 1211651已抓取跳過
# 1215554已抓取跳過
# 1126100已抓取跳過
# 1216148已抓取跳過
# 1215920已抓取跳過
# 1214834已抓取跳過
# 1216901已抓取跳過
# 1213625已抓取跳過
# 1216262已抓取跳過
# 1204049已抓取跳過
# 1214489已抓取跳過
# 1217153已抓取跳過
# 1214357已抓取跳過
# 1127906已抓取跳過
# 1216811已抓取跳過
# 1215881已抓取跳過
# 1216316已抓取跳過
# 1216889已抓取跳過
# 1216829已抓取跳過
# 1217021已抓取跳過
# 1215170已抓取跳過
# 1215887已抓取跳過
# 1215998已抓取跳過
# 1216634已抓取跳過
# 1215101已抓取跳過
# 1214441已抓取跳過
# 1211570已抓取跳過
# 1216787已抓取跳過
# 1215668已抓取跳過
# 1215590已抓取跳過
# 1215857已抓取跳過
# 1215641已抓取跳過
# 1215740已抓取跳過
# 1215326已抓取跳過
# 1214471已抓取跳過
# 1214870已抓取跳過
# 1216646已抓取跳過
# 1208627已抓取跳過
# 1215782已抓取跳過
# 1214351已抓取跳過
# 1215908已抓取跳過
# 1216415已抓取跳過
# 1215770已抓取跳過
# 1214483已抓取跳過
# 1214345已抓取跳過
# 1214591已抓取跳過
# 1215470已抓取跳過
# 1213985已抓取跳過
# 1215416已抓取跳過
# 1216610已抓取跳過
# 1215560已抓取跳過
# 1216268已抓取跳過
# 1215338已抓取跳過
# 1215644已抓取跳過
# 1217249已抓取跳過
# 1208075已抓取跳過
# 1216784已抓取跳過
# 1211780已抓取跳過
# 1214399已抓取跳過
# 1215152已抓取跳過
# 1215752已抓取跳過
# 1215776已抓取跳過
# 1215011已抓取跳過
# 1214798已抓取跳過
# 1215743已抓取跳過
# 1215827已抓取跳過
# 1216226已抓取跳過
# 1094012已抓取跳過
# 1214672已抓取跳過
# 1216037已抓取跳過
# 1215629已抓取跳過
# 1216142已抓取跳過
# 1216031已抓取跳過
# 1215125已抓取跳過
# 1163498已抓取跳過
# 1216040已抓取跳過
# 1215803已抓取跳過
# 1167554已抓取跳過
# 1215833已抓取跳過
# 1214618已抓取跳過
# 1215107已抓取跳過
# 1215791已抓取跳過
# 1214648已抓取跳過
# 1215662已抓取跳過
# 1215815已抓取跳過
# 1215986已抓取跳過
# 1216601已抓取跳過
# 1214786已抓取跳過
# 1215839已抓取跳過
# 1216670已抓取跳過
# 1205858已抓取跳過
# 1216532已抓取跳過
# 1082594已抓取跳過
# 1215617已抓取跳過
# 1214822已抓取跳過
# 1215737已抓取跳過
# 1214417已抓取跳過
# 1215692已抓取跳過
# 1214642已抓取跳過
# 1215071已抓取跳過
# 1214321已抓取跳過
# 1204082已抓取跳過
# 1214447已抓取跳過
# 1216373已抓取跳過
# 1217429已抓取跳過
# 1214858已抓取跳過
# 1216577已抓取跳過
# 1214924已抓取跳過
# 1216616已抓取跳過
# 1215992已抓取跳過
# 1214561已抓取跳過
# 1215764已抓取跳過
# 1217039已抓取跳過
# 1206941已抓取跳過
# 1214930已抓取跳過
# 1215146已抓取跳過
# 1215584已抓取跳過
# 1215794已抓取跳過
# 1214597已抓取跳過
# 1214978已抓取跳過
# 1215224已抓取跳過
# 1215008已抓取跳過
# 1216331已抓取跳過
# 1216250已抓取跳過
# 1215716已抓取跳過
# 1214567已抓取跳過
# 1214954已抓取跳過
# 1214732已抓取跳過
# 1171157已抓取跳過
# 1216997已抓取跳過
# 1215809已抓取跳過
# 1211594已抓取跳過
# 1216130已抓取跳過
# 1216466已抓取跳過
# 1215248已抓取跳過
# 1215017已抓取跳過
# 1214585已抓取跳過
# 1216508已抓取跳過
# 1214453已抓取跳過
# 1145852已抓取跳過
# 1214840已抓取跳過
# 1215302已抓取跳過
# 1215731已抓取跳過
# 1216304已抓取跳過
# 1215680已抓取跳過
# 1215710已抓取跳過
# 1216385已抓取跳過
# 1217123已抓取跳過
# 1216772已抓取跳過
# 1217423已抓取跳過
# 1214303已抓取跳過
# 1215950已抓取跳過
# 1202522已抓取跳過
# 1215788已抓取跳過
# 1217393已抓取跳過
# 1088261已抓取跳過
# 1214678已抓取跳過
# 1214852已抓取跳過
# 1159787已抓取跳過
# 1215464已抓取跳過
# 1215119已抓取跳過
# 1210697已抓取跳過
# 1214780已抓取跳過
# 1215650已抓取跳過
# 1217405已抓取跳過
# 1216025已抓取跳過
# 1214696已抓取跳過
# 1215506已抓取跳過
# 1216007已抓取跳過
# 1216502已抓取跳過
# 1215980已抓取跳過
# 1094000已抓取跳過
# 1214513已抓取跳過
# 1216397已抓取跳過
# 1078438已抓取跳過
# 1215686已抓取跳過
# 1215404已抓取跳過
# 1216391已抓取跳過
# 1093988已抓取跳過
# 1215722已抓取跳過
# 1214762已抓取跳過
# 1215758已抓取跳過
# 1215821已抓取跳過
# 1216298已抓取跳過
# 1214948已抓取跳過
# 1215698已抓取跳過
# 1215452已抓取跳過
# 1214792已抓取跳過
# 1214339已抓取跳過
# 1214171已抓取跳過
# 1215230已抓取跳過
# 1215254已抓取跳過
# 1216979已抓取跳過
# 1215512已抓取跳過
# 1215674已抓取跳過
# 1094018已抓取跳過
# 1215623已抓取跳過
# 1214543已抓取跳過
# 1215182已抓取跳過
# 1152704已抓取跳過
# 1215704已抓取跳過
# 1216004已抓取跳過
# 1216550已抓取跳過
# 1214477已抓取跳過
# 1214804已抓取跳過
# 1216124已抓取跳過
# 1215053已抓取跳過
# 1214690已抓取跳過
# 1215728已抓取跳過
# 1215440已抓取跳過
# 1215749已抓取跳過
# 1215260已抓取跳過
# 1216460已抓取跳過
# 1216562已抓取跳過
# 1217279已抓取跳過
# 1215548已抓取跳過
# 1215656已抓取跳過
# 1215611已抓取跳過
# 1093994已抓取跳過
# 1216724已抓取跳過
# 1214501已抓取跳過
# 1214411已抓取跳過
# 1216484已抓取跳過
# 1214750已抓取跳過
# 1214507已抓取跳過
# 1216583已抓取跳過
# 1219046已抓取跳過
# 1219604已抓取跳過
# 1217069已抓取跳過
# 1219865已抓取跳過
# 1220573已抓取跳過
# 1219487已抓取跳過
# 1218797已抓取跳過
# 1220264已抓取跳過
# 1219880已抓取跳過
# 1219976已抓取跳過
# 1154309已抓取跳過
# 1220012已抓取跳過
# 1219643已抓取跳過
# 1218293已抓取跳過
# 1217552已抓取跳過
# 1217567已抓取跳過
# 1219751已抓取跳過
# 1217561已抓取跳過
# 1217801已抓取跳過
# 1218752已抓取跳過
# 1219610已抓取跳過
# 1219544已抓取跳過
# 1219868已抓取跳過
# 1220261已抓取跳過
# 1220639已抓取跳過
# 1220591已抓取跳過
# 1212977已抓取跳過
# 1218050已抓取跳過
# 1220171已抓取跳過
# 1218149已抓取跳過
# 1217741已抓取跳過
# 1211687已抓取跳過
# 1219463已抓取跳過
# 1220234已抓取跳過
# 1218143已抓取跳過
# 1218104已抓取跳過
# 1219145已抓取跳過
# 1217705已抓取跳過
# 1220270已抓取跳過
# 1217609已抓取跳過
# 1219853已抓取跳過
# 1219106已抓取跳過
# 1217852已抓取跳過
# 1220390已抓取跳過
# 1217735已抓取跳過
# 1218026已抓取跳過
# 1219241已抓取跳過
# 1219277已抓取跳過
# 1219175已抓取跳過
# 1219829已抓取跳過
# 1220042已抓取跳過
# 1220450已抓取跳過
# 1220456已抓取跳過
# 1218434已抓取跳過
# 1218875已抓取跳過
# 1217231已抓取跳過
# 1220288已抓取跳過
# 1218335已抓取跳過
# 1219253已抓取跳過
# 1219331已抓取跳過
# 1220603已抓取跳過
# 1220360已抓取跳過
# 1218518已抓取跳過
# 1220087已抓取跳過
# 1217027已抓取跳過
# 1219727已抓取跳過
# 1220105已抓取跳過
# 1217930已抓取跳過
# 1220246已抓取跳過
# 1220633已抓取跳過
# 1220414已抓取跳過
# 1219838已抓取跳過
# 1218458已抓取跳過
# 1217972已抓取跳過
# 1217924已抓取跳過
# 1218263已抓取跳過
# 1220330已抓取跳過
# 1217441已抓取跳過
# 1218452已抓取跳過
# 1217471已抓取跳過
# 1219934已抓取跳過
# 1220195已抓取跳過
# 1214966已抓取跳過
# 1218287已抓取跳過
# 1219478已抓取跳過
# 1217825已抓取跳過
# 1219691已抓取跳過
# 1220621已抓取跳過
# 1218161已抓取跳過
# 1217090已抓取跳過
# 1217675已抓取跳過
# 1219319已抓取跳過
# 1219388已抓取跳過
# 1219892已抓取跳過
# 1219118已抓取跳過
# 1219970已抓取跳過
# 1217777已抓取跳過
# 1219445已抓取跳過
# 1220231已抓取跳過
# 1218809已抓取跳過
# 1219211已抓取跳過
# 1218305已抓取跳過
# 1158704已抓取跳過
# 1217834已抓取跳過
# 1217789已抓取跳過
# 1218086已抓取跳過
# 1219424已抓取跳過
# 1220522已抓取跳過
# 1217273已抓取跳過
# 1219556已抓取跳過
# 1220420已抓取跳過
# 1219799已抓取跳過
# 1220318已抓取跳過
# 1219430已抓取跳過
# 1220714已抓取跳過
# 1219409已抓取跳過
# 1217645已抓取跳過
# 1220030已抓取跳過
# 1219460已抓取跳過
# 1219592已抓取跳過
# 1220306已抓取跳過
# 1218299已抓取跳過
# 1218416已抓取跳過
# 1219739已抓取跳過
# 1219922已抓取跳過
# 1217585已抓取跳過
# 1216856已抓取跳過
# 1218209已抓取跳過
# 1218038已抓取跳過
# 1219433已抓取跳過
# 1220153已抓取跳過
# 1217876已抓取跳過
# 1218362已抓取跳過
# 1217573已抓取跳過
# 1219451已抓取跳過
# 1219679已抓取跳過
# 1220213已抓取跳過
# 1218785已抓取跳過
# 1219076已抓取跳過
# 1219484已抓取跳過
# 1217795已抓取跳過
# 1219640已抓取跳過
# 1219400已抓取跳過
# 1218590已抓取跳過
# 1216862已抓取跳過
# 1088057已抓取跳過
# 1219283已抓取跳過
# 1217303已抓取跳過
# 1168058已抓取跳過
# 1218815已抓取跳過
# 1220468已抓取跳過
# 1217546已抓取跳過
# 1218185已抓取跳過
# 1218536已抓取跳過
# 1219187已抓取跳過
# 1219358已抓取跳過
# 1219511已抓取跳過
# 1220081已抓取跳過
# 1218593已抓取跳過
# 1220189已抓取跳過
# 1220474已抓取跳過
# 1134281已抓取跳過
# 1218239已抓取跳過
# 1217894已抓取跳過
# 1217990已抓取跳過
# 1217984已抓取跳過
# 1219412已抓取跳過
# 1220282已抓取跳過
# 1219259已抓取跳過
# 1220255已抓取跳過
# 1220240已抓取跳過
# 1217417已抓取跳過
# 1218821已抓取跳過
# 1219454已抓取跳過
# 1218056已抓取跳過
# 1217711已抓取跳過
# 1219538已抓取跳過
# 1217498已抓取跳過
# 1220528已抓取跳過
# 1218080已抓取跳過
# 1217807已抓取跳過
# 1219472已抓取跳過
# 1181222已抓取跳過
# 1220225已抓取跳過
# 1217621已抓取跳過
# 1218245已抓取跳過
# 1217603已抓取跳過
# 1219346已抓取跳過
# 1087217已抓取跳過
# 1219469已抓取跳過
# 1218677已抓取跳過
# 1220048已抓取跳過
# 1220147已抓取跳過
# 1210397已抓取跳過
# 1218092已抓取跳過
# 1220651已抓取跳過
# 1217828已抓取跳過
# 1196528已抓取跳過
# 1220366已抓取跳過
# 1217996已抓取跳過
# 1166090已抓取跳過
# 1217528已抓取跳過
# 1219787已抓取跳過
# 1217954已抓取跳過
# 1092614已抓取跳過
# 1220111已抓取跳過
# 1220627已抓取跳過
# 1217504已抓取跳過
# 1219661已抓取跳過
# 1217717已抓取跳過
# 1220342已抓取跳過
# 1093211已抓取跳過
# 1220312已抓取跳過
# 1210343已抓取跳過
# 1219568已抓取跳過
# 1220276已抓取跳過
# 1218233已抓取跳過
# 1220300已抓取跳過
# 1218062已抓取跳過
# 1219499已抓取跳過
# 1220294已抓取跳過
# 1210136已抓取跳過
# 1192193已抓取跳過
# 1218446已抓取跳過
# 1195943已抓取跳過
# 1222040已抓取跳過
# 1128353已抓取跳過
# 1223648已抓取跳過
# 1220561已抓取跳過
# 1222658已抓取跳過
# 1221086已抓取跳過
# 1224155已抓取跳過
# 1220516已抓取跳過
# 1143236已抓取跳過
# 1205246已抓取跳過
# 1221419已抓取跳過
# 1221200已抓取跳過
# 1219598已抓取跳過
# 1221353已抓取跳過
# 1224149已抓取跳過
# 1154351已抓取跳過
# 1213244已抓取跳過
# 1223255已抓取跳過
# 1095383已抓取跳過
# 1222364已抓取跳過
# 1128341已抓取跳過
# 1223219已抓取跳過
# 1220993已抓取跳過
# 1222988已抓取跳過
# 1221011已抓取跳過
# 1190819已抓取跳過
# 1221122已抓取跳過
# 1223153已抓取跳過
# 1221767已抓取跳過
# 1221128已抓取跳過
# 1221824已抓取跳過
# 1224029已抓取跳過
# 1222538已抓取跳過
# 1223573已抓取跳過
# 1222220已抓取跳過
# 1220981已抓取跳過
# 1222868已抓取跳過
# 1221503已抓取跳過
# 1223855已抓取跳過
# 1222154已抓取跳過
# 1220801已抓取跳過
# 1213757已抓取跳過
# 1224212已抓取跳過
# 1224143已抓取跳過
# 1221656已抓取跳過
# 1223012已抓取跳過
# 1215350已抓取跳過
# 1223408已抓取跳過
# 1221575已抓取跳過
# 1221884已抓取跳過
# 1218257已抓取跳過
# 1221005已抓取跳過
# 1223849已抓取跳過
# 1127900已抓取跳過
# 1222853已抓取跳過
# 1224200已抓取跳過
# 1223714已抓取跳過
# 1216778已抓取跳過
# 1221662已抓取跳過
# 1222478已抓取跳過
# 1221179已抓取跳過
# 1223702已抓取跳過
# 1223243已抓取跳過
# 1223120已抓取跳過
# 1222982已抓取跳過
# 1151153已抓取跳過
# 1223666，該頁已死
# 1209368已抓取跳過
# 1224242已抓取跳過
# 1224035已抓取跳過
# 1223531已抓取跳過
# 1223123已抓取跳過
# 1220552已抓取跳過
# 1221581已抓取跳過
# 1221611已抓取跳過
# 1107110已抓取跳過
# 1221896已抓取跳過
# 1222952已抓取跳過
# 1224182已抓取跳過
# 1222769已抓取跳過
# 1075286已抓取跳過
# 1222994已抓取跳過
# 1220951已抓取跳過
# 1094564已抓取跳過
# 1224188已抓取跳過
# 1223207已抓取跳過
# 1223138已抓取跳過
# 1224161已抓取跳過
# 1223498已抓取跳過
# 1221839已抓取跳過
# 1222946已抓取跳過
# 1222910已抓取跳過
# 1222646已抓取跳過
# 1222628已抓取跳過
# 1209119已抓取跳過
# 1220843已抓取跳過
# 1222865已抓取跳過
# 1222616已抓取跳過
# 1095692已抓取跳過
# 1192124已抓取跳過
# 1222412已抓取跳過
# 1223939已抓取跳過
# 1223225已抓取跳過
# 1221050已抓取跳過
# 1221062已抓取跳過
# 1088891已抓取跳過
# 1222835已抓取跳過
# 1222904已抓取跳過
# 1220915已抓取跳過
# 1223525已抓取跳過
# 1220927已抓取跳過
# 1222046已抓取跳過
# 1221869已抓取跳過
# 1222940已抓取跳過
# 1220921已抓取跳過
# 1224059已抓取跳過
# 1222886已抓取跳過
# 1222580已抓取跳過
# 1222358已抓取跳過
# 1142180已抓取跳過
# 1223678已抓取跳過
# 1223630已抓取跳過
# 1223867已抓取跳過
# 1223519已抓取跳過
# 1223708已抓取跳過
# 1222448已抓取跳過
# 1221068已抓取跳過
# 1223108已抓取跳過
# 1223273已抓取跳過
# 1223351已抓取跳過
# 1220879已抓取跳過
# 1222214已抓取跳過
# 1223561
# 1223396
# 1221509
# 1198970
# 1219364
# 1224011
# 1223873
# 1222058
# 1221779
# 1128347
# 1221734
# 1221914
# 1219715
# 1223180
# 1221890
# 1218251
# 1223018
# 1220486
# 1223444
# 目前有89526筆資料
# 1220891
# 1223654
# 1221401
# 1223843
# 1221248
# 1222640
# 1218368
# 1220945
# 1222964
# 1220807
# 1223450
# 1221035
# 1222226
# 1223156
# 1207379
# 1223342
# 1222160
# 1222757
# 1223744
# 1221413
# 目前有89546筆資料
# 1222418
# 1223324
# 1223369
# 1073304
# 1222859
# 1221098
# 1221443
# 1222166
# 1223129
# 1220933
# 1221809
# 1092824
# 1214435
# 1221074
# 1222682
# 1222532
# 1224041
# 1224245
# 1221569
# 1221134
# 目前有89566筆資料
# 1092620
# 1223375
# 1221218
# 1079696
# 1221650
# 1214555
# 1223267
# 1096550
# 1129124
# 1221056
# 1223606
# 1223696
# 1224053
# 1224236
# 1220663
# 1223195
# 1220855
# 1221029
# 1221224
# 1221563
# 目前有89586筆資料
# 1224065
# 1221431
# 1224017
# 1223132
# 1221497
# 1221785
# 1223363
# 1194770
# 1223636
# 1223336
# 1222823
# 1221629
# 1221041
# 1224500
# 1226267
# 1225232
# 1225967
# 1226096
# 1225841
# 1225508
# 目前有89606筆資料
# 1224917
# 1226462
# 1226369
# 1224575
# 1226564
# 1224869
# 1226474
# 1225532
# 1226285
# 1219016
# 1225184
# 1195337
# 1226510
# 1225136
# 1225130
# 1225148
# 1224653
# 1219022
# 1223672
# 1219010
# 目前有89626筆資料
# 1226894
# 1226975
# 1224812
# 1226858
# 1224452
# 1225160
# 1226126
# 1226990
# 1218965
# 1224536
# 1226273
# 1225859
# 1226912
# 1224257
# 1225082
# 1224836
# 1225106
# 1093154
# 1226576
# 1219343
# 目前有89646筆資料
# 1226516
# 1225604
# 1224554
# 1097369
# 1226411
# 1128221
# 1219295
# 1224911
# 1191767
# 1224893
# 1226186
# 1219034
# 1224596
# 1225487
# 1225481
# 1219403
# 1225706
# 1219376
# 1219004
# 1224632
# 目前有89666筆資料
# 1219370
# 1109921
# 1092632
# 1224947
# 1219439
# 1114859
# 1101515
# 1226702
# 1225568
# 1225931
# 1225943
# 1088075
# 1226198
# 1219337
# 1225424
# 1219394
# 1219301
# 1226768
# 1225811
# 1219028
# 目前有89686筆資料
# 1224677
# 1224383
# 1224386
# 1225412
# 1226321
# 1225949
# 1226876
# 1224365
# 1224422
# 1225142
# 1224899
# 1225334
# 1225817
# 1225682
# 1225268
# 1225469
# 1213136
# 1225070
# 1225628
# 1226249
# 目前有89706筆資料
# 1225442
# 1226309
# 1226864
# 1225196
# 1226339
# 1224047
# 1225406
# 1225736
# 1226762
# 1226174
# 1225208
# 1224824
# 1225925
# 1226393
# 1219418
# 1219307
# 1224683
# 1224458
# 1094084
# 1180268
# 目前有89726筆資料
# 1226996
# 1225865
# 1226150
# 1226192
# 1226003
# 1226678
# 1226819
# 1225292
# 1226009
# 1225634
# 1226432
# 1224905
# 1225559
# 1224929
# 1224746
# 1104011
# 1224923
# 1224998
# 1226114
# 1224464
# 目前有89746筆資料
# 1226756
# 1218983
# 1227014
# 1225352
# 1224506
# 1226315
# 1225550
# 1225919
# 1225877
# 1226075
# 1218995
# 1093193
# 1224638
# 1225226
# 1224524
# 1225346
# 1218989
# 1226180
# 1219352
# 1226777
# 目前有89766筆資料
# 1225112
# 1225370
# 1216823
# 1224776
# 1224392
# 1225748
# 1226696
# 1226570
# 1224287
# 1227056
# 1225310
# 1225316
# 1223000
# 1226588
# 1219382
# 1186643
# 1224476
# 1226120
# 1225190
# 1225280
# 目前有89786筆資料
# 1226087
# 1220897
# 1226684
# 1174766
# 1226039
# 1218977
# 1219313
# 1225823
# 1224671
# 1226327
# 1219001
# 1225262
# 1226720
# 1097135
# 1224644
# 1225835
# 1219040
# 1225028
# 1224341
# 1224689
# 目前有89806筆資料
# 1224560
# 1226363
# 1224470
# 1226051
# 1224887
# 1225154
# 1224377
# 1140638
# 1221617
# 1226801
# 1101674
# 1088981
# 1226969
# 1227026
# 1225076
# 1214237
# 1225670
# 1226255
# 1228220
# 1227842
# 目前有89826筆資料
# 1229096
# 1228934
# 1227770
# 1229186
# 1229528
# 1092965
# 1228667
# 1229810
# 1228862
# 1228931
# 1229450
# 1228892
# 1229264
# 1229855
# 1227917
# 1226726
# 1227899
# 1127288
# 1229120
# 1227854
# 目前有89846筆資料
# 1229288
# 1228007
# 1228706
# 1229060
# 1227335
# 1218392
# 1228178
# 1227677
# 1228334
# 1228922
# 1227233
# 1227602
# 1229921
# 1226744
# 1227953
# 1229156
# 1206053
# 1156946
# 1212773
# 1092656
# 目前有89866筆資料
# 1228886
# 1156079
# 1229012
# 1227563
# 1227764
# 1229042
# 1198736
# 1226843
# 1227293
# 1229891
# 1229114
# 1228718
# 1229897
# 1191383
# 1228082
# 1229924
# 1228898
# 1106048
# 1227716
# 1227341
# 目前有89886筆資料
# 1228946
# 1227275
# 1229210
# 1229483
# 1227695
# 1228712
# 1228244
# 1229318
# 1228553
# 1229039
# 1229087
# 1226387
# 1227431
# 1228916
# 1229258
# 1229819
# 1227887
# 1229066
# 1229828
# 1229330
# 目前有89906筆資料
# 1227836
# 1229126
# 1229903
# 1227593
# 1227905
# 1228814
# 1228274
# 1228580
# 1229804
# 1227146
# 1229390
# 1229522
# 1229093
# 1227245
# 1228820
# 1227881
# 1228772
# 1228988
# 1229222
# 1227122
# 目前有89926筆資料
# 1078780
# 1104659
# 1228979
# 1222466
# 1227632
# 1227575
# 1229813
# 1229294
# 1179101
# 1227866
# 1227860
# 1228955
# 1229057
# 1227911
# 1227818
# 1228340
# 1227923
# 1227683
# 1228208
# 1229027
# 目前有89946筆資料
# 1229558
# 1228874
# 1229015
# 1229837
# 1227407
# 1229150
# 1227104
# 1229006
# 1228136
# 1227179
# 1175507
# 1229879
# 1227560
# 1228901
# 1228700
# 1229090
# 1217225
# 1227269
# 1229843
# 1228967
# 目前有89966筆資料
# 1228352
# 1228940
# 1229900
# 1229021
# 1229000
# 1227323
# 1228928
# 1229216
# 1228406
# 1227185
# 1227365
# 1227554
# 1228202
# 1229324
# 1227488
# 1227251
# 1229072
# 1228436
# 1227080
# 1227878
# 目前有89986筆資料
# 1229861
# 1227110
# 1226456
# 1228880
# 1228238
# 1228907
# 1227074
# 1104986
# 1229909
# 1227068
# 1228418
# 1227965
# 1227299
# 1228442
# 1227620
# 1228019
# 1229033
# 1227848
# 1229912
# 1229081
# 目前有90006筆資料
# 1229831
# 1228910
# 1229102
# 1229873
# 1228796
# 1228100
# 1228430
# 1227062
# 1227086
# 1229540
# 1227989
# 1197281
# 1226528
# 1229075
# 1204793
# 1229822
# 1228997
# 1228364
# 1227893
# 1228985
# 目前有90026筆資料
# 1229051
# 1229885
# 1227872
# 1228448
# 1228070
# 1227650
# 1227728
# 1227257
# 1227614
# 1229930
# 1229384
# 1211558
# 1229849
# 1229867
# 1228961
# 1228058
# 1228973
# 1228304
# 1229915
# 1228952
# 目前有90046筆資料
# 1227530
# 1190432
# 1225646
# 1231115
# 1197152
# 1204256
# 1231970
# 1176992
# 1229792
# 1231199
# 1230347
# 1230809
# 1230935
# 1230407
# 1094993
# 1232144
# 1232150
# 1097288
# 1175963
# 1229765
# 目前有90066筆資料
# 1229723
# 1184861
# 1231613
# 1172930
# 1229738
# 1231736
# 1230923
# 1110446
# 1201475
# 1090376
# 1231850
# 1171586
# 1166591
# 1229708
# 1231946
# 1230533
# 1229138
# 1229717
# 1229780
# 1162253
# 目前有90086筆資料
# 1228064
# 1162163
# 1185416
# 1231079
# 1099523
# 1232036
# 1122962
# 1229744
# 1229456
# 1230437
# 1231412
# 1196762
# 1229642
# 1230575
# 1232042
# 1229969
# 1229600
# 1230413
# 1231109
# 1229678
# 目前有90106筆資料
# 1229774
# 1231391
# 1176974
# 1231514
# 1231994
# 1230605
# 1231496
# 1229276
# 1229702
# 1229960
# 1230104
# 1231430
# 1231634
# 1221641
# 1162091
# 1228466
# 1229732
# 1162493
# 1230377
# 1230014
# 目前有90126筆資料
# 1229966
# 1231289
# 1231646
# 1230941
# 1225166
# 1109102
# 1106258
# 1229948
# 1155617
# 1231229
# 1229705
# 1229726
# 1228052
# 1230863
# 1230134
# 1231103
# 1230449
# 1188131
# 1191740
# 1230509
# 目前有90146筆資料
# 1230443
# 1232060
# 1225214
# 1231193
# 1187597
# 1230467
# 1227020
# 1229777
# 1229696
# 1230734
# 1229771
# 1229786
# 1166861
# 1229666
# 1229954
# 1229984
# 1230791
# 1231664
# 1184165
# 1229660
# 目前有90166筆資料
# 1229750
# 1230002
# 1229942
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-a6cb28ec8a46> in <module>()
#      81
#      82             diendata["_id"]=int(i)#id
# ---> 83             diendata["name"]=info.find('span', attrs={'itemprop': 'name'}).text.replace('"',"")
#      84             try:
#      85                 diendata['othername']=re.findall("\((\w*[店|館|門市|百貨|街|夜市|商場|時代|廣場|中心|三越|大學|中|區|高鐵])\)",diendata['name'])[0]
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
client = pymongo.MongoClient('localhost', 27017)
#連DB名
db=client['rawData']
#秀DB內的collection list
print(db.collection_names())

collectionInfo = db.ipeenInfo
ipeenInfo=list(collectionInfo.find({}))
# Out:
# ['ipeenWebsite', 'Nhumnan', 'ipeenInfo', 'addressCoordinate', 'HRdata104', 'CostPower', 'Nhuman', 'sample']

# %%
bs(res.text,"lxml")
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 8]><html class="no-js ie7" lang="zh-tw"><![endif]--><!--[if IE 8]><html class="no-js ie8" lang="zh-tw"><![endif]--><!--[if IE 9]><html class="no-js ie9" lang="zh-tw"><![endif]--><!--[if IE 10]><html class="no-js ie10" lang="zh-tw"><![endif]--><!--[if gt IE 10]><!--><html class="no-js" lang="zh-tw"><!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="zh-Hant-TW" http-equiv="content-language"/>
# <title>iPeen 愛評網-美食、旅遊、電影、美妝...最豐富的生活休閒消費情報集散地</title>
# <meta content="180154523139" property="fb:pages"/>
# <link href="/sass/bower_components/mdi/css/materialdesignicons.min.css" rel="stylesheet"/>
# <meta content="app-id=366479443" name="apple-itunes-app"/>
# <link href="/css/frame/frame.css?update=201412261631" rel="stylesheet"/>
# <link href="/css/v2/404.css" rel="stylesheet"/>
# <!--[if lt IE 9]>
# 	<script src="/js/ie8/html5shiv.js"></script>
# 	<script src="/js/ie8/respond.min.js"></script>
# 	<![endif]-->
# <script type="text/javascript">
# 		var googletag = googletag || {};
# 		googletag.cmd = googletag.cmd || [];
# 		(function() {
# 			var gads = document.createElement('script');
# 			gads.async = true;
# 			gads.type = 'text/javascript';
# 			var useSSL = 'https:' == document.location.protocol;
# 			gads.src = (useSSL ? 'https:' : 'http:') +
# 			'//www.googletagservices.com/tag/js/gpt.js';
# 			var node = document.getElementsByTagName('script')[0];
# 			node.parentNode.insertBefore(gads, node);
# 		})();
# 	</script>
# <script type="text/javascript">
# 	googletag.cmd.push(function() {
# 		googletag.defineSlot('/65829459/web_comment_970*500//250', [[970, 250], [970, 500]], 'div-gpt-ad-1492153122901-0').addService(googletag.pubads());
# 		googletag.pubads().enableSingleRequest();
# 		googletag.pubads().collapseEmptyDivs(true,true);
# 		googletag.enableServices();
# 	});
# </script>
# <script type="text/javascript">
# googletag.cmd.push(function() {
# googletag.defineSlot('/65829459/Web_all_diamond-title_left_1200', [250, 22], 'div-gpt-ad-1383290806662-0').addService(googletag.pubads());
# googletag.pubads().enableSingleRequest();
# googletag.enableServices();
# });
# </script>
# <script type="text/javascript">
# googletag.cmd.push(function() {
# googletag.defineSlot('/65829459/Web_all_diamond-title_middle-left_1200', [250, 22], 'div-gpt-ad-1383291166432-0').addService(googletag.pubads());
# googletag.pubads().enableSingleRequest();
# googletag.enableServices();
# });
# </script>
# <script type="text/javascript">
# googletag.cmd.push(function() {
# googletag.defineSlot('/65829459/Web_all_diamond-title_middle-right_1200', [250, 22], 'div-gpt-ad-1383291190522-0').addService(googletag.pubads());
# googletag.pubads().enableSingleRequest();
# googletag.enableServices();
# });
# </script>
# <script type="text/javascript">
# googletag.cmd.push(function() {
# googletag.defineSlot('/65829459/Web_all_diamond-title_right_1200', [250, 22], 'div-gpt-ad-1383291215171-0').addService(googletag.pubads());
# googletag.pubads().enableSingleRequest();
# googletag.enableServices();
# });
# </script>
# <script type="text/javascript">
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];
# a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# ga('create', 'UA-2241395-2');
# ga('require', 'displayfeatures');
# ga('send', 'pageview');
# </script>
# <script src="//d17m68fovwmgxj.cloudfront.net/js/appier-track-v1.7.js"></script>
# <!-- Begin comScore Tag -->
# <script>
# 	  var _comscore = _comscore || [];
# 	  _comscore.push({ c1: "2", c2: "18271341" });
# 	  (function() {
# 	    var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
# 	    s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
# 	    el.parentNode.insertBefore(s, el);
# 	  })();
# 	</script>
# <noscript>
# <img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=18271341&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <!-- End comScore Tag -->
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <!-- Begin google Tag -->
# <script>
# 	  var googletag = googletag || {};
# 	  googletag.cmd = googletag.cmd || [];
# 	</script>
# <script>
# 	  googletag.cmd.push(function() {
# 	    googletag.defineSlot('/65829459/web_index_left_responsive_728x90', [728, 90], 'div-gpt-ad-1477652809977-0').addService(googletag.pubads());
# 	    googletag.pubads().enableSingleRequest();
# 	    googletag.enableServices();
# 	  });
# 	</script>
# <!-- End google Tag -->
# <!--Begin Tenmax KianGi-->
# <!--End Tenmax KianGi-->
# </head>
# <body class="no-vip">
# <div id="wrap">
# <header data-block="main" id="header" role="banner">
# <div class="top-header">
# <div class="layout-wrapper">
# <div class="ui-select" id="region">
# <a href="#">生活圈：<span class="i">全台灣</span></a>
# <div>
# <ul class="area hide">
# <li>
# <strong>
# <span>不限：</span>
# </strong>
# <ul class="city">
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="全台灣" data-lbsname="taiwan" href="/taiwan/">全台灣</a>
# </li>
# </ul>
# </li>
# <li>
# <strong>
# <span>北部：</span>
# </strong>
# <ul class="city">
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="基隆市" data-lbsname="keelung" href="/keelung/">基隆市</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="台北市" data-lbsname="taipei" href="/taipei/">台北市</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="新北市" data-lbsname="xinbei" href="/xinbei/">新北市</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="桃園市" data-lbsname="taoyuan" href="/taoyuan/">桃園市</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="新竹市" data-lbsname="hsinchu" href="/hsinchu/">新竹市</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="新竹縣" data-lbsname="hsinchucounty" href="/hsinchucounty/">新竹縣</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="苗栗縣" data-lbsname="miaoli" href="/miaoli/">苗栗縣</a>
# </li>
# </ul>
# </li>
# <li>
# <strong>
# <span>中部：</span>
# </strong>
# <ul class="city">
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="台中市" data-lbsname="taichung" href="/taichung/">台中市</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="南投縣" data-lbsname="nantou" href="/nantou/">南投縣</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="彰化縣" data-lbsname="changhua" href="/changhua/">彰化縣</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="雲林縣" data-lbsname="yunlin" href="/yunlin/">雲林縣</a>
# </li>
# </ul>
# </li>
# <li>
# <strong>
# <span>南部：</span>
# </strong>
# <ul class="city">
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="嘉義市" data-lbsname="chiayi" href="/chiayi/">嘉義市</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="嘉義縣" data-lbsname="chiayicounty" href="/chiayicounty/">嘉義縣</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="台南市" data-lbsname="tainan" href="/tainan/">台南市</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="高雄市" data-lbsname="kaohsiung" href="/kaohsiung/">高雄市</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="屏東縣" data-lbsname="pingtung" href="/pingtung/">屏東縣</a>
# </li>
# </ul>
# </li>
# <li>
# <strong>
# <span>東部：</span>
# </strong>
# <ul class="city">
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="宜蘭縣" data-lbsname="ilan" href="/ilan/">宜蘭縣</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="花蓮縣" data-lbsname="hualien" href="/hualien/">花蓮縣</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="台東縣" data-lbsname="taitung" href="/taitung/">台東縣</a>
# </li>
# </ul>
# </li>
# <li>
# <strong>
# <span>離島：</span>
# </strong>
# <ul class="city">
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="澎湖縣" data-lbsname="penghu" href="/penghu/">澎湖縣</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="連江縣" data-lbsname="lianjiang" href="/lianjiang/">連江縣</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="金門縣" data-lbsname="kinmen" href="/kinmen/">金門縣</a>
# </li>
# </ul>
# </li>
# <li>
# <strong>
# <span>其它：</span>
# </strong>
# <ul class="city">
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="台灣以外" data-lbsname="foreign" href="/foreign/">台灣以外</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="美國" data-lbsname="america" href="/america/">美國</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="加拿大" data-lbsname="canada" href="/canada/">加拿大</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="墨西哥" data-lbsname="mexico" href="/mexico/">墨西哥</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="義大利" data-lbsname="italy" href="/italy/">義大利</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="法國" data-lbsname="france" href="/france/">法國</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="德國" data-lbsname="germany" href="/germany/">德國</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="英國" data-lbsname="england" href="/england/">英國</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="俄羅斯" data-lbsname="russian" href="/russian/">俄羅斯</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="日本" data-lbsname="japan" href="/japan/">日本</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="韓國" data-lbsname="korea" href="/korea/">韓國</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="中國" data-lbsname="china" href="/china/">中國</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="香港" data-lbsname="hongkong" href="/hongkong/">香港</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="澳門" data-lbsname="macao" href="/macao/">澳門</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="泰國" data-lbsname="thailand" href="/thailand/">泰國</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="越南" data-lbsname="vietnam" href="/vietnam/">越南</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="新加坡" data-lbsname="singapore" href="/singapore/">新加坡</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="菲律賓" data-lbsname="philippines" href="/philippines/">菲律賓</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="印度" data-lbsname="india" href="/india/">印度</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="巴西" data-lbsname="brazil" href="/brazil/">巴西</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="澳洲" data-lbsname="australia" href="/australia/">澳洲</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="紐西蘭" data-lbsname="zealand" href="/zealand/">紐西蘭</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="捷克" data-lbsname="czech" href="/czech/">捷克</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="希臘" data-lbsname="greece" href="/greece/">希臘</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="印尼" data-lbsname="indonesia" href="/indonesia/">印尼</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="馬來西亞" data-lbsname="malaysia" href="/malaysia/">馬來西亞</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="南非" data-lbsname="southafrica" href="/southafrica/">南非</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="瑞士" data-lbsname="switzerland" href="/switzerland/">瑞士</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="緬甸" data-lbsname="myanmar" href="/myanmar/">緬甸</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="荷蘭" data-lbsname="netherlands" href="/netherlands/">荷蘭</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="西班牙" data-lbsname="spain" href="/spain/">西班牙</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="土耳其" data-lbsname="turkey" href="/turkey/">土耳其</a>
# </li>
# <li>
# <a class="ga_tracking" data-action="生活圈" data-category="New-header" data-label="其他" data-lbsname="others" href="/others/">其他</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="top-info"><a class="ga_tracking i" data-action="手機下載連結" data-category="New-header" data-label="手機下載連結" href="/service/service_app.php" target="_blank">下載愛評生活通</a></div>
# <ul data-block="headuser" id="user">
# <li><a class="ga_tracking" data-action="會員登入" data-category="New-header" data-key="13" data-label="會員登入" href="/login/?next=">會員登入</a></li>
# <li><a class="fb-login i ga_tracking" data-action="fb登入" data-category="New-header" data-label="fb登入" href="#"><i>Facebook</i>登入</a></li>
# <li><a class="yh-login i ga_tracking" data-action="yahoo登入" data-category="New-header" data-label="yahoo登入" href="/login/yahoo_auth.php?login=1&amp;next="><i>Yahoo!</i>登入</a></li>
# <li><a class="ga_tracking" data-action="合作商家登入" data-category="New-header" data-key="14" data-label="合作商家登入" href="/public/index.php?id=39785c5f3c535f93bf705c58b8e104ed">合作商家登入</a></li>
# <li><a class="ga_tracking" data-action="免費註冊" data-category="New-header" data-key="15" data-label="免費註冊" href="/register/">免費註冊</a></li>
# </ul>
# </div>
# </div> <div class="middle-header">
# <div class="layout-wrapper">
# <h2><a class="" data-key="34" href="/">iPeen 愛評網</a></h2>
# <h3 class="hide">吃好料更愛好生活</h3>
# <form action="/search/search_redirect.php" id="search" method="post" role="search">
# <div class="wrapper">
# <div class="type">
# <label class="" for="search-type">全部</label>
# <select id="search-type" name="d">
# <option data-placeholder="關鍵字 或 店名" value="100">全部</option>
# <option data-placeholder="關鍵字 或 店名" data-type="food" value="0">美食店家</option>
# <option data-placeholder="產品名稱，例如：乖乖" data-type="pfood" value="1">實體包裝食品</option>
# <option data-placeholder="產品名稱或品牌，例如：金口福" data-type="netbuy" value="14">網購包裝食品</option>
# <option data-placeholder="關鍵字 或 店名" data-type="inn" value="6">住宿</option>
# <option data-placeholder="關鍵字 或 店名" data-type="view" value="7">景點</option>
# <option data-placeholder="片名、演員或導演" data-type="mov" value="2">電影</option>
# <option data-placeholder="書名、作者或出版社" data-type="book" value="16">書籍</option>
# </select>
# </div>
# <div class="inputs">
# <input autocomplete="off" name="kw" placeholder="關鍵字 或 店名" type="text"/>
# <input name="adkw" placeholder="輸入地點" type="text"/>
# </div>
# </div>
# <input type="submit" value="搜尋"/>
# </form>
# <ul data-block="headbar" id="function">
# <li><a class="add-shop button header-red i ga_tracking" data-action="新增店家景點" data-category="New-header" data-key="0" data-label="新增店家景點" href="/addshop/addshop_search.php">新增店家 / 景點</a></li>
# <li><a class="add-cmmt button header-red i ga_tracking" data-action="發表分享文" data-category="New-header" data-key="1" data-label="發表分享文" href="/addcmm/addcmm_search.php">發表分享文</a></li>
# <!-- <li><a data-key="2" class="add-tour" href="/tour/step1.php">旅遊規劃</a></li> -->
# </ul>
# </div>
# </div><div class="bottom-header">
# <div class="layout-wrapper">
# <!-- -->
# <!-- <div id="query-nav" class="ui-select hoverable"> -->
# <!-- <a title="" href="#">試試 快速查找</a> -->
# <!-- <div>
#    <ul id="query-list" class="hide" style="position: absolute;">
#       <li class="tag first-tag"><span>依頻道搜尋</span></li>
#       <li data-submenu-id="cfood"><span id="food-row" class="i" href="#" title="美食">美食</span>
#         <div id="cfood" class="submenu hide">
#             <div class="container">
#           <dl>
#             <dd>餐廳風格</dd>
#             <dt><a target="_blank" href="/search/taiwan/000/1-0-25-42/" title="義式料理" class="ga_tracking" data-category="New-navigation" data-action="餐廳風格" data-label="義式料理">義式料理</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-2-0/" title="日式料理" class="ga_tracking" data-category="New-navigation" data-action="餐廳風格" data-label="日式料理">日式料理</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-27-0/" title="中式料理" class="ga_tracking" data-category="New-navigation" data-action="餐廳風格" data-label="中式料理">中式料理</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-27-27/" title="海鮮餐廳" class="ga_tracking" data-category="New-navigation" data-action="餐廳風格" data-label="海鮮餐廳">海鮮餐廳</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-25-0/" title="異國料理" class="ga_tracking" data-category="New-navigation" data-action="餐廳風格" data-label="異國料理">異國料理</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-4-44/" title="韓式料理" class="ga_tracking" data-category="New-navigation" data-action="餐廳風格" data-label="韓式料理">韓式料理</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-25-41/" title="美式料理" class="ga_tracking" data-category="New-navigation" data-action="餐廳風格" data-label="美式料理">美式料理</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-27-54/" title="粵菜/港式飲茶" class="ga_tracking" data-category="New-navigation" data-action="餐廳風格" data-label="粵菜/港式飲茶">粵菜/港式飲茶</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-27-52/" title="台菜餐廳" class="ga_tracking" data-category="New-navigation" data-action="餐廳風格" data-label="台菜餐廳">台菜餐廳</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-25-40/" title="法式料理" class="ga_tracking" data-category="New-navigation" data-action="餐廳風格" data-label="法式料理">法式料理</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-4-45/" title="泰式料理" class="ga_tracking" data-category="New-navigation" data-action="餐廳風格" data-label="泰式料理">泰式料理</a>
#                 <a target="_blank" href="/taiwan/channel/F" title="看更多餐廳風格" class="ga_tracking" data-category="New-navigation" data-action="餐廳風格" data-label="看更多">看更多</a>
#             </dt>
#           </dl>
#           <dl>
#             <dd>美食類型</dd>
#             <dt><a target="_blank" href="/search/taiwan/000/1-0-27-149/" title="熱炒/快炒" class="ga_tracking" data-category="New-navigation" data-action="美食類型" data-label="熱炒/快炒">熱炒/快炒</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-23-0/" title="主題特色餐廳" class="ga_tracking" data-category="New-navigation" data-action="美食類型" data-label="主題特色餐廳">主題特色餐廳</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-2-696/" title="生魚片/壽司專賣" class="ga_tracking" data-category="New-navigation" data-action="美食類型" data-label="生魚片/壽司專賣">生魚片/壽司專賣</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-21-0/" title="鍋類" class="ga_tracking" data-category="New-navigation" data-action="美食類型" data-label="鍋類">鍋類</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-17-0/" title="咖啡/簡餐/茶" class="ga_tracking" data-category="New-navigation" data-action="美食類型" data-label="咖啡/簡餐/茶">咖啡/簡餐/茶</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-127-0/" title="buffet自助餐" class="ga_tracking" data-category="New-navigation" data-action="美食類型" data-label="buffet自助餐">buffet自助餐</a>
#                 <a target="_blank" href="/search/all/000/1-14-50-0/" title="網購包裝食品" class="ga_tracking" data-category="New-navigation" data-action="美食類型" data-label="網購包裝食品">網購包裝食品</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-19-0/" title="燒烤類" class="ga_tracking" data-category="New-navigation" data-action="美食類型" data-label="燒烤類">燒烤類</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-126-0/" title="早餐" class="ga_tracking" data-category="New-navigation" data-action="美食類型" data-label="早餐">早餐</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-6-0/" title="素食" class="ga_tracking" data-category="New-navigation" data-action="美食類型" data-label="素食">素食</a>
#                 <a target="_blank" href="/search/all/000/1-14-50-0/" title="小吃" class="ga_tracking" data-category="New-navigation" data-action="美食類型" data-label="小吃">小吃</a>
#                 <a target="_blank" href="/taiwan/channel/F" title="看更多美食類型" class="ga_tracking" data-category="New-navigation" data-action="美食類型" data-label="看更多">看更多</a>
#             </dt>
#           </dl>
#           <dl>
#             <dd>用餐目的</dd>
#             <dt><a target="_blank" href="/search/taiwan/000/1-0-0-0/?purpose=2" title="友聚會" class="ga_tracking" data-category="New-navigation" data-action="用餐目的" data-label="朋友聚會">朋友聚會</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-0-0/?purpose=9" title="謝師宴" class="ga_tracking" data-category="New-navigation" data-action="用餐目的" data-label="謝師宴">謝師宴</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-0-0/?purpose=4" title="情侶約會" class="ga_tracking" data-category="New-navigation" data-action="用餐目的" data-label="情侶約會">情侶約會</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-0-0/?purpose=5" title="家庭聚會" class="ga_tracking" data-category="New-navigation" data-action="用餐目的" data-label="家庭聚會">家庭聚會</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-0-0/?purpose=7" title="生日聚會" class="ga_tracking" data-category="New-navigation" data-action="用餐目的" data-label="生日聚會">生日聚會</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-0-0/?purpose=11" title="尾牙" class="ga_tracking" data-category="New-navigation" data-action="用餐目的" data-label="尾牙">尾牙</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-0-0/?purpose=12" title="春酒" class="ga_tracking" data-category="New-navigation" data-action="用餐目的" data-label="春酒">春酒</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-0-0/?purpose=10" title="婚宴" class="ga_tracking" data-category="New-navigation" data-action="用餐目的" data-label="婚宴">婚宴</a>
#             </dt>
#           </dl>
#           <dl>
#             <dd>平均價位</dd>
#             <dt><a target="_blank" href="/search/taiwan/000/1-0-0-0/?ae=1" title="99元以下" class="ga_tracking" data-category="New-navigation" data-action="平均價位" data-label="99元以下">99元以下</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-0-0/?ae=2" title="100~299元" class="ga_tracking" data-category="New-navigation" data-action="平均價位" data-label="100~299元">100~299元</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-0-0/?ae=3" title="300~499元" class="ga_tracking" data-category="New-navigation" data-action="平均價位" data-label="300~499元">300~499元</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-0-0/?ae=4" title="500~699元" class="ga_tracking" data-category="New-navigation" data-action="平均價位" data-label="500~699元">500~699元</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-0-0/?ae=5" title="700~999元" class="ga_tracking" data-category="New-navigation" data-action="平均價位" data-label="700~999元">700~999元</a>
#                 <a target="_blank" href="/search/taiwan/000/1-0-0-0/?ae=6" title="1000元以上" class="ga_tracking" data-category="New-navigation" data-action="平均價位" data-label="1000元以上">1000元以上</a>
#             </dt>
#           </dl>
#           </div>
#         </div>
#       </li>
#       <li data-submenu-id="ctravel"><span id="travel-row" class="i" href="#" title="休閒旅遊">休閒旅遊</span>
#         <div id="ctravel" class="submenu hide">
#         <div class="container">
#           <dl>
#             <dd>住宿類型</dd>
#             <dt><a target="_blank" href="/search/taiwan/000/4-6-42-189/" title="星級飯店" class="ga_tracking" data-category="New-navigation" data-action="住宿類型" data-label="星級飯店">星級飯店</a>
#                 <a target="_blank" href="/search/taiwan/000/4-6-42-190/" title="商務旅館" class="ga_tracking" data-category="New-navigation" data-action="住宿類型" data-label="商務旅館">商務旅館</a>
#                 <a target="_blank" href="/search/taiwan/000/4-6-42-191/" title="一般飯店/旅館/旅社" class="ga_tracking" data-category="New-navigation" data-action="住宿類型" data-label="一般飯店/旅館/旅社">一般飯店/旅館/旅社</a>
#                 <a target="_blank" href="/search/taiwan/000/4-6-42-192/" title="青年會館" class="ga_tracking" data-category="New-navigation" data-action="住宿類型" data-label="青年會館">青年會館</a>
#                 <a target="_blank" href="/search/taiwan/000/4-6-12-193/" title="民宿" class="ga_tracking" data-category="New-navigation" data-action="住宿類型" data-label="民宿">民宿</a>
#                 <a target="_blank" href="/search/taiwan/000/4-6-12-76/" title="民宿" class="ga_tracking" data-category="New-navigation" data-action="住宿類型" data-label="別墅">別墅</a>
#                 <a target="_blank" href="/search/taiwan/000/4-6-12-77/" title="景觀飯店" class="ga_tracking" data-category="New-navigation" data-action="住宿類型" data-label="景觀飯店">景觀飯店</a>
#                 <a target="_blank" href="/search/taiwan/000/4-6-12-195/" title="溫泉旅館" class="ga_tracking" data-category="New-navigation" data-action="住宿類型" data-label="溫泉旅館">溫泉旅館</a>
#                 <a target="_blank" href="/search/taiwan/000/4-6-12-194/" title="汽車旅館" class="ga_tracking" data-category="New-navigation" data-action="住宿類型" data-label="汽車旅館">汽車旅館</a>
#                 <a target="_blank" href="/taiwan/channel/P" title="看更多住宿類型" class="ga_tracking" data-category="New-navigation" data-action="住宿類型" data-label="看更多">看更多</a>
#             </dt>
#           </dl>
#           <dl>
#             <dd>景點</dd>
#             <dt><a target="_blank" href="/search/taiwan/000/4-7-43-80/" title="國家公園" class="ga_tracking" data-category="New-navigation" data-action="景點" data-label="國家公園">國家公園</a>
#                 <a target="_blank" href="/search/taiwan/000/4-7-43-211/" title="風景區" class="ga_tracking" data-category="New-navigation" data-action="景點" data-label="風景區">風景區</a>
#                 <a target="_blank" href="/search/taiwan/000/4-7-14-90/" title="聚落/老街" class="ga_tracking" data-category="New-navigation" data-action="景點" data-label="聚落/老街">聚落/老街</a>
#                 <a target="_blank" href="/search/taiwan/000/4-7-14-95/" title="文化園區" class="ga_tracking" data-category="New-navigation" data-action="景點" data-label="文化園區">文化園區</a>
#                 <a target="_blank" href="/search/taiwan/000/4-7-14-93/" title="自行車道" class="ga_tracking" data-category="New-navigation" data-action="景點" data-label="自行車道">自行車道</a>
#                 <a target="_blank" href="/search/taiwan/000/4-7-14-214/" title="古蹟、遺跡" class="ga_tracking" data-category="New-navigation" data-action="景點" data-label="古蹟、遺跡">古蹟、遺跡</a>
#                 <a target="_blank" href="/search/taiwan/000/4-7-14-203/" title="美術館" class="ga_tracking" data-category="New-navigation" data-action="景點" data-label="美術館">美術館</a>
#                 <a target="_blank" href="/search/taiwan/000/4-7-14-96/" title="藝術展演空間" class="ga_tracking" data-category="New-navigation" data-action="景點" data-label="藝術展演空間">藝術展演空間</a>
#                 <a target="_blank" href="/search/taiwan/000/4-7-16-311/" title="溫泉/冷泉" class="ga_tracking" data-category="New-navigation" data-action="景點" data-label="溫泉/冷泉">溫泉/冷泉</a>
#                 <a target="_blank" href="/search/taiwan/000/4-7-16-437/" title="商圈市集" class="ga_tracking" data-category="New-navigation" data-action="景點" data-label="商圈市集">商圈市集</a>
#                 <a target="_blank" href="/taiwan/channel/P" title="看更多景點" class="ga_tracking" data-category="New-navigation" data-action="景點" data-label="看更多">看更多</a>
#             </dt>
#           </dl>
#           <dl>
#             <dd>休閒娛樂</dd>
#             <dt><a target="_blank" href="/search/taiwan/000/4-8-44-0/" title="室內運動" class="ga_tracking" data-category="New-navigation" data-action="休閒娛樂" data-label="室內運動">室內運動</a>
#                 <a target="_blank" href="/search/taiwan/000/4-8-18-0/" title="室外運動" class="ga_tracking" data-category="New-navigation" data-action="休閒娛樂" data-label="室外運動">室外運動</a>
#                 <a target="_blank" href="/search/taiwan/000/4-9-20-0/" title="觀光購物" class="ga_tracking" data-category="New-navigation" data-action="休閒娛樂" data-label="觀光購物">觀光購物</a>
#                 <a target="_blank" href="/search/taiwan/000/4-19-61-0/" title="主題活動" class="ga_tracking" data-category="New-navigation" data-action="休閒娛樂" data-label="主題活動">主題活動</a>
#                 <a target="_blank" href="/search/taiwan/000/4-19-24-0/" title="展覽活動" class="ga_tracking" data-category="New-navigation" data-action="休閒娛樂" data-label="展覽活動">展覽活動</a>
#                 <a target="_blank" href="/search/taiwan/000/4-20-62-0/" title="美妍舒壓" class="ga_tracking" data-category="New-navigation" data-action="休閒娛樂" data-label="美妍舒壓">美妍舒壓</a>
#                 <a target="_blank" href="/search/taiwan/000/4-9-45-0/" title="其它娛樂" class="ga_tracking" data-category="New-navigation" data-action="休閒娛樂" data-label="其它娛樂">其它娛樂</a>
#                 <a target="_blank" href="/taiwan/channel/P" title="看更多休閒娛樂" class="ga_tracking" data-category="New-navigation" data-action="休閒娛樂" data-label="看更多">看更多</a>
#             </dt>
#           </dl>
#         </div>
#         </div>
#       </li>
#       <li data-submenu-id="cother"><span id="other-row" class="i" href="#" title="其它頻道">其它頻道</span>
#         <div id="cother" class="submenu hide">
#         <div class="container">
#           <dl>
#             <dd>影音藝文</dd>
#             <dt><a target="_blank" href="http://www.ipeen.com.tw/search/all/000/2-2-0-0/" title="電影" class="ga_tracking" data-category="New-navigation" data-action="影音藝文" data-label="電影">電影</a>
#                 <a target="_blank" href="/search/all/000/2-24-11-0/" title="音樂" class="ga_tracking" data-category="New-navigation" data-action="影音藝文" data-label="音樂">音樂</a>
#                 <a target="_blank" href="/search/all/000/2-16-80-0/" title="文學小說" class="ga_tracking" data-category="New-navigation" data-action="影音藝文" data-label="文學小說">文學小說</a>
#                 <a target="_blank" href="/search/all/000/2-16-81-0/" title="商業企管" class="ga_tracking" data-category="New-navigation" data-action="影音藝文" data-label="商業企管">商業企管</a>
#                 <a target="_blank" href="/search/all/000/2-16-83-0/" title="藝術設計" class="ga_tracking" data-category="New-navigation" data-action="影音藝文" data-label="藝術設計">藝術設計</a>
#                 <a target="_blank" href="/search/all/000/2-16-82-0/" title="生活休閒" class="ga_tracking" data-category="New-navigation" data-action="影音藝文" data-label="生活休閒">生活休閒</a>
#                 <a target="_blank" href="/search/all/000/2-16-84-0/" title="人文科普" class="ga_tracking" data-category="New-navigation" data-action="影音藝文" data-label="人文科普">人文科普</a>
#                 <a target="_blank" href="/search/all/000/2-16-87-0/" title="圖文漫畫" class="ga_tracking" data-category="New-navigation" data-action="影音藝文" data-label="圖文漫畫">圖文漫畫</a>
#                 <a target="_blank" href="/play/" title="看更多其它頻道" class="ga_tracking" data-category="New-navigation" data-action="影音藝文" data-label="看更多">看更多</a>
#             </dt>
#           </dl>
#           <dl>
#             <dd>美容美妝</dd>
#             <dt><a target="_blank" href="/search/all/000/5-11-47-0/" title="彩妝" class="ga_tracking" data-category="New-navigation" data-action="美容美妝" data-label="彩妝">彩妝</a>
#                 <a target="_blank" href="/search/all/000/5-11-48-0/" title="臉部保養" class="ga_tracking" data-category="New-navigation" data-action="美容美妝" data-label="臉部保養">臉部保養</a>
#                 <a target="_blank" href="/search/all/000/5-11-49-0/" title="身體保養" class="ga_tracking" data-category="New-navigation" data-action="美容美妝" data-label="身體保養">身體保養</a>
#                 <a target="_blank" href="/search/all/000/5-11-26-0/" title="美髮護理" class="ga_tracking" data-category="New-navigation" data-action="美容美妝" data-label="美髮護理">美髮護理</a>
#                 <a target="_blank" href="/search/all/000/5-11-28-0/" title="口腔護理" class="ga_tracking" data-category="New-navigation" data-action="美容美妝" data-label="口腔護理">口腔護理</a>
#                 <a target="_blank" href="/taiwan/channel/C" title="看更多美容美妝" class="ga_tracking" data-category="New-navigation" data-action="美容美妝" data-label="看更多">看更多</a>
#             </dt>
#           </dl>
#           <dl>
#             <dd>3C頻道</dd>
#             <dt><a target="_blank" href="/search/all/000/3-3-39-0/" title="" class="ga_tracking" data-category="New-navigation" data-action="3C頻道" data-label="衛星導航">衛星導航</a>
#                 <a target="_blank" href="/search/all/000/3-3-40-0/" title="" class="ga_tracking" data-category="New-navigation" data-action="3C頻道" data-label="相機/DV">相機/DV</a>
#                 <a target="_blank" href="/search/all/000/3-3-41-0/" title="" class="ga_tracking" data-category="New-navigation" data-action="3C頻道" data-label="手機">手機</a>
#                 <a target="_blank" href="/search/all/000/3-3-129-0/" title="" class="ga_tracking" data-category="New-navigation" data-action="3C頻道" data-label="筆記型電腦">筆記型電腦</a>
#                 <a target="_blank" href="/taiwan/channel/W" title="看更多3C頻道" class="ga_tracking" data-category="New-navigation" data-action="3C頻道" data-label="看更多">看更多</a>
#             </dt>
#           </dl>
#           <dl>
#             <dd>生活服務</dd>
#             <dt><a target="_blank" href="/search/taiwan/000/6-21-104-0/" title="寵物" class="ga_tracking" data-category="New-navigation" data-action="生活服務" data-label="寵物">寵物</a>
#                 <a target="_blank" href="/search/taiwan/000/6-21-102-0/" title="生活庶務" class="ga_tracking" data-category="New-navigation" data-action="生活服務" data-label="生活庶務">生活庶務</a>
#                 <a target="_blank" href="/search/taiwan/000/6-21-101-0/" title="交通服務" class="ga_tracking" data-category="New-navigation" data-action="生活服務" data-label="交通服務">交通服務</a>
#                 <a target="_blank" href="/search/all/000/6-23-52-0/" title="居家生活用品" class="ga_tracking" data-category="New-navigation" data-action="生活服務" data-label="居家生活用品">居家生活用品</a>
#                 <a target="_blank" href="/search/taiwan/000/6-25-95-0/" title="生活百貨" class="ga_tracking" data-category="New-navigation" data-action="生活服務" data-label="生活百貨">生活百貨</a>
#                 <a target="_blank" href="/search/taiwan/000/6-30-120-0/" title="金融機構" class="ga_tracking" data-category="New-navigation" data-action="生活服務" data-label="金融機構">金融機構</a>
#                 <a target="_blank" href="/taiwan/channel/L" title="看更多生活服務" class="ga_tracking" data-category="New-navigation" data-action="生活服務" data-label="看更多">看更多</a>
#             </dt>
#           </dl>
#         </div>
#         </div>
#       </li>
#       <li class="tag"><span>依地區搜尋</span></li>
#       <li data-submenu-id="cdis"><span id="dis-row" class="i" href="#" title="地區商圈">地區商圈</span>
#         <div id="cdis" class="submenu hide">
#         <div class="container">
#           <dl>
#             <dd>基隆市</dd>
#             <dt><a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.130819,121.745403/z=17/" title="義二路" class="ga_tracking" data-category="New-navigation" data-action="基隆市" data-label="義二路">義二路</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.139645,121.793116/z=17/" title="八斗子" class="ga_tracking" data-category="New-navigation" data-action="基隆市" data-label="八斗子">八斗子</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.128142,121.743596/z=17/" title="基隆廟口夜市" class="ga_tracking" data-category="New-navigation" data-action="基隆市" data-label="基隆廟口夜市">基隆廟口夜市</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.127917,121.747521/z=17/" title="愛六路" class="ga_tracking" data-category="New-navigation" data-action="基隆市" data-label="愛六路">愛六路</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.096091,121.713413/z=17/" title="七堵廟口市場" class="ga_tracking" data-category="New-navigation" data-action="基隆市" data-label="七堵廟口市場">七堵廟口市場</a>
#             </dt>
#           </dl>
#           <dl>
#             <dd>台北市</dd>
#             <dt><a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.046416,121.514875/z=17/" title="台北車站" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="台北車站">台北車站</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.029448,121.50512/z=17/" title="南機場" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="南機場">南機場</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.012569,121.535386/z=17/" title="公館商圈" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="公館商圈">公館商圈</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.056961,121.515455/z=17/" title="寧夏夜市" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="寧夏夜市">寧夏夜市</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.056835,121.511071/z=17/" title="迪化街" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="迪化街">迪化街</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.042919,121.507663/z=17/" title="西門町" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="西門町">西門町</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.036826,121.498311/z=17/" title="華西街" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="華西街">華西街</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.086521,121.525336/z=17/" title="士林夜市" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="士林夜市">士林夜市</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.131841,121.498633/z=17/" title="北投商圈" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="北投商圈">北投商圈</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.041492,121.548754/z=18/" title="東區" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="東區">東區</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.024503,121.529351/z=17/" title="師大商圈" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="師大商圈">師大商圈</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.031283,121.52971/z=17/" title="永康商圈" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="永康商圈">永康商圈</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.029439,121.556925/z=17/" title="臨江(通化街)夜市" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="臨江(通化街)夜市">臨江(通化街)夜市</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.034249,121.566815/z=17/" title="信義商圈" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="信義商圈">信義商圈</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.046595,121.577939/z=17/" title="五分埔商圈" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="五分埔商圈">五分埔商圈</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.050809,121.577222/z=17/" title="饒河夜市" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="饒河夜市">饒河夜市</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.119255,121.530586/z=17/" title="天母商圈" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="天母商圈">天母商圈</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=24.968425,121.587951/z=17/" title="貓空商圈" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="貓空商圈">貓空商圈</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=24.99118,121.541845/z=17/" title="景美夜市" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="景美夜市">景美夜市</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.050211,121.515505/z=17/" title="後火車站" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="後火車站">後火車站</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.071883,121.515727/z=17/" title="大龍峒商圈" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="大龍峒商圈">大龍峒商圈</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.06349,121.511065/z=17/" title="延三夜市" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="延三夜市">延三夜市</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.063679,121.524471/z=17/" title="雙城街夜市" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="雙城街夜市">雙城街夜市</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.04973,121.542196/z=17/" title="遼寧街夜市" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="遼寧街夜市">遼寧街夜市</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.052433,121.520518/z=17/" title="捷運中山站商圈" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="捷運中山站商圈">捷運中山站商圈</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.035345,121.499865/z=17/" title="艋舺商圈" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="艋舺商圈">艋舺商圈</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.058866,121.522625/z=17/" title="中山北路" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="中山北路">中山北路</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.143163,121.567871/z=16/" title="陽明山" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="陽明山">陽明山</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.137449,121.54397/z=17/" title="文化大學" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="文化大學">文化大學</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.08124,121.579292/z=17/" title="內湖737夜市" class="ga_tracking" data-category="New-navigation" data-action="台北市" data-label="內湖737夜市">內湖737夜市</a>
#             </dt>
#           </dl>
#           <dl>
#             <dd>新北市</dd>
#             <dt><a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.110554,121.856805/z=16/" title="金瓜石" class="ga_tracking" data-category="New-navigation" data-action="新北市" data-label="金瓜石">金瓜石</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.037794,121.427608/z=17/" title="輔大花園夜市" class="ga_tracking" data-category="New-navigation" data-action="新北市" data-label="輔大花園夜市">輔大花園夜市</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.065747,121.500631/z=17/" title="三和夜市" class="ga_tracking" data-category="New-navigation" data-action="新北市" data-label="三和夜市">三和夜市</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.024895,121.728743/z=17/" title="菁桐老街" class="ga_tracking" data-category="New-navigation" data-action="新北市" data-label="菁桐老街">菁桐老街</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.291763,121.568218/z=16/" title="石門商圈" class="ga_tracking" data-category="New-navigation" data-action="新北市" data-label="石門商圈">石門商圈</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.221826,121.638086/z=17/" title="金山老街" class="ga_tracking" data-category="New-navigation" data-action="新北市" data-label="金山老街">金山老街</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.189487,121.683418/z=16/" title="萬里商圈" class="ga_tracking" data-category="New-navigation" data-action="新北市" data-label="萬里商圈">萬里商圈</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=24.953134,121.351159/z=17/" title="鶯歌商圈" class="ga_tracking" data-category="New-navigation" data-action="新北市" data-label="鶯歌商圈">鶯歌商圈</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=24.935136,121.709934/z=17/" title="坪林商圈" class="ga_tracking" data-category="New-navigation" data-action="新北市" data-label="坪林商圈">坪林商圈</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=24.85983,121.551529/z=17/" title="烏來商圈" class="ga_tracking" data-category="New-navigation" data-action="新北市" data-label="烏來商圈">烏來商圈</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.108375,121.84359/z=17/" title="九份商圈" class="ga_tracking" data-category="New-navigation" data-action="新北市" data-label="九份商圈">九份商圈</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.034039,121.451807/z=17/" title="新莊廟街" class="ga_tracking" data-category="New-navigation" data-action="新北市" data-label="新莊廟街">新莊廟街</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.025148,121.73808/z=17/" title="平溪商圈" class="ga_tracking" data-category="New-navigation" data-action="新北市" data-label="平溪商圈">平溪商圈</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=24.956793,121.537049/z=17/" title="碧潭商圈" class="ga_tracking" data-category="New-navigation" data-action="新北市" data-label="碧潭商圈">碧潭商圈</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.172985,121.443458/z=17/" title="淡水商圈" class="ga_tracking" data-category="New-navigation" data-action="新北市" data-label="淡水商圈">淡水商圈</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.158215,121.433793/z=17/" title="八里商圈" class="ga_tracking" data-category="New-navigation" data-action="新北市" data-label="八里商圈">八里商圈</a>
#                 <a target="_blank" href="http://www.ipeen.com.tw/map/#!/s=0/f=0|0|0|0|0,6,7|10|0|0|0/c=25.002952,121.616598/z=17/" title="深坑商圈" class="ga_tracking" data-category="New-navigation" data-action="新北市" data-label="深坑商圈">深坑商圈</a>
# ...
# <li><a class="ga_tracking" data-action="熱門體驗券中" data-category="New-header" data-key="20" data-label="熱門體驗券中" href="http://service.ipeen.com.tw/experience/list/now">熱門體驗券中</a></li>
# <li><a class="ga_tracking" data-action="口碑券首頁" data-category="New-header" data-key="0" data-label="口碑券首頁" href="http://service.ipeen.com.tw/reputation/">口碑券首頁</a></li>
# <li><a class="ga_tracking" data-action="最新預告" data-category="New-header" data-key="19" data-label="最新預告" href="http://service.ipeen.com.tw/reputation/list/new">最新預告</a></li>
# <li><a class="ga_tracking" data-action="熱門兌換" data-category="New-header" data-key="20" data-label="熱門兌換" href="http://service.ipeen.com.tw/reputation/list/now">熱門兌換中</a></li>
# <li><a class="ga_tracking" data-action="最新口碑分享" data-category="New-header" data-key="21" data-label="最新口碑分享" href="/taiwan/newcmm/R">最新口碑分享</a></li>
# </ul>
# </div>
# </li>
# <li>
# <a class="ga_tracking new-tag" data-action="愛吃閃購" data-category="New-header" data-label="愛吃閃購" href="http://service.ipeen.com.tw/flash_buy/">愛吃閃購</a>
# </li>
# <li class="ui-select hoverable">
# <a class="" href="#">精選情報</a>
# <div>
# <ul class="hide">
# <li><a class="ga_tracking" data-action="精選特輯" data-category="New-header" data-key="27" data-label="精選特輯" href="/focus/">精選特輯</a></li>
# <li><a class="ga_tracking" data-action="媒體情報" data-category="New-header" data-key="28" data-label="媒體情報" href="/taiwan/media/">媒體情報</a></li>
# <li><a class="ga_tracking" data-action="愛評賞味報" data-category="New-header" data-key="29" data-label="愛評賞味報" href="http://content.ipeen.com.tw/tastenews/tastenews/index">愛評賞味報</a></li>
# <li><a class="ga_tracking" data-action="愛評體驗團" data-category="New-header" data-key="31" data-label="愛評體驗團" href="http://content.ipeen.com.tw/exptour/article">愛評體驗團</a></li>
# </ul>
# </div>
# </li>
# <li><a class="ga_tracking" data-action="排行榜" data-category="New-header" data-key="6" data-label="排行榜" href="/taiwan/rank/">排行榜</a></li>
# <!-- <li><a class="ga_tracking" data-category="New-header" data-action="獎勵" data-label="獎勵" data-key="9" href="/lottery/">獎勵</a></li> -->
# </ul>
# </nav>
# </div>
# </div>
# </header>
# <div id="top-golden-link">
# <!-- 1000 -->
# <ul class="ad" id="narrow-ad">
# <li>
# <div id="div-gpt-ad-1383290806662-0" style="width:250px; height:22px;margin:0 auto;">
# <script type="text/javascript">
# 				googletag.cmd.push(function() { googletag.display('div-gpt-ad-1383290806662-0'); });
# 				</script>
# </div>
# </li>
# <li> <!-- Web_all_diamond-title_middle-left_1200 -->
# <div id="div-gpt-ad-1383291166432-0" style="width:250px; height:22px;margin:0 auto;">
# <script type="text/javascript">
# 			googletag.cmd.push(function() { googletag.display('div-gpt-ad-1383291166432-0'); });
# 			</script>
# </div>
# </li>
# <li> <!-- Web_all_diamond-title_middle-right_1200 -->
# <div id="div-gpt-ad-1383291190522-0" style="width:250px; height:22px;margin:0 auto;">
# <script type="text/javascript">
# 			googletag.cmd.push(function() { googletag.display('div-gpt-ad-1383291190522-0'); });
# 			</script>
# </div>
# </li>
# <li> <!-- Web_all_diamond-title_right_1200 -->
# <div id="div-gpt-ad-1383291215171-0" style="width:250px; height:22px;margin:0 auto;">
# <script type="text/javascript">
# 			googletag.cmd.push(function() { googletag.display('div-gpt-ad-1383291215171-0'); });
# 			</script>
# </div>
# </li>
# </ul>
# </div>
# <div id="breadcrumb">
# <div class="layout-wrapper">
# <div itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
# <a href="/" itemprop="url">
# <span itemprop="title">iPeen 愛評網</span>
# </a>
# </div>
# <span>&gt;</span>
#         很抱歉，找不到此頁面！  </div>
# </div>
# <div class="layout-wrapper">
# <section class="error_msg">
# <div class="error_links">
# <a href="/">回首頁 »</a>
# 					<a href="javascript:history.back();"> 回到上一頁 »</a>
# </div>
# </section>
# <style>body{margin: 0}</style><iframe frameborder="0" height="635" src="http://404page.missingkids.org.tw/api?key=aJVnCgyDpM9AMT3RNbsU" width="100%"></iframe>
# </div>
# <footer data-block="footer" id="footer" role="contentinfo">
# <div class="layout-wrapper">
# <section class="latest">
# <h3 class="h1">最新分享</h3>
# <div>
# <h2>美食旅遊</h2>
# <ul>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="0" data-label="美食旅遊-餐廳" href="/taiwan/newcmm/F">餐廳</a></li>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="1" data-label="美食旅遊-網購團購" href="/taiwan/newcmm/N">網購團購</a></li>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="2" data-label="美食旅遊-包裝食品" href="/taiwan/newcmm/K">包裝食品</a></li>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="3" data-label="美食旅遊-住宿" href="/taiwan/newcmm/H">住宿</a></li>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="4" data-label="美食旅遊-景點" href="/taiwan/newcmm/V">景點</a></li>
# </ul>
# </div>
# <div>
# <h2>娛樂藝文</h2>
# <ul>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="5" data-label="娛樂藝文-電影" href="/taiwan/newcmm/M">電影</a></li>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="6" data-label="娛樂藝文-書籍" href="/taiwan/newcmm/B">書籍</a></li>
# </ul>
# </div>
# </section>
# <section class="features">
# <h3 class="h1">吃喝玩樂去</h3>
# <div>
# <h2>愛評特搜</h2>
# <ul>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="7" data-label="愛評特搜-地圖快搜" href="/map/">地圖快搜</a></li>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="8" data-label="愛評特搜-排行榜" href="/rank/">排行榜</a></li>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="9" data-label="愛評特搜-愛吃閃購" href="http://service.ipeen.com.tw/flash_buy/ ">愛吃閃購</a></li>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="10" data-label="愛評特搜-體驗券" href="http://service.ipeen.com.tw/experience/">體驗券</a></li>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="11" data-label="愛評特搜-優惠/KoKo 回饋金" href="/ad/blockclick.php?page=/index.php&amp;block=footer&amp;key=12&amp;next=%2Fbenefit%2F">優惠/KoKo 回饋金</a></li>
# </ul>
# </div>
# <div>
# <h2>愛評佈告欄</h2>
# <ul>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="12" data-label="愛評佈告欄-愛評公告" href="/announcement/">愛評公告</a></li>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="13" data-label="愛評佈告欄-活動特區" href="/action/">活動特區</a></li>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="14" data-label="愛評佈告欄-熱門話題" href="/group/category.php?id=1">熱門話題</a></li>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="15" data-label="愛評佈告欄-精選特輯" href="/focus/">精選特輯</a></li>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="16" data-label="愛評佈告欄-媒體情報" href="/media/media_index.php">媒體情報</a></li>
# </ul>
# </div>
# </section>
# <section class="service_new">
# <h3 class="h1">服務中心</h3>
# <div>
# <h2>關於愛評</h2>
# <ul>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="17" data-label="關於愛評-關於我們" href="/introduction.php">關於我們</a></li>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="18" data-label="關於愛評-網站地圖" href="/service/service_teach.php">網站地圖</a></li>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="19" data-label="關於愛評-服務條款" href="/service/service_law.php">服務條款</a></li>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="20" data-label="關於愛評-資訊安全政策" href="/privacy.php">資訊安全政策</a></li>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="21" data-label="關於愛評-線上徵才" href="http://www.104.com.tw/jobbank/custjob/index.php?r=cust&amp;j=5e4a446c4c46402552583a1d1d1d1d5f2443a363189j01&amp;jobsource=checkc">線上徵才</a></li>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="22" data-label="關於愛評-廣告服務" href="/adrules/">廣告服務</a></li>
# <li><a data-key="23" href="mailto:corpsales@ipeen.com.tw">合作提案</a></li>
# </ul>
# </div>
# <div>
# <h2>會員專區</h2>
# <ul>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="24" data-label="會員專區-加入愛評網" href="/register/register.php">加入愛評網</a></li>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="25" data-label="會員專區-忘記密碼" href="/signin/forget.php">忘記密碼</a></li>
# </ul>
# <h2>愛評店家專區</h2>
# <ul>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="26" data-label="愛評店家專區-合作店家登入" href="/public/index.php?id=15968ff0c32d0792c0f5ceb1ced10f30">合作店家登入</a></li>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="27" data-label="愛評店家專區-加入合作店家" href="/public/index.php?id=378759ed35a3a0c8020eb8615f9732a2">加入合作店家</a></li>
# <li><a data-key="28" href="mailto:sales-qa@ipeen.com.tw">合作店家客服</a></li>
# <li><a href="http://biz.ipeen.com.tw/board/">店家管理工具2.0</a></li>
# </ul>
# </div>
# <div>
# <h2>建議與問題</h2>
# <ul>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="29" data-label="建議與問題-會員客服" href="/report/">會員客服</a></li>
# <li><a data-key="30" href="mailto:service@ipeen.com.tw">活動客服</a></li>
# <li><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="31" data-label="建議與問題-愛評生活通APP客服" href="/report/?type=8">愛評生活通APP客服</a></li>
# </ul>
# </div>
# </section>
# <section class="service">
# <h3 class="h1">關注我們</h3>
# <div class="footer_icon"><a class="ga_tracking" data-action="Click" data-category="New-footer" data-label="關注我們-Facebook" href="https://www.facebook.com/ipeen/" target="view_window"><img src="../../../images/frame/footer_icon04.png"/></a></div>
# <div class="footer_icon"><a class="ga_tracking" data-action="Click" data-category="New-footer" data-label="關注我們-Line" href="https://line.me/ti/p/%40ntq4580m" target="view_window"><img src="../../../images/frame/footer_icon03.png"/></a></div>
# <div class="footer_icon"><a class="ga_tracking" data-action="Click" data-category="New-footer" data-label="關注我們-Instagram" href="https://www.instagram.com/ipeen.com.tw/" target="view_window"><img src="../../../images/frame/footer_icon02.png"/></a></div>
# <div class="footer_icon"><a class="ga_tracking" data-action="Click" data-category="New-footer" data-label="關注我們-YouTube" href="https://www.youtube.com/user/iPeenLife/" target="view_window"><img src="../../../images/frame/footer_icon01.png"/></a></div>
# </section>
# <div id="copyright">
# <div class="logo i">iPeen 愛評網</div>
# <p><a class="ga_tracking" data-action="Click" data-category="New-footer" data-key="39" data-label="紅谷資訊" href="/introduction.php">紅谷資訊</a> 版權所有©2018 HongKu Info Co., Ltd., All Rights Reserved.</p>
# <p>本網站內會員言論僅代表個人觀點，不代表本站同意其說法，本站不承擔由該言論引起的法律責任</p>
# <p class="bottom">著作權所有，請勿任意傳載本網站內容</p>
# </div>
# </div>
# </footer>
# </div>
# <script src="/js/jquery/jquery-1.9.1.min.js" type="text/javascript"></script>
# <script src="http://maps.googleapis.com/maps/api/js?sensor=true"></script>
# <link href="/js/jquery/lightview/data/lightview.css" rel="stylesheet"/>
# <script src="/js/jquery/lightview/data/lightview.js"></script>
# <script src="/js/jquery/jquery.cookie.js"></script>
# <script src="/js/ipeen/ipeen.js"></script>
# <script src="/js/ipeen/ipeen.jquery-extension.js"></script>
# <script src="/js/ipeen/ipeen.internal.js"></script>
# <script src="/js/ipeen/ipeen.support.js"></script>
# <script src="/js/ipeen/ipeen.layout.js"></script>
# <script src="/js/ipeen/ipeen.mobile.js"></script>
# <script src="/js/ui-object/ui-select/ui-select.js"></script>
# <script src="/js/ui-object/ui-pressbutton/ui-pressbutton.js"></script>
# <script src="/js/ui-object/tab/tab.js"></script>
# <script src="/js/facebook/common.js"></script>
# <script src="/js/push/iPeenPush.js"></script>
# <script src="/js/shop/push-actions.js?v=13784.1"></script>
# <script src="/js/frame/facebook.js"></script>
# <script src="/js/frame/plurk.js"></script>
# <link href="/css/badge/badge.css" rel="stylesheet"/>
# <script src="/js/badge/badge.js"></script>
# <link href="/css/tour/tour.css" rel="stylesheet"/>
# <script src="/js/tour/actions.js"></script>
# <script src="/js/tour/add.js"></script>
# <script src="/js/jquery/jquery.menu-aim.js"></script>
# <script src="/js/frame/search-form.js"></script>
# <script src="/js/frame/common-actions.js"></script>
# <!-- <script src="/js/shop/shop-actions.js"></script> -->
# <!-- <script src="/js/comment/comment-actions.js"></script> -->
# <script src="/js/frame/ad-actions.js?201403071500"></script>
# <script>ipeen.batch(['add layout','view.cozy','view.compact'],['ui select'],['query dropdown'],['write &sul= url'],['write &next= url'],['blockclick tracking init','/msg.php'],['tour init'],['show badge'],['facebook init',{"app_id":"156261592614","set_fb_host":"","fb_app_channel":"","fb_app_session":""}],['search form init'],['breadcrumb init'],['trigger layout']);</script>
# <script>
# !function(d,s,id){
# 	window.twttr = (function (d,s,id) {
# 		var t, js, fjs = d.getElementsByTagName(s)[0];
# 		if (d.getElementById(id)) return; js=d.createElement(s); js.id=id;
# 		js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js, fjs);
# 		return window.twttr || (t = { _e: [], ready: function(f){ t._e.push(f) } });
# 	}(document, "script", "twitter-wjs"));
# }(document,"script","twitter-wjs");
#
# function trackTwitter(intent_event) {
# 	if (intent_event) {
# 		var opt_pagePath;
# 		if (intent_event.target && intent_event.target.nodeName == 'IFRAME') {
# 			opt_target = extractParamFromUri(intent_event.target.src, 'url');
# 		}
# 		ga('send', 'social', 'twitter', 'tweet', opt_pagePath);
# 	}
# }
#
# //Wrap event bindings - Wait for async js to load
# twttr.ready(function (twttr) {
# 	//event bindings
# 	twttr.events.bind('tweet', trackTwitter);
# });
#
# function extractParamFromUri(uri, paramName) {
# 	if (!uri) {
# 		return;
# 	}
# 	var regex = new RegExp('[\\?&#]' + paramName + '=([^&#]*)');
# 	var params = regex.exec(uri);
# 	if (params != null) {
# 		return unescape(params[1]);
# 	}
# 	return;
# }
# </script>
# <script src="http://track.sitetag.us/tracking.js?hash=32c91352f8246775a18dd6a529167bbf" type="text/javascript"></script>
# <script src="/js/sitebro.js" type="text/javascript"></script>
# <script type="text/javascript">
# (function($) {
# $(document).on("click", ".ga_tracking", function(event) {
#     var me = $(this);
#     ga('send', 'event', me.attr('data-category'), me.attr('data-action'), me.attr('data-label'));
# });
# })(jQuery);
# </script>
# <!--Cymmetrics Code-->
# <script class="Cym_dmp_tag" type="text/javascript">
# var ipeen_uid = 0;
# var cy_src = 'pt.cymmetrics.com.tw/acjs/cyd_iPeen.js'
# var cym_ct = document.createElement('script');
# var src = (location.protocol == 'https:') ? 'https://' : 'http://';
# cym_ct.setAttribute('src',src+cy_src); cym_ct.charset = 'utf-8';
# var cym_cts = document.getElementsByTagName('script')[0];
# cym_cts.parentNode.insertBefore(cym_ct, cym_cts);
# </script>
# <!--end of Cymmetrics Code-->
# <script src="/js/analytics/analytics.js" type="text/javascript"></script>
# <!-- Start Alexa Certify Javascript -->
# <script type="text/javascript">
# _atrk_opts = { atrk_acct:"FtYQh1aUXR00gV", domain:"ipeen.com.tw",dynamic: true};
# (function() { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://d31qbv1cthcecs.cloudfront.net/atrk.js"; var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })();
# </script>
# <noscript><img alt="" height="1" src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=FtYQh1aUXR00gV" style="display:none" width="1"/></noscript>
# <!-- End Alexa Certify Javascript -->
# <script>
# (function(w, d, s, m) {
# var f = d.getElementsByTagName('script')[0],
# j = d.createElement('script'),
# ns = 'APPIER_RETARGET';
# w._appierSendQueue = [];
# w['appierRetargetJson'] = { id: s, site: m};
# j.async = true;
# j.src = '//d17m68fovwmgxj.cloudfront.net/js/rt/track.js';
# f.parentNode.insertBefore(j, f);
# !w[ns] && (w[ns] = {});
# (!w[ns].send) && (w[ns].send = function(j){
#     w._appierSendQueue.push(j);
# });
# })(window, document, 'VOH6','ipeen.com.tw');
# </script>
# </body>
# </html>
# <!-- 0.056770 D03/0 -->

# %%
res.text
# Out:
# '\nWarning: Header may not contain more than a single header, new line detected in /www/ipeen/shop/shop.php on line 134\n'

# %%
url
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-20be803fa762> in <module>()
# ----> 1 url
#
# NameError: name 'url' is not defined

# %%
ipeenWebsite[i]
# Out:
# 'http://www.ipeen.com.tw/shop/1230314'
