# %%
import requests
import pymongo
import time
from bs4 import BeautifulSoup as bs
import json




b=time.time()
res=requests.get("https://twcoupon.com/brandshop-%E5%B1%88%E8%87%A3%E6%B0%8F-%E9%9B%BB%E8%A9%B1-%E5%9C%B0%E5%9D%80.html")
soup=bs(res.text,'lxml')
watsonsList=[]
for i in soup.select_one("div.right").select("li"):
    dien={}
    datalist=i.select('span')
    dien['name']=datalist[0].text.replace("\r\n","_")
    dien['tele']=datalist[1].text.replace("-","_")
    dien['address']=datalist[2].text.replace("\n","")
    ###############
    try:
        dien["bigadd"] = re.findall("(\w\w[市|縣])(\w\w?\w?[區|市|鎮|鄉])",dien['address'])[0][0]
        dien["smalladd"] = re.findall("(\w\w[市|縣])(\w\w?\w?[區|市|鎮|鄉])",dien['address'])[0][1]
    except:
        dien["bigadd"]=0
        dien["smalladd"]=0
    ##############
    
    
    dien['_id']=datalist[1].text.replace("-","_")
    watsonsList.append(dien)
    
    
nn=0
Alln=len(watsonsList)
for dien in watsonsList:
    nn+=1
    if nn%30==0:
        print("{}%".format(round(nn/Alln,2)*100))
    if 'lat' not in dien or dien['lat']=='24.1491968':
        add='沒有地址'
        n=0
        while add=='沒有地址':
            res=requests.get('http://3wa.tw/API/getTGOSAddress_XY?address='+dien['address'])
            add=res.text
            n+=1
            time.sleep(0.4)
            if n >10:
                break
        try:
            jsonData=json.loads(add)
            dien['lat']=jsonData['lat']
            dien['lng']=jsonData['long']
            print(dien['address'],dien['lat'],dien['lng'])
        except:
            print(add)
            print(dien['address']+"轉換失敗")
    

    
# 用googleApi轉換
import googlemaps
gmaps = googlemaps.Client(key='AIzaSyAF9GKxqgmgDEW_h7M4TtM5CbkK03xnS0E')
for dien in watsonsList:
    address=dien['address']
    try:
        if 'lat' not in dien or dien['lat']=='24.1491968':
            #關閉的店、店號有A的、大陸的店都不需要做
                geocode_result = gmaps.geocode(address)
                if geocode_result==[]:
                    geocode_result = gmaps.geocode(address[:11])            
                dien['lat']=geocode_result[0]['geometry']['location']['lat']
                dien['lng']=geocode_result[0]['geometry']['location']['lng']
                print(dien['address'],dien['lat'],dien['lng'])
                time.sleep(1.5)

    except Exception as e:
        print(e)
        print(dien['address']+"無經緯度資料")
    
    
    
# client=pymongo.MongoClient("localhost",27017,username="j122085",password="850605")
client=pymongo.MongoClient("192.168.1.113",27017,username="j122085",password="850605")

collection=client.rawData.Watsons
# collection.drop()


ids=[i.pop("_id") for i in watsonsList]
bulk=[]
operations=[pymongo.UpdateOne({"_id":idn,},{"$set":dien},upsert=True) for idn,dien in zip(ids,watsonsList)]
try:
    collection.bulk_write(operations,ordered=True)
except:
    print("some _id is exist")

e=time.time()

print("耗時:{}秒".format(round(e-b)))
    
client.close()
# Out:
# 基隆市七堵區明德一路188號1-2F 25.097466336135 121.71298920337
# 基隆市仁愛區仁三路68號 25.128810100447 121.74260974975
# 基隆市仁愛區忠一路8號 25.130816352298 121.74063265631
# 基隆市仁愛區愛四路76號 25.129567765372 121.74455233426
# 基隆市安樂區安一路115號 25.131745537517 121.73441712045
# 基隆市安樂區安樂路二段159號1-2F 25.12071120727 121.72343253684
# 基隆市安樂區基金一路172-1號1-2F 25.14077277603 121.71117521955
# 基隆市信義區深溪路192號 25.134923574252 121.78286583422
# 基隆市暖暖區暖暖街181號 25.099204525451 121.73584731435
# 台北市士林區士東路134號 25.112209286136 121.53051446007
# 台北市士林區大東路11-7號1樓 25.086748025075 121.52530226471
# 台北市士林區中正路243號 25.095133555095 121.525794064
# 台北市士林區中正路285號 25.09475122631 121.52410794361
# 台北市士林區天母北路6號1樓 25.119102824069 121.52616322784
# 台北市士林區天母東路32號 25.117894820503 121.5322417828
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ...
