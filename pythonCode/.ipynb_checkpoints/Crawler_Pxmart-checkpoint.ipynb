# %%
headerstr='''Accept: application/json, text/javascript, */*; q=0.01
Accept-Encoding: gzip, deflate
Accept-Language: zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7
Cache-Control: no-cache
Connection: keep-alive
Cookie: JSESSIONID=0000E4wuOYFjU_Ofg5ZbfzN02Ej:-1; _ga=GA1.3.1914857536.1524711838; _gid=GA1.3.1481704526.1524711838; amnetjs_ses=yGJpSAUzB2i3vpRc
Host: www.pxmart.com.tw
Pragma: no-cache
Referer: http://www.pxmart.com.tw/px/map.px
User-Agent: Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.181 Safari/537.36
X-Requested-With: XMLHttpRequest'''

headers={i.split(":")[0].strip():i.split(":")[1].strip() for i in headerstr.split("\n")}
headers
# Out:
# {'Accept': 'application/json, text/javascript, */*; q=0.01',
#  'Accept-Encoding': 'gzip, deflate',
#  'Accept-Language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7',
#  'Cache-Control': 'no-cache',
#  'Connection': 'keep-alive',
#  'Cookie': 'JSESSIONID=0000E4wuOYFjU_Ofg5ZbfzN02Ej',
#  'Host': 'www.pxmart.com.tw',
#  'Pragma': 'no-cache',
#  'Referer': 'http',
#  'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.181 Safari/537.36',
#  'X-Requested-With': 'XMLHttpRequest'}

# %%
paramstr='''id: 420453184803564
ev: SubscribedButtonClick
dl: http://www.pxmart.com.tw/px/map.px
rl: http://www.pxmart.com.tw/px/index.px
if: false
ts: 1524711902411
cd[buttonText]: 搜尋
cd[buttonFeatures]: {"name":"","id":"btn-search","tag":"a","classList":"paxmart-map-search-btn","innerText":"搜尋","numChildButtons":0,"destination":"javascript:void(0)"}
cd[formFeatures]: []
sw: 1600
sh: 900
v: 2.8.14
r: stable
ec: 4
o: 28
it: 1524711876032
es: automatic'''

params={i.split(":")[0].strip():i.split(":")[1].strip() for i in paramstr.split("\n")}
params
# Out:
# {'cd[buttonFeatures]': '{"name"',
#  'cd[buttonText]': '搜尋',
#  'cd[formFeatures]': '[]',
#  'dl': 'http',
#  'ec': '4',
#  'es': 'automatic',
#  'ev': 'SubscribedButtonClick',
#  'id': '420453184803564',
#  'if': 'false',
#  'it': '1524711876032',
#  'o': '28',
#  'r': 'stable',
#  'rl': 'http',
#  'sh': '900',
#  'sw': '1600',
#  'ts': '1524711902411',
#  'v': '2.8.14'}

# %%
url='''http://www.pxmart.com.tw/px/store1?cityid=&cityzoneid=&cityroadid=&name_short='''

# %%
import requests
res=requests.get(url,params=params,headers=headers)

# %%
import json
data=json.loads(res.text)

# %%
[i['address'] for i in data]
# Out:
# ['(20349)基隆市中山區西定路230號',
#  '(20145)基隆市信義區東信路55巷17號',
#  '(20348)基隆市中山區復興路151號',
#  '(20644)基隆市七堵區南興路106號',
#  '(20148)基隆市信義區義六路５號',
#  '(20044)基隆市仁愛區成功一路133巷1號',
#  '(20445)基隆市安樂區基金一路135巷21弄2號之1',
#  '(20649)基隆市七堵區百六街116號',
#  '(11046)臺北市信義區松仁路240巷19號',
#  '(10074)臺北市中正區南昌路１段51巷1號',
#  '臺北市士林區士東路23號',
#  '(10492)臺北市中山區龍江路15號1.2樓',
#  '臺北市內湖區星雲街163號',
#  '(10477)臺北市中山區合江街137號1樓',
#  '臺北市中山區吉林路26巷34號',
#  '(11661)臺北市文山區興隆路４段143號',
#  '(40663)臺中市北屯區東山路１段346號',
#  '(35641)苗栗縣後龍鎮中華路55-6、55-7、55-15號',
#  '(42042)臺中市豐原區大順街121、123號',
#  '(33458)桃園市八德區東勇北路566、568號',
#  '(32546)桃園市龍潭區中正路三林段298號',
#  '(32850)桃園市觀音區中山路２段891、893號',
#  '(32083)桃園市中壢區普忠路1168號',
#  '(51055)彰化縣員林鎮浮圳路２段135號',
#  '(80453)高雄市鼓山區明誠三路463號',
#  '(33046)桃園市桃園區中埔二街158.160號',
#  '(80789)高雄市三民區鼎力路15、17、19、21號',
#  '(30062)新竹市東區食品路305之1號',
#  '(55779)南投縣竹山鎮集山路３段227、229號']

# %%
import requests
import pymongo
from pymongo import UpdateOne
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.message import EmailMessage
import smtplib
import json

def mailTo(title,mailAdds,message,whoSend='Crawler591Info'):
    msg = MIMEMultipart()    
    sender = whoSend
    subject = title
    body = message
    msg['From'] = sender
    msg['To'] = ','.join(mailAdds)
    msg['Subject'] = subject
    msg.attach(MIMEText(body, 'plain'))
    text=msg.as_string()
    #print text
    # Send the message via our SMTP server
    s = smtplib.SMTP('192.168.2.1',25)
    s.sendmail(sender,mailAdds, text)
    s.quit()  

try:
    headerstr='''Accept: application/json, text/javascript, */*; q=0.01
    Accept-Encoding: gzip, deflate
    Accept-Language: zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7
    Cache-Control: no-cache
    Connection: keep-alive
    Cookie: JSESSIONID=0000E4wuOYFjU_Ofg5ZbfzN02Ej:-1; _ga=GA1.3.1914857536.1524711838; _gid=GA1.3.1481704526.1524711838; amnetjs_ses=yGJpSAUzB2i3vpRc
    Host: www.pxmart.com.tw
    Pragma: no-cache
    Referer: http://www.pxmart.com.tw/px/map.px
    User-Agent: Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.181 Safari/537.36
    X-Requested-With: XMLHttpRequest'''
    headers={i.split(":")[0].strip():i.split(":")[1].strip() for i in headerstr.split("\n")}
    
    paramstr='''id: 420453184803564
    ev: SubscribedButtonClick
    dl: http://www.pxmart.com.tw/px/map.px
    rl: http://www.pxmart.com.tw/px/index.px
    if: false
    ts: 1524711902411
    cd[buttonText]: 搜尋
    cd[buttonFeatures]: {"name":"","id":"btn-search","tag":"a","classList":"paxmart-map-search-btn","innerText":"搜尋","numChildButtons":0,"destination":"javascript:void(0)"}
    cd[formFeatures]: []
    sw: 1600
    sh: 900
    v: 2.8.14
    r: stable
    ec: 4
    o: 28
    it: 1524711876032
    es: automatic'''
    params={i.split(":")[0].strip():i.split(":")[1].strip() for i in paramstr.split("\n")}
    url='''http://www.pxmart.com.tw/px/store1?cityid=&cityzoneid=&cityroadid=&name_short='''
    res=requests.get(url,params=params,headers=headers)
    
    
    
    pxmartDatasO=json.loads(res.text)
    pxmartDatas=[]
    for i in pxmartDatasO:
        pxmartData={}
        pxmartData['name']="全聯"+i['name_short']
        pxmartData['lat']=i['mapy']
        pxmartData['lng']=i['mapx']
        if ")" in i['address']:
            pxmartData['address']=i['address'].split(")")[1] 
        else:
            pxmartData['address']=i['address']
        pxmartData['bigadd']=i['city']
        pxmartData['smalladd']=i['cityzone']
        pxmartData['road']=i['cityroad']
        pxmartData['tele']=i['tel_zno']+"-"+i['tel_no']
        pxmartData['_id']=pxmartData['name']
        pxmartDatas.append(pxmartData)
    Client=pymongo.MongoClient('localhost',27017,username='j122085',password='850605')
    collection=Client.rawData.pxmart
    ids=[i.pop("_id") for i in pxmartDatas]
    writeList=[UpdateOne({"_id":idn},{"$set":data},upsert=True) for idn,data in zip(ids,pxmartDatas)]
    try:
        collection.bulk_write(writeList,ordered=False)
    except Exception as er:
        print(er)

    mailTo("CrawlerPxmart",["andy.yuan@wowprime.com"],"finish")
except Exception as er:
    mailTo("CrawlerPxmart",["andy.yuan@wowprime.com"],"loss error:"+str(er))

# %%
Client=pymongo.MongoClient('localhost',27017,username='j122085',password='850605')
collection=Client.rawData.pxmart
list(collection.find())
# Out:
# [{'_id': '全聯基隆西定',
#   'address': '基隆市中山區西定路230號',
#   'bigadd': '基隆市',
#   'lat': 25.137486,
#   'lng': 121.732153,
#   'name': '全聯基隆西定',
#   'road': '西定路',
#   'smalladd': '中山區',
#   'tele': '02-2423-3772'},
#  {'_id': '全聯基隆東光',
#   'address': '基隆市信義區東信路55巷17號',
#   'bigadd': '基隆市',
#   'lat': 25.126743,
#   'lng': 121.766072,
#   'name': '全聯基隆東光',
#   'road': '東信路',
#   'smalladd': '信義區',
#   'tele': '02-2466-4711'},
#  {'_id': '全聯基隆復興',
#   'address': '基隆市中山區復興路151號',
#   'bigadd': '基隆市',
#   'lat': 25.145508,
#   'lng': 121.726424,
#   'name': '全聯基隆復興',
#   'road': '復興路',
#   'smalladd': '中山區',
#   'tele': '02-2437-6268'},
#  {'_id': '全聯七堵',
#   'address': '基隆市七堵區南興路106號',
#   'bigadd': '基隆市',
#   'lat': 25.096608,
#   'lng': 121.712004,
#   'name': '全聯七堵',
#   'road': '南興路',
#   'smalladd': '七堵區',
#   'tele': '02-2455-2098'},
#  {'_id': '全聯基隆信義',
#   'address': '基隆市信義區義六路５號',
#   'bigadd': '基隆市',
#   'lat': 25.128875,
#   'lng': 121.750939,
#   'name': '全聯基隆信義',
#   'road': '義六路',
#   'smalladd': '信義區',
#   'tele': '02-2427-8376'},
#  {'_id': '全聯基隆光華',
#   'address': '基隆市仁愛區成功一路133巷1號',
#   'bigadd': '基隆市',
#   'lat': 25.128452,
#   'lng': 121.73638,
#   'name': '全聯基隆光華',
#   'road': '成功一路',
#   'smalladd': '仁愛區',
#   'tele': '02-2433-8842'},
#  {'_id': '全聯大武崙',
#   'address': '基隆市安樂區基金一路135巷21弄2號之1',
#   'bigadd': '基隆市',
#   'lat': 25.138894,
#   'lng': 121.70959,
#   'name': '全聯大武崙',
#   'road': '基金一路',
#   'smalladd': '安樂區',
#   'tele': '02-2430-0481'},
#  {'_id': '全聯基隆百福',
#   'address': '基隆市七堵區百六街116號',
#   'bigadd': '基隆市',
#   'lat': 25.085463,
#   'lng': 121.69737,
#   'name': '全聯基隆百福',
#   'road': '百六街',
#   'smalladd': '七堵區',
#   'tele': '02-2451-1182'},
#  {'_id': '全聯信義六合',
#   'address': '臺北市信義區松仁路240巷19號',
#   'bigadd': '臺北市',
#   'lat': 25.024472,
#   'lng': 121.569018,
#   'name': '全聯信義六合',
#   'road': '松仁路',
#   'smalladd': '信義區',
#   'tele': '02-2720-1907'},
#  {'_id': '全聯中正南昌',
#   'address': '臺北市中正區南昌路１段51巷1號',
#   'bigadd': '臺北市',
#   'lat': 25.031654,
#   'lng': 121.517329,
#   'name': '全聯中正南昌',
#   'road': '南昌路１段',
#   'smalladd': '中正區',
#   'tele': '02-2393-1505'},
#  {'_id': '全聯士林士東',
#   'address': '臺北市士林區士東路23號',
#   'bigadd': '臺北市',
#   'lat': 25.11197,
#   'lng': 121.527001,
#   'name': '全聯士林士東',
#   'road': '士東路',
#   'smalladd': '士林區',
#   'tele': '02-2871-1360'},
#  {'_id': '全聯中山朱崙',
#   'address': '臺北市中山區龍江路15號1.2樓',
#   'bigadd': '臺北市',
#   'lat': 25.047493,
#   'lng': 121.540498,
#   'name': '全聯中山朱崙',
#   'road': '龍江路',
#   'smalladd': '中山區',
#   'tele': '02-2721-0291'},
#  {'_id': '全聯內湖星雲',
#   'address': '臺北市內湖區星雲街163號',
#   'bigadd': '臺北市',
#   'lat': 25.081175,
#   'lng': 121.596452,
#   'name': '全聯內湖星雲',
#   'road': '星雲街',
#   'smalladd': '內湖區',
#   'tele': '02-2792-0119'},
#  {'_id': '全聯松花',
#   'address': '臺北市中山區合江街137號1樓',
#   'bigadd': '臺北市',
#   'lat': 25.061652,
#   'lng': 121.539364,
#   'name': '全聯松花',
#   'road': '合江街',
#   'smalladd': '中山區',
#   'tele': '02-2515-1077'},
#  {'_id': '全聯南京',
#   'address': '臺北市中山區吉林路26巷34號',
#   'bigadd': '臺北市',
#   'lat': 25.051374,
#   'lng': 121.528364,
#   'name': '全聯南京',
#   'road': '吉林路',
#   'smalladd': '中山區',
#   'tele': '02-2581-4121'},
#  {'_id': '全聯順興',
#   'address': '臺北市文山區興隆路４段143號',
#   'bigadd': '臺北市',
#   'lat': 24.985132,
#   'lng': 121.561655,
#   'name': '全聯順興',
#   'road': '興隆路４段',
#   'smalladd': '文山區',
#   'tele': '02-2937-0515'},
#  {'_id': '全聯北市延平',
#   'address': '臺北市士林區延平北路５段238號',
#   'bigadd': '臺北市',
#   'lat': 25.084418,
#   'lng': 121.510031,
#   'name': '全聯北市延平',
#   'road': '延平北路５段',
#   'smalladd': '士林區',
#   'tele': '02-2816-4306'},
#  {'_id': '全聯士林天母',
#   'address': '臺北市士林區中山北路７段81巷7號',
#   'bigadd': '臺北市',
#   'lat': 25.121745,
#   'lng': 121.530394,
#   'name': '全聯士林天母',
#   'road': '中山北路７段',
#   'smalladd': '士林區',
#   'tele': '02-2871-1915'},
#  {'_id': '全聯士林大南',
#   'address': '臺北市士林區大南路315號',
#   'bigadd': '臺北市',
#   'lat': 25.08889,
#   'lng': 121.518067,
#   'name': '全聯士林大南',
#   'road': '大南路',
#   'smalladd': '士林區',
#   'tele': '02-2880-2763'},
#  {'_id': '全聯北市和平',
#   'address': '臺北市大安區和平東路１段63號',
#   'bigadd': '臺北市',
#   'lat': 25.027158,
#   'lng': 121.524609,
#   'name': '全聯北市和平',
#   'road': '和平東路１段',
#   'smalladd': '大安區',
#   'tele': '02-2396-5361'},
#  {'_id': '全聯文山萬年',
#   'address': '臺北市文山區羅斯福路５段170巷41號',
#   'bigadd': '臺北市',
#   'lat': 25.004432,
#   'lng': 121.536314,
#   'name': '全聯文山萬年',
#   'road': '羅斯福路５段',
#   'smalladd': '文山區',
#   'tele': '02-2933-3205'},
#  {'_id': '全聯北市建國',
#   'address': '臺北市大安區建國南路２段123巷16號',
#   'bigadd': '臺北市',
#   'lat': 25.029479,
#   'lng': 121.539063,
#   'name': '全聯北市建國',
#   'road': '建國南路２段',
#   'smalladd': '大安區',
#   'tele': '02-2784-9591'},
#  {'_id': '全聯萬華雙園',
#   'address': '臺北市萬華區興寧街2號',
#   'bigadd': '臺北市',
#   'lat': 25.032259,
#   'lng': 121.502027,
#   'name': '全聯萬華雙園',
#   'road': '興寧街',
#   'smalladd': '萬華區',
#   'tele': '02-2302-1066'},
#  {'_id': '全聯松山松興',
#   'address': '臺北市信義區松隆路36號',
#   'bigadd': '臺北市',
#   'lat': 25.043374,
#   'lng': 121.567473,
#   'name': '全聯松山松興',
#   'road': '松隆路',
#   'smalladd': '信義區',
#   'tele': '02-2763-8669'},
#  {'_id': '全聯南港凌雲',
#   'address': '臺北市南港區研究院路３段68巷9號',
#   'bigadd': '臺北市',
#   'lat': 25.035253,
#   'lng': 121.614331,
#   'name': '全聯南港凌雲',
#   'road': '研究院路３段',
#   'smalladd': '南港區',
#   'tele': '02-2788-2864'},
#  {'_id': '全聯文山永建',
#   'address': '臺北市文山區木柵路１段177號',
#   'bigadd': '臺北市',
#   'lat': 24.987731,
#   'lng': 121.550996,
#   'name': '全聯文山永建',
#   'road': '木柵路１段',
#   'smalladd': '文山區',
#   'tele': '02-2236-8375'},
#  {'_id': '全聯大安延吉',
#   'address': '臺北市大安區市民大道４段190號',
#   'bigadd': '臺北市',
#   'lat': 25.044188,
#   'lng': 121.553982,
#   'name': '全聯大安延吉',
#   'road': '市民大道４段',
#   'smalladd': '大安區',
#   'tele': '02-2772-5870'},
#  {'_id': '全聯文山忠順',
#   'address': '臺北市文山區忠順街２段22號',
#   'bigadd': '臺北市',
#   'lat': 24.984663,
#   'lng': 121.563104,
#   'name': '全聯文山忠順',
#   'road': '忠順街２段',
#   'smalladd': '文山區',
#   'tele': '02-2234-1532'},
#  {'_id': '全聯內湖',
#   'address': '臺北市內湖區港墘路１２７巷１０號',
#   'bigadd': '臺北市',
#   'lat': 25.077888,
#   'lng': 121.576952,
#   'name': '全聯內湖',
#   'road': '港墘路',
#   'smalladd': '內湖區',
#   'tele': '02-2799-6619'},
#  {'_id': '全聯中華',
#   'address': '臺北市萬華區中華路２段666號之12',
#   'bigadd': '臺北市',
#   'lat': 25.024239,
#   'lng': 121.511082,
#   'name': '全聯中華',
#   'road': '中華路２段',
#   'smalladd': '萬華區',
#   'tele': '02-2304-9528'},
#  {'_id': '全聯和德',
#   'address': '臺北市萬華區西園路２段215號',
#   'bigadd': '臺北市',
#   'lat': 25.027085,
#   'lng': 121.494217,
#   'name': '全聯和德',
#   'road': '西園路２段',
#   'smalladd': '萬華區',
#   'tele': '02-2301-6978'},
#  {'_id': '全聯關渡',
#   'address': '臺北市北投區中央北路４段532號',
#   'bigadd': '臺北市',
#   'lat': 25.128069,
#   'lng': 121.467818,
#   'name': '全聯關渡',
#   'road': '中央北路４段',
#   'smalladd': '北投區',
#   'tele': '02-2898-2362'},
#  {'_id': '全聯唭哩岸',
#   'address': '臺北市北投區東華街２段180號',
#   'bigadd': '臺北市',
#   'lat': 25.120295,
#   'lng': 121.51097,
#   'name': '全聯唭哩岸',
#   'road': '東華街２段',
#   'smalladd': '北投區',
#   'tele': '02-2826-1176'},
#  {'_id': '全聯大安',
#   'address': '臺北市大安區復興南路２段237號',
#   'bigadd': '臺北市',
#   'lat': 25.026015,
#   'lng': 121.543827,
#   'name': '全聯大安',
#   'road': '復興南路２段',
#   'smalladd': '大安區',
#   'tele': '02-2755-3018'},
#  {'_id': '全聯西門町',
#   'address': '臺北市萬華區長沙街２段110號',
#   'bigadd': '臺北市',
#   'lat': 25.04031,
#   'lng': 121.504023,
#   'name': '全聯西門町',
#   'road': '長沙街２段',
#   'smalladd': '萬華區',
#   'tele': '02-2370-8218'},
#  {'_id': '全聯台北東門',
#   'address': '臺北市大安區金山南路２段12號',
#   'bigadd': '臺北市',
#   'lat': 25.033493,
#   'lng': 121.526988,
#   'name': '全聯台北東門',
#   'road': '金山南路２段',
#   'smalladd': '大安區',
#   'tele': '02-2395-8765'},
#  {'_id': '全聯圓環',
#   'address': '臺北市大同區南京西路165號1樓',
#   'bigadd': '臺北市',
#   'lat': 25.054088,
#   'lng': 121.512992,
#   'name': '全聯圓環',
#   'road': '南京西路',
#   'smalladd': '大同區',
#   'tele': '02-2558-2526'},
#  {'_id': '全聯北投',
#   'address': '臺北市北投區北投路２段11號',
#   'bigadd': '臺北市',
#   'lat': 25.130538,
#   'lng': 121.498763,
#   'name': '全聯北投',
#   'road': '北投路２段',
#   'smalladd': '北投區',
#   'tele': '02-2894-8533'},
#  {'_id': '全聯中崙',
#   'address': '臺北市松山區八德路３段106巷1號',
#   'bigadd': '臺北市',
#   'lat': 25.047639,
#   'lng': 121.553794,
#   'name': '全聯中崙',
#   'road': '八德路３段',
#   'smalladd': '松山區',
#   'tele': '02-2579-0236'},
#  {'_id': '全聯鵬程',
#   'address': '臺北市松山區健康路399號',
#   'bigadd': '臺北市',
#   'lat': 25.054642,
#   'lng': 121.568809,
#   'name': '全聯鵬程',
#   'road': '健康路',
#   'smalladd': '松山區',
#   'tele': '02-2762-1233'},
#  {'_id': '全聯東湖',
#   'address': '臺北市內湖區東湖路118號',
#   'bigadd': '臺北市',
#   'lat': 25.06819,
#   'lng': 121.616185,
#   'name': '全聯東湖',
#   'road': '東湖路',
#   'smalladd': '內湖區',
#   'tele': '02-2630-8318'},
#  {'_id': '全聯西盛',
#   'address': '新北市新莊區西盛街202號',
#   'bigadd': '新北市',
#   'lat': 25.018296,
#   'lng': 121.42803,
#   'name': '全聯西盛',
#   'road': '西盛街',
#   'smalladd': '新莊區',
#   'tele': '02-2201-0388'},
#  {'_id': '全聯龍山',
#   'address': '臺北市萬華區廣州街263號',
#   'bigadd': '臺北市',
#   'lat': 25.036898,
#   'lng': 121.496467,
#   'name': '全聯龍山',
#   'road': '廣州街',
#   'smalladd': '萬華區',
#   'tele': '02-2336-7191'},
#  {'_id': '全聯三興',
#   'address': '臺北市信義區吳興街156巷6號',
#   'bigadd': '臺北市',
#   'lat': 25.029073,
#   'lng': 121.561167,
#   'name': '全聯三興',
#   'road': '吳興街',
#   'smalladd': '信義區',
#   'tele': '02-2739-0287'},
#  {'_id': '全聯社子',
#   'address': '臺北市士林區社正路59號',
#   'bigadd': '臺北市',
#   'lat': 25.089019,
#   'lng': 121.510087,
#   'name': '全聯社子',
#   'road': '社正路',
#   'smalladd': '士林區',
#   'tele': '02-2811-0786'},
#  {'_id': '全聯信義林口',
#   'address': '臺北市信義區林口街176號',
#   'bigadd': '臺北市',
#   'lat': 25.040631,
#   'lng': 121.580863,
#   'name': '全聯信義林口',
#   'road': '林口街',
#   'smalladd': '信義區',
#   'tele': '02-2726-7216'},
#  {'_id': '全聯敦南',
#   'address': '臺北市大安區忠孝東路４段126號B1',
#   'bigadd': '臺北市',
#   'lat': 25.041046,
#   'lng': 121.547335,
#   'name': '全聯敦南',
#   'road': '忠孝東路４段',
#   'smalladd': '大安區',
#   'tele': '02-8772-0102'},
#  {'_id': '全聯中山興安',
#   'address': '臺北市中山區興安街55號',
#   'bigadd': '臺北市',
#   'lat': 25.056289,
#   'lng': 121.541847,
#   'name': '全聯中山興安',
#   'road': '興安街',
#   'smalladd': '中山區',
#   'tele': '02-2500-0562'},
#  {'_id': '全聯民生社區',
#   'address': '臺北市松山區民生東路４段133號',
#   'bigadd': '臺北市',
#   'lat': 25.058476,
#   'lng': 121.554904,
#   'name': '全聯民生社區',
#   'road': '民生東路４段',
#   'smalladd': '松山區',
#   'tele': '02-2713-9682'},
#  {'_id': '全聯中山雙連',
#   'address': '臺北市中山區錦西街8號',
#   'bigadd': '臺北市',
#   'lat': 25.060233,
#   'lng': 121.521642,
#   'name': '全聯中山雙連',
#   'road': '錦西街',
#   'smalladd': '中山區',
#   'tele': '02-2511-7062'},
#  {'_id': '全聯文山木柵',
#   'address': '臺北市文山區木柵路３段41號',
#   'bigadd': '臺北市',
#   'lat': 24.988599,
#   'lng': 121.565807,
#   'name': '全聯文山木柵',
#   'road': '木柵路３段',
#   'smalladd': '文山區',
#   'tele': '02-2936-1296'},
#  {'_id': '全聯吉林',
#   'address': '臺北市中山區吉林路213號',
#   'bigadd': '臺北市',
#   'lat': 25.060507,
#   'lng': 121.530432,
#   'name': '全聯吉林',
#   'road': '吉林路',
#   'smalladd': '中山區',
#   'tele': '02-2562-1333'},
#  {'_id': '全聯五股',
#   'address': '新北市五股區成泰路１段235號之13',
#   'bigadd': '新北市',
#   'lat': 25.079402,
#   'lng': 121.436015,
#   'name': '全聯五股',
#   'road': '成泰路１段',
#   'smalladd': '五股區',
#   'tele': '02-8295-3966'},
#  {'_id': '全聯汐止龍安',
#   'address': '新北市汐止區龍安路28巷6號',
#   'bigadd': '新北市',
#   'lat': 25.064555,
#   'lng': 121.655082,
#   'name': '全聯汐止龍安',
#   'road': '龍安路',
#   'smalladd': '汐止區',
#   'tele': '02-2649-4296'},
#  {'_id': '全聯板橋新埔',
#   'address': '新北市板橋區光武街61號',
#   'bigadd': '新北市',
#   'lat': 25.025867,
#   'lng': 121.467349,
#   'name': '全聯板橋新埔',
#   'road': '光武街',
#   'smalladd': '板橋區',
#   'tele': '02-8253-6506'},
#  {'_id': '全聯鴻金寶',
#   'address': '新北市新莊區民安路188巷5號之2',
#   'bigadd': '新北市',
#   'lat': 25.023276,
#   'lng': 121.424927,
#   'name': '全聯鴻金寶',
#   'road': '民安路',
#   'smalladd': '新莊區',
#   'tele': '02-2208-2396'},
#  {'_id': '全聯三重天台',
#   'address': '新北市三重區重新路２段78號之21',
#   'bigadd': '新北市',
#   'lat': 25.061924,
#   'lng': 121.497226,
#   'name': '全聯三重天台',
#   'road': '重新路２段',
#   'smalladd': '三重區',
#   'tele': '02-2973-9535'},
#  {'_id': '全聯汐止建成',
#   'address': '新北市汐止區建成路58號',
#   'bigadd': '新北市',
#   'lat': 25.07301,
#   'lng': 121.663547,
#   'name': '全聯汐止建成',
#   'road': '建成路',
#   'smalladd': '汐止區',
#   'tele': '02-2641-6373'},
#  {'_id': '全聯中和秀朗',
#   'address': '新北市中和區秀朗路３段175巷2號',
#   'bigadd': '新北市',
#   'lat': 24.991394,
#   'lng': 121.524571,
#   'name': '全聯中和秀朗',
#   'road': '秀朗路３段',
#   'smalladd': '中和區',
#   'tele': '02-2946-6606'},
#  {'_id': '全聯北縣金山',
#   'address': '新北市金山區中山路114號',
#   'bigadd': '新北市',
#   'lat': 25.219739,
#   'lng': 121.639504,
#   'name': '全聯北縣金山',
#   'road': '中山路',
#   'smalladd': '金山區',
#   'tele': '02-2498-9013'},
#  {'_id': '全聯板橋溪洲',
#   'address': '新北市板橋區金門街295號B1',
#   'bigadd': '新北市',
#   'lat': 24.986654,
#   'lng': 121.430329,
#   'name': '全聯板橋溪洲',
#   'road': '金門街',
#   'smalladd': '板橋區',
#   'tele': '02-2682-5192'},
#  {'_id': '全聯永和永安',
#   'address': '新北市永和區中正路742號',
#   'bigadd': '新北市',
#   'lat': 25.010394,
#   'lng': 121.515342,
#   'name': '全聯永和永安',
#   'road': '中正路',
#   'smalladd': '永和區',
#   'tele': '02-8660-2181'},
#  {'_id': '全聯新店三民',
#   'address': '新北市新店區三民路42-1號',
#   'bigadd': '新北市',
#   'lat': 24.971742,
#   'lng': 121.536,
#   'name': '全聯新店三民',
#   'road': '三民路',
#   'smalladd': '新店區',
#   'tele': '02-2912-8002'},
#  {'_id': '全聯新店安康',
#   'address': '新北市新店區安康路二段133號',
#   'bigadd': '新北市',
#   'lat': 24.960679,
#   'lng': 121.512702,
#   'name': '全聯新店安康',
#   'road': '安康路２段',
#   'smalladd': '新店區',
#   'tele': '02-2211-3205'},
#  {'_id': '全聯深坑平埔',
#   'address': '新北市深坑區平埔街22巷8號',
#   'bigadd': '新北市',
#   'lat': 25.001038,
#   'lng': 121.615053,
#   'name': '全聯深坑平埔',
#   'road': '平埔街',
#   'smalladd': '深坑區',
#   'tele': '02-2662-0822'},
#  {'_id': '全聯汐止忠孝',
#   'address': '新北市汐止區忠孝東路429號',
#   'bigadd': '新北市',
#   'lat': 25.071829,
#   'lng': 121.665967,
#   'name': '全聯汐止忠孝',
#   'road': '忠孝東路',
#   'smalladd': '汐止區',
#   'tele': '02-8647-6668'},
#  {'_id': '全聯三重',
#   'address': '新北市三重區重安街70號光明市場2樓',
#   'bigadd': '新北市',
#   'lat': 25.057052,
#   'lng': 121.491854,
#   'name': '全聯三重',
#   'road': '重安街',
#   'smalladd': '三重區',
#   'tele': '02-2976-9224'},
#  {'_id': '全聯新莊',
#   'address': '新北市新莊區中和街１８８號地下室',
#   'bigadd': '新北市',
#   'lat': 25.049828,
#   'lng': 121.447605,
#   'name': '全聯新莊',
#   'road': '中和街',
#   'smalladd': '新莊區',
#   'tele': '02-2993-1995'},
#  {'_id': '全聯興隆',
#   'address': '臺北市文山區興隆路一段53號地下室',
#   'bigadd': '臺北市',
#   'lat': 25.003989,
#   'lng': 121.540941,
#   'name': '全聯興隆',
#   'road': '興隆路１段',
#   'smalladd': '文山區',
#   'tele': '02-8931-1551'},
#  {'_id': '全聯北新',
#   'address': '新北市新店區北新路二段252號地下室',
#   'bigadd': '新北市',
#   'lat': 24.97794,
#   'lng': 121.543349,
#   'name': '全聯北新',
#   'road': '北新路２段',
#   'smalladd': '新店區',
#   'tele': '02-2910-0370'},
#  {'_id': '全聯木新',
#   'address': '臺北市文山區恆光街37號',
#   'bigadd': '臺北市',
#   'lat': 24.982705,
#   'lng': 121.567063,
#   'name': '全聯木新',
#   'road': '恆光街',
#   'smalladd': '文山區',
#   'tele': '02-2234-8532'},
#  {'_id': '全聯竹圍',
#   'address': '新北市淡水區民族路31號地下室',
#   'bigadd': '新北市',
#   'lat': 25.136781,
#   'lng': 121.461244,
#   'name': '全聯竹圍',
#   'road': '民族路',
#   'smalladd': '淡水區',
#   'tele': '02-2624-2377'},
#  {'_id': '全聯蘆洲民族',
#   'address': '新北市蘆洲區水湳街74號1樓',
#   'bigadd': '新北市',
#   'lat': 25.090022,
#   'lng': 121.470407,
#   'name': '全聯蘆洲民族',
#   'road': '水湳街',
#   'smalladd': '蘆洲區',
#   'tele': '02-8283-2182'},
#  {'_id': '全聯永樂',
#   'address': '新北市蘆洲區永樂街38巷57弄2號',
#   'bigadd': '新北市',
#   'lat': 25.090343,
#   'lng': 121.458404,
#   'name': '全聯永樂',
#   'road': '永樂街',
#   'smalladd': '蘆洲區',
#   'tele': '02-8285-6732~3'},
#  {'_id': '全聯中平',
#   'address': '新北市新莊區中平路82巷27號',
#   'bigadd': '新北市',
#   'lat': 25.045129,
#   'lng': 121.446165,
#   'name': '全聯中平',
#   'road': '中平路',
#   'smalladd': '新莊區',
#   'tele': '02-8992-9800'},
#  {'_id': '全聯三峽安溪',
#   'address': '新北市三峽區中華路95號一樓',
#   'bigadd': '新北市',
#   'lat': 24.929311,
#   'lng': 121.371691,
#   'name': '全聯三峽安溪',
#   'road': '中華路',
#   'smalladd': '三峽區',
#   'tele': '02-2673-5246'},
#  {'_id': '全聯中安',
#   'address': '新北市中和區中安街196號B1',
#   'bigadd': '新北市',
#   'lat': 24.998952,
#   'lng': 121.511672,
#   'name': '全聯中安',
#   'road': '中安街',
#   'smalladd': '中和區',
#   'tele': '02-2925-0128'},
#  {'_id': '全聯大豐',
#   'address': '新北市新店區民族路190號地下室',
#   'bigadd': '新北市',
#   'lat': 24.975642,
#   'lng': 121.536319,
#   'name': '全聯大豐',
#   'road': '民族路',
#   'smalladd': '新店區',
#   'tele': '02-8667-3217'},
#  {'_id': '全聯中港',
#   'address': '新北市新莊區中華路二段1號地下1樓',
#   'bigadd': '新北市',
#   'lat': 25.044721,
#   'lng': 121.453085,
#   'name': '全聯中港',
#   'road': '中華路２段',
#   'smalladd': '新莊區',
#   'tele': '02-2992-7409'},
#  {'_id': '全聯江子翠',
#   'address': '新北市板橋區雙十路２段209號B1',
#   'bigadd': '新北市',
#   'lat': 25.029418,
#   'lng': 121.47333,
#   'name': '全聯江子翠',
#   'road': '雙十路２段',
#   'smalladd': '板橋區',
#   'tele': '02-8253-4058'},
#  {'_id': '全聯淡水博愛',
#   'address': '新北市淡水區中正東路35巷22號1+B1F',
#   'bigadd': '新北市',
#   'lat': 25.168793,
#   'lng': 121.446575,
#   'name': '全聯淡水博愛',
#   'road': '中正東路',
#   'smalladd': '淡水區',
#   'tele': '02-2626-6229'},
#  {'_id': '全聯大觀',
#   'address': '新北市板橋區大觀路３段236號B1',
#   'bigadd': '新北市',
#   'lat': 24.992308,
#   'lng': 121.429275,
#   'name': '全聯大觀',
#   'road': '大觀路３段',
#   'smalladd': '板橋區',
#   'tele': '02-2675-6939'},
#  {'_id': '全聯文聖',
#   'address': '新北市板橋區文聖街73號1+2樓',
#   'bigadd': '新北市',
#   'lat': 25.030531,
#   'lng': 121.477364,
#   'name': '全聯文聖',
#   'road': '文聖街',
#   'smalladd': '板橋區',
#   'tele': '02-8259-5352'},
#  {'_id': '全聯雨農',
#   'address': '新北市板橋區雨農路27巷2號',
#   'bigadd': '新北市',
#   'lat': 25.024076,
#   'lng': 121.46122,
#   'name': '全聯雨農',
#   'road': '雨農路',
#   'smalladd': '板橋區',
#   'tele': '02-8251-0515'},
#  {'_id': '全聯泰山',
#   'address': '新北市泰山區明志路三段87號',
#   'bigadd': '新北市',
#   'lat': 25.041464,
#   'lng': 121.425128,
#   'name': '全聯泰山',
#   'road': '明志路３段',
#   'smalladd': '泰山區',
#   'tele': '02-2906-1835'},
#  {'_id': '全聯南華',
#   'address': '新北市中和區南華路２７號Ｂ１',
#   'bigadd': '新北市',
#   'lat': 24.996006,
#   'lng': 121.503036,
#   'name': '全聯南華',
#   'road': '南華路',
#   'smalladd': '中和區',
#   'tele': '02-2248-2639'},
#  {'_id': '全聯金城',
#   'address': '新北市土城區金城路３段12號B1、B1-1，14號B1',
#   'bigadd': '新北市',
#   'lat': 24.986077,
#   'lng': 121.464801,
#   'name': '全聯金城',
#   'road': '金城路３段',
#   'smalladd': '土城區',
#   'tele': '02-2266-5567'},
#  {'_id': '全聯土城裕民',
#   'address': '新北市土城區裕民路116號B1',
#   'bigadd': '新北市',
#   'lat': 24.986359,
#   'lng': 121.451127,
#   'name': '全聯土城裕民',
#   'road': '裕民路',
#   'smalladd': '土城區',
#   'tele': '02-2266-5123'},
#  {'_id': '全聯三重介壽',
#   'address': '新北市三重區龍門路6-1號',
#   'bigadd': '新北市',
#   'lat': 25.071241,
#   'lng': 121.494702,
#   'name': '全聯三重介壽',
#   'road': '龍門路',
#   'smalladd': '三重區',
#   'tele': '02-8983-2512'},
#  {'_id': '全聯三重中正',
#   'address': '新北市三重區中正北路592號',
#   'bigadd': '新北市',
#   'lat': 25.072082,
#   'lng': 121.469859,
#   'name': '全聯三重中正',
#   'road': '中正北路',
#   'smalladd': '三重區',
#   'tele': '02-8982-7689'},
#  {'_id': '全聯新莊化成',
#   'address': '新北市新莊區化成路71號',
#   'bigadd': '新北市',
#   'lat': 25.046096,
#   'lng': 121.465284,
#   'name': '全聯新莊化成',
#   'road': '化成路',
#   'smalladd': '新莊區',
#   'tele': '02-2276-0765'},
#  {'_id': '全聯三重仁愛',
#   'address': '新北市三重區仁愛街278號',
#   'bigadd': '新北市',
#   'lat': 25.078972,
#   'lng': 121.492441,
#   'name': '全聯三重仁愛',
#   'road': '仁愛街',
#   'smalladd': '三重區',
#   'tele': '02-2980-0318'},
#  {'_id': '全聯瑞芳中正',
#   'address': '新北市瑞芳區中正路81號',
#   'bigadd': '新北市',
#   'lat': 25.107589,
#   'lng': 121.805342,
#   'name': '全聯瑞芳中正',
#   'road': '中正路',
#   'smalladd': '瑞芳區',
#   'tele': '02-2497-6356'},
#  {'_id': '全聯蘆洲長安',
#   'address': '新北市蘆洲區長安街232號',
#   'bigadd': '新北市',
#   'lat': 25.085718,
#   'lng': 121.458079,
#   'name': '全聯蘆洲長安',
#   'road': '長安街',
#   'smalladd': '蘆洲區',
#   'tele': '02-2282-8611'},
#  {'_id': '全聯中壢環東',
#   'address': '桃園市中壢區環中東路２段746、750、750-1、750-2號',
#   'bigadd': '桃園市',
#   'lat': 24.943237,
#   'lng': 121.227452,
#   'name': '全聯中壢環東',
#   'road': '環中東路２段',
#   'smalladd': '中壢區',
#   'tele': '03-428-5469'},
#  {'_id': '全聯中美',
#   'address': '桃園市中壢區中美路二段77號',
#   'bigadd': '桃園市',
#   'lat': 24.959439,
#   'lng': 121.222029,
#   'name': '全聯中美',
#   'road': '中美路２段',
#   'smalladd': '中壢區',
#   'tele': '03-422-6777'},
#  {'_id': '全聯平鎮南豐',
#   'address': '桃園市平鎮區南豐路53.55號',
#   'bigadd': '桃園市',
#   'lat': 24.900278,
#   'lng': 121.209524,
#   'name': '全聯平鎮南豐',
#   'road': '南豐路',
#   'smalladd': '平鎮區',
#   'tele': '03-469-0356'},
#  {'_id': '全聯平鎮中豐',
#   'address': '桃園市平鎮區中豐路南勢二段326號',
#   'bigadd': '桃園市',
#   'lat': 24.911101,
#   'lng': 121.211032,
#   'name': '全聯平鎮中豐',
#   'road': '中豐路南勢２段',
#   'smalladd': '平鎮區',
#   'tele': '03-439-5082'},
#  {'_id': '全聯蘆竹大竹',
#   'address': '桃園市蘆竹區大新一街15號',
#   'bigadd': '桃園市',
#   'lat': 25.024268,
#   'lng': 121.256745,
#   'name': '全聯蘆竹大竹',
#   'road': '大新一街',
#   'smalladd': '蘆竹區',
#   'tele': '03-313-3162'},
#  {'_id': '全聯竹北勝利',
#   'address': '新竹縣竹北市勝利六街36號',
#   'bigadd': '新竹縣',
#   'lat': 24.825096,
#   'lng': 121.025589,
#   'name': '全聯竹北勝利',
#   'road': '勝利六街',
#   'smalladd': '竹北市',
#   'tele': '03-658-9361'},
#  {'_id': '全聯新竹竹東',
#   'address': '新竹縣竹東鎮仁愛路226號',
#   'bigadd': '新竹縣',
#   'lat': 24.734939,
#   'lng': 121.09074,
#   'name': '全聯新竹竹東',
#   'road': '仁愛路',
#   'smalladd': '竹東鎮',
#   'tele': '03-594-0278'},
#  {'_id': '全聯竹北',
#   'address': '新竹縣竹北市民權街40巷2號',
#   'bigadd': '新竹縣',
#   'lat': 24.833275,
#   'lng': 121.011808,
#   'name': '全聯竹北',
#   'road': '民權街',
#   'smalladd': '竹北市',
#   'tele': '03-551-1123'},
#  {'_id': '全聯竹北中正西',
#   'address': '新竹縣竹北市中正西路49號',
#   'bigadd': '新竹縣',
#   'lat': 24.8402,
#   'lng': 121.001723,
#   'name': '全聯竹北中正西',
#   'road': '中正西路',
#   'smalladd': '竹北市',
#   'tele': '03-656-2123'},
#  {'_id': '全聯新豐',
#   'address': '新竹縣新豐鄉學府路131號',
#   'bigadd': '新竹縣',
#   'lat': 24.871389,
#   'lng': 120.996648,
#   'name': '全聯新豐',
#   'road': '學府路',
#   'smalladd': '新豐鄉',
#   'tele': '03-557-5434'},
#  {'_id': '全聯湖口二',
#   'address': '新竹縣湖口鄉民權街61號',
#   'bigadd': '新竹縣',
#   'lat': 24.903494,
#   'lng': 121.046754,
#   'name': '全聯湖口二',
#   'road': '民權街',
#   'smalladd': '湖口鄉',
#   'tele': '03-599-7434'},
#  {'_id': '全聯竹南',
#   'address': '苗栗縣竹南鎮大營路175-1號',
#   'bigadd': '苗栗縣',
#   'lat': 24.686928,
#   'lng': 120.872612,
#   'name': '全聯竹南',
#   'road': '大營路',
#   'smalladd': '竹南鎮',
#   'tele': '037-464-790'},
#  {'_id': '全聯通霄',
#   'address': '苗栗縣通霄鎮中正路20號',
#   'bigadd': '苗栗縣',
#   'lat': 24.490341,
#   'lng': 120.681837,
#   'name': '全聯通霄',
#   'road': '通東里中正路',
#   'smalladd': '通霄鎮',
#   'tele': '037-754-854'},
#  {'_id': '全聯台中崇德',
#   'address': '臺中市北區崇德路一段230號',
#   'bigadd': '臺中市',
#   'lat': 24.160547,
#   'lng': 120.685158,
#   'name': '全聯台中崇德',
#   'road': '崇德路１段',
#   'smalladd': '北區',
#   'tele': '04-2230-0365'},
#  {'_id': '全聯台中復興',
#   'address': '臺中市南區復興路二段160號',
#   'bigadd': '臺中市',
#   'lat': 24.126758,
#   'lng': 120.665811,
#   'name': '全聯台中復興',
#   'road': '復興路２段',
#   'smalladd': '南區',
#   'tele': '04-2261-2116'},
#  {'_id': '全聯台中黎明',
#   'address': '臺中市南屯區黎明路一段1040號',
#   'bigadd': '臺中市',
#   'lat': 24.139027,
#   'lng': 120.638029,
#   'name': '全聯台中黎明',
#   'road': '黎明路１段',
#   'smalladd': '南屯區',
#   'tele': '04-2381-3031'},
#  {'_id': '全聯台中東山',
#   'address': '臺中市北屯區東山路一段173之1號',
#   'bigadd': '臺中市',
#   'lat': 24.170292,
#   'lng': 120.708026,
#   'name': '全聯台中東山',
#   'road': '東山路１段',
#   'smalladd': '北屯區',
#   'tele': '04-2437-5028'},
#  {'_id': '全聯台中陜西',
#   'address': '臺中市北區陜西路66號',
#   'bigadd': '臺中市',
#   'lat': 24.169058,
#   'lng': 120.668351,
#   'name': '全聯台中陜西',
#   'road': '陜西路',
#   'smalladd': '北區',
#   'tele': '04-2298-0326'},
#  {'_id': '全聯台中東興',
#   'address': '臺中市南屯區東興路二段236號',
#   'bigadd': '臺中市',
#   'lat': 24.142473,
#   'lng': 120.653119,
#   'name': '全聯台中東興',
#   'road': '東興路２段',
#   'smalladd': '南屯區',
#   'tele': '04-2475-2129'},
#  {'_id': '全聯五權',
#   'address': '臺中市北區五權路１７６號中央市場內',
#   'bigadd': '臺中市',
#   'lat': 24.149027,
#   'lng': 120.675266,
#   'name': '全聯五權',
#   'road': '五權路',
#   'smalladd': '北區',
#   'tele': '04-2202-3660'},
#  {'_id': '全聯軍功',
#   'address': '臺中市北屯區軍功路２段39號',
#   'bigadd': '臺中市',
#   'lat': 24.176693,
#   'lng': 120.719069,
#   'name': '全聯軍功',
#   'road': '軍功路２段',
#   'smalladd': '北屯區',
#   'tele': '04-2436-8748'},
#  {'_id': '全聯大墩',
#   'address': '臺中市西屯區大墩路1168號',
#   'bigadd': '臺中市',
#   'lat': 24.160072,
#   'lng': 120.652907,
#   'name': '全聯大墩',
#   'road': '大墩路',
#   'smalladd': '西屯區',
#   'tele': '04-2327-5976'},
#  {'_id': '全聯天津',
#   'address': '臺中市北區天津路二段171號',
#   'bigadd': '臺中市',
#   'lat': 24.169959,
#   'lng': 120.678514,
#   'name': '全聯天津',
#   'road': '天津路２段',
#   'smalladd': '北區',
#   'tele': '04-2298-2334'},
#  {'_id': '全聯精誠',
#   'address': '臺中市西區精誠路294號1樓',
#   'bigadd': '臺中市',
#   'lat': 24.148704,
#   'lng': 120.655061,
#   'name': '全聯精誠',
#   'road': '精誠路',
#   'smalladd': '西區',
#   'tele': '04-2328-2660'},
#  {'_id': '全聯中工',
#   'address': '臺中市西屯區中工二路2號',
#   'bigadd': '臺中市',
#   'lat': 24.182152,
#   'lng': 120.616587,
#   'name': '全聯中工',
#   'road': '中工二路',
#   'smalladd': '西屯區',
#   'tele': '04-2350-4708'},
#  {'_id': '全聯五權二',
#   'address': '臺中市北區中清路１段27號1樓',
#   'bigadd': '臺中市',
#   'lat': 24.152766,
#   'lng': 120.676925,
#   'name': '全聯五權二',
#   'road': '中清路１段',
#   'smalladd': '北區',
#   'tele': '04-2208-2870'},
#  {'_id': '全聯松竹',
#   'address': '臺中市北屯區松竹路二段178巷51號',
#   'bigadd': '臺中市',
#   'lat': 24.184474,
#   'lng': 120.695538,
#   'name': '全聯松竹',
#   'road': '松竹路２段',
#   'smalladd': '北屯區',
#   'tele': '04-2242-5357'},
#  {'_id': '全聯大連',
#   'address': '臺中市北屯區大連路二段12號',
#   'bigadd': '臺中市',
#   'lat': 24.176182,
#   'lng': 120.682199,
#   'name': '全聯大連',
#   'road': '大連路２段',
#   'smalladd': '北屯區',
#   'tele': '04-2249-3677'},
#  {'_id': '全聯忠明',
#   'address': '臺中市西區忠明南路445號',
#   'bigadd': '臺中市',
#   'lat': 0,
#   'lng': 0,
#   'name': '全聯忠明',
#   'road': '忠明南路',
#   'smalladd': '西區',
#   'tele': '04-2375-6219'},
#  {'_id': '全聯北屯',
#   'address': '臺中市北屯區北屯路289之10號',
#   'bigadd': '臺中市',
#   'lat': 24.16748,
#   'lng': 120.695557,
#   'name': '全聯北屯',
#   'road': '北屯路',
#   'smalladd': '北屯區',
#   'tele': '04-2231-2080'},
#  {'_id': '全聯南屯',
#   'address': '臺中市南屯區永春東路1043號',
#   'bigadd': '臺中市',
#   'lat': 24.135247,
#   'lng': 120.637849,
#   'name': '全聯南屯',
#   'road': '永春東路',
#   'smalladd': '南屯區',
#   'tele': '04-2380-0222'},
#  {'_id': '全聯大智',
#   'address': '臺中市東區大智路350巷2號1樓',
#   'bigadd': '臺中市',
#   'lat': 24.12949,
#   'lng': 120.690117,
#   'name': '全聯大智',
#   'road': '大智路',
#   'smalladd': '東區',
#   'tele': '04-2280-2267'},
#  {'_id': '全聯文心',
#   'address': '臺中市西屯區重慶路136號',
#   'bigadd': '臺中市',
#   'lat': 24.16633,
#   'lng': 120.65667,
#   'name': '全聯文心',
#   'road': '重慶路',
#   'smalladd': '西屯區',
#   'tele': '04-2315-1050'},
#  {'_id': '全聯十甲',
#   'address': '臺中市東區十甲路452號',
#   'bigadd': '臺中市',
#   'lat': 24.144367,
#   'lng': 120.709282,
#   'name': '全聯十甲',
#   'road': '十甲路',
#   'smalladd': '東區',
#   'tele': '04-2215-3229'},
#  {'_id': '全聯台中文華',
#   'address': '臺中市西屯區河南路１段125號',
#   'bigadd': '臺中市',
#   'lat': 24.169844,
#   'lng': 120.661941,
#   'name': '全聯台中文華',
#   'road': '河南路１段',
#   'smalladd': '西屯區',
#   'tele': '04-2316-5317'},
#  {'_id': '全聯台中中科',
#   'address': '臺中市西屯區福科路600號',
#   'bigadd': '臺中市',
#   'lat': 24.186999,
#   'lng': 120.613344,
#   'name': '全聯台中中科',
#   'road': '福科路',
#   'smalladd': '西屯區',
#   'tele': '04-2462-0379'},
#  {'_id': '全聯旅順',
#   'address': '臺中市北屯區旅順路二段78號1樓',
#   'bigadd': '臺中市',
#   'lat': 24.174393,
#   'lng': 120.687888,
#   'name': '全聯旅順',
#   'road': '旅順路２段',
#   'smalladd': '北屯區',
#   'tele': '04-2241-0470'},
#  {'_id': '全聯中清',
#   'address': '臺中市北屯區后庄路３５巷１號',
#   'bigadd': '臺中市',
#   'lat': 24.189211,
#   'lng': 120.663502,
#   'name': '全聯中清',
#   'road': '后庄路',
#   'smalladd': '北屯區',
#   'tele': '04-2426-1698'},
#  {'_id': '全聯逢甲',
#   'address': '臺中市西屯區黎明路三段246號',
#   'bigadd': '臺中市',
#   'lat': 24.179568,
#   'lng': 120.637675,
#   'name': '全聯逢甲',
#   'road': '黎明路３段',
#   'smalladd': '西屯區',
#   'tele': '04-2708-4655'},
#  {'_id': '全聯台中外埔',
#   'address': '臺中市外埔區六分路297號1樓',
#   'bigadd': '臺中市',
#   'lat': 24.331725,
#   'lng': 120.653787,
#   'name': '全聯台中外埔',
#   'road': '六分路',
#   'smalladd': '外埔區',
#   'tele': '04-2683-8355'},
#  {'_id': '全聯頭家',
#   'address': '臺中市潭子區中山路一段225巷6號',
#   'bigadd': '臺中市',
#   'lat': 24.197123,
#   'lng': 120.702335,
#   'name': '全聯頭家',
#   'road': '中山路１段',
#   'smalladd': '潭子區',
#   'tele': '04-2531-2709'},
#  {'_id': '全聯神岡二',
#   'address': '臺中市神岡區昌平路５段313巷1號',
#   'bigadd': '臺中市',
#   'lat': 24.244225,
#   'lng': 120.682803,
#   'name': '全聯神岡二',
#   'road': '昌平路５段',
#   'smalladd': '神岡區',
#   'tele': '04-2562-0416'},
#  {'_id': '全聯太平宜昌',
#   'address': '臺中市太平區宜昌路568號1樓',
#   'bigadd': '臺中市',
#   'lat': 24.14787,
#   'lng': 120.715848,
#   'name': '全聯太平宜昌',
#   'road': '宜昌路',
#   'smalladd': '太平區',
#   'tele': '04-2278-7351'},
#  {'_id': '全聯豐原大社',
#   'address': '臺中市豐原區大豐路５段516號',
#   'bigadd': '臺中市',
#   'lat': 24.247752,
#   'lng': 120.69969,
#   'name': '全聯豐原大社',
#   'road': '大豐路５段',
#   'smalladd': '豐原區',
#   'tele': '04-2528-0230'},
#  {'_id': '全聯太平',
#   'address': '臺中市太平區樹德路117號',
#   'bigadd': '臺中市',
#   'lat': 24.154204,
#   'lng': 120.711878,
#   'name': '全聯太平',
#   'road': '樹德路',
#   'smalladd': '太平區',
#   'tele': '04-2395-2770'},
#  {'_id': '全聯東勢東蘭',
#   'address': '臺中市東勢區東蘭路５４之２號',
#   'bigadd': '臺中市',
#   'lat': 24.266538,
#   'lng': 120.824761,
#   'name': '全聯東勢東蘭',
#   'road': '東蘭路',
#   'smalladd': '東勢區',
#   'tele': '04-2587-7537'},
#  {'_id': '全聯后里',
#   'address': '臺中市后里區后里村甲后路587號',
#   'bigadd': '臺中市',
#   'lat': 24.309444,
#   'lng': 120.718068,
#   'name': '全聯后里',
#   'road': '甲后路',
#   'smalladd': '后里區',
#   'tele': '04-2558-3498'},
#  {'_id': '全聯國光',
#   'address': '臺中市大里區國光路二段70號',
#   'bigadd': '臺中市',
#   'lat': 24.102137,
#   'lng': 120.682186,
#   'name': '全聯國光',
#   'road': '國光路２段',
#   'smalladd': '大里區',
#   'tele': '04-2483-0340'},
#  {'_id': '全聯大里',
#   'address': '臺中市大里區東榮路八號',
#   'bigadd': '臺中市',
#   'lat': 24.110251,
#   'lng': 120.689149,
#   'name': '全聯大里',
#   'road': '東榮路',
#   'smalladd': '大里區',
#   'tele': '04-2483-9901'},
#  {'_id': '全聯沙鹿',
#   'address': '臺中市沙鹿區大同街119之1號',
#   'bigadd': '臺中市',
#   'lat': 24.239134,
#   'lng': 120.559035,
#   'name': '全聯沙鹿',
#   'road': '大同街',
#   'smalladd': '沙鹿區',
#   'tele': '04-2663-2748'},
#  {'_id': '全聯向陽',
#   'address': '臺中市豐原區向陽路230號',
#   'bigadd': '臺中市',
#   'lat': 24.251728,
#   'lng': 120.726925,
#   'name': '全聯向陽',
#   'road': '向陽路',
#   'smalladd': '豐原區',
#   'tele': '04-2524-3672'},
#  {'_id': '全聯霧峰',
#   'address': '臺中市霧峰區民生路７５號',
#   'bigadd': '臺中市',
#   'lat': 24.064633,
#   'lng': 120.700023,
#   'name': '全聯霧峰',
#   'road': '民生路',
#   'smalladd': '霧峰區',
#   'tele': '04-2331-2832'},
#  {'_id': '全聯大肚',
#   'address': '臺中市大肚區沙田路二段592號',
#   'bigadd': '臺中市',
#   'lat': 24.150065,
#   'lng': 120.545983,
#   'name': '全聯大肚',
#   'road': '沙田路２段',
#   'smalladd': '大肚區',
#   'tele': '04-2699-0351'},
#  {'_id': '全聯神岡',
#   'address': '臺中市神岡區中山路832號',
#   'bigadd': '臺中市',
#   'lat': 24.249792,
#   'lng': 120.678602,
#   'name': '全聯神岡',
#   'road': '中山路',
#   'smalladd': '神岡區',
#   'tele': '04-2561-8046'},
#  {'_id': '全聯潭子',
#   'address': '臺中市潭子區勝利路348號',
#   'bigadd': '臺中市',
#   'lat': 24.21427,
#   'lng': 120.70076,
#   'name': '全聯潭子',
#   'road': '勝利路',
#   'smalladd': '潭子區',
#   'tele': '04-2533-6535'},
#  {'_id': '全聯大雅學府',
#   'address': '臺中市大雅區學府路109之11號',
#   'bigadd': '臺中市',
#   'lat': 24.218734,
#   'lng': 120.65038,
#   'name': '全聯大雅學府',
#   'road': '學府路',
#   'smalladd': '大雅區',
#   'tele': '04-2565-4966'},
#  {'_id': '全聯塗城',
#   'address': '臺中市大里區成功路538號',
#   'bigadd': '臺中市',
#   'lat': 24.091048,
#   'lng': 120.703523,
#   'name': '全聯塗城',
#   'road': '成功路',
#   'smalladd': '大里區',
#   'tele': '04-2496-8218'},
#  {'_id': '全聯田心',
#   'address': '臺中市豐原區田心路二段182號',
#   'bigadd': '臺中市',
#   'lat': 24.239562,
#   'lng': 120.72107,
#   'name': '全聯田心',
#   'road': '田心路２段',
#   'smalladd': '豐原區',
#   'tele': '04-2524-4638'},
#  {'_id': '全聯中興',
#   'address': '臺中市清水區中興街57號',
#   'bigadd': '臺中市',
#   'lat': 24.271995,
#   'lng': 120.574619,
#   'name': '全聯中興',
#   'road': '中興街',
#   'smalladd': '清水區',
#   'tele': '04-2622-2558'},
#  {'_id': '全聯大甲',
#   'address': '臺中市大甲區復興路59號',
#   'bigadd': '臺中市',
#   'lat': 24.346324,
#   'lng': 120.620071,
#   'name': '全聯大甲',
#   'road': '復興路',
#   'smalladd': '大甲區',
#   'tele': '04-2688-0775'},
#  {'_id': '全聯遊園',
#   'address': '臺中市大肚區遊園路二段216號',
#   'bigadd': '臺中市',
#   'lat': 24.174133,
#   'lng': 120.581211,
#   'name': '全聯遊園',
#   'road': '遊園路２段',
#   'smalladd': '大肚區',
#   'tele': '04-2691-6097'},
#  {'_id': '全聯東平',
#   'address': '臺中市太平區東平路499號',
#   'bigadd': '臺中市',
#   'lat': 24.133495,
#   'lng': 120.719115,
#   'name': '全聯東平',
#   'road': '東平路',
#   'smalladd': '太平區',
#   'tele': '04-2277-2726'},
#  {'_id': '全聯烏日',
#   'address': '臺中市烏日區中山路２段１０８號',
#   'bigadd': '臺中市',
#   'lat': 24.106148,
#   'lng': 120.626573,
#   'name': '全聯烏日',
#   'road': '中山路２段',
#   'smalladd': '烏日區',
#   'tele': '04-2336-6467'},
#  {'_id': '全聯潭陽',
#   'address': '臺中市潭子區潭子街１段31巷64號',
#   'bigadd': '臺中市',
#   'lat': 24.212223,
#   'lng': 120.706508,
#   'name': '全聯潭陽',
#   'road': '潭子街１段',
#   'smalladd': '潭子區',
#   'tele': '04-2538-0588'},
#  {'_id': '全聯雅環',
#   'address': '臺中市大雅區雅環路二段87號',
#   'bigadd': '臺中市',
#   'lat': 24.225684,
#   'lng': 120.652907,
#   'name': '全聯雅環',
#   'road': '雅環路２段',
#   'smalladd': '大雅區',
#   'tele': '04-2568-5868'},
#  {'_id': '全聯沙鹿二',
#   'address': '臺中市沙鹿區中山路434號',
#   'bigadd': '臺中市',
#   'lat': 24.243915,
#   'lng': 120.562251,
#   'name': '全聯沙鹿二',
#   'road': '中山路',
#   'smalladd': '沙鹿區',
#   'tele': '04-2662-0334'},
#  {'_id': '全聯明賢',
#   'address': '南投縣草屯鎮中山街57號',
#   'bigadd': '南投縣',
#   'lat': 23.975783,
#   'lng': 120.682398,
#   'name': '全聯明賢',
#   'road': '中山街',
#   'smalladd': '草屯鎮',
#   'tele': '049-231-3422'},
#  {'_id': '全聯埔里',
#   'address': '南投縣埔里鎮中山路３段376號',
#   'bigadd': '南投縣',
#   'lat': 23.969414,
#   'lng': 120.95557,
#   'name': '全聯埔里',
#   'road': '中山路３段',
#   'smalladd': '埔里鎮',
#   'tele': '049-291-7624'},
#  {'_id': '全聯南投',
#   'address': '南投縣南投市南陽路452號1樓',
#   'bigadd': '南投縣',
#   'lat': 23.912494,
#   'lng': 120.681489,
#   'name': '全聯南投',
#   'road': '南陽路',
#   'smalladd': '南投市',
#   'tele': '049-224-8375'},
#  {'_id': '全聯大明',
#   'address': '南投縣竹山鎮竹圍里大禮路129號',
#   'bigadd': '南投縣',
#   'lat': 23.759407,
#   'lng': 120.680338,
#   'name': '全聯大明',
#   'road': '大禮路',
#   'smalladd': '竹山鎮',
#   'tele': '049-263-3062'},
#  {'_id': '全聯南興',
#   'address': '南投縣埔里鎮南興街249號',
#   'bigadd': '南投縣',
#   'lat': 23.963813,
#   'lng': 120.965459,
#   'name': '全聯南興',
#   'road': '南興街',
#   'smalladd': '埔里鎮',
#   'tele': '049-299-8508'},
#  {'_id': '全聯草屯',
#   'address': '南投縣草屯鎮信義街368號',
#   'bigadd': '南投縣',
#   'lat': 23.982979,
#   'lng': 120.679976,
#   'name': '全聯草屯',
#   'road': '信義街',
#   'smalladd': '草屯鎮',
#   'tele': '049-231-4191'},
#  {'_id': '全聯北門',
#   'address': '南投縣埔里鎮自強路80號',
#   'bigadd': '南投縣',
#   'lat': 23.967068,
#   'lng': 120.972213,
#   'name': '全聯北門',
#   'road': '自強路',
#   'smalladd': '埔里鎮',
#   'tele': '049-242-1160'},
#  {'_id': '全聯虎山',
#   'address': '南投縣草屯鎮虎山路500之1之4號',
#   'bigadd': '南投縣',
#   'lat': 23.968855,
#   'lng': 120.687228,
#   'name': '全聯虎山',
#   'road': '虎山路',
#   'smalladd': '草屯鎮',
#   'tele': '049-233-1920'},
#  {'_id': '全聯竹山',
#   'address': '南投縣竹山鎮竹山路136號',
#   'bigadd': '南投縣',
#   'lat': 23.754848,
#   'lng': 120.682685,
#   'name': '全聯竹山',
#   'road': '竹山路',
#   'smalladd': '竹山鎮',
#   'tele': '049-263-5201'},
#  {'_id': '全聯彰安',
#   'address': '彰化縣彰化市中正路二段828號1樓',
#   'bigadd': '彰化縣',
#   'lat': 24.064554,
#   'lng': 120.534155,
#   'name': '全聯彰安',
#   'road': '中正路２段',
#   'smalladd': '彰化市',
#   'tele': '04-751-7411'},
#  {'_id': '全聯三民',
#   'address': '彰化縣彰化市三民路430號1樓',
#   'bigadd': '彰化縣',
#   'lat': 24.086673,
#   'lng': 120.549315,
#   'name': '全聯三民',
#   'road': '三民路',
#   'smalladd': '彰化市',
#   'tele': '04-729-5416'},
#  {'_id': '全聯長興',
#   'address': '彰化縣彰化市光復路35號1樓',
#   'bigadd': '彰化縣',
#   'lat': 24.080712,
#   'lng': 120.544728,
#   'name': '全聯長興',
#   'road': '光復路',
#   'smalladd': '彰化市',
#   'tele': '04-729-8796'},
#  {'_id': '全聯彰化自強南',
#   'address': '彰化縣彰化市自強南路589號1樓',
#   'bigadd': '彰化縣',
#   'lat': 24.078966,
#   'lng': 120.530526,
#   'name': '全聯彰化自強南',
#   'road': '自強南路',
#   'smalladd': '彰化市',
#   'tele': '04-763-4986'},
#  {'_id': '全聯彰化延平',
#   'address': '彰化縣彰化市延平路479號',
#   'bigadd': '彰化縣',
#   'lat': 24.062749,
#   'lng': 120.54012,
#   'name': '全聯彰化延平',
#   'road': '延平路',
#   'smalladd': '彰化市',
#   'tele': '04-712-1751'},
#  {'_id': '全聯新北斗',
#   'address': '彰化縣北斗鎮復興路353號1樓',
#   'bigadd': '彰化縣',
#   'lat': 23.879044,
#   'lng': 120.526661,
#   'name': '全聯新北斗',
#   'road': '復興路',
#   'smalladd': '北斗鎮',
#   'tele': '04-888-2124'},
#  {'_id': '全聯員林',
#   'address': '彰化縣員林鎮三和里三民東街359號1樓',
#   'bigadd': '彰化縣',
#   'lat': 23.960869,
#   'lng': 120.582464,
#   'name': '全聯員林',
#   'road': '三民東街',
#   'smalladd': '員林鎮',
#   'tele': '04-833-2099'},
#  {'_id': '全聯二林',
#   'address': '彰化縣二林鎮南光里大成路342號1樓',
#   'bigadd': '彰化縣',
#   'lat': 23.894114,
#   'lng': 120.363824,
#   'name': '全聯二林',
#   'road': '大成路',
#   'smalladd': '二林鎮',
#   'tele': '04-896-0724'},
#  {'_id': '全聯田中',
#   'address': '彰化縣田中鎮中正路305號1樓',
#   'bigadd': '彰化縣',
#   'lat': 23.859147,
#   'lng': 120.583143,
#   'name': '全聯田中',
#   'road': '中正路',
#   'smalladd': '田中鎮',
#   'tele': '04-875-6389'},
#  {'_id': '全聯溪湖',
#   'address': '彰化縣溪湖鎮大發路56號1樓',
#   'bigadd': '彰化縣',
#   'lat': 23.963455,
#   'lng': 120.476222,
#   'name': '全聯溪湖',
#   'road': '大發路',
#   'smalladd': '溪湖鎮',
#   'tele': '04-885-6279'},
#  {'_id': '全聯靜修',
#   'address': '彰化縣員林鎮南平一街66號1樓',
#   'bigadd': '彰化縣',
#   'lat': 23.965227,
#   'lng': 120.564971,
#   'name': '全聯靜修',
#   'road': '南平一街',
#   'smalladd': '員林鎮',
#   'tele': '04-838-1050'},
#  {'_id': '全聯鹿港',
#   'address': '彰化縣鹿港鎮復興路210號1樓',
#   'bigadd': '彰化縣',
#   'lat': 24.054855,
#   'lng': 120.438459,
#   'name': '全聯鹿港',
#   'road': '復興路',
#   'smalladd': '鹿港鎮',
#   'tele': '04-778-9871'},
#  {'_id': '全聯育英',
#   'address': '彰化縣員林鎮育英路600號1樓',
#   'bigadd': '彰化縣',
#   'lat': 23.969345,
#   'lng': 120.573937,
#   'name': '全聯育英',
#   'road': '育英路',
#   'smalladd': '員林鎮',
#   'tele': '04-836-9077'},
#  {'_id': '全聯永靖',
#   'address': '彰化縣永靖鄉瑚璉村瑚璉路116號1樓',
#   'bigadd': '彰化縣',
#   'lat': 23.926288,
#   'lng': 120.550586,
#   'name': '全聯永靖',
#   'road': '瑚璉路',
#   'smalladd': '永靖鄉',
#   'tele': '04-824-3546'},
#  {'_id': '全聯道周',
#   'address': '彰化縣和美鎮山梨里平安路115號1樓',
#   'bigadd': '彰化縣',
#   'lat': 24.108456,
#   'lng': 120.492685,
#   'name': '全聯道周',
#   'road': '平安路',
#   'smalladd': '和美鎮',
#   'tele': '04-757-8138'},
#  {'_id': '全聯南昌',
#   'address': '彰化縣員林鎮惠來里南昌路75號1樓',
#   'bigadd': '彰化縣',
#   'lat': 23.954359,
#   'lng': 120.571478,
#   'name': '全聯南昌',
#   'road': '南昌路',
#   'smalladd': '員林鎮',
#   'tele': '04-837-2500'},
#  {'_id': '全聯伸港',
#   'address': '彰化縣伸港鄉新港路311號1樓',
#   'bigadd': '彰化縣',
#   'lat': 24.149044,
#   'lng': 120.487211,
#   'name': '全聯伸港',
#   'road': '新港路',
#   'smalladd': '伸港鄉',
#   'tele': '047-996-125'},
#  {'_id': '全聯溪湖二',
#   'address': '彰化縣溪湖鎮平和街184號1樓',
#   'bigadd': '彰化縣',
#   'lat': 23.956563,
#   'lng': 120.479722,
#   'name': '全聯溪湖二',
#   'road': '平和街',
#   'smalladd': '溪湖鎮',
#   'tele': '04-882-6130'},
#  {'_id': '全聯秀水',
#   'address': '彰化縣秀水鄉彰水路一段22號1樓',
#   'bigadd': '彰化縣',
#   'lat': 24.036127,
#   'lng': 120.501574,
#   'name': '全聯秀水',
#   'road': '彰水路１段',
#   'smalladd': '秀水鄉',
#   'tele': '04-768-5510'},
#  {'_id': '全聯竹塘',
#   'address': '彰化縣竹塘鄉中興街57巷22號1樓',
#   'bigadd': '彰化縣',
#   'lat': 23.858764,
#   'lng': 120.42619,
#   'name': '全聯竹塘',
#   'road': '中興街',
#   'smalladd': '竹塘鄉',
#   'tele': '04-897-6601'},
#  {'_id': '全聯芬園',
#   'address': '彰化縣芬園鄉芬草路二段252號',
#   'bigadd': '彰化縣',
#   'lat': 24.013772,
#   'lng': 120.630317,
#   'name': '全聯芬園',
#   'road': '芬草路２段',
#   'smalladd': '芬園鄉',
#   'tele': '049-252-6667'},
#  {'_id': '全聯彰化旭光',
#   'address': '彰化縣彰化市旭光路141號1樓',
#   'bigadd': '彰化縣',
#   'lat': 24.072641,
#   'lng': 120.547257,
#   'name': '全聯彰化旭光',
#   'road': '旭光路',
#   'smalladd': '彰化市',
#   'tele': '04-727-1125'},
#  {'_id': '全聯斗六上海',
#   'address': '雲林縣斗六市杭州街18號',
#   'bigadd': '雲林縣',
#   'lat': 23.714954,
#   'lng': 120.541885,
#   'name': '全聯斗六上海',
#   'road': '杭州街',
#   'smalladd': '斗六市',
#   'tele': '05-537-8158'},
#  {'_id': '全聯雲林古坑',
#   'address': '雲林縣古坑鄉中山路179號',
#   'bigadd': '雲林縣',
#   'lat': 23.646077,
#   'lng': 120.561733,
#   'name': '全聯雲林古坑',
#   'road': '中山路',
#   'smalladd': '古坑鄉',
#   'tele': '05-582-0436'},
#  {'_id': '全聯雲林麥寮',
#   'address': '雲林縣麥寮鄉中山路436號',
#   'bigadd': '雲林縣',
#   'lat': 23.750559,
#   'lng': 120.250348,
#   'name': '全聯雲林麥寮',
#   'road': '中山路',
#   'smalladd': '麥寮鄉',
#   'tele': '05-693-0278'},
#  {'_id': '全聯斗六',
#   'address': '雲林縣斗六市林頭里莊敬路43號',
#   'bigadd': '雲林縣',
#   'lat': 23.703846,
#   'lng': 120.550589,
#   'name': '全聯斗六',
#   'road': '莊敬路',
#   'smalladd': '斗六市',
#   'tele': '05-532-2594'},
#  {'_id': '全聯斗南',
#   'address': '雲林縣斗南鎮中山路32巷6號',
#   'bigadd': '雲林縣',
#   'lat': 23.674163,
#   'lng': 120.480355,
#   'name': '全聯斗南',
#   'road': '中山路',
#   'smalladd': '斗南鎮',
#   'tele': '05-595-1419'},
#  {'_id': '全聯虎尾二',
#   'address': '雲林縣虎尾鎮民生路39號',
#   'bigadd': '雲林縣',
#   'lat': 23.709313,
#   'lng': 120.439116,
#   'name': '全聯虎尾二',
#   'road': '民生路',
#   'smalladd': '虎尾鎮',
#   'tele': '05-636-3098'},
#  {'_id': '全聯斗六圓環',
#   'address': '雲林縣斗六市公正街11號',
#   'bigadd': '雲林縣',
#   'lat': 23.709833,
#   'lng': 120.543779,
#   'name': '全聯斗六圓環',
#   'road': '公正街',
#   'smalladd': '斗六市',
#   'tele': '05-534-9218'},
#  {'_id': '全聯西螺中山',
#   'address': '雲林縣西螺鎮中山路182號',
#   'bigadd': '雲林縣',
#   'lat': 23.800021,
#   'lng': 120.45812,
#   'name': '全聯西螺中山',
#   'road': '中山路',
#   'smalladd': '西螺鎮',
#   'tele': '05-586-2575'},
#  {'_id': '全聯北港民享',
#   'address': '雲林縣北港鎮民享路9號',
#   'bigadd': '雲林縣',
#   'lat': 23.575085,
#   'lng': 120.301843,
#   'name': '全聯北港民享',
#   'road': '民享路',
#   'smalladd': '北港鎮',
#   'tele': '05-773-0031'},
#  {'_id': '全聯斗六民生',
#   'address': '雲林縣斗六市南興街41號',
#   'bigadd': '雲林縣',
#   'lat': 23.704143,
#   'lng': 120.537218,
#   'name': '全聯斗六民生',
#   'road': '南興街',
#   'smalladd': '斗六市',
#   'tele': '05-537-1892'},
#  {'_id': '全聯虎尾',
#   'address': '雲林縣虎尾鎮光復路503號之8',
#   'bigadd': '雲林縣',
#   'lat': 23.711442,
#   'lng': 120.433116,
#   'name': '全聯虎尾',
#   'road': '光復路',
#   'smalladd': '虎尾鎮',
#   'tele': '05-633-2513'},
#  {'_id': '全聯西螺',
#   'address': '雲林縣西螺鎮光復西路117號',
#   'bigadd': '雲林縣',
#   'lat': 23.796698,
#   'lng': 120.461078,
#   'name': '全聯西螺',
#   'road': '光復西路',
#   'smalladd': '西螺鎮',
#   'tele': '05-586-0703'},
#  {'_id': '全聯北港',
#   'address': '雲林縣北港鎮華勝路171號',
#   'bigadd': '雲林縣',
#   'lat': 23.577386,
#   'lng': 120.298163,
#   'name': '全聯北港',
#   'road': '華勝路',
#   'smalladd': '北港鎮',
#   'tele': '05-783-4540'},
#  {'_id': '全聯崙背中山',
#   'address': '雲林縣崙背鄉中山路200號',
#   'bigadd': '雲林縣',
#   'lat': 23.760664,
#   'lng': 120.356032,
#   'name': '全聯崙背中山',
#   'road': '中山路',
#   'smalladd': '崙背鄉',
#   'tele': '05-696-9939'},
#  {'_id': '全聯吳鳳',
#   'address': '嘉義市東區吳鳳南路529號',
#   'bigadd': '嘉義市',
#   'lat': 23.461116,
#   'lng': 120.457191,
#   'name': '全聯吳鳳',
#   'road': '吳鳳南路',
#   'smalladd': '東區',
#   'tele': '05-227-2869'},
#  {'_id': '全聯嘉義興業',
#   'address': '嘉義市西區興業西路325號',
#   'bigadd': '嘉義市',
#   'lat': 23.467677,
#   'lng': 120.438759,
#   'name': '全聯嘉義興業',
#   'road': '興業西路',
#   'smalladd': '西區',
#   'tele': '05-285-0056'},
#  {'_id': '全聯嘉義東門',
#   'address': '嘉義市東區和平路134-13號',
#   'bigadd': '嘉義市',
#   'lat': 23.478148,
#   'lng': 120.457489,
#   'name': '全聯嘉義東門',
#   'road': '和平路',
#   'smalladd': '東區',
#   'tele': '05-276-2093'},
#  {'_id': '全聯嘉義竹圍',
#   'address': '嘉義市西區四維路368號',
#   'bigadd': '嘉義市',
#   'lat': 23.487524,
#   'lng': 120.427784,
#   'name': '全聯嘉義竹圍',
#   'road': '四維路',
#   'smalladd': '西區',
#   'tele': '05-281-5889'},
#  {'_id': '全聯嘉義忠孝',
#   'address': '嘉義市東區忠孝路436號',
#   'bigadd': '嘉義市',
#   'lat': 23.492082,
#   'lng': 120.453077,
#   'name': '全聯嘉義忠孝',
#   'road': '忠孝路',
#   'smalladd': '東區',
#   'tele': '05-276-1070'},
#  {'_id': '全聯民雄頭橋',
#   'address': '嘉義縣民雄鄉福樂村埤角139號',
#   'bigadd': '嘉義縣',
#   'lat': 23.523956,
#   'lng': 120.439939,
#   'name': '全聯民雄頭橋',
#   'road': '埤角',
#   'smalladd': '民雄鄉',
#   'tele': '05-221-1583'},
#  {'_id': '全聯民雄',
#   'address': '嘉義縣民雄鄉復興路226號',
#   'bigadd': '嘉義縣',
#   'lat': 23.559444,
#   'lng': 120.42662,
#   'name': '全聯民雄',
#   'road': '復興路',
#   'smalladd': '民雄鄉',
#   'tele': '05-226-0789'},
#  {'_id': '全聯大同',
#   'address': '嘉義縣朴子市大同路60號',
#   'bigadd': '嘉義縣',
#   'lat': 23.461359,
#   'lng': 120.244954,
#   'name': '全聯大同',
#   'road': '大同路',
#   'smalladd': '朴子市',
#   'tele': '05-379-2189'},
#  {'_id': '全聯新港',
#   'address': '嘉義縣新港鄉中山路72巷2之1號',
#   'bigadd': '嘉義縣',
#   'lat': 23.55432,
#   'lng': 120.346451,
#   'name': '全聯新港',
#   'road': '中山路',
#   'smalladd': '新港鄉',
#   'tele': '05-374-0900'},
#  {'_id': '全聯竹崎',
#   'address': '嘉義縣竹崎鄉中華路106號',
#   'bigadd': '嘉義縣',
#   'lat': 23.520459,
#   'lng': 120.548038,
#   'name': '全聯竹崎',
#   'road': '中華路',
#   'smalladd': '竹崎鄉',
#   'tele': '05-261-2028'},
#  {'_id': '全聯水上',
#   'address': '嘉義縣水上鄉吳竹街135號',
#   'bigadd': '嘉義縣',
#   'lat': 23.431444,
#   'lng': 120.403003,
#   'name': '全聯水上',
#   'road': '吳竹街',
#   'smalladd': '水上鄉',
#   'tele': '05-268-7735'},
#  {'_id': '全聯台南湖美',
#   'address': '臺南市北區和緯路五段30號',
#   'bigadd': '臺南市',
#   'lat': 23.006787,
#   'lng': 120.185478,
#   'name': '全聯台南湖美',
#   'road': '和緯路５段',
#   'smalladd': '北區',
#   'tele': '06-259-0500'},
#  {'_id': '全聯台南安中',
#   'address': '臺南市安南區安中路１段872號',
#   'bigadd': '臺南市',
#   'lat': 23.044234,
#   'lng': 120.193933,
#   'name': '全聯台南安中',
#   'road': '安中路１段',
#   'smalladd': '安南區',
#   'tele': '06-256-3017'},
#  {'_id': '全聯台南',
#   'address': '臺南市北區忠義路３段１１號',
#   'bigadd': '臺南市',
#   'lat': 22.998931,
#   'lng': 120.205058,
#   'name': '全聯台南',
#   'road': '忠義路３段',
#   'smalladd': '北區',
#   'tele': '06-220-3009'},
#  {'_id': '全聯後甲',
#   'address': '臺南市東區東安路20號',
#   'bigadd': '臺南市',
#   'lat': 22.991121,
#   'lng': 120.226197,
#   'name': '全聯後甲',
#   'road': '東安路',
#   'smalladd': '東區',
#   'tele': '06-238-3270'},
#  {'_id': '全聯崇善',
#   'address': '臺南市東區崇善路666號',
#   'bigadd': '臺南市',
#   'lat': 22.968151,
#   'lng': 120.231245,
#   'name': '全聯崇善',
#   'road': '崇善路',
#   'smalladd': '東區',
#   'tele': '06-335-5809'},
#  {'_id': '全聯延平',
#   'address': '臺南市北區公園路798號1樓',
#   'bigadd': '臺南市',
#   'lat': 23.011724,
#   'lng': 120.211327,
#   'name': '全聯延平',
#   'road': '公園路',
#   'smalladd': '北區',
#   'tele': '06-283-2310'},
#  {'_id': '全聯裕農',
#   'address': '臺南市東區裕農路400號',
#   'bigadd': '臺南市',
#   'lat': 22.98758,
#   'lng': 120.231162,
#   'name': '全聯裕農',
#   'road': '裕農路',
#   'smalladd': '東區',
#   'tele': '06-236-1346'},
#  {'_id': '全聯金華',
#   'address': '臺南市南區金華路二段85號',
#   'bigadd': '臺南市',
#   'lat': 22.979291,
#   'lng': 120.191191,
#   'name': '全聯金華',
#   'road': '金華路２段',
#   'smalladd': '南區',
#   'tele': '06-291-0826'},
#  {'_id': '全聯台南和緯',
#   'address': '臺南市北區和緯路二段172號',
#   'bigadd': '臺南市',
#   'lat': 23.012233,
#   'lng': 120.207671,
#   'name': '全聯台南和緯',
#   'road': '和緯路２段',
#   'smalladd': '北區',
#   'tele': '06-281-0737'},
#  {'_id': '全聯台南自強',
#   'address': '臺南市東區中華東路二段237號1樓',
#   'bigadd': '臺南市',
#   'lat': 22.983419,
#   'lng': 120.231926,
#   'name': '全聯台南自強',
#   'road': '中華東路２段',
#   'smalladd': '東區',
#   'tele': '06-269-9822'},
#  {'_id': '全聯永康大灣',
#   'address': '臺南市永康區崑山街1號',
#   'bigadd': '臺南市',
#   'lat': 23.000323,
#   'lng': 120.257831,
#   'name': '全聯永康大灣',
#   'road': '崑山街',
#   'smalladd': '永康區',
#   'tele': '06-205-5428'},
#  {'_id': '全聯永康中山',
#   'address': '臺南市永康區中山南路63.65.67.69號',
#   'bigadd': '臺南市',
#   'lat': 23.012356,
#   'lng': 120.227519,
#   'name': '全聯永康中山',
#   'road': '中山南路',
#   'smalladd': '永康區',
#   'tele': '06-303-5210'},
#  {'_id': '全聯台南仁德',
#   'address': '臺南市仁德區民安路一段402號',
#   'bigadd': '臺南市',
#   'lat': 22.953575,
#   'lng': 120.250897,
#   'name': '全聯台南仁德',
#   'road': '民安路１段',
#   'smalladd': '仁德區',
#   'tele': '06-249-8371'},
#  {'_id': '全聯永康永大',
#   'address': '臺南市永康區永大路三段35號',
#   'bigadd': '臺南市',
#   'lat': 23.027588,
#   'lng': 120.260494,
#   'name': '全聯永康永大',
#   'road': '永大路３段',
#   'smalladd': '永康區',
#   'tele': '06-203-1075'},
#  {'_id': '全聯民治',
#   'address': '臺南市新營區民治路5之1號1樓',
#   'bigadd': '臺南市',
#   'lat': 23.31089,
#   'lng': 120.320777,
#   'name': '全聯民治',
#   'road': '民治路',
#   'smalladd': '新營區',
#   'tele': '06-637-4487'},
#  {'_id': '全聯歸仁',
#   'address': '臺南市歸仁區復興路87號',
#   'bigadd': '臺南市',
#   'lat': 22.965464,
#   'lng': 120.295939,
#   'name': '全聯歸仁',
#   'road': '復興路',
#   'smalladd': '歸仁區',
#   'tele': '06-239-1358'},
#  {'_id': '全聯白河',
#   'address': '臺南市白河區富民路142號',
#   'bigadd': '臺南市',
#   'lat': 23.345174,
#   'lng': 120.414172,
#   'name': '全聯白河',
#   'road': '富民路',
#   'smalladd': '白河區',
#   'tele': '06-684-0717'},
#  {'_id': '全聯永康正強',
#   'address': '臺南市永康區正強街172號',
#   'bigadd': '臺南市',
#   'lat': 23.027635,
#   'lng': 120.252005,
#   'name': '全聯永康正強',
#   'road': '正強街',
#   'smalladd': '永康區',
#   'tele': '06-203-0220'},
#  {'_id': '全聯麻豆',
#   'address': '臺南市麻豆區博愛路7號',
#   'bigadd': '臺南市',
#   'lat': 23.185315,
#   'lng': 120.250753,
#   'name': '全聯麻豆',
#   'road': '博愛路',
#   'smalladd': '麻豆區',
#   'tele': '06-572-2740'},
#  {'_id': '全聯佳里',
#   'address': '臺南市佳里區建南街112號',
#   'bigadd': '臺南市',
#   'lat': 23.157885,
#   'lng': 120.176488,
#   'name': '全聯佳里',
#   'road': '建南街',
#   'smalladd': '佳里區',
#   'tele': '06-722-3866'},
#  {'_id': '全聯瑞祥',
#   'address': '高雄市前鎮區崗山西街206號',
#   'bigadd': '高雄市',
#   'lat': 22.603676,
#   'lng': 120.328008,
#   'name': '全聯瑞祥',
#   'road': '崗山西街',
#   'smalladd': '前鎮區',
#   'tele': '07-715-3377'},
#  {'_id': '全聯小港宏平',
#   'address': '高雄市小港區宏平路１５２號１樓',
#   'bigadd': '高雄市',
#   'lat': 22.570256,
#   'lng': 120.361705,
#   'name': '全聯小港宏平',
#   'road': '宏平路',
#   'smalladd': '小港區',
#   'tele': '07-805-3690'},
#  {'_id': '全聯光華',
#   'address': '高雄市苓雅區光華一路148號之31',
#   'bigadd': '高雄市',
#   'lat': 22.622939,
#   'lng': 120.316188,
#   'name': '全聯光華',
#   'road': '光華一路',
#   'smalladd': '苓雅區',
#   'tele': '07-727-4633'},
#  {'_id': '全聯北左營',
#   'address': '高雄市左營區重愛路112號',
#   'bigadd': '高雄市',
#   'lat': 22.684002,
#   'lng': 120.317558,
#   'name': '全聯北左營',
#   'road': '重愛路',
#   'smalladd': '左營區',
#   'tele': '07-345-5301'},
#  {'_id': '全聯鼓山',
#   'address': '高雄市鼓山區銘傳路61號',
#   'bigadd': '高雄市',
#   'lat': 22.665183,
#   'lng': 120.28431,
#   'name': '全聯鼓山',
#   'road': '銘傳路',
#   'smalladd': '鼓山區',
#   'tele': '07-588-5867'},
#  {'_id': '全聯鼎金',
#   'address': '高雄市三民區鼎泰街232號',
#   'bigadd': '高雄市',
#   'lat': 22.665868,
#   'lng': 120.318438,
#   'name': '全聯鼎金',
#   'road': '鼎泰街',
#   'smalladd': '三民區',
#   'tele': '07-342-3622'},
#  {'_id': '全聯高雄博愛',
#   'address': '高雄市三民區博愛一路229號',
#   'bigadd': '高雄市',
#   'lat': 22.648009,
#   'lng': 120.303072,
#   'name': '全聯高雄博愛',
#   'road': '博愛一路',
#   'smalladd': '三民區',
#   'tele': '07-323-5033'},
#  {'_id': '全聯小港漢民',
#   'address': '高雄市小港區漢民路393號',
#   'bigadd': '高雄市',
#   'lat': 22.566996,
#   'lng': 120.356815,
#   'name': '全聯小港漢民',
#   'road': '漢民路',
#   'smalladd': '小港區',
#   'tele': '07-806-5380'},
#  {'_id': '全聯草衙',
#   'address': '高雄市前鎮區草衙二路３３７號',
#   'bigadd': '高雄市',
#   'lat': 22.577582,
#   'lng': 120.323234,
#   'name': '全聯草衙',
#   'road': '草衙二路',
#   'smalladd': '前鎮區',
#   'tele': '07-811-5011'},
#  {'_id': '全聯右昌',
#   'address': '高雄市楠梓區德民路838號',
#   'bigadd': '高雄市',
#   'lat': 22.721862,
#   'lng': 120.290798,
#   'name': '全聯右昌',
#   'road': '德民路',
#   'smalladd': '楠梓區',
#   'tele': '07-360-0218'},
#  {'_id': '全聯高雄一心',
#   'address': '高雄市前鎮區一心二路157號1樓',
#   'bigadd': '高雄市',
#   'lat': 22.61228,
#   'lng': 120.307674,
#   'name': '全聯高雄一心',
#   'road': '一心二路',
#   'smalladd': '前鎮區',
#   'tele': '07-330-0128'},
#  {'_id': '全聯左營富國',
#   'address': '高雄市左營區富國路87號',
#   'bigadd': '高雄市',
#   'lat': 22.659482,
#   'lng': 120.306462,
#   'name': '全聯左營富國',
#   'road': '富國路',
#   'smalladd': '左營區',
#   'tele': '07-557-0038'},
#  {'_id': '全聯高雄苓雅',
#   'address': '高雄市苓雅區林森二路36號',
# ...
#   'smalladd': '中山區',
#   'tele': '02-25966358'},
#  {'_id': '全聯新莊中原',
#   'address': '新北市新莊區中原東路192.196號1-2樓',
#   'bigadd': '新北市',
#   'lat': 25.054477,
#   'lng': 121.465828,
#   'name': '全聯新莊中原',
#   'road': '中原東路',
#   'smalladd': '新莊區',
#   'tele': '02-8521-1671'},
#  {'_id': '全聯神岡中正',
#   'address': '臺中市神岡區中正路21號',
#   'bigadd': '臺中市',
#   'lat': 24.257289,
#   'lng': 120.658247,
#   'name': '全聯神岡中正',
#   'road': '中正路',
#   'smalladd': '神岡區',
#   'tele': '04-2561-0126'},
#  {'_id': '全聯大安泰順',
#   'address': '臺北市大安區泰順街45號1樓',
#   'bigadd': '臺北市',
#   'lat': 25.022513,
#   'lng': 121.531254,
#   'name': '全聯大安泰順',
#   'road': '泰順街',
#   'smalladd': '大安區',
#   'tele': '02-23620475'},
#  {'_id': '全聯文山辛亥',
#   'address': '臺北市文山區興隆路２段252號1樓',
#   'bigadd': '臺北市',
#   'lat': 25.000676,
#   'lng': 121.554242,
#   'name': '全聯文山辛亥',
#   'road': '興隆路２段',
#   'smalladd': '文山區',
#   'tele': '02-86631396'},
#  {'_id': '全聯信義松隆',
#   'address': '臺北市信義區松隆路125號1樓',
#   'bigadd': '臺北市',
#   'lat': 25.046987,
#   'lng': 121.571873,
#   'name': '全聯信義松隆',
#   'road': '松隆路',
#   'smalladd': '信義區',
#   'tele': '02-27658081'},
#  {'_id': '全聯中山長春',
#   'address': '臺北市中山區長春路258巷6號1樓',
#   'bigadd': '臺北市',
#   'lat': 25.054135,
#   'lng': 121.538794,
#   'name': '全聯中山長春',
#   'road': '長春路',
#   'smalladd': '中山區',
#   'tele': '02-25006155'},
#  {'_id': '全聯內湖文德',
#   'address': '臺北市內湖區文德路212號B1',
#   'bigadd': '臺北市',
#   'lat': 25.078304,
#   'lng': 121.584025,
#   'name': '全聯內湖文德',
#   'road': '文德路',
#   'smalladd': '內湖區',
#   'tele': '02-26272375'},
#  {'_id': '全聯台中仁和',
#   'address': '臺中市南區國光路 198號',
#   'bigadd': '臺中市',
#   'lat': 24.126518,
#   'lng': 120.679109,
#   'name': '全聯台中仁和',
#   'road': '國光路',
#   'smalladd': '南區',
#   'tele': '04-22851052'},
#  {'_id': '全聯台中健行',
#   'address': '臺中市北區健行路447號',
#   'bigadd': '臺中市',
#   'lat': 24.158969,
#   'lng': 120.679848,
#   'name': '全聯台中健行',
#   'road': '健行路',
#   'smalladd': '北區',
#   'tele': '04-22011256'},
#  {'_id': '全聯台中東海',
#   'address': '臺中市龍井區新興路87號',
#   'bigadd': '臺中市',
#   'lat': 24.18187,
#   'lng': 120.585106,
#   'name': '全聯台中東海',
#   'road': '新興路',
#   'smalladd': '龍井區',
#   'tele': '04-26527581'},
#  {'_id': '全聯台中水湳',
#   'address': '臺中市北屯區中清路２段392號',
#   'bigadd': '臺中市',
#   'lat': 24.18063,
#   'lng': 120.66674,
#   'name': '全聯台中水湳',
#   'road': '中清路２段',
#   'smalladd': '北屯區',
#   'tele': '04-22911035'},
#  {'_id': '全聯台中三民',
#   'address': '臺中市中區三民路２段140號',
#   'bigadd': '臺中市',
#   'lat': 24.143705,
#   'lng': 120.681032,
#   'name': '全聯台中三民',
#   'road': '三民路２段',
#   'smalladd': '中區',
#   'tele': '04-22200736'},
#  {'_id': '全聯苗栗銅鑼',
#   'address': '苗栗縣銅鑼鄉大同路51.53號',
#   'bigadd': '苗栗縣',
#   'lat': 24.489292,
#   'lng': 120.786539,
#   'name': '全聯苗栗銅鑼',
#   'road': '大同路',
#   'smalladd': '銅鑼鄉',
#   'tele': '037-981218'},
#  {'_id': '全聯嘉義中埔',
#   'address': '嘉義縣中埔鄉司公?73-1.73-2.73-3.73-4號',
#   'bigadd': '嘉義縣',
#   'lat': 23.451911,
#   'lng': 120.458508,
#   'name': '全聯嘉義中埔',
#   'road': '司公?',
#   'smalladd': '中埔鄉',
#   'tele': '05-2305206'},
#  {'_id': '全聯中和宜安',
#   'address': '新北市中和區安平路109號',
#   'bigadd': '新北市',
#   'lat': 24.997686,
#   'lng': 121.511508,
#   'name': '全聯中和宜安',
#   'road': '安平路',
#   'smalladd': '中和區',
#   'tele': '02-22310375'},
#  {'_id': '全聯台中豐后',
#   'address': '臺中市豐原區三豐路556號',
#   'bigadd': '臺中市',
#   'lat': 24.264371,
#   'lng': 120.720356,
#   'name': '全聯台中豐后',
#   'road': '三豐路',
#   'smalladd': '豐原區',
#   'tele': '04-25120752'},
#  {'_id': '全聯宜蘭校舍',
#   'address': '宜蘭縣宜蘭市校舍路116號',
#   'bigadd': '宜蘭縣',
#   'lat': 24.751503,
#   'lng': 121.76168,
#   'name': '全聯宜蘭校舍',
#   'road': '校舍路',
#   'smalladd': '宜蘭市',
#   'tele': '03-9389238'},
#  {'_id': '全聯高雄大昌二',
#   'address': '高雄市三民區大昌二路146號',
#   'bigadd': '高雄市',
#   'lat': 22.644329,
#   'lng': 120.33235,
#   'name': '全聯高雄大昌二',
#   'road': '大昌二路',
#   'smalladd': '三民區',
#   'tele': '07-3816489'},
#  {'_id': '全聯美村綠',
#   'address': '臺中市西區五權五街68號',
#   'bigadd': '臺中市',
#   'lat': 24.136636,
#   'lng': 120.662251,
#   'name': '全聯美村綠',
#   'road': '五權五街',
#   'smalladd': '西區',
#   'tele': '04-23711917'},
#  {'_id': '全聯高雄正義',
#   'address': '高雄市苓雅區正義路248號',
#   'bigadd': '高雄市',
#   'lat': 22.633063,
#   'lng': 120.340975,
#   'name': '全聯高雄正義',
#   'road': '正義路',
#   'smalladd': '苓雅區',
#   'tele': '07-7408719'},
#  {'_id': '全聯大園和平',
#   'address': '桃園市大園區和平東路65號',
#   'bigadd': '桃園市',
#   'lat': 25.061478,
#   'lng': 121.199893,
#   'name': '全聯大園和平',
#   'road': '和平東路',
#   'smalladd': '大園區',
#   'tele': '03-3860756'},
#  {'_id': '全聯大社金龍',
#   'address': '高雄市大社區金龍路338、340號',
#   'bigadd': '高雄市',
#   'lat': 22.724751,
#   'lng': 120.353565,
#   'name': '全聯大社金龍',
#   'road': '金龍路',
#   'smalladd': '大社區',
#   'tele': '07-3510359'},
#  {'_id': '全聯台中松五',
#   'address': '臺中市北屯區松竹五路180號',
#   'bigadd': '臺中市',
#   'lat': 24.177156,
#   'lng': 120.713433,
#   'name': '全聯台中松五',
#   'road': '松竹五路',
#   'smalladd': '北屯區',
#   'tele': '04-24350457'},
#  {'_id': '全聯埔心東明',
#   'address': '彰化縣埔心鄉員林大道７段133、135、137號',
#   'bigadd': '彰化縣',
#   'lat': 23.953612,
#   'lng': 120.562697,
#   'name': '全聯埔心東明',
#   'road': '員林大道７段',
#   'smalladd': '埔心鄉',
#   'tele': '04-8281656'},
#  {'_id': '全聯淡水沙崙',
#   'address': '新北市淡水區沙崙路50號',
#   'bigadd': '新北市',
#   'lat': 25.18165,
#   'lng': 121.422072,
#   'name': '全聯淡水沙崙',
#   'road': '沙崙路',
#   'smalladd': '淡水區',
#   'tele': '02-28056428'},
#  {'_id': '全聯中壢廣州',
#   'address': '桃園市中壢區廣州路90號',
#   'bigadd': '桃園市',
#   'lat': 24.951008,
#   'lng': 121.230616,
#   'name': '全聯中壢廣州',
#   'road': '廣州路',
#   'smalladd': '中壢區',
#   'tele': '03-2840195'},
#  {'_id': '全聯台中軍太',
#   'address': '臺中市北屯區軍功路１段183.185號',
#   'bigadd': '臺中市',
#   'lat': 24.163669,
#   'lng': 120.714728,
#   'name': '全聯台中軍太',
#   'road': '軍功路１段',
#   'smalladd': '北屯區',
#   'tele': '04-24350809'},
#  {'_id': '全聯屏東新埤',
#   'address': '屏東縣新埤鄉中正路7，9號',
#   'bigadd': '屏東縣',
#   'lat': 22.470085,
#   'lng': 120.552216,
#   'name': '全聯屏東新埤',
#   'road': '中正路',
#   'smalladd': '新埤鄉',
#   'tele': '08-7973536'},
#  {'_id': '全聯南投集集',
#   'address': '南投縣集集鎮民生路9-21、9-22號',
#   'bigadd': '南投縣',
#   'lat': 23.82817,
#   'lng': 120.796472,
#   'name': '全聯南投集集',
#   'road': '民生路',
#   'smalladd': '集集鎮',
#   'tele': '049-2760012'},
#  {'_id': '全聯嘉義忠孝北',
#   'address': '嘉義市東區忠孝北街231.233號',
#   'bigadd': '嘉義市',
#   'lat': 23.516167,
#   'lng': 120.44269,
#   'name': '全聯嘉義忠孝北',
#   'road': '忠孝北街',
#   'smalladd': '東區',
#   'tele': '05-2210312'},
#  {'_id': '全聯新竹西大',
#   'address': '新竹市北區西大路594號',
#   'bigadd': '新竹市',
#   'lat': 24.806932,
#   'lng': 120.961961,
#   'name': '全聯新竹西大',
#   'road': '西大路',
#   'smalladd': '北區',
#   'tele': '03-5220985'},
#  {'_id': '全聯士林蘭雅',
#   'address': '臺北市士林區德行東路109巷104號1樓',
#   'bigadd': '臺北市',
#   'lat': 25.111023,
#   'lng': 121.52885,
#   'name': '全聯士林蘭雅',
#   'road': '德行東路',
#   'smalladd': '士林區',
#   'tele': '02-28310117'},
#  {'_id': '全聯松山民有',
#   'address': '臺北市松山區民權東路３段140巷15號1樓',
#   'bigadd': '臺北市',
#   'lat': 25.060401,
#   'lng': 121.547074,
#   'name': '全聯松山民有',
#   'road': '民權東路３段',
#   'smalladd': '松山區',
#   'tele': '02-25148205'},
#  {'_id': '全聯大安民榮',
#   'address': '臺北市大安區仁愛路３段24巷12號1樓',
#   'bigadd': '臺北市',
#   'lat': 25.035291,
#   'lng': 121.535885,
#   'name': '全聯大安民榮',
#   'road': '仁愛路３段',
#   'smalladd': '大安區',
#   'tele': '02-23250572'},
#  {'_id': '全聯文山景美',
#   'address': '臺北市文山區羅斯福路６段218號B1',
#   'bigadd': '臺北市',
#   'lat': 24.993061,
#   'lng': 121.540532,
#   'name': '全聯文山景美',
#   'road': '羅斯福路６段',
#   'smalladd': '文山區',
#   'tele': '02-29303528'},
#  {'_id': '全聯中正同安',
#   'address': '臺北市中正區南昌路２段112號B1',
#   'bigadd': '臺北市',
#   'lat': 25.025784,
#   'lng': 121.522124,
#   'name': '全聯中正同安',
#   'road': '南昌路２段',
#   'smalladd': '中正區',
#   'tele': '02-23620529'},
#  {'_id': '全聯西港新興',
#   'address': '臺南市西港區新興街8-78號',
#   'bigadd': '臺南市',
#   'lat': 23.117334,
#   'lng': 120.20303,
#   'name': '全聯西港新興',
#   'road': '新興街',
#   'smalladd': '西港區',
#   'tele': '06-7950267'},
#  {'_id': '全聯永靖中山',
#   'address': '彰化縣永靖鄉永社路291號',
#   'bigadd': '彰化縣',
#   'lat': 23.917676,
#   'lng': 120.546578,
#   'name': '全聯永靖中山',
#   'road': '永社路',
#   'smalladd': '永靖鄉',
#   'tele': '04-8220266'},
#  {'_id': '全聯仁武八德',
#   'address': '高雄市仁武區八德中路52、56、58、60號',
#   'bigadd': '高雄市',
#   'lat': 22.68489,
#   'lng': 120.339329,
#   'name': '全聯仁武八德',
#   'road': '八德中路',
#   'smalladd': '仁武區',
#   'tele': '07-3714089'},
#  {'_id': '全聯清水五權',
#   'address': '臺中市清水區五權路71號',
#   'bigadd': '臺中市',
#   'lat': 24.276669,
#   'lng': 120.568098,
#   'name': '全聯清水五權',
#   'road': '五權路',
#   'smalladd': '清水區',
#   'tele': '04-26261562'},
#  {'_id': '全聯湖內保生',
#   'address': '高雄市湖內區保生路169號',
#   'bigadd': '高雄市',
#   'lat': 22.907257,
#   'lng': 120.220121,
#   'name': '全聯湖內保生',
#   'road': '保生路',
#   'smalladd': '湖內區',
#   'tele': '07-6993006'},
#  {'_id': '全聯台中博二',
#   'address': '臺中市西區博館二街123.125號',
#   'bigadd': '臺中市',
#   'lat': 24.152126,
#   'lng': 120.66962,
#   'name': '全聯台中博二',
#   'road': '博館二街',
#   'smalladd': '西區',
#   'tele': '04-23103175'},
#  {'_id': '全聯士林後港',
#   'address': '臺北市士林區後港街30號',
#   'bigadd': '臺北市',
#   'lat': 25.083381,
#   'lng': 121.522827,
#   'name': '全聯士林後港',
#   'road': '後港街',
#   'smalladd': '士林區',
#   'tele': '02-28850905'},
#  {'_id': '全聯蘆竹南竹',
#   'address': '桃園市蘆竹區南竹路２段171.171-1號',
#   'bigadd': '桃園市',
#   'lat': 25.03871,
#   'lng': 121.282992,
#   'name': '全聯蘆竹南竹',
#   'road': '南竹路２段',
#   'smalladd': '蘆竹區',
#   'tele': '03-2120390'},
#  {'_id': '全聯新竹牛埔',
#   'address': '新竹市香山區牛埔東路247號',
#   'bigadd': '新竹市',
#   'lat': 24.796092,
#   'lng': 120.944169,
#   'name': '全聯新竹牛埔',
#   'road': '牛埔東路',
#   'smalladd': '香山區',
#   'tele': '03-5302107'},
#  {'_id': '全聯新竹龍山',
#   'address': '新竹市東區龍山西路100.102號',
#   'bigadd': '新竹市',
#   'lat': 24.790361,
#   'lng': 121.010312,
#   'name': '全聯新竹龍山',
#   'road': '龍山西路',
#   'smalladd': '東區',
#   'tele': '03-5630456'},
#  {'_id': '全聯太平新興',
#   'address': '臺中市太平區新興路115.117號',
#   'bigadd': '臺中市',
#   'lat': 24.159116,
#   'lng': 120.709608,
#   'name': '全聯太平新興',
#   'road': '新興路',
#   'smalladd': '太平區',
#   'tele': '04-23950516'},
#  {'_id': '全聯永康北灣',
#   'address': '臺南市永康區永大路２段936號',
#   'bigadd': '臺南市',
#   'lat': 23.016215,
#   'lng': 120.263373,
#   'name': '全聯永康北灣',
#   'road': '永大路２段',
#   'smalladd': '永康區',
#   'tele': '06-2051485'},
#  {'_id': '全聯內埔永光',
#   'address': '屏東縣內埔鄉永光路3號',
#   'bigadd': '屏東縣',
#   'lat': 22.608832,
#   'lng': 120.564469,
#   'name': '全聯內埔永光',
#   'road': '永光路',
#   'smalladd': '內埔鄉',
#   'tele': '08-7781217'},
#  {'_id': '全聯雲林東勢',
#   'address': '雲林縣東勢鄉內環東路2.6號',
#   'bigadd': '雲林縣',
#   'lat': 23.677309,
#   'lng': 120.256529,
#   'name': '全聯雲林東勢',
#   'road': '內環東路',
#   'smalladd': '東勢鄉',
#   'tele': '05-6990058'},
#  {'_id': '全聯楠梓土庫',
#   'address': '高雄市楠梓區土庫三路55、57號',
#   'bigadd': '高雄市',
#   'lat': 0,
#   'lng': 0,
#   'name': '全聯楠梓土庫',
#   'road': '土庫三路',
#   'smalladd': '楠梓區',
#   'tele': '07-3511929'},
#  {'_id': '全聯三芝中興',
#   'address': '新北市三芝區中興街２段71號',
#   'bigadd': '新北市',
#   'lat': 25.25617,
#   'lng': 121.49852,
#   'name': '全聯三芝中興',
#   'road': '中興街２段',
#   'smalladd': '三芝區',
#   'tele': '02-86353658'},
#  {'_id': '全聯關西北平',
#   'address': '新竹縣關西鎮北平路463、465號',
#   'bigadd': '新竹縣',
#   'lat': 24.794815,
#   'lng': 121.171459,
#   'name': '全聯關西北平',
#   'road': '北平路',
#   'smalladd': '關西鎮',
#   'tele': '03-5170256'},
#  {'_id': '全聯中和南山',
#   'address': '新北市中和區南山路146巷1號1樓',
#   'bigadd': '新北市',
#   'lat': 24.992072,
#   'lng': 121.503895,
#   'name': '全聯中和南山',
#   'road': '南山路',
#   'smalladd': '中和區',
#   'tele': '02-22400572'},
#  {'_id': '全聯梧棲文昌',
#   'address': '臺中市梧棲區文昌路501號',
#   'bigadd': '臺中市',
#   'lat': 24.24521,
#   'lng': 120.537947,
#   'name': '全聯梧棲文昌',
#   'road': '文昌路',
#   'smalladd': '梧棲區',
#   'tele': '04-26572317'},
#  {'_id': '全聯士林中正',
#   'address': '臺北市士林區中正路115號1樓',
#   'bigadd': '臺北市',
#   'lat': 25.095724,
#   'lng': 121.528915,
#   'name': '全聯士林中正',
#   'road': '中正路',
#   'smalladd': '士林區',
#   'tele': '02-28802728'},
#  {'_id': '全聯竹北自強',
#   'address': '新竹縣竹北市自強五路60號',
#   'bigadd': '新竹縣',
#   'lat': 24.81922,
#   'lng': 121.023522,
#   'name': '全聯竹北自強',
#   'road': '自強五路',
#   'smalladd': '竹北市',
#   'tele': '03-5504015'},
#  {'_id': '全聯雲林四湖',
#   'address': '雲林縣四湖鄉關聖路66號',
#   'bigadd': '雲林縣',
#   'lat': 23.638904,
#   'lng': 120.227191,
#   'name': '全聯雲林四湖',
#   'road': '關聖路',
#   'smalladd': '四湖鄉',
#   'tele': '05-7874816'},
#  {'_id': '全聯竹南龍山',
#   'address': '苗栗縣竹南鎮龍山路１段260、262號',
#   'bigadd': '苗栗縣',
#   'lat': 24.691871,
#   'lng': 120.866435,
#   'name': '全聯竹南龍山',
#   'road': '龍山路１段',
#   'smalladd': '竹南鎮',
#   'tele': '037-550-969'},
#  {'_id': '全聯台中四平',
#   'address': '臺中市北屯區四平路523號',
#   'bigadd': '臺中市',
#   'lat': 24.193032,
#   'lng': 120.68168,
#   'name': '全聯台中四平',
#   'road': '四平路',
#   'smalladd': '北屯區',
#   'tele': '04-24213318'},
#  {'_id': '全聯台東更生',
#   'address': '臺東縣臺東市更生路1051號',
#   'bigadd': '臺東縣',
#   'lat': 22.773286,
#   'lng': 121.130789,
#   'name': '全聯台東更生',
#   'road': '更生路',
#   'smalladd': '臺東市',
#   'tele': '089-237311'},
#  {'_id': '全聯鹿港長安',
#   'address': '彰化縣鹿港鎮長安路200號',
#   'bigadd': '彰化縣',
#   'lat': 0,
#   'lng': 0,
#   'name': '全聯鹿港長安',
#   'road': '長安路',
#   'smalladd': '鹿港鎮',
#   'tele': '04-7740106'},
#  {'_id': '全聯台南民權',
#   'address': '臺南市中西區民權路４段350、352號',
#   'bigadd': '臺南市',
#   'lat': 22.999173,
#   'lng': 120.176365,
#   'name': '全聯台南民權',
#   'road': '民權路４段',
#   'smalladd': '中西區',
#   'tele': '06-2580061'},
#  {'_id': '全聯平鎮上海',
#   'address': '桃園市平鎮區上海路250號',
#   'bigadd': '桃園市',
#   'lat': 24.915704,
#   'lng': 121.206238,
#   'name': '全聯平鎮上海',
#   'road': '上海路',
#   'smalladd': '平鎮區',
#   'tele': '03-4395715'},
#  {'_id': '全聯土庫馬光',
#   'address': '雲林縣土庫鎮和平街18、18-1號',
#   'bigadd': '雲林縣',
#   'lat': 23.686439,
#   'lng': 120.355118,
#   'name': '全聯土庫馬光',
#   'road': '和平街',
#   'smalladd': '土庫鎮',
#   'tele': '05-6656935'},
#  {'_id': '全聯大園華興',
#   'address': '桃園市大園區華興路36號',
#   'bigadd': '桃園市',
#   'lat': 25.064529,
#   'lng': 121.192685,
#   'name': '全聯大園華興',
#   'road': '華興路',
#   'smalladd': '大園區',
#   'tele': '03-3840126'},
#  {'_id': '全聯楊梅梅獅',
#   'address': '桃園市楊梅區梅獅路２段25、27號',
#   'bigadd': '桃園市',
#   'lat': 24.910711,
#   'lng': 121.174693,
#   'name': '全聯楊梅梅獅',
#   'road': '梅獅路２段',
#   'smalladd': '楊梅區',
#   'tele': '03-4315268'},
#  {'_id': '全聯內湖文湖',
#   'address': '臺北市內湖區文湖街31號1樓、B1',
#   'bigadd': '臺北市',
#   'lat': 0,
#   'lng': 0,
#   'name': '全聯內湖文湖',
#   'road': '文湖街',
#   'smalladd': '內湖區',
#   'tele': '02-26271936'},
#  {'_id': '全聯台中福星',
#   'address': '臺中市西屯區福星北路60號',
#   'bigadd': '臺中市',
#   'lat': 23.978631,
#   'lng': 120.698571,
#   'name': '全聯台中福星',
#   'road': '福星北路',
#   'smalladd': '西屯區',
#   'tele': '04-27065253'},
#  {'_id': '全聯台中大坑',
#   'address': '臺中市北屯區東山路１段346號',
#   'bigadd': '臺中市',
#   'lat': 24.176663,
#   'lng': 120.727755,
#   'name': '全聯台中大坑',
#   'road': '東山路１段',
#   'smalladd': '北屯區',
#   'tele': '04-2435-1518'},
#  {'_id': '全聯後龍中華',
#   'address': '苗栗縣後龍鎮中華路55-6、55-7、55-15號',
#   'bigadd': '苗栗縣',
#   'lat': 24.616405,
#   'lng': 120.791344,
#   'name': '全聯後龍中華',
#   'road': '中華路',
#   'smalladd': '後龍鎮',
#   'tele': '037-720122'},
#  {'_id': '全聯豐原大順',
#   'address': '臺中市豐原區大順街121、123號',
#   'bigadd': '臺中市',
#   'lat': 0,
#   'lng': 0,
#   'name': '全聯豐原大順',
#   'road': '大順街',
#   'smalladd': '豐原區',
#   'tele': '04-25120216'},
#  {'_id': '全聯八德東勇',
#   'address': '桃園市八德區東勇北路566、568號',
#   'bigadd': '桃園市',
#   'lat': 24.965308,
#   'lng': 121.306516,
#   'name': '全聯八德東勇',
#   'road': '東勇北路',
#   'smalladd': '八德區',
#   'tele': '03-3612022'},
#  {'_id': '全聯龍潭三林',
#   'address': '桃園市龍潭區中正路三林段298號',
#   'bigadd': '桃園市',
#   'lat': 24.848972,
#   'lng': 121.230143,
#   'name': '全聯龍潭三林',
#   'road': '中正路三林段',
#   'smalladd': '龍潭區',
#   'tele': '03-4090731'},
#  {'_id': '全聯觀音中山',
#   'address': '桃園市觀音區中山路２段891、893號',
#   'bigadd': '桃園市',
#   'lat': 25.01017,
#   'lng': 121.140526,
#   'name': '全聯觀音中山',
#   'road': '中山路２段',
#   'smalladd': '觀音區',
#   'tele': '03-2825135'},
#  {'_id': '全聯中壢普忠',
#   'address': '桃園市中壢區普忠路1168號',
#   'bigadd': '桃園市',
#   'lat': 24.951176,
#   'lng': 121.253857,
#   'name': '全聯中壢普忠',
#   'road': '普忠路',
#   'smalladd': '中壢區',
#   'tele': '03-4163011'},
#  {'_id': '全聯員林浮圳',
#   'address': '彰化縣員林鎮浮圳路２段135號',
#   'bigadd': '彰化縣',
#   'lat': 0,
#   'lng': 0,
#   'name': '全聯員林浮圳',
#   'road': '浮圳路２段',
#   'smalladd': '員林鎮',
#   'tele': '04-8339398'},
#  {'_id': '全聯鼓山明誠',
#   'address': '高雄市鼓山區明誠三路463號',
#   'bigadd': '高雄市',
#   'lat': 0,
#   'lng': 0,
#   'name': '全聯鼓山明誠',
#   'road': '明誠三路',
#   'smalladd': '鼓山區',
#   'tele': '07-5224436'},
#  {'_id': '全聯桃園中埔',
#   'address': '桃園市桃園區中埔二街158.160號',
#   'bigadd': '桃園市',
#   'lat': 25.012682,
#   'lng': 121.295604,
#   'name': '全聯桃園中埔',
#   'road': '中埔二街',
#   'smalladd': '桃園區',
#   'tele': '03-2150291'},
#  {'_id': '全聯三民金獅湖',
#   'address': '高雄市三民區鼎力路15、17、19、21號',
#   'bigadd': '高雄市',
#   'lat': 22.670007,
#   'lng': 120.325801,
#   'name': '全聯三民金獅湖',
#   'road': '鼎力路',
#   'smalladd': '三民區',
#   'tele': '07-3103722'},
#  {'_id': '全聯新竹食品',
#   'address': '新竹市東區食品路305之1號',
#   'bigadd': '新竹市',
#   'lat': 24.794705,
#   'lng': 120.972572,
#   'name': '全聯新竹食品',
#   'road': '食品路',
#   'smalladd': '東區',
#   'tele': '03-5611256'},
#  {'_id': '全聯竹山集山',
#   'address': '南投縣竹山鎮集山路３段227、229號',
#   'bigadd': '南投縣',
#   'lat': 23.763293,
#   'lng': 120.701009,
#   'name': '全聯竹山集山',
#   'road': '集山路３段',
#   'smalladd': '竹山鎮',
#   'tele': '049-2630196'}]
