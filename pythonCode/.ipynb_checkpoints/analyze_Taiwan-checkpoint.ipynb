# %% [markdown]
# # 2000M

# %%
import numpy as np
TaiwanLatRange=np.arange(21.91456,25.29548,0.00676184)
TaiwanLngRange=np.arange(120.04193,122.00059,0.009793304)

# %%
TWLocs=[]
for i in TaiwanLatRange:
    for j in TaiwanLngRange:
        TWLoc={}
        TWLoc['lat']=i
        TWLoc['lng']=j
        TWLocs.append(TWLoc)

# %%
TWLocs
# Out:
# [{'lat': 21.91456, 'lng': 120.04193},
#  {'lat': 21.91456, 'lng': 120.05172330399999},
#  {'lat': 21.91456, 'lng': 120.06151660799999},
#  {'lat': 21.91456, 'lng': 120.07130991199999},
#  {'lat': 21.91456, 'lng': 120.08110321599999},
#  {'lat': 21.91456, 'lng': 120.09089651999999},
#  {'lat': 21.91456, 'lng': 120.10068982399999},
#  {'lat': 21.91456, 'lng': 120.11048312799998},
#  {'lat': 21.91456, 'lng': 120.12027643199998},
#  {'lat': 21.91456, 'lng': 120.13006973599998},
#  {'lat': 21.91456, 'lng': 120.13986303999998},
#  {'lat': 21.91456, 'lng': 120.14965634399998},
#  {'lat': 21.91456, 'lng': 120.15944964799998},
#  {'lat': 21.91456, 'lng': 120.16924295199998},
#  {'lat': 21.91456, 'lng': 120.17903625599997},
#  {'lat': 21.91456, 'lng': 120.18882955999997},
#  {'lat': 21.91456, 'lng': 120.19862286399997},
#  {'lat': 21.91456, 'lng': 120.20841616799997},
#  {'lat': 21.91456, 'lng': 120.21820947199997},
#  {'lat': 21.91456, 'lng': 120.22800277599997},
#  {'lat': 21.91456, 'lng': 120.23779607999997},
#  {'lat': 21.91456, 'lng': 120.24758938399997},
#  {'lat': 21.91456, 'lng': 120.25738268799996},
#  {'lat': 21.91456, 'lng': 120.26717599199996},
#  {'lat': 21.91456, 'lng': 120.27696929599996},
#  {'lat': 21.91456, 'lng': 120.28676259999996},
#  {'lat': 21.91456, 'lng': 120.29655590399996},
#  {'lat': 21.91456, 'lng': 120.30634920799996},
#  {'lat': 21.91456, 'lng': 120.31614251199996},
#  {'lat': 21.91456, 'lng': 120.32593581599996},
#  {'lat': 21.91456, 'lng': 120.33572911999995},
#  {'lat': 21.91456, 'lng': 120.34552242399995},
#  {'lat': 21.91456, 'lng': 120.35531572799995},
#  {'lat': 21.91456, 'lng': 120.36510903199995},
#  {'lat': 21.91456, 'lng': 120.37490233599995},
#  {'lat': 21.91456, 'lng': 120.38469563999995},
#  {'lat': 21.91456, 'lng': 120.39448894399995},
#  {'lat': 21.91456, 'lng': 120.40428224799994},
#  {'lat': 21.91456, 'lng': 120.41407555199994},
#  {'lat': 21.91456, 'lng': 120.42386885599994},
#  {'lat': 21.91456, 'lng': 120.43366215999994},
#  {'lat': 21.91456, 'lng': 120.44345546399994},
#  {'lat': 21.91456, 'lng': 120.45324876799994},
#  {'lat': 21.91456, 'lng': 120.46304207199994},
#  {'lat': 21.91456, 'lng': 120.47283537599994},
#  {'lat': 21.91456, 'lng': 120.48262867999993},
#  {'lat': 21.91456, 'lng': 120.49242198399993},
#  {'lat': 21.91456, 'lng': 120.50221528799993},
#  {'lat': 21.91456, 'lng': 120.51200859199993},
#  {'lat': 21.91456, 'lng': 120.52180189599993},
#  {'lat': 21.91456, 'lng': 120.53159519999993},
#  {'lat': 21.91456, 'lng': 120.54138850399993},
#  {'lat': 21.91456, 'lng': 120.55118180799992},
#  {'lat': 21.91456, 'lng': 120.56097511199992},
#  {'lat': 21.91456, 'lng': 120.57076841599992},
#  {'lat': 21.91456, 'lng': 120.58056171999992},
#  {'lat': 21.91456, 'lng': 120.59035502399992},
#  {'lat': 21.91456, 'lng': 120.60014832799992},
#  {'lat': 21.91456, 'lng': 120.60994163199992},
#  {'lat': 21.91456, 'lng': 120.61973493599992},
#  {'lat': 21.91456, 'lng': 120.62952823999991},
#  {'lat': 21.91456, 'lng': 120.63932154399991},
#  {'lat': 21.91456, 'lng': 120.64911484799991},
#  {'lat': 21.91456, 'lng': 120.65890815199991},
#  {'lat': 21.91456, 'lng': 120.66870145599991},
#  {'lat': 21.91456, 'lng': 120.67849475999991},
#  {'lat': 21.91456, 'lng': 120.6882880639999},
#  {'lat': 21.91456, 'lng': 120.6980813679999},
#  {'lat': 21.91456, 'lng': 120.7078746719999},
#  {'lat': 21.91456, 'lng': 120.7176679759999},
#  {'lat': 21.91456, 'lng': 120.7274612799999},
#  {'lat': 21.91456, 'lng': 120.7372545839999},
#  {'lat': 21.91456, 'lng': 120.7470478879999},
#  {'lat': 21.91456, 'lng': 120.7568411919999},
#  {'lat': 21.91456, 'lng': 120.7666344959999},
#  {'lat': 21.91456, 'lng': 120.7764277999999},
#  {'lat': 21.91456, 'lng': 120.78622110399989},
#  {'lat': 21.91456, 'lng': 120.79601440799989},
#  {'lat': 21.91456, 'lng': 120.80580771199989},
#  {'lat': 21.91456, 'lng': 120.81560101599989},
#  {'lat': 21.91456, 'lng': 120.82539431999989},
#  {'lat': 21.91456, 'lng': 120.83518762399989},
#  {'lat': 21.91456, 'lng': 120.84498092799988},
#  {'lat': 21.91456, 'lng': 120.85477423199988},
#  {'lat': 21.91456, 'lng': 120.86456753599988},
#  {'lat': 21.91456, 'lng': 120.87436083999988},
#  {'lat': 21.91456, 'lng': 120.88415414399988},
#  {'lat': 21.91456, 'lng': 120.89394744799988},
#  {'lat': 21.91456, 'lng': 120.90374075199988},
#  {'lat': 21.91456, 'lng': 120.91353405599988},
#  {'lat': 21.91456, 'lng': 120.92332735999987},
#  {'lat': 21.91456, 'lng': 120.93312066399987},
#  {'lat': 21.91456, 'lng': 120.94291396799987},
#  {'lat': 21.91456, 'lng': 120.95270727199987},
#  {'lat': 21.91456, 'lng': 120.96250057599987},
#  {'lat': 21.91456, 'lng': 120.97229387999987},
#  {'lat': 21.91456, 'lng': 120.98208718399987},
#  {'lat': 21.91456, 'lng': 120.99188048799986},
#  {'lat': 21.91456, 'lng': 121.00167379199986},
#  {'lat': 21.91456, 'lng': 121.01146709599986},
#  {'lat': 21.91456, 'lng': 121.02126039999986},
#  {'lat': 21.91456, 'lng': 121.03105370399986},
#  {'lat': 21.91456, 'lng': 121.04084700799986},
#  {'lat': 21.91456, 'lng': 121.05064031199986},
#  {'lat': 21.91456, 'lng': 121.06043361599986},
#  {'lat': 21.91456, 'lng': 121.07022691999985},
#  {'lat': 21.91456, 'lng': 121.08002022399985},
#  {'lat': 21.91456, 'lng': 121.08981352799985},
#  {'lat': 21.91456, 'lng': 121.09960683199985},
#  {'lat': 21.91456, 'lng': 121.10940013599985},
#  {'lat': 21.91456, 'lng': 121.11919343999985},
#  {'lat': 21.91456, 'lng': 121.12898674399985},
#  {'lat': 21.91456, 'lng': 121.13878004799984},
#  {'lat': 21.91456, 'lng': 121.14857335199984},
#  {'lat': 21.91456, 'lng': 121.15836665599984},
#  {'lat': 21.91456, 'lng': 121.16815995999984},
#  {'lat': 21.91456, 'lng': 121.17795326399984},
#  {'lat': 21.91456, 'lng': 121.18774656799984},
#  {'lat': 21.91456, 'lng': 121.19753987199984},
#  {'lat': 21.91456, 'lng': 121.20733317599984},
#  {'lat': 21.91456, 'lng': 121.21712647999983},
#  {'lat': 21.91456, 'lng': 121.22691978399983},
#  {'lat': 21.91456, 'lng': 121.23671308799983},
#  {'lat': 21.91456, 'lng': 121.24650639199983},
#  {'lat': 21.91456, 'lng': 121.25629969599983},
#  {'lat': 21.91456, 'lng': 121.26609299999983},
#  {'lat': 21.91456, 'lng': 121.27588630399983},
#  {'lat': 21.91456, 'lng': 121.28567960799982},
#  {'lat': 21.91456, 'lng': 121.29547291199982},
#  {'lat': 21.91456, 'lng': 121.30526621599982},
#  {'lat': 21.91456, 'lng': 121.31505951999982},
#  {'lat': 21.91456, 'lng': 121.32485282399982},
#  {'lat': 21.91456, 'lng': 121.33464612799982},
#  {'lat': 21.91456, 'lng': 121.34443943199982},
#  {'lat': 21.91456, 'lng': 121.35423273599982},
#  {'lat': 21.91456, 'lng': 121.36402603999981},
#  {'lat': 21.91456, 'lng': 121.37381934399981},
#  {'lat': 21.91456, 'lng': 121.38361264799981},
#  {'lat': 21.91456, 'lng': 121.39340595199981},
#  {'lat': 21.91456, 'lng': 121.40319925599981},
#  {'lat': 21.91456, 'lng': 121.41299255999981},
#  {'lat': 21.91456, 'lng': 121.4227858639998},
#  {'lat': 21.91456, 'lng': 121.4325791679998},
#  {'lat': 21.91456, 'lng': 121.4423724719998},
#  {'lat': 21.91456, 'lng': 121.4521657759998},
#  {'lat': 21.91456, 'lng': 121.4619590799998},
#  {'lat': 21.91456, 'lng': 121.4717523839998},
#  {'lat': 21.91456, 'lng': 121.4815456879998},
#  {'lat': 21.91456, 'lng': 121.4913389919998},
#  {'lat': 21.91456, 'lng': 121.5011322959998},
#  {'lat': 21.91456, 'lng': 121.5109255999998},
#  {'lat': 21.91456, 'lng': 121.52071890399979},
#  {'lat': 21.91456, 'lng': 121.53051220799979},
#  {'lat': 21.91456, 'lng': 121.54030551199979},
#  {'lat': 21.91456, 'lng': 121.55009881599979},
#  {'lat': 21.91456, 'lng': 121.55989211999979},
#  {'lat': 21.91456, 'lng': 121.56968542399979},
#  {'lat': 21.91456, 'lng': 121.57947872799978},
#  {'lat': 21.91456, 'lng': 121.58927203199978},
#  {'lat': 21.91456, 'lng': 121.59906533599978},
#  {'lat': 21.91456, 'lng': 121.60885863999978},
#  {'lat': 21.91456, 'lng': 121.61865194399978},
#  {'lat': 21.91456, 'lng': 121.62844524799978},
#  {'lat': 21.91456, 'lng': 121.63823855199978},
#  {'lat': 21.91456, 'lng': 121.64803185599978},
#  {'lat': 21.91456, 'lng': 121.65782515999977},
#  {'lat': 21.91456, 'lng': 121.66761846399977},
#  {'lat': 21.91456, 'lng': 121.67741176799977},
#  {'lat': 21.91456, 'lng': 121.68720507199977},
#  {'lat': 21.91456, 'lng': 121.69699837599977},
#  {'lat': 21.91456, 'lng': 121.70679167999977},
#  {'lat': 21.91456, 'lng': 121.71658498399977},
#  {'lat': 21.91456, 'lng': 121.72637828799976},
#  {'lat': 21.91456, 'lng': 121.73617159199976},
#  {'lat': 21.91456, 'lng': 121.74596489599976},
#  {'lat': 21.91456, 'lng': 121.75575819999976},
#  {'lat': 21.91456, 'lng': 121.76555150399976},
#  {'lat': 21.91456, 'lng': 121.77534480799976},
#  {'lat': 21.91456, 'lng': 121.78513811199976},
#  {'lat': 21.91456, 'lng': 121.79493141599976},
#  {'lat': 21.91456, 'lng': 121.80472471999975},
#  {'lat': 21.91456, 'lng': 121.81451802399975},
#  {'lat': 21.91456, 'lng': 121.82431132799975},
#  {'lat': 21.91456, 'lng': 121.83410463199975},
#  {'lat': 21.91456, 'lng': 121.84389793599975},
#  {'lat': 21.91456, 'lng': 121.85369123999975},
#  {'lat': 21.91456, 'lng': 121.86348454399975},
#  {'lat': 21.91456, 'lng': 121.87327784799974},
#  {'lat': 21.91456, 'lng': 121.88307115199974},
#  {'lat': 21.91456, 'lng': 121.89286445599974},
#  {'lat': 21.91456, 'lng': 121.90265775999974},
#  {'lat': 21.91456, 'lng': 121.91245106399974},
#  {'lat': 21.91456, 'lng': 121.92224436799974},
#  {'lat': 21.91456, 'lng': 121.93203767199974},
#  {'lat': 21.91456, 'lng': 121.94183097599974},
#  {'lat': 21.91456, 'lng': 121.95162427999973},
#  {'lat': 21.91456, 'lng': 121.96141758399973},
#  {'lat': 21.91456, 'lng': 121.97121088799973},
#  {'lat': 21.91456, 'lng': 121.98100419199973},
#  {'lat': 21.91456, 'lng': 121.99079749599973},
#  {'lat': 21.92132184, 'lng': 120.04193},
#  {'lat': 21.92132184, 'lng': 120.05172330399999},
#  {'lat': 21.92132184, 'lng': 120.06151660799999},
#  {'lat': 21.92132184, 'lng': 120.07130991199999},
#  {'lat': 21.92132184, 'lng': 120.08110321599999},
#  {'lat': 21.92132184, 'lng': 120.09089651999999},
#  {'lat': 21.92132184, 'lng': 120.10068982399999},
#  {'lat': 21.92132184, 'lng': 120.11048312799998},
#  {'lat': 21.92132184, 'lng': 120.12027643199998},
#  {'lat': 21.92132184, 'lng': 120.13006973599998},
#  {'lat': 21.92132184, 'lng': 120.13986303999998},
#  {'lat': 21.92132184, 'lng': 120.14965634399998},
#  {'lat': 21.92132184, 'lng': 120.15944964799998},
#  {'lat': 21.92132184, 'lng': 121.73617159199976},
#  {'lat': 21.92132184, 'lng': 121.74596489599976},
#  {'lat': 21.92132184, 'lng': 121.75575819999976},
#  {'lat': 21.92132184, 'lng': 121.76555150399976},
#  {'lat': 21.92132184, 'lng': 121.77534480799976},
#  {'lat': 21.92132184, 'lng': 121.78513811199976},
#  {'lat': 21.92132184, 'lng': 121.79493141599976},
#  {'lat': 21.92132184, 'lng': 121.80472471999975},
#  {'lat': 21.92132184, 'lng': 121.81451802399975},
#  {'lat': 21.92132184, 'lng': 121.82431132799975},
#  {'lat': 21.92132184, 'lng': 121.83410463199975},
#  {'lat': 21.92132184, 'lng': 121.84389793599975},
#  {'lat': 21.92132184, 'lng': 121.85369123999975},
#  {'lat': 21.92132184, 'lng': 121.86348454399975},
#  {'lat': 21.92132184, 'lng': 121.87327784799974},
#  {'lat': 21.92132184, 'lng': 121.88307115199974},
#  {'lat': 21.92132184, 'lng': 121.89286445599974},
#  {'lat': 21.92132184, 'lng': 121.90265775999974},
#  {'lat': 21.92132184, 'lng': 121.91245106399974},
#  {'lat': 21.92132184, 'lng': 121.92224436799974},
#  {'lat': 21.92132184, 'lng': 121.93203767199974},
#  {'lat': 21.92132184, 'lng': 121.94183097599974},
#  {'lat': 21.92132184, 'lng': 121.95162427999973},
#  {'lat': 21.92132184, 'lng': 121.96141758399973},
#  {'lat': 21.92132184, 'lng': 121.97121088799973},
#  {'lat': 21.92132184, 'lng': 121.98100419199973},
#  {'lat': 21.92132184, 'lng': 121.99079749599973},
#  {'lat': 21.92808368, 'lng': 120.04193},
#  {'lat': 21.92808368, 'lng': 120.05172330399999},
#  {'lat': 21.92808368, 'lng': 120.06151660799999},
#  {'lat': 21.92808368, 'lng': 120.07130991199999},
#  {'lat': 21.92808368, 'lng': 120.08110321599999},
#  {'lat': 21.92808368, 'lng': 120.09089651999999},
#  {'lat': 21.92808368, 'lng': 120.10068982399999},
#  {'lat': 21.92808368, 'lng': 120.11048312799998},
#  {'lat': 21.92808368, 'lng': 120.12027643199998},
#  {'lat': 21.92808368, 'lng': 120.13006973599998},
#  {'lat': 21.92808368, 'lng': 120.13986303999998},
#  {'lat': 21.92808368, 'lng': 120.14965634399998},
#  {'lat': 21.92808368, 'lng': 120.15944964799998},
#  {'lat': 21.92808368, 'lng': 120.16924295199998},
#  {'lat': 21.92808368, 'lng': 120.17903625599997},
#  {'lat': 21.92808368, 'lng': 120.18882955999997},
#  {'lat': 21.92808368, 'lng': 120.19862286399997},
#  {'lat': 21.92808368, 'lng': 120.20841616799997},
#  {'lat': 21.92808368, 'lng': 120.21820947199997},
#  {'lat': 21.92808368, 'lng': 120.22800277599997},
#  {'lat': 21.92808368, 'lng': 120.23779607999997},
#  {'lat': 21.92808368, 'lng': 120.24758938399997},
#  {'lat': 21.92808368, 'lng': 120.25738268799996},
#  {'lat': 21.92808368, 'lng': 120.26717599199996},
#  {'lat': 21.92808368, 'lng': 120.27696929599996},
#  {'lat': 21.92808368, 'lng': 120.28676259999996},
#  {'lat': 21.92808368, 'lng': 120.82539431999989},
#  {'lat': 21.92808368, 'lng': 120.83518762399989},
#  {'lat': 21.92808368, 'lng': 120.84498092799988},
#  {'lat': 21.92808368, 'lng': 120.85477423199988},
#  {'lat': 21.92808368, 'lng': 120.86456753599988},
#  {'lat': 21.92808368, 'lng': 120.87436083999988},
#  {'lat': 21.92808368, 'lng': 120.88415414399988},
#  {'lat': 21.92808368, 'lng': 120.89394744799988},
#  {'lat': 21.92808368, 'lng': 120.90374075199988},
#  {'lat': 21.92808368, 'lng': 120.91353405599988},
#  {'lat': 21.92808368, 'lng': 120.92332735999987},
#  {'lat': 21.92808368, 'lng': 120.93312066399987},
#  {'lat': 21.92808368, 'lng': 120.94291396799987},
#  {'lat': 21.92808368, 'lng': 120.95270727199987},
#  {'lat': 21.92808368, 'lng': 120.96250057599987},
#  {'lat': 21.92808368, 'lng': 120.97229387999987},
#  {'lat': 21.92808368, 'lng': 120.98208718399987},
#  {'lat': 21.92808368, 'lng': 120.99188048799986},
#  {'lat': 21.92808368, 'lng': 121.00167379199986},
#  {'lat': 21.92808368, 'lng': 121.01146709599986},
#  {'lat': 21.92808368, 'lng': 121.02126039999986},
#  {'lat': 21.92808368, 'lng': 121.03105370399986},
#  {'lat': 21.92808368, 'lng': 121.04084700799986},
#  {'lat': 21.92808368, 'lng': 121.05064031199986},
#  {'lat': 21.92808368, 'lng': 121.06043361599986},
#  {'lat': 21.92808368, 'lng': 121.07022691999985},
#  {'lat': 21.92808368, 'lng': 121.08002022399985},
#  {'lat': 21.92808368, 'lng': 121.08981352799985},
#  {'lat': 21.92808368, 'lng': 121.09960683199985},
#  {'lat': 21.92808368, 'lng': 121.10940013599985},
#  {'lat': 21.92808368, 'lng': 121.11919343999985},
#  {'lat': 21.92808368, 'lng': 121.12898674399985},
#  {'lat': 21.92808368, 'lng': 121.13878004799984},
#  {'lat': 21.92808368, 'lng': 121.14857335199984},
#  {'lat': 21.92808368, 'lng': 121.15836665599984},
#  {'lat': 21.92808368, 'lng': 121.16815995999984},
#  {'lat': 21.92808368, 'lng': 121.17795326399984},
#  {'lat': 21.92808368, 'lng': 121.18774656799984},
#  {'lat': 21.92808368, 'lng': 121.19753987199984},
#  {'lat': 21.92808368, 'lng': 121.20733317599984},
#  {'lat': 21.92808368, 'lng': 121.21712647999983},
#  {'lat': 21.92808368, 'lng': 121.22691978399983},
#  {'lat': 21.92808368, 'lng': 121.23671308799983},
#  {'lat': 21.92808368, 'lng': 121.24650639199983},
#  {'lat': 21.92808368, 'lng': 121.25629969599983},
#  {'lat': 21.92808368, 'lng': 121.26609299999983},
#  {'lat': 21.92808368, 'lng': 121.27588630399983},
#  {'lat': 21.92808368, 'lng': 121.28567960799982},
#  {'lat': 21.92808368, 'lng': 121.29547291199982},
#  {'lat': 21.92808368, 'lng': 121.30526621599982},
#  {'lat': 21.92808368, 'lng': 121.31505951999982},
#  {'lat': 21.92808368, 'lng': 121.32485282399982},
#  {'lat': 21.92808368, 'lng': 121.33464612799982},
#  {'lat': 21.94160736, 'lng': 121.59906533599978},
#  {'lat': 21.94160736, 'lng': 121.60885863999978},
#  {'lat': 21.94160736, 'lng': 121.61865194399978},
#  {'lat': 21.94160736, 'lng': 121.62844524799978},
#  {'lat': 21.94160736, 'lng': 121.63823855199978},
#  {'lat': 21.94160736, 'lng': 121.64803185599978},
#  {'lat': 21.94160736, 'lng': 121.65782515999977},
#  {'lat': 21.94160736, 'lng': 121.66761846399977},
#  {'lat': 21.94160736, 'lng': 121.67741176799977},
#  {'lat': 21.94160736, 'lng': 121.68720507199977},
#  {'lat': 21.94160736, 'lng': 121.69699837599977},
#  {'lat': 21.94160736, 'lng': 121.70679167999977},
#  {'lat': 21.94160736, 'lng': 121.71658498399977},
#  {'lat': 21.94160736, 'lng': 121.72637828799976},
#  {'lat': 21.94160736, 'lng': 121.73617159199976},
#  {'lat': 21.94160736, 'lng': 121.74596489599976},
#  {'lat': 21.94160736, 'lng': 121.75575819999976},
#  {'lat': 21.94160736, 'lng': 121.76555150399976},
#  {'lat': 21.94160736, 'lng': 121.77534480799976},
#  {'lat': 21.94160736, 'lng': 121.78513811199976},
#  {'lat': 21.94160736, 'lng': 121.79493141599976},
#  {'lat': 21.94160736, 'lng': 121.80472471999975},
#  {'lat': 21.94160736, 'lng': 121.81451802399975},
#  {'lat': 21.94160736, 'lng': 121.82431132799975},
#  {'lat': 21.94160736, 'lng': 121.83410463199975},
#  {'lat': 21.94160736, 'lng': 121.84389793599975},
#  {'lat': 21.94160736, 'lng': 121.85369123999975},
#  {'lat': 21.94160736, 'lng': 121.86348454399975},
#  {'lat': 21.94160736, 'lng': 121.87327784799974},
#  {'lat': 21.94160736, 'lng': 121.88307115199974},
#  {'lat': 21.94160736, 'lng': 121.89286445599974},
#  {'lat': 21.94160736, 'lng': 121.90265775999974},
#  {'lat': 21.94160736, 'lng': 121.91245106399974},
#  {'lat': 21.94160736, 'lng': 121.92224436799974},
#  {'lat': 21.94160736, 'lng': 121.93203767199974},
#  {'lat': 21.94160736, 'lng': 121.94183097599974},
#  {'lat': 21.94160736, 'lng': 121.95162427999973},
#  {'lat': 21.94160736, 'lng': 121.96141758399973},
#  {'lat': 21.94160736, 'lng': 121.97121088799973},
#  {'lat': 21.94160736, 'lng': 121.98100419199973},
#  {'lat': 21.94160736, 'lng': 121.99079749599973},
#  ...]

# %%
import json
import pymongo
from pymongo import UpdateOne
import numpy
import math
from math import radians, cos, sin, asin, sqrt
from collections import Counter
import time
import sys
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.message import EmailMessage
import smtplib

def haversine(lng1, lat1, lng2, lat2):
    # 将十进制度数转化为弧度
    lng1, lat1, lng2, lat2 = map(radians, [lng1, lat1, lng2, lat2])
    # haversine公式
    dlng = lng2 - lng1
    dlat = lat2 - lat1
    a = sin(dlat / 2) ** 2 + cos(lat1) * cos(lat2) * sin(dlng / 2) ** 2
    c = 2 * asin(sqrt(a))
    r = 6371  # 地球平均半径，单位为公里
    return c * r * 1000


b=time.time()
def mailTo(title,mailAdds,message,whoSend='AutoAddInsurance'):
    msg = MIMEMultipart()    
    sender = whoSend
    subject = title
    body = message
    msg['From'] = sender
    msg['To'] = ','.join(mailAdds)
    msg['Subject'] = subject
    msg.attach(MIMEText(body, 'plain'))
    text=msg.as_string()
    #print text
    # Send the message via our SMTP server
    s = smtplib.SMTP('192.168.2.1',25)
    s.sendmail(sender,mailAdds, text)
    s.quit()  

try:
    ######################################################IPEEN
    b=time.time()
    queryElements = {}
    client = pymongo.mongo_client.MongoClient("localhost", 27017, username='j122085', password='850605')
    collectionTaiwan = client.rawData.taiwanInfo
    TWLocs=list(collectionTaiwan.find({}))
    
    # collection = client.rawData.wowprimeipeen
    collection = client.rawData.ipeenInfo
    ipeendata = list(collection.find(queryElements))
    ipeendata = [dien for dien in ipeendata if dien['status'] == "正常營業"
                 and dien['lat'] > 18
                 and dien['lat'] < 27
                 and dien['lng'] < 125
                 and dien['lng'] > 117
                 and dien['bigadd'] != 0
                 and dien['smalladd'] != 0
                 and dien['averagecost'] < 8000]

    for dien in ipeendata:
        dien["id"] = dien.pop("_id")
    ######################################################IPEEN
    ######################################################104
    collection = client.rawData.HRdata104
    hr104data = list(collection.find(queryElements))
    hr104data = [dien for dien in hr104data if dien['LAT'] > 18
                 and dien['LAT'] < 27
                 and dien['SAL_MONTH_LOW'] > 18000
                 and dien['SAL_MONTH_LOW'] < 100000
                 and dien['SAL_MONTH_HIGH'] > 18000
                 and dien['SAL_MONTH_HIGH'] < 200000
                 and dien['LON'] < 125
                 and dien['LON'] > 117
                 and dien['bigadd'] != 0
                 and dien['smalladd'] != 0]

    for dien in hr104data:
        dien["lat"] = dien.pop("LAT")
        dien["lng"] = dien.pop("LON")
        del dien["_id"]
    ######################################################104
    ######################################################Nhuman
    collection = client.rawData.Nhuman
    Nhumandata = list(collection.find(queryElements))
    for dien in Nhumandata:
        dien["weight"] = int(dien.pop("Nhuman"))
        dien["add"] = dien.pop("_id")
    ######################################################Nhuman
    ######################################################CostPower
    collection = client.rawData.CostPower
    CostPowerdata = list(collection.find(queryElements))
    for dien in CostPowerdata:
        dien["weight"] = int(dien.pop('costPower'))
        dien["add"] = dien.pop("_id")
    ######################################################CostPower
    ######################################################Bus0320
    collection = client.rawData.busData
    busData = list(collection.find(queryElements))
    for dien in busData:
        dien["add"] = dien.pop("_id")
    ######################################################Bus0320
    ######################################################conStore0320
    collection = client.rawData.conStore
    conStoreData = list(collection.find(queryElements))
    for dien in conStoreData:
        dien.pop("_id")
    ######################################################conStore0320
    ######################################################Wow


    TWLocs = [i for i in TWLocs if ('costPower_Analyze' in i and
              i['costPower_Analyze'] >0) or
              ('Nhuman_Analyze' in i and
              i['Nhuman_Analyze']>0)]
    allN=len(TWLocs)
    print("有{}筆資料要分析".format(allN))
    radius=2000
    n = 0
    for TWLoc in TWLocs:
        n += 1
        if n % 15 == 0:
            print("已完成{}%分析-{}項".format(round(n/allN,4)*100,n))
        if n % 1000 == 0:
            for i in TWLocs:
                i["_id"]="{}_{}".format(i['lat'],i['lng'])
            client = pymongo.mongo_client.MongoClient("localhost", 27017, username='j122085', password='850605')
            collection = client.rawData.taiwanInfo
            ids=[data.pop("_id") for data in TWLocs]
            operations=[UpdateOne({"_id":idn},{'$set':data},upsert=True) for idn ,data in zip(ids,TWLocs)]
            try:
                collection.bulk_write(operations ,ordered=False)
            except Exception as er:
                print(er)
            client.close()

        TWLoc["areaRadius_Analyze"] = radius
        dienCostPower = round(numpy.mean([dien['weight'] for dien in CostPowerdata if haversine(lng1=dien["lng"],
                                                                                                lat1=dien["lat"],
                                                                                                lng2=TWLoc["lng"],
                                                                                                lat2=TWLoc[
                                                                                                    "lat"]) <= radius and 'weight' in dien]))

        if not math.isnan(dienCostPower):
            TWLoc["costPower_Analyze"] = dienCostPower
        else:
            TWLoc["costPower_Analyze"] =0
        TWLoc["NcostData_Analyze"] = len([dien['weight'] for dien in CostPowerdata if haversine(lng1=dien["lng"],
                                                                                lat1=dien["lat"],
                                                                                lng2=TWLoc["lng"],
                                                                                lat2=TWLoc["lat"]) <= radius and 'weight' in dien])

        dienHuman = sum([dien['weight'] for dien in Nhumandata if haversine(lng1=dien["lng"],
                                                                            lat1=dien["lat"],
                                                                            lng2=TWLoc["lng"],
                                                                            lat2=TWLoc["lat"]) <= radius and 'weight' in dien])
        TWLoc['Nhuman_Analyze'] = dienHuman

        avgSalary = round(numpy.mean(
            [dien['SAL_MONTH_LOW'] * 1 / 3 + dien['SAL_MONTH_HIGH'] * 2 / 3 for dien in hr104data if
             haversine(lng1=dien["lng"],
                       lat1=dien["lat"],
                       lng2=TWLoc["lng"],
                       lat2=TWLoc["lat"]) <= radius and 'SAL_MONTH_HIGH' in dien and 'SAL_MONTH_LOW' in dien]))
        if not math.isnan(avgSalary):
            TWLoc['avgSalary_Analyze'] = avgSalary
        else:
            TWLoc["avgSalary_Analyze"] =0

        TWLoc['Njob_Analyze'] = len([dien['SAL_MONTH_LOW'] * 1 / 3 + dien['SAL_MONTH_HIGH'] * 2 / 3 for dien in hr104data if
                            haversine(lng1=dien["lng"],
                                      lat1=dien["lat"],
                                      lng2=TWLoc["lng"],
                                      lat2=TWLoc["lat"]) <= radius and 'SAL_MONTH_HIGH' in dien  and 'SAL_MONTH_LOW' in dien])

        avgCost = round(numpy.mean([dien['averagecost'] for dien in ipeendata if haversine(lng1=dien["lng"],
                                                                                           lat1=dien["lat"],
                                                                                           lng2=TWLoc["lng"],
                                                                                           lat2=TWLoc[
                                                                                               "lat"]) <= radius and 'averagecost' in dien]))
        if not math.isnan(avgCost):
            TWLoc['avgCost_Analyze'] = avgCost
        else:
            TWLoc["avgCost_Analyze"] =0

        try:
            mostStyle = Counter([dien['bigstyle'] for dien in ipeendata if haversine(lng1=dien["lng"],
                                                                                     lat1=dien["lat"],
                                                                                     lng2=TWLoc["lng"],
                                                                                     lat2=TWLoc[
                                                                                         "lat"]) <= radius and 'bigstyle' in dien]).most_common(1)[0][0]
        except:
            mostStyle = ""
        TWLoc['mostStyle_Analyze'] = mostStyle

        ###############################################################################################################0320
        TWLoc["NbusStation_Analyze"] = len([dien['stationName'] for dien in busData if "lng" in dien and haversine(lng1=dien["lng"],
                                                                                lat1=dien["lat"],
                                                                                lng2=TWLoc["lng"],
                                                                                lat2=TWLoc["lat"]) <= 500])#0326 change radius

        TWLoc["NconStore_Analyze"] = len([dien['name'] for dien in conStoreData if "lng" in dien and haversine(lng1=float(dien["lng"]),
                                                                                lat1=float(dien["lat"]),
                                                                                lng2=TWLoc["lng"],
                                                                                lat2=TWLoc["lat"]) <= radius])
    #         conStoreData
        TWLoc["Nstar_Analyze"] = len([dien['name'] for dien in ipeendata 
                                if '星巴' in dien['name'] 
                                and haversine(lng1=dien["lng"],
                                              lat1=dien["lat"],
                                              lng2=TWLoc["lng"],
                                              lat2=TWLoc["lat"]) <= radius])
        TWLoc["Nmc_Analyze"] = len([dien['name'] for dien in ipeendata 
                                if '麥當' in dien['name'] 
                                and haversine(lng1=dien["lng"],
                                              lat1=dien["lat"],
                                              lng2=TWLoc["lng"],
                                              lat2=TWLoc["lat"]) <= radius])
        TWLoc["Nken_Analyze"] = len([dien['name'] for dien in ipeendata 
                                if '肯德' in dien['name'] 
                                and haversine(lng1=dien["lng"],
                                              lat1=dien["lat"],
                                              lng2=TWLoc["lng"],
                                              lat2=TWLoc["lat"]) <= radius])
        TWLoc["Nwa_Analyze"] = len([dien['name'] for dien in ipeendata 
                                if '瓦城泰' in dien['name'] 
                                and haversine(lng1=dien["lng"],
                                              lat1=dien["lat"],
                                              lng2=TWLoc["lng"],
                                              lat2=TWLoc["lat"]) <= radius])
        ################################################################################################################0320
        
        
        
        
    e = time.time()
    print(e-b)


#     ids=[data.pop("_id") for data in TWLocs]
#     operations=[UpdateOne({"_id":idn},{'$set':data},upsert=True) for idn ,data in zip(ids,TWLocs)]
#     try:
#         collection.bulk_write(operations ,ordered=False)
#     except Exception as er:
#         print(er)

#     alldata=list(collection.find({}))

#     client.close()
    for i in TWLocs:
        i["_id"]="{}_{}".format(i['lat'],i['lng'])
    client = pymongo.mongo_client.MongoClient("192.168.1.113", 27017, username='j122085', password='850605')
    collection = client.rawData.taiwanInfo
    ids=[data.pop("_id") for data in TWLocs]
    operations=[UpdateOne({"_id":idn},{'$set':data},upsert=True) for idn ,data in zip(ids,TWLocs)]
    try:
        collection.bulk_write(operations ,ordered=False)
    except Exception as er:
        print(er)
    client.close()
    
    mailTo(title="TaiwanDataSuccess",mailAdds=["andy.yuan@wowprime.com"],message="分析完畢_耗時{}秒".format(e-b),whoSend='analyzeTaiwanData')
except Exception as er:
    errorMsg=str(er)+"出錯位置:"+str(sys.exc_info()[2].tb_lineno)
    mailTo(title="analyzeTaiwanDataFail",mailAdds=["andy.yuan@wowprime.com"],message=errorMsg,whoSend='analyzeTaiwanData')
# Out:
# 有27298筆資料要分析
# D:\anaconda\lib\site-packages\numpy\core\fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# D:\anaconda\lib\site-packages\numpy\core\_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 已完成0.05%分析-15項
# 已完成0.11%分析-30項
# 已完成0.16%分析-45項
# 已完成0.22%分析-60項
# 已完成0.27%分析-75項
# 已完成0.33%分析-90項
# 已完成0.38%分析-105項
# 已完成0.44%分析-120項
# 已完成0.49%分析-135項
# 已完成0.5499999999999999%分析-150項
# 已完成0.6%分析-165項
# 已完成0.66%分析-180項
# 已完成0.7100000000000001%分析-195項
# 已完成0.77%分析-210項
# 已完成0.8200000000000001%分析-225項
# 已完成0.88%分析-240項
# 已完成0.9299999999999999%分析-255項
# 已完成0.9900000000000001%分析-270項
# 已完成1.04%分析-285項
# 已完成1.0999999999999999%分析-300項
# 已完成1.15%分析-315項
# 已完成1.21%分析-330項
# 已完成1.26%分析-345項
# 已完成1.32%分析-360項
# 已完成1.37%分析-375項
# 已完成1.43%分析-390項
# 已完成1.48%分析-405項
# 已完成1.54%分析-420項
# 已完成1.59%分析-435項
# 已完成1.6500000000000001%分析-450項
# 已完成1.7000000000000002%分析-465項
# 已完成1.76%分析-480項
# 已完成1.81%分析-495項
# 已完成1.87%分析-510項
# 已完成1.92%分析-525項
# 已完成1.9800000000000002%分析-540項
# 已完成2.03%分析-555項
# 已完成2.09%分析-570項
# 已完成2.1399999999999997%分析-585項
# 已完成2.1999999999999997%分析-600項
# 已完成2.25%分析-615項
# 已完成2.31%分析-630項
# 已完成2.36%分析-645項
# 已完成2.42%分析-660項
# 已完成2.4699999999999998%分析-675項
# 已完成2.53%分析-690項
# 已完成2.58%分析-705項
# 已完成2.64%分析-720項
# 已完成2.69%分析-735項
# 已完成2.75%分析-750項
# 已完成2.8000000000000003%分析-765項
# 已完成2.86%分析-780項
# 已完成2.91%分析-795項
# 已完成2.97%分析-810項
# 已完成3.02%分析-825項
# 已完成3.08%分析-840項
# 已完成3.1300000000000003%分析-855項
# 已完成3.19%分析-870項
# 已完成3.2399999999999998%分析-885項
# 已完成3.3000000000000003%分析-900項
# 已完成3.35%分析-915項
# 已完成3.4099999999999997%分析-930項
# 已完成3.46%分析-945項
# 已完成3.52%分析-960項
# 已完成3.5700000000000003%分析-975項
# 已完成3.63%分析-990項
# 已完成3.6799999999999997%分析-1005項
# 已完成3.74%分析-1020項
# 已完成3.7900000000000005%分析-1035項
# 已完成3.85%分析-1050項
# 已完成3.9%分析-1065項
# 已完成3.9600000000000004%分析-1080項
# 已完成4.01%分析-1095項
# 已完成4.07%分析-1110項
# 已完成4.12%分析-1125項
# 已完成4.18%分析-1140項
# 已完成4.2299999999999995%分析-1155項
# 已完成4.29%分析-1170項
# 已完成4.34%分析-1185項
# 已完成4.3999999999999995%分析-1200項
# 已完成4.45%分析-1215項
# 已完成4.51%分析-1230項
# 已完成4.5600000000000005%分析-1245項
# 已完成4.62%分析-1260項
# 已完成4.67%分析-1275項
# 已完成4.73%分析-1290項
# 已完成4.78%分析-1305項
# 已完成4.84%分析-1320項
# 已完成4.89%分析-1335項
# 已完成4.95%分析-1350項
# 已完成5.0%分析-1365項
# 已完成5.06%分析-1380項
# 已完成5.11%分析-1395項
# 已完成15.110000000000001%分析-4125項
# 已完成15.17%分析-4140項
# 已完成15.22%分析-4155項
# 已完成15.28%分析-4170項
# 已完成15.329999999999998%分析-4185項
# 已完成15.39%分析-4200項
# 已完成15.440000000000001%分析-4215項
# 已完成15.5%分析-4230項
# 已完成15.55%分析-4245項
# 已完成15.61%分析-4260項
# 已完成15.659999999999998%分析-4275項
# 已完成15.72%分析-4290項
# 已完成15.770000000000001%分析-4305項
# 已完成15.83%分析-4320項
# 已完成15.879999999999999%分析-4335項
# 已完成15.939999999999998%分析-4350項
# 已完成15.989999999999998%分析-4365項
# 已完成16.05%分析-4380項
# 已完成16.1%分析-4395項
# 已完成16.16%分析-4410項
# 已完成16.21%分析-4425項
# 已完成16.259999999999998%分析-4440項
# 已完成16.32%分析-4455項
# 已完成16.37%分析-4470項
# 已完成16.43%分析-4485項
# 已完成16.48%分析-4500項
# 已完成16.54%分析-4515項
# 已完成16.59%分析-4530項
# 已完成16.650000000000002%分析-4545項
# 已完成16.7%分析-4560項
# 已完成16.76%分析-4575項
# 已完成16.81%分析-4590項
# 已完成16.869999999999997%分析-4605項
# 已完成16.919999999999998%分析-4620項
# 已完成16.98%分析-4635項
# 已完成17.03%分析-4650項
# 已完成17.09%分析-4665項
# 已完成17.14%分析-4680項
# 已完成17.2%分析-4695項
# 已完成17.25%分析-4710項
# 已完成17.31%分析-4725項
# 已完成17.36%分析-4740項
# 已完成17.419999999999998%分析-4755項
# 已完成17.47%分析-4770項
# 已完成17.53%分析-4785項
# 已完成17.580000000000002%分析-4800項
# 已完成17.64%分析-4815項
# 已完成17.69%分析-4830項
# 已完成17.75%分析-4845項
# 已完成17.8%分析-4860項
# 已完成17.86%分析-4875項
# 已完成17.91%分析-4890項
# 已完成17.97%分析-4905項
# 已完成18.02%分析-4920項
# 已完成18.08%分析-4935項
# 已完成18.13%分析-4950項
# 已完成18.19%分析-4965項
# 已完成18.240000000000002%分析-4980項
# 已完成18.3%分析-4995項
# 已完成18.35%分析-5010項
# 已完成18.41%分析-5025項
# 已完成18.459999999999997%分析-5040項
# 已完成18.52%分析-5055項
# 已完成18.57%分析-5070項
# 已完成18.63%分析-5085項
# 已完成18.68%分析-5100項
# 已完成18.740000000000002%分析-5115項
# 已完成18.790000000000003%分析-5130項
# 已完成18.85%分析-5145項
# 已完成18.9%分析-5160項
# 已完成18.96%分析-5175項
# 已完成19.009999999999998%分析-5190項
# 已完成19.07%分析-5205項
# 已完成19.12%分析-5220項
# 已完成19.18%分析-5235項
# 已完成19.23%分析-5250項
# 已完成19.29%分析-5265項
# 已完成19.34%分析-5280項
# 已完成19.400000000000002%分析-5295項
# 已完成19.45%分析-5310項
# 已完成19.509999999999998%分析-5325項
# 已完成19.56%分析-5340項
# 已完成19.62%分析-5355項
# 已完成19.67%分析-5370項
# 已完成19.73%分析-5385項
# 已完成19.78%分析-5400項
# 已完成19.84%分析-5415項
# 已完成19.89%分析-5430項
# 已完成19.950000000000003%分析-5445項
# 已完成20.0%分析-5460項
# 已完成20.06%分析-5475項
# 已完成20.11%分析-5490項
# 已完成20.169999999999998%分析-5505項
# 已完成20.22%分析-5520項
# 已完成20.28%分析-5535項
# 已完成20.330000000000002%分析-5550項
# 已完成20.39%分析-5565項
# 已完成20.44%分析-5580項
# 已完成20.5%分析-5595項
# 已完成20.549999999999997%分析-5610項
# 已完成20.61%分析-5625項
# 已完成20.66%分析-5640項
# 已完成20.72%分析-5655項
# 已完成20.77%分析-5670項
# 已完成20.830000000000002%分析-5685項
# 已完成20.880000000000003%分析-5700項
# 已完成20.94%分析-5715項
# 已完成20.990000000000002%分析-5730項
# 已完成21.05%分析-5745項
# 已完成21.099999999999998%分析-5760項
# 已完成21.16%分析-5775項
# 已完成21.21%分析-5790項
# 已完成21.27%分析-5805項
# 已完成21.32%分析-5820項
# 已完成21.38%分析-5835項
# 已完成21.43%分析-5850項
# 已完成21.490000000000002%分析-5865項
# 已完成21.54%分析-5880項
# 已完成21.59%分析-5895項
# 已完成21.65%分析-5910項
# 已完成21.7%分析-5925項
# 已完成21.759999999999998%分析-5940項
# 已完成21.81%分析-5955項
# 已完成21.87%分析-5970項
# 已完成21.92%分析-5985項
# 已完成21.98%分析-6000項
# 已完成22.03%分析-6015項
# 已完成22.09%分析-6030項
# 已完成22.14%分析-6045項
# 已完成22.2%分析-6060項
# 已完成22.25%分析-6075項
# 已完成22.31%分析-6090項
# 已完成22.36%分析-6105項
# 已完成22.42%分析-6120項
# 已完成22.470000000000002%分析-6135項
# 已完成22.53%分析-6150項
# 已完成22.58%分析-6165項
# 已完成22.64%分析-6180項
# 已完成22.689999999999998%分析-6195項
# 已完成22.75%分析-6210項
# 已完成22.8%分析-6225項
# 已完成22.86%分析-6240項
# 已完成22.91%分析-6255項
# 已完成22.97%分析-6270項
# 已完成23.02%分析-6285項
# 已完成23.080000000000002%分析-6300項
# 已完成23.13%分析-6315項
# 已完成23.189999999999998%分析-6330項
# 已完成23.24%分析-6345項
# 已完成23.3%分析-6360項
# 已完成23.35%分析-6375項
# 已完成23.41%分析-6390項
# 已完成23.46%分析-6405項
# 已完成23.52%分析-6420項
# 已完成23.57%分析-6435項
# 已完成23.630000000000003%分析-6450項
# 已完成23.68%分析-6465項
# 已完成23.74%分析-6480項
# 已完成23.79%分析-6495項
# 已完成23.849999999999998%分析-6510項
# 已完成23.9%分析-6525項
# 已完成23.96%分析-6540項
# 已完成24.01%分析-6555項
# 已完成24.07%分析-6570項
# 已完成24.12%分析-6585項
# 已完成24.18%分析-6600項
# 已完成24.23%分析-6615項
# 已完成24.29%分析-6630項
# 已完成24.34%分析-6645項
# 已完成24.4%分析-6660項
# 已完成24.45%分析-6675項
# 已完成24.51%分析-6690項
# 已完成24.560000000000002%分析-6705項
# 已完成24.62%分析-6720項
# 已完成24.67%分析-6735項
# 已完成24.73%分析-6750項
# 已完成24.779999999999998%分析-6765項
# 已完成24.84%分析-6780項
# 已完成24.89%分析-6795項
# 已完成24.95%分析-6810項
# 已完成25.0%分析-6825項
# 已完成25.06%分析-6840項
# 已完成25.11%分析-6855項
# 已完成34.949999999999996%分析-9540項
# 已完成35.0%分析-9555項
# 已完成35.06%分析-9570項
# 已完成35.11%分析-9585項
# 已完成35.17%分析-9600項
# 已完成35.22%分析-9615項
# 已完成35.28%分析-9630項
# 已完成35.33%分析-9645項
# 已完成35.39%分析-9660項
# 已完成35.44%分析-9675項
# 已完成35.5%分析-9690項
# 已完成35.55%分析-9705項
# 已完成35.61%分析-9720項
# 已完成35.66%分析-9735項
# 已完成35.72%分析-9750項
# 已完成35.77%分析-9765項
# 已完成35.83%分析-9780項
# 已完成35.88%分析-9795項
# 已完成35.94%分析-9810項
# 已完成35.99%分析-9825項
# 已完成36.05%分析-9840項
# 已完成36.1%分析-9855項
# 已完成36.16%分析-9870項
# 已完成36.21%分析-9885項
# 已完成36.27%分析-9900項
# 已完成36.32%分析-9915項
# 已完成36.38%分析-9930項
# 已完成36.43%分析-9945項
# 已完成36.49%分析-9960項
# 已完成36.54%分析-9975項
# 已完成36.6%分析-9990項
# 已完成36.65%分析-10005項
# 已完成36.71%分析-10020項
# 已完成36.76%分析-10035項
# 已完成36.82%分析-10050項
# 已完成36.870000000000005%分析-10065項
# 已完成36.93%分析-10080項
# 已完成36.980000000000004%分析-10095項
# 已完成37.04%分析-10110項
# 已完成37.09%分析-10125項
# 已完成37.15%分析-10140項
# 已完成37.2%分析-10155項
# 已完成37.26%分析-10170項
# 已完成37.31%分析-10185項
# 已完成37.37%分析-10200項
# 已完成37.419999999999995%分析-10215項
# 已完成37.480000000000004%分析-10230項
# 已完成37.53%分析-10245項
# 已完成37.59%分析-10260項
# 已完成37.64%分析-10275項
# 已完成37.7%分析-10290項
# 已完成37.75%分析-10305項
# 已完成37.8%分析-10320項
# 已完成37.86%分析-10335項
# 已完成37.91%分析-10350項
# 已完成37.97%分析-10365項
# 已完成38.019999999999996%分析-10380項
# 已完成38.080000000000005%分析-10395項
# 已完成38.129999999999995%分析-10410項
# 已完成38.190000000000005%分析-10425項
# 已完成38.24%分析-10440項
# 已完成38.3%分析-10455項
# 已完成38.35%分析-10470項
# 已完成38.41%分析-10485項
# 已完成38.46%分析-10500項
# 已完成38.519999999999996%分析-10515項
# 已完成38.57%分析-10530項
# 已完成38.629999999999995%分析-10545項
# 已完成38.68%分析-10560項
# 已完成38.74%分析-10575項
# 已完成38.79%分析-10590項
# 已完成38.85%分析-10605項
# 已完成38.9%分析-10620項
# 已完成38.96%分析-10635項
# 已完成39.01%分析-10650項
# 已完成39.07%分析-10665項
# 已完成39.12%分析-10680項
# 已完成39.18%分析-10695項
# 已完成39.23%分析-10710項
# 已完成39.290000000000006%分析-10725項
# 已完成39.34%分析-10740項
# 已完成39.4%分析-10755項
# 已完成39.45%分析-10770項
# 已完成39.51%分析-10785項
# 已完成39.56%分析-10800項
# 已完成39.62%分析-10815項
# 已完成39.67%分析-10830項
# 已完成39.73%分析-10845項
# 已完成39.78%分析-10860項
# 已完成39.839999999999996%分析-10875項
# 已完成39.89%分析-10890項
# 已完成39.95%分析-10905項
# 已完成40.0%分析-10920項
# 已完成40.06%分析-10935項
# 已完成40.11%分析-10950項
# 已完成40.17%分析-10965項
# 已完成40.22%分析-10980項
# 已完成40.28%分析-10995項
# 已完成40.33%分析-11010項
# 已完成40.39%分析-11025項
# 已完成40.44%分析-11040項
# 已完成40.5%分析-11055項
# 已完成40.550000000000004%分析-11070項
# 已完成40.61%分析-11085項
# 已完成40.660000000000004%分析-11100項
# 已完成40.72%分析-11115項
# 已完成40.77%分析-11130項
# 已完成40.83%分析-11145項
# 已完成40.88%分析-11160項
# 已完成40.94%分析-11175項
# 已完成40.99%分析-11190項
# 已完成41.05%分析-11205項
# 已完成41.099999999999994%分析-11220項
# 已完成41.160000000000004%分析-11235項
# 已完成41.21%分析-11250項
# 已完成41.27%分析-11265項
# 已完成41.32%分析-11280項
# 已完成41.38%分析-11295項
# 已完成41.43%分析-11310項
# 已完成41.49%分析-11325項
# 已完成41.54%分析-11340項
# 已完成41.6%分析-11355項
# 已完成41.65%分析-11370項
# 已完成41.71%分析-11385項
# 已完成41.760000000000005%分析-11400項
# 已完成41.82%分析-11415項
# 已完成41.870000000000005%分析-11430項
# 已完成41.93%分析-11445項
# 已完成41.980000000000004%分析-11460項
# 已完成42.04%分析-11475項
# 已完成42.089999999999996%分析-11490項
# 已完成42.15%分析-11505項
# 已完成42.199999999999996%分析-11520項
# 已完成42.26%分析-11535項
# 已完成42.309999999999995%分析-11550項
# 已完成42.370000000000005%分析-11565項
# 已完成42.42%分析-11580項
# 已完成42.480000000000004%分析-11595項
# 已完成42.53%分析-11610項
# 已完成42.59%分析-11625項
# 已完成42.64%分析-11640項
# 已完成42.699999999999996%分析-11655項
# 已完成42.75%分析-11670項
# 已完成42.809999999999995%分析-11685項
# 已完成42.86%分析-11700項
# 已完成42.92%分析-11715項
# 已完成42.970000000000006%分析-11730項
# 已完成43.03%分析-11745項
# 已完成43.08%分析-11760項
# 已完成43.14%分析-11775項
# 已完成43.19%分析-11790項
# 已完成43.24%分析-11805項
# 已完成43.3%分析-11820項
# 已完成43.35%分析-11835項
# 已完成43.41%分析-11850項
# 已完成43.46%分析-11865項
# 已完成43.519999999999996%分析-11880項
# 已完成43.57%分析-11895項
# 已完成43.63%分析-11910項
# 已完成43.68%分析-11925項
# 已完成43.74%分析-11940項
# 已完成43.79%分析-11955項
# 已完成43.85%分析-11970項
# 已完成43.9%分析-11985項
# 已完成43.96%分析-12000項
# 已完成44.01%分析-12015項
# 已完成44.07%分析-12030項
# 已完成44.12%分析-12045項
# 已完成44.18%分析-12060項
# 已完成44.230000000000004%分析-12075項
# 已完成44.29%分析-12090項
# 已完成44.34%分析-12105項
# 已完成44.4%分析-12120項
# 已完成44.45%分析-12135項
# 已完成44.51%分析-12150項
# 已完成44.56%分析-12165項
# 已完成44.62%分析-12180項
# 已完成44.67%分析-12195項
# 已完成44.73%分析-12210項
# 已完成44.78%分析-12225項
# 已完成44.84%分析-12240項
# 已完成44.89%分析-12255項
# 已完成44.95%分析-12270項
# 已完成45.0%分析-12285項
# 已完成45.06%分析-12300項
# 已完成45.11%分析-12315項
# 已完成50.17%分析-13695項
# 已完成50.22%分析-13710項
# 已完成50.28%分析-13725項
# 已完成50.33%分析-13740項
# 已完成50.39%分析-13755項
# 已完成50.44%分析-13770項
# 已完成50.5%分析-13785項
# 已完成50.55%分析-13800項
# 已完成50.61%分析-13815項
# 已完成50.660000000000004%分析-13830項
# 已完成50.72%分析-13845項
# 已完成50.77%分析-13860項
# 已完成50.83%分析-13875項
# 已完成50.88%分析-13890項
# 已完成50.94%分析-13905項
# 已完成50.99%分析-13920項
# 已完成51.05%分析-13935項
# 已完成51.1%分析-13950項
# 已完成51.160000000000004%分析-13965項
# 已完成51.21%分析-13980項
# 已完成51.27%分析-13995項
# 已完成51.32%分析-14010項
# 已完成51.38%分析-14025項
# 已完成51.43%分析-14040項
# 已完成51.49%分析-14055項
# 已完成51.54%分析-14070項
# 已完成51.6%分析-14085項
# 已完成51.65%分析-14100項
# 已完成51.71%分析-14115項
# 已完成51.76%分析-14130項
# 已完成51.82%分析-14145項
# 已完成51.870000000000005%分析-14160項
# 已完成51.93%分析-14175項
# 已完成51.980000000000004%分析-14190項
# 已完成52.04%分析-14205項
# 已完成52.09%分析-14220項
# 已完成52.15%分析-14235項
# 已完成52.2%分析-14250項
# 已完成52.26%分析-14265項
# 已完成52.31%分析-14280項
# 已完成52.370000000000005%分析-14295項
# 已完成52.42%分析-14310項
# 已完成52.480000000000004%分析-14325項
# 已完成52.53%分析-14340項
# 已完成52.59%分析-14355項
# 已完成52.64%分析-14370項
# 已完成52.7%分析-14385項
# 已完成52.75%分析-14400項
# 已完成52.81%分析-14415項
# 已完成52.86%分析-14430項
# 已完成52.92%分析-14445項
# 已完成52.96999999999999%分析-14460項
# 已完成53.03%分析-14475項
# 已完成53.080000000000005%分析-14490項
# 已完成53.14%分析-14505項
# 已完成53.190000000000005%分析-14520項
# 已完成53.25%分析-14535項
# 已完成53.300000000000004%分析-14550項
# 已完成53.36%分析-14565項
# 已完成53.410000000000004%分析-14580項
# 已完成53.47%分析-14595項
# 已完成53.52%分析-14610項
# 已完成53.580000000000005%分析-14625項
# 已完成53.63%分析-14640項
# 已完成53.690000000000005%分析-14655項
# 已完成53.74%分析-14670項
# 已完成53.800000000000004%分析-14685項
# 已完成53.849999999999994%分析-14700項
# 已完成53.910000000000004%分析-14715項
# 已完成53.959999999999994%分析-14730項
# 已完成54.010000000000005%分析-14745項
# 已完成54.06999999999999%分析-14760項
# 已完成54.120000000000005%分析-14775項
# 已完成54.17999999999999%分析-14790項
# 已完成54.230000000000004%分析-14805項
# 已完成54.290000000000006%分析-14820項
# 已完成54.339999999999996%分析-14835項
# 已完成54.400000000000006%分析-14850項
# 已完成54.449999999999996%分析-14865項
# 已完成54.510000000000005%分析-14880項
# 已完成54.559999999999995%分析-14895項
# 已完成54.620000000000005%分析-14910項
# 已完成54.669999999999995%分析-14925項
# 已完成54.730000000000004%分析-14940項
# 已完成54.779999999999994%分析-14955項
# 已完成54.84%分析-14970項
# 已完成54.89000000000001%分析-14985項
# 已完成54.949999999999996%分析-15000項
# 已完成64.68%分析-17655項
# 已完成64.73%分析-17670項
# 已完成64.78%分析-17685項
# 已完成64.84%分析-17700項
# 已完成64.89%分析-17715項
# 已完成64.95%分析-17730項
# 已完成65.0%分析-17745項
# 已完成65.06%分析-17760項
# 已完成65.11%分析-17775項
# 已完成65.16999999999999%分析-17790項
# 已完成65.22%分析-17805項
# 已完成65.28%分析-17820項
# 已完成65.33%分析-17835項
# 已完成65.39%分析-17850項
# 已完成65.44%分析-17865項
# 已完成65.5%分析-17880項
# 已完成65.55%分析-17895項
# 已完成65.61%分析-17910項
# 已完成65.66%分析-17925項
# 已完成65.72%分析-17940項
# 已完成65.77%分析-17955項
# 已完成65.83%分析-17970項
# 已完成65.88000000000001%分析-17985項
# 已完成65.94%分析-18000項
# 已完成65.99000000000001%分析-18015項
# 已完成66.05%分析-18030項
# 已完成66.10000000000001%分析-18045項
# 已完成66.16%分析-18060項
# 已完成66.21000000000001%分析-18075項
# 已完成66.27%分析-18090項
# 已完成66.32000000000001%分析-18105項
# 已完成66.38%分析-18120項
# 已完成66.43%分析-18135項
# 已完成66.49000000000001%分析-18150項
# 已完成66.53999999999999%分析-18165項
# 已完成66.60000000000001%分析-18180項
# 已完成66.64999999999999%分析-18195項
# 已完成66.71000000000001%分析-18210項
# 已完成66.75999999999999%分析-18225項
# 已完成66.82000000000001%分析-18240項
# 已完成66.86999999999999%分析-18255項
# 已完成66.93%分析-18270項
# 已完成66.97999999999999%分析-18285項
# 已完成67.04%分析-18300項
# 已完成67.09%分析-18315項
# 已完成67.15%分析-18330項
# 已完成67.2%分析-18345項
# 已完成67.25999999999999%分析-18360項
# 已完成67.31%分析-18375項
# 已完成67.36999999999999%分析-18390項
# 已完成67.42%分析-18405項
# 已完成67.47999999999999%分析-18420項
# 已完成67.53%分析-18435項
# 已完成67.58999999999999%分析-18450項
# 已完成67.64%分析-18465項
# 已完成67.7%分析-18480項
# 已完成67.75%分析-18495項
# 已完成67.81%分析-18510項
# 已完成67.86%分析-18525項
# 已完成67.92%分析-18540項
# 已完成67.97%分析-18555項
# 已完成68.03%分析-18570項
# 已完成68.08%分析-18585項
# 已完成68.14%分析-18600項
# 已完成68.19%分析-18615項
# 已完成68.25%分析-18630項
# 已完成68.30000000000001%分析-18645項
# 已完成68.36%分析-18660項
# 已完成68.41000000000001%分析-18675項
# 已完成68.47%分析-18690項
# 已完成68.52000000000001%分析-18705項
# 已完成68.58%分析-18720項
# 已完成68.63%分析-18735項
# 已完成68.69%分析-18750項
# 已完成68.74%分析-18765項
# 已完成68.8%分析-18780項
# 已完成68.85%分析-18795項
# 已完成68.91000000000001%分析-18810項
# 已完成68.96%分析-18825項
# 已完成69.02000000000001%分析-18840項
# 已完成69.07%分析-18855項
# 已完成69.13%分析-18870項
# 已完成69.17999999999999%分析-18885項
# 已完成69.24%分析-18900項
# 已完成69.28999999999999%分析-18915項
# 已完成69.35%分析-18930項
# 已完成69.39999999999999%分析-18945項
# 已完成69.46%分析-18960項
# 已完成69.51%分析-18975項
# 已完成79.73%分析-21765項
# 已完成79.79%分析-21780項
# 已完成79.84%分析-21795項
# 已完成79.9%分析-21810項
# 已完成79.95%分析-21825項
# 已完成80.01%分析-21840項
# 已完成80.06%分析-21855項
# 已完成80.12%分析-21870項
# 已完成80.17%分析-21885項
# 已完成80.23%分析-21900項
# 已完成80.28%分析-21915項
# 已完成80.34%分析-21930項
# 已完成80.39%分析-21945項
# 已完成80.45%分析-21960項
# 已完成80.5%分析-21975項
# 已完成80.56%分析-21990項
# 已完成80.61%分析-22005項
# 已完成80.67%分析-22020項
# 已完成80.72%分析-22035項
# 已完成80.78%分析-22050項
# 已完成80.83%分析-22065項
# 已完成80.89%分析-22080項
# 已完成80.94%分析-22095項
# 已完成80.99%分析-22110項
# 已完成81.05%分析-22125項
# 已完成81.10000000000001%分析-22140項
# 已完成81.16%分析-22155項
# 已完成81.21000000000001%分析-22170項
# 已完成81.27%分析-22185項
# 已完成81.32000000000001%分析-22200項
# 已完成81.38%分析-22215項
# 已完成81.43%分析-22230項
# 已完成81.49%分析-22245項
# 已完成81.54%分析-22260項
# 已完成81.6%分析-22275項
# 已完成81.65%分析-22290項
# 已完成81.71000000000001%分析-22305項
# 已完成81.76%分析-22320項
# 已完成81.82000000000001%分析-22335項
# 已完成81.87%分析-22350項
# 已完成81.93%分析-22365項
# 已完成81.98%分析-22380項
# 已完成82.04%分析-22395項
# 已完成82.09%分析-22410項
# 已完成82.15%分析-22425項
# 已完成82.19999999999999%分析-22440項
# 已完成82.26%分析-22455項
# 已完成82.31%分析-22470項
# 已完成82.37%分析-22485項
# 已完成82.42%分析-22500項
# 已完成82.48%分析-22515項
# 已完成82.53%分析-22530項
# 已完成82.59%分析-22545項
# 已完成82.64%分析-22560項
# 已完成82.69999999999999%分析-22575項
# 已完成82.75%分析-22590項
# 已完成82.80999999999999%分析-22605項
# 已完成82.86%分析-22620項
# 已完成82.92%分析-22635項
# 已完成82.97%分析-22650項
# 已完成83.03%分析-22665項
# 已完成83.08%分析-22680項
# 已完成83.14%分析-22695項
# 已完成83.19%分析-22710項
# 已完成83.25%分析-22725項
# 已完成83.3%分析-22740項
# 已完成83.36%分析-22755項
# 已完成83.41%分析-22770項
# 已完成83.47%分析-22785項
# 已完成83.52000000000001%分析-22800項
# 已完成83.58%分析-22815項
# 已完成83.63000000000001%分析-22830項
# 已完成83.69%分析-22845項
# 已完成83.74000000000001%分析-22860項
# 已完成83.8%分析-22875項
# 已完成83.85000000000001%分析-22890項
# 已完成83.91%分析-22905項
# 已完成83.96000000000001%分析-22920項
# 已完成84.02%分析-22935項
# 已完成84.07%分析-22950項
# 已完成84.13000000000001%分析-22965項
# 已完成84.17999999999999%分析-22980項
# 已完成84.24000000000001%分析-22995項
# 已完成84.28999999999999%分析-23010項
# 已完成84.35000000000001%分析-23025項
# 已完成84.39999999999999%分析-23040項
# 已完成84.46000000000001%分析-23055項
# 已完成84.50999999999999%分析-23070項
# 已完成84.57000000000001%分析-23085項
# 已完成84.61999999999999%分析-23100項
# 已完成84.68%分析-23115項
# 已完成94.84%分析-25890項
# 已完成94.89999999999999%分析-25905項
# 已完成94.95%分析-25920項
# 已完成95.00999999999999%分析-25935項
# 已完成95.06%分析-25950項
# 已完成95.12%分析-25965項
# 已完成95.17%分析-25980項
# 已完成95.23%分析-25995項
# 已完成95.28%分析-26010項
# 已完成95.34%分析-26025項
# 已完成95.39%分析-26040項
# 已完成95.45%分析-26055項
# 已完成95.5%分析-26070項
# 已完成95.56%分析-26085項
# 已完成95.61%分析-26100項
# 已完成95.67%分析-26115項
# 已完成95.72%分析-26130項
# 已完成95.78%分析-26145項
# 已完成95.83%分析-26160項
# 已完成95.89%分析-26175項
# 已完成95.94%分析-26190項
# 已完成96.0%分析-26205項
# 已完成96.05%分析-26220項
# 已完成96.11%分析-26235項
# 已完成96.16%分析-26250項
# 已完成96.22%分析-26265項
# 已完成96.27%分析-26280項
# 已完成96.33%分析-26295項
# 已完成96.38%分析-26310項
# 已完成96.44%分析-26325項
# 已完成96.49%分析-26340項
# 已完成96.55%分析-26355項
# 已完成96.6%分析-26370項
# 已完成96.66%分析-26385項
# 已完成96.71%分析-26400項
# 已完成96.77%分析-26415項
# 已完成96.82%分析-26430項
# 已完成96.88%分析-26445項
# 已完成96.93%分析-26460項
# 已完成96.99%分析-26475項
# 已完成97.04%分析-26490項
# 已完成97.1%分析-26505項
# 已完成97.15%分析-26520項
# 已完成97.2%分析-26535項
# 已完成97.26%分析-26550項
# 已完成97.31%分析-26565項
# 已完成97.37%分析-26580項
# 已完成97.42%分析-26595項
# 已完成97.48%分析-26610項
# 已完成97.53%分析-26625項
# 已完成97.59%分析-26640項
# 已完成97.64%分析-26655項
# 已完成97.7%分析-26670項
# 已完成97.75%分析-26685項
# 已完成97.81%分析-26700項
# 已完成97.86%分析-26715項
# 已完成97.92%分析-26730項
# 已完成97.97%分析-26745項
# 已完成98.03%分析-26760項
# 已完成98.08%分析-26775項
# 已完成98.14%分析-26790項
# 已完成98.19%分析-26805項
# 已完成98.25%分析-26820項
# 已完成98.3%分析-26835項
# 已完成98.36%分析-26850項
# 已完成98.41%分析-26865項
# 已完成98.47%分析-26880項
# 已完成98.52%分析-26895項
# 已完成98.58%分析-26910項
# 已完成98.63%分析-26925項
# 已完成98.69%分析-26940項
# 已完成98.74000000000001%分析-26955項
# 已完成98.8%分析-26970項
# 已完成98.85000000000001%分析-26985項
# 已完成98.91%分析-27000項
# 已完成98.96000000000001%分析-27015項
# 已完成99.02%分析-27030項
# 已完成99.07000000000001%分析-27045項
# 已完成99.13%分析-27060項
# 已完成99.18%分析-27075項
# 已完成99.24%分析-27090項
# 已完成99.29%分析-27105項
# 已完成99.35000000000001%分析-27120項
# 已完成99.4%分析-27135項
# 已完成99.46000000000001%分析-27150項
# 已完成99.51%分析-27165項
# 已完成99.57000000000001%分析-27180項
# 已完成99.62%分析-27195項
# 已完成99.68%分析-27210項
# 已完成99.72999999999999%分析-27225項
# 已完成99.79%分析-27240項
# 已完成99.83999999999999%分析-27255項
# 已完成99.9%分析-27270項
# 已完成99.95%分析-27285項
# 31890.03825569153

# %%
for i in wowDiensData:
    i["_id"]="{}_{}".format(i['lat'],i['lng'])
client = pymongo.mongo_client.MongoClient("192.168.1.113", 27017, username='j122085', password='850605')
collection = client.rawData.taiwanInfo
ids=[data.pop("_id") for data in wowDiensData]
operations=[UpdateOne({"_id":idn},{'$set':data},upsert=True) for idn ,data in zip(ids,wowDiensData)]
try:
    collection.bulk_write(operations ,ordered=False)
except Exception as er:
    print(er)

alldata=list(collection.find({}))

client.close()

# %%
import pymongo
from pymongo import UpdateOne
client = pymongo.mongo_client.MongoClient("localhost", 27017, username='j122085', password='850605')
collection = client.rawData.taiwanInfo
wowDiensData=list(collection.find({}))

# %%
import pymongo
from pymongo import UpdateOne
client = pymongo.mongo_client.MongoClient("localhost", 27017, username='j122085', password='850605')
collection = client.rawData.taiwanInfo
wowDiensData=list(collection.find({}))

# %% [markdown]
# # 500M

# %%
import numpy as np
TaiwanLatRange=np.arange(21.91456,25.29548,0.00169046)
TaiwanLngRange=np.arange(120.04193,122.00059,0.002448325)

# %%
TWLocs=[]
for i in TaiwanLatRange:
    for j in TaiwanLngRange:
        TWLoc={}
        TWLoc['lat']=i
        TWLoc['lng']=j
        TWLocs.append(TWLoc)

# %%
import json
import pymongo
from pymongo import UpdateOne
import numpy
import math
from math import radians, cos, sin, asin, sqrt
from collections import Counter
import time
import sys
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.message import EmailMessage
import smtplib
import gc
gc.enable() 



def haversine(lng1, lat1, lng2, lat2):
    # 将十进制度数转化为弧度
    lng1, lat1, lng2, lat2 = map(radians, [lng1, lat1, lng2, lat2])
    # haversine公式
    dlng = lng2 - lng1
    dlat = lat2 - lat1
    a = sin(dlat / 2) ** 2 + cos(lat1) * cos(lat2) * sin(dlng / 2) ** 2
    c = 2 * asin(sqrt(a))
    r = 6371  # 地球平均半径，单位为公里
    return c * r * 1000


b=time.time()
def mailTo(title,mailAdds,message,whoSend='AutoAddInsurance'):
    msg = MIMEMultipart()    
    sender = whoSend
    subject = title
    body = message
    msg['From'] = sender
    msg['To'] = ','.join(mailAdds)
    msg['Subject'] = subject
    msg.attach(MIMEText(body, 'plain'))
    text=msg.as_string()
    #print text
    # Send the message via our SMTP server
    s = smtplib.SMTP('192.168.2.1',25)
    s.sendmail(sender,mailAdds, text)
    s.quit()  

try:
    ######################################################IPEEN
    b=time.time()
    queryElements = {}
    client = pymongo.mongo_client.MongoClient("localhost", 27017, username='j122085', password='850605')
    collectionTaiwan = client.rawData.taiwanInfoStoneTwo
    ##################################################第一次跑不執行
    TWLocs=list(collectionTaiwan.find({}, {'_id': False}))
    ##################################################第一次跑不執行
    
    
    # collection = client.rawData.wowprimeipeen
    collection = client.rawData.ipeenInfo
    ipeendata = list(collection.find(queryElements))
    ipeendata = [dien for dien in ipeendata if dien['status'] == "正常營業"
                 and dien['lat'] > 18
                 and dien['lat'] < 27
                 and dien['lng'] < 125
                 and dien['lng'] > 117
                 and dien['bigadd'] != 0
                 and dien['smalladd'] != 0
                 and dien['averagecost'] < 8000]

    for dien in ipeendata:
        dien["id"] = dien.pop("_id")
    ######################################################IPEEN
    ######################################################104
    collection = client.rawData.HRdata104
    hr104data = list(collection.find(queryElements))
    hr104data = [dien for dien in hr104data if dien['LAT'] > 18
                 and dien['LAT'] < 27
                 and dien['SAL_MONTH_LOW'] > 18000
                 and dien['SAL_MONTH_LOW'] < 100000
                 and dien['SAL_MONTH_HIGH'] > 18000
                 and dien['SAL_MONTH_HIGH'] < 200000
                 and dien['LON'] < 125
                 and dien['LON'] > 117
                 and dien['bigadd'] != 0
                 and dien['smalladd'] != 0]

    for dien in hr104data:
        dien["lat"] = dien.pop("LAT")
        dien["lng"] = dien.pop("LON")
        del dien["_id"]
    ######################################################104
    ######################################################Nhuman
    collection = client.rawData.Nhuman
    Nhumandata = list(collection.find(queryElements))
    for dien in Nhumandata:
        dien["weight"] = int(dien.pop("Nhuman"))
        dien["add"] = dien.pop("_id")
    ######################################################Nhuman
    ######################################################CostPower
    collection = client.rawData.CostPower
    CostPowerdata = list(collection.find(queryElements))
    for dien in CostPowerdata:
        dien["weight"] = int(dien.pop('costPower'))
        dien["add"] = dien.pop("_id")
    ######################################################CostPower
    ######################################################Bus0320
    collection = client.rawData.busData
    busData = list(collection.find(queryElements))
    for dien in busData:
        dien["add"] = dien.pop("_id")
    ######################################################Bus0320
    ######################################################conStore0320
    collection = client.rawData.conStore
    conStoreData = list(collection.find(queryElements))
    for dien in conStoreData:
        dien.pop("_id")
    ######################################################conStore0320
    ######################################################Watsons
    collection = client.rawData.Watsons
    watsonsData = list(collection.find(queryElements))
    for dien in watsonsData:
        dien.pop("_id")
    ######################################################Watsons
    ######################################################carrefour0504
    collection = client.rawData.carrefour
    carrefourData = list(collection.find(queryElements))
    for dien in carrefourData:
        dien.pop("_id")
    ######################################################carrefour0504
    ######################################################pxmart0504
    collection = client.rawData.pxmart
    pxmartData = list(collection.find(queryElements))
    for dien in pxmartData:
        dien.pop("_id")
    ######################################################pxmart0504
    ######################################################Wow
    ##################################################第一次跑不執行
#     TWLocs = [i for i in TWLocs if ('score' in i and
#               i['score'] >0)]
    ##################################################第一次跑不執行
    allN=len(TWLocs)
    print("有{}筆資料要分析".format(allN))
    radius=500
    n = 0
    
    
    for TWLoc in TWLocs:
        score=0
        
        n += 1
        if n % 100 == 0:
            e=time.time()
            print("已完成{}%分析-{}項,花費{}秒".format(round(n/allN,4)*100,n,round(e-b)))
        if n % 1000 == 0:
            gc.collect()
            client = pymongo.mongo_client.MongoClient("localhost", 27017, username='j122085', password='850605')
            collection = client.rawData.taiwanInfoStoneTwo
            
            ids=["{}_{}".format(i['lat'],i['lng']) for i in TWLocs if i.get("score",0)>0]
            datas=[i for i in TWLocs if i.get("score",0)>0]
            operations=[UpdateOne({"_id":idn},{'$set':data},upsert=True) for idn ,data in zip(ids,datas)]
            try:
                collection.bulk_write(operations ,ordered=False)
            except Exception as er:
                print(er)
            client.close()

        TWLoc["areaRadius_Analyze"] = radius

        
        
       

        #############################################################0523Score
        
        

        TWLoc["NconStore_Analyze"] = len([dien['name'] for dien in conStoreData if "lng" in dien and haversine(lng1=float(dien["lng"]),
                                                                                lat1=float(dien["lat"]),
                                                                                lng2=TWLoc["lng"],
                                                                                lat2=TWLoc["lat"]) <= radius])
        if TWLoc["NconStore_Analyze"]>12:
            score=score+2
        elif TWLoc["NconStore_Analyze"]>4:
            score=score+1
            
        if score==0:
            TWLoc["score"]=score
            continue
            
            
        TWLoc["NbusStation_Analyze"] = len([dien['stationName'] for dien in busData if "lng" in dien and haversine(lng1=dien["lng"],
                                                                                lat1=dien["lat"],
                                                                                lng2=TWLoc["lng"],
                                                                                lat2=TWLoc["lat"]) <= 500])#0326 change radius
        if TWLoc["NbusStation_Analyze"]>11:
            score=score+2
        elif TWLoc["NbusStation_Analyze"]>4:
            score=score+1
        
        
    #         conStoreData
        TWLoc["Nstar_Analyze"] = len([dien['name'] for dien in ipeendata 
                                if '星巴' in dien['name'] 
                                and haversine(lng1=dien["lng"],
                                              lat1=dien["lat"],
                                              lng2=TWLoc["lng"],
                                              lat2=TWLoc["lat"]) <= radius])
        TWLoc["Nmc_Analyze"] = len([dien['name'] for dien in ipeendata 
                                if '麥當' in dien['name'] 
                                and haversine(lng1=dien["lng"],
                                              lat1=dien["lat"],
                                              lng2=TWLoc["lng"],
                                              lat2=TWLoc["lat"]) <= radius])
        TWLoc["Nken_Analyze"] = len([dien['name'] for dien in ipeendata 
                                if '肯德' in dien['name'] 
                                and haversine(lng1=dien["lng"],
                                              lat1=dien["lat"],
                                              lng2=TWLoc["lng"],
                                              lat2=TWLoc["lat"]) <= radius])
        TWLoc["Nwa_Analyze"] = len([dien['name'] for dien in ipeendata 
                                if '瓦城泰' in dien['name'] 
                                and haversine(lng1=dien["lng"],
                                              lat1=dien["lat"],
                                              lng2=TWLoc["lng"],
                                              lat2=TWLoc["lat"]) <= radius])
        
        if TWLoc["Nstar_Analyze"]+TWLoc["Nmc_Analyze"]+TWLoc["Nken_Analyze"]+TWLoc["Nwa_Analyze"]>2:
            score=score+2
        elif TWLoc["Nstar_Analyze"]+TWLoc["Nmc_Analyze"]+TWLoc["Nken_Analyze"]+TWLoc["Nwa_Analyze"]>0:
            score=score+1
        
        TWLoc["Nwatson_Analyze"] = len([dien for dien in watsonsData
                                          if haversine(lng1=float(dien["lng"]),
                                                       lat1=float(dien["lat"]),
                                                       lng2=TWLoc["lng"],
                                                       lat2=TWLoc["lat"]) <= radius])

        TWLoc["Ncarrefour_Analyze"] = len([dien for dien in carrefourData
                                             if haversine(lng1=float(dien["lng"]),
                                                          lat1=float(dien["lat"]),
                                                          lng2=TWLoc["lng"],
                                                          lat2=TWLoc["lat"]) <= radius])
        TWLoc["Npxmart_Analyze"] = len([dien for dien in pxmartData
                                          if haversine(lng1=float(dien["lng"]),
                                                       lat1=float(dien["lat"]),
                                                       lng2=TWLoc["lng"],
                                                       lat2=TWLoc["lat"]) <= radius])
        
        if TWLoc["Nwatson_Analyze"]+TWLoc["Npxmart_Analyze"]>2:
            score=score+2
        elif TWLoc["Nwatson_Analyze"]+TWLoc["Npxmart_Analyze"]>0:
            score=score+1
            
        
        
        
        
        rangeCost = 1.4

        simDien = [dien['bigstyle'] for dien in ipeendata if haversine(lng1=dien["lng"],
                                                                       lat1=dien["lat"],
                                                                       lng2=TWLoc["lng"],
                                                                       lat2=TWLoc["lat"]) <= 500
                   and dien['averagecost'] < ((240) * rangeCost)
                   and dien['averagecost'] > ((240) / rangeCost)]
        # stoneTwoCost==240
        TWLoc["NsimCostDien"] = len(simDien)
        # print(simDien)
        # print(wowDien['Called'])
        if TWLoc["NsimCostDien"]>29:
            score=score+2
        elif TWLoc["NsimCostDien"]>11:
            score=score+1
        
        
        
            
            
        TWLoc["score"]=score
        
        dienHuman = sum([dien['weight'] for dien in Nhumandata if haversine(lng1=dien["lng"],
                                                                            lat1=dien["lat"],
                                                                            lng2=TWLoc["lng"],
                                                                            lat2=TWLoc["lat"]) <= radius and 'weight' in dien])
        TWLoc['Nhuman_Analyze'] = dienHuman

        #############################################################0523Score
        
        
        
    e = time.time()
    print(e-b)


#     ids=[data.pop("_id") for data in TWLocs]
#     operations=[UpdateOne({"_id":idn},{'$set':data},upsert=True) for idn ,data in zip(ids,TWLocs)]
#     try:
#         collection.bulk_write(operations ,ordered=False)
#     except Exception as er:
#         print(er)

#     alldata=list(collection.find({}))

#     client.close()
    client = pymongo.mongo_client.MongoClient("192.168.1.113", 27017, username='j122085', password='850605')
    collection = client.rawData.taiwanInfoStoneTwo
    ids=["{}_{}".format(i['lat'],i['lng']) for i in TWLocs]
    operations=[UpdateOne({"_id":idn},{'$set':data},upsert=True) for idn ,data in zip(ids,TWLocs)]
    try:
        collection.bulk_write(operations ,ordered=False)
    except Exception as er:
        print(er)
    client.close()
    
    mailTo(title="TaiwanDataSuccess",mailAdds=["andy.yuan@wowprime.com"],message="分析完畢_耗時{}秒".format(e-b),whoSend='analyzeTaiwanData')
except Exception as er:
    errorMsg=str(er)+"出錯位置:"+str(sys.exc_info()[2].tb_lineno)
    mailTo(title="analyzeTaiwanDataFail",mailAdds=["andy.yuan@wowprime.com"],message=errorMsg,whoSend='analyzeTaiwanData')
