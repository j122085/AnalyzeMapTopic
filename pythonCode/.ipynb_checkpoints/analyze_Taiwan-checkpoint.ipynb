# %% [markdown]
# # 2000M

# %%
import numpy as np
TaiwanLatRange=np.arange(21.91456,25.29548,0.00676184)
TaiwanLngRange=np.arange(120.04193,122.00059,0.009793304)

# %%
TWLocs=[]
for i in TaiwanLatRange:
    for j in TaiwanLngRange:
        TWLoc={}
        TWLoc['lat']=i
        TWLoc['lng']=j
        TWLocs.append(TWLoc)

# %%
TWLocs

# %%
import json
import pymongo
from pymongo import UpdateOne
import numpy
import math
from math import radians, cos, sin, asin, sqrt
from collections import Counter
import time
import sys
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.message import EmailMessage
import smtplib

def haversine(lng1, lat1, lng2, lat2):
    # 将十进制度数转化为弧度
    lng1, lat1, lng2, lat2 = map(radians, [lng1, lat1, lng2, lat2])
    # haversine公式
    dlng = lng2 - lng1
    dlat = lat2 - lat1
    a = sin(dlat / 2) ** 2 + cos(lat1) * cos(lat2) * sin(dlng / 2) ** 2
    c = 2 * asin(sqrt(a))
    r = 6371  # 地球平均半径，单位为公里
    return c * r * 1000


b=time.time()
def mailTo(title,mailAdds,message,whoSend='AutoAddInsurance'):
    msg = MIMEMultipart()    
    sender = whoSend
    subject = title
    body = message
    msg['From'] = sender
    msg['To'] = ','.join(mailAdds)
    msg['Subject'] = subject
    msg.attach(MIMEText(body, 'plain'))
    text=msg.as_string()
    #print text
    # Send the message via our SMTP server
    s = smtplib.SMTP('192.168.2.1',25)
    s.sendmail(sender,mailAdds, text)
    s.quit()  

try:
    ######################################################IPEEN
    b=time.time()
    queryElements = {}
    client = pymongo.mongo_client.MongoClient("localhost", 27017, username='j122085', password='850605')
    collectionTaiwan = client.rawData.taiwanInfo
    TWLocs=list(collectionTaiwan.find({}))
    
    # collection = client.rawData.wowprimeipeen
    collection = client.rawData.ipeenInfo
    ipeendata = list(collection.find(queryElements))
    ipeendata = [dien for dien in ipeendata if dien['status'] == "正常營業"
                 and dien['lat'] > 18
                 and dien['lat'] < 27
                 and dien['lng'] < 125
                 and dien['lng'] > 117
                 and dien['bigadd'] != 0
                 and dien['smalladd'] != 0
                 and dien['averagecost'] < 8000]

    for dien in ipeendata:
        dien["id"] = dien.pop("_id")
    ######################################################IPEEN
    ######################################################104
    collection = client.rawData.HRdata104
    hr104data = list(collection.find(queryElements))
    hr104data = [dien for dien in hr104data if dien['LAT'] > 18
                 and dien['LAT'] < 27
                 and dien['SAL_MONTH_LOW'] > 18000
                 and dien['SAL_MONTH_LOW'] < 100000
                 and dien['SAL_MONTH_HIGH'] > 18000
                 and dien['SAL_MONTH_HIGH'] < 200000
                 and dien['LON'] < 125
                 and dien['LON'] > 117
                 and dien['bigadd'] != 0
                 and dien['smalladd'] != 0]

    for dien in hr104data:
        dien["lat"] = dien.pop("LAT")
        dien["lng"] = dien.pop("LON")
        del dien["_id"]
    ######################################################104
    ######################################################Nhuman
    collection = client.rawData.Nhuman
    Nhumandata = list(collection.find(queryElements))
    for dien in Nhumandata:
        dien["weight"] = int(dien.pop("Nhuman"))
        dien["add"] = dien.pop("_id")
    ######################################################Nhuman
    ######################################################CostPower
    collection = client.rawData.CostPower
    CostPowerdata = list(collection.find(queryElements))
    for dien in CostPowerdata:
        dien["weight"] = int(dien.pop('costPower'))
        dien["add"] = dien.pop("_id")
    ######################################################CostPower
    ######################################################Bus0320
    collection = client.rawData.busData
    busData = list(collection.find(queryElements))
    for dien in busData:
        dien["add"] = dien.pop("_id")
    ######################################################Bus0320
    ######################################################conStore0320
    collection = client.rawData.conStore
    conStoreData = list(collection.find(queryElements))
    for dien in conStoreData:
        dien.pop("_id")
    ######################################################conStore0320
    ######################################################Wow


    TWLocs = [i for i in TWLocs if ('costPower_Analyze' in i and
              i['costPower_Analyze'] >0) or
              ('Nhuman_Analyze' in i and
              i['Nhuman_Analyze']>0)]
    allN=len(TWLocs)
    print("有{}筆資料要分析".format(allN))
    radius=2000
    n = 0
    for TWLoc in TWLocs:
        n += 1
        if n % 15 == 0:
            print("已完成{}%分析-{}項".format(round(n/allN,4)*100,n))
        if n % 1000 == 0:
            for i in TWLocs:
                i["_id"]="{}_{}".format(i['lat'],i['lng'])
            client = pymongo.mongo_client.MongoClient("localhost", 27017, username='j122085', password='850605')
            collection = client.rawData.taiwanInfo
            ids=[data.pop("_id") for data in TWLocs]
            operations=[UpdateOne({"_id":idn},{'$set':data},upsert=True) for idn ,data in zip(ids,TWLocs)]
            try:
                collection.bulk_write(operations ,ordered=False)
            except Exception as er:
                print(er)
            client.close()

        TWLoc["areaRadius_Analyze"] = radius
        dienCostPower = round(numpy.mean([dien['weight'] for dien in CostPowerdata if haversine(lng1=dien["lng"],
                                                                                                lat1=dien["lat"],
                                                                                                lng2=TWLoc["lng"],
                                                                                                lat2=TWLoc[
                                                                                                    "lat"]) <= radius and 'weight' in dien]))

        if not math.isnan(dienCostPower):
            TWLoc["costPower_Analyze"] = dienCostPower
        else:
            TWLoc["costPower_Analyze"] =0
        TWLoc["NcostData_Analyze"] = len([dien['weight'] for dien in CostPowerdata if haversine(lng1=dien["lng"],
                                                                                lat1=dien["lat"],
                                                                                lng2=TWLoc["lng"],
                                                                                lat2=TWLoc["lat"]) <= radius and 'weight' in dien])

        dienHuman = sum([dien['weight'] for dien in Nhumandata if haversine(lng1=dien["lng"],
                                                                            lat1=dien["lat"],
                                                                            lng2=TWLoc["lng"],
                                                                            lat2=TWLoc["lat"]) <= radius and 'weight' in dien])
        TWLoc['Nhuman_Analyze'] = dienHuman

        avgSalary = round(numpy.mean(
            [dien['SAL_MONTH_LOW'] * 1 / 3 + dien['SAL_MONTH_HIGH'] * 2 / 3 for dien in hr104data if
             haversine(lng1=dien["lng"],
                       lat1=dien["lat"],
                       lng2=TWLoc["lng"],
                       lat2=TWLoc["lat"]) <= radius and 'SAL_MONTH_HIGH' in dien and 'SAL_MONTH_LOW' in dien]))
        if not math.isnan(avgSalary):
            TWLoc['avgSalary_Analyze'] = avgSalary
        else:
            TWLoc["avgSalary_Analyze"] =0

        TWLoc['Njob_Analyze'] = len([dien['SAL_MONTH_LOW'] * 1 / 3 + dien['SAL_MONTH_HIGH'] * 2 / 3 for dien in hr104data if
                            haversine(lng1=dien["lng"],
                                      lat1=dien["lat"],
                                      lng2=TWLoc["lng"],
                                      lat2=TWLoc["lat"]) <= radius and 'SAL_MONTH_HIGH' in dien  and 'SAL_MONTH_LOW' in dien])

        avgCost = round(numpy.mean([dien['averagecost'] for dien in ipeendata if haversine(lng1=dien["lng"],
                                                                                           lat1=dien["lat"],
                                                                                           lng2=TWLoc["lng"],
                                                                                           lat2=TWLoc[
                                                                                               "lat"]) <= radius and 'averagecost' in dien]))
        if not math.isnan(avgCost):
            TWLoc['avgCost_Analyze'] = avgCost
        else:
            TWLoc["avgCost_Analyze"] =0
        
        TWLoc["Ndien_Analyze"] = len([dien['averagecost'] for dien in ipeendata if haversine(lng1=dien["lng"],
                                                                                           lat1=dien["lat"],
                                                                                           lng2=TWLoc["lng"],
                                                                                           lat2=TWLoc[
                                                                                               "lat"]) <= radius])
        
        try:
            mostStyle = Counter([dien['bigstyle'] for dien in ipeendata if haversine(lng1=dien["lng"],
                                                                                     lat1=dien["lat"],
                                                                                     lng2=TWLoc["lng"],
                                                                                     lat2=TWLoc[
                                                                                         "lat"]) <= radius and 'bigstyle' in dien]).most_common(1)[0][0]
        except:
            mostStyle = ""
        TWLoc['mostStyle_Analyze'] = mostStyle

        ###############################################################################################################0320
        TWLoc["NbusStation_Analyze"] = len([dien['stationName'] for dien in busData if "lng" in dien and haversine(lng1=dien["lng"],
                                                                                lat1=dien["lat"],
                                                                                lng2=TWLoc["lng"],
                                                                                lat2=TWLoc["lat"]) <= 500])#0326 change radius

        TWLoc["NconStore_Analyze"] = len([dien['name'] for dien in conStoreData if "lng" in dien and haversine(lng1=float(dien["lng"]),
                                                                                lat1=float(dien["lat"]),
                                                                                lng2=TWLoc["lng"],
                                                                                lat2=TWLoc["lat"]) <= radius])
    #         conStoreData
        TWLoc["Nstar_Analyze"] = len([dien['name'] for dien in ipeendata 
                                if '星巴' in dien['name'] 
                                and haversine(lng1=dien["lng"],
                                              lat1=dien["lat"],
                                              lng2=TWLoc["lng"],
                                              lat2=TWLoc["lat"]) <= radius])
        TWLoc["Nmc_Analyze"] = len([dien['name'] for dien in ipeendata 
                                if '麥當' in dien['name'] 
                                and haversine(lng1=dien["lng"],
                                              lat1=dien["lat"],
                                              lng2=TWLoc["lng"],
                                              lat2=TWLoc["lat"]) <= radius])
        TWLoc["Nken_Analyze"] = len([dien['name'] for dien in ipeendata 
                                if '肯德' in dien['name'] 
                                and haversine(lng1=dien["lng"],
                                              lat1=dien["lat"],
                                              lng2=TWLoc["lng"],
                                              lat2=TWLoc["lat"]) <= radius])
        TWLoc["Nwa_Analyze"] = len([dien['name'] for dien in ipeendata 
                                if '瓦城泰' in dien['name'] 
                                and haversine(lng1=dien["lng"],
                                              lat1=dien["lat"],
                                              lng2=TWLoc["lng"],
                                              lat2=TWLoc["lat"]) <= radius])
        ################################################################################################################0320
        
        
        
        
    e = time.time()
    print(e-b)


#     ids=[data.pop("_id") for data in TWLocs]
#     operations=[UpdateOne({"_id":idn},{'$set':data},upsert=True) for idn ,data in zip(ids,TWLocs)]
#     try:
#         collection.bulk_write(operations ,ordered=False)
#     except Exception as er:
#         print(er)

#     alldata=list(collection.find({}))

#     client.close()
    for i in TWLocs:
        i["_id"]="{}_{}".format(i['lat'],i['lng'])
    client = pymongo.mongo_client.MongoClient("192.168.1.113", 27017, username='j122085', password='850605')
    collection = client.rawData.taiwanInfo
    ids=[data.pop("_id") for data in TWLocs]
    operations=[UpdateOne({"_id":idn},{'$set':data},upsert=True) for idn ,data in zip(ids,TWLocs)]
    try:
        collection.bulk_write(operations ,ordered=False)
    except Exception as er:
        print(er)
    client.close()
    
    mailTo(title="TaiwanDataSuccess",mailAdds=["andy.yuan@wowprime.com"],message="分析完畢_耗時{}秒".format(e-b),whoSend='analyzeTaiwanData')
except Exception as er:
    errorMsg=str(er)+"出錯位置:"+str(sys.exc_info()[2].tb_lineno)
    mailTo(title="analyzeTaiwanDataFail",mailAdds=["andy.yuan@wowprime.com"],message=errorMsg,whoSend='analyzeTaiwanData')

# %%
for i in wowDiensData:
    i["_id"]="{}_{}".format(i['lat'],i['lng'])
client = pymongo.mongo_client.MongoClient("192.168.1.113", 27017, username='j122085', password='850605')
collection = client.rawData.taiwanInfo
ids=[data.pop("_id") for data in wowDiensData]
operations=[UpdateOne({"_id":idn},{'$set':data},upsert=True) for idn ,data in zip(ids,wowDiensData)]
try:
    collection.bulk_write(operations ,ordered=False)
except Exception as er:
    print(er)

alldata=list(collection.find({}))

client.close()

# %%
import pymongo
from pymongo import UpdateOne
client = pymongo.mongo_client.MongoClient("localhost", 27017, username='j122085', password='850605')
collection = client.rawData.taiwanInfo
wowDiensData=list(collection.find({}))

# %%
import pymongo
from pymongo import UpdateOne
client = pymongo.mongo_client.MongoClient("localhost", 27017, username='j122085', password='850605')
collection = client.rawData.taiwanInfo
wowDiensData=list(collection.find({}))

# %% [markdown]
# # 500M for stoneTwo

# %%
import numpy as np
TaiwanLatRange=np.arange(21.91456,25.29548,0.00169046)
TaiwanLngRange=np.arange(120.04193,122.00059,0.002448325)

# %%
TWLocs=[]
for i in TaiwanLatRange:
    for j in TaiwanLngRange:
        TWLoc={}
        TWLoc['lat']=i
        TWLoc['lng']=j
        TWLocs.append(TWLoc)

# %%
import json
import pymongo
from pymongo import UpdateOne
import numpy
import math
from math import radians, cos, sin, asin, sqrt
from collections import Counter
import time
import sys
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.message import EmailMessage
import smtplib
import gc
gc.enable() 



def haversine(lng1, lat1, lng2, lat2):
    # 将十进制度数转化为弧度
    lng1, lat1, lng2, lat2 = map(radians, [lng1, lat1, lng2, lat2])
    # haversine公式
    dlng = lng2 - lng1
    dlat = lat2 - lat1
    a = sin(dlat / 2) ** 2 + cos(lat1) * cos(lat2) * sin(dlng / 2) ** 2
    c = 2 * asin(sqrt(a))
    r = 6371  # 地球平均半径，单位为公里
    return c * r * 1000


b=time.time()
def mailTo(title,mailAdds,message,whoSend='StoneTwo'):
    msg = MIMEMultipart()    
    sender = whoSend
    subject = title
    body = message
    msg['From'] = sender
    msg['To'] = ','.join(mailAdds)
    msg['Subject'] = subject
    msg.attach(MIMEText(body, 'plain'))
    text=msg.as_string()
    #print text
    # Send the message via our SMTP server
    s = smtplib.SMTP('192.168.2.1',25)
    s.sendmail(sender,mailAdds, text)
    s.quit()  

mailTo(title="StoneTwobegin",mailAdds=["andy.yuan@wowprime.com"],message="分析開始",whoSend='StoneTwo')
    
try:
    ######################################################IPEEN
    b=time.time()
    queryElements = {}
    client = pymongo.mongo_client.MongoClient("localhost", 27017, username='j122085', password='850605')
    collectionTaiwan = client.rawData.taiwanInfoStoneTwo
    ##################################################第一次跑不執行
    TWLocs=list(collectionTaiwan.find({}, {'_id': False}))
    ##################################################第一次跑不執行
    
    
    # collection = client.rawData.wowprimeipeen
    collection = client.rawData.ipeenInfo
    ipeendata = list(collection.find(queryElements))
    ipeendata = [dien for dien in ipeendata if dien['status'] == "正常營業"
                 and dien['lat'] > 18
                 and dien['lat'] < 27
                 and dien['lng'] < 125
                 and dien['lng'] > 117
                 and dien['bigadd'] != 0
                 and dien['smalladd'] != 0
                 and dien['averagecost'] < 8000]

    for dien in ipeendata:
        dien["id"] = dien.pop("_id")
    ######################################################IPEEN
    ######################################################104
    collection = client.rawData.HRdata104
    hr104data = list(collection.find(queryElements))
    hr104data = [dien for dien in hr104data if dien['LAT'] > 18
                 and dien['LAT'] < 27
                 and dien['SAL_MONTH_LOW'] > 18000
                 and dien['SAL_MONTH_LOW'] < 100000
                 and dien['SAL_MONTH_HIGH'] > 18000
                 and dien['SAL_MONTH_HIGH'] < 200000
                 and dien['LON'] < 125
                 and dien['LON'] > 117
                 and dien['bigadd'] != 0
                 and dien['smalladd'] != 0]

    for dien in hr104data:
        dien["lat"] = dien.pop("LAT")
        dien["lng"] = dien.pop("LON")
        del dien["_id"]
    ######################################################104
    ######################################################Nhuman
    collection = client.rawData.Nhuman
    Nhumandata = list(collection.find(queryElements))
    for dien in Nhumandata:
        dien["weight"] = int(dien.pop("Nhuman"))
        dien["add"] = dien.pop("_id")
    ######################################################Nhuman
    ######################################################CostPower
    collection = client.rawData.CostPower
    CostPowerdata = list(collection.find(queryElements))
    for dien in CostPowerdata:
        dien["weight"] = int(dien.pop('costPower'))
        dien["add"] = dien.pop("_id")
    ######################################################CostPower
    ######################################################Bus0320
    collection = client.rawData.busData
    busData = list(collection.find(queryElements))
    for dien in busData:
        dien["add"] = dien.pop("_id")
    ######################################################Bus0320
    ######################################################conStore0320
    collection = client.rawData.conStore
    conStoreData = list(collection.find(queryElements))
    for dien in conStoreData:
        dien.pop("_id")
    ######################################################conStore0320
    ######################################################Watsons
    collection = client.rawData.Watsons
    watsonsData = list(collection.find(queryElements))
    for dien in watsonsData:
        dien.pop("_id")
    ######################################################Watsons
    ######################################################carrefour0504
    collection = client.rawData.carrefour
    carrefourData = list(collection.find(queryElements))
    for dien in carrefourData:
        dien.pop("_id")
    ######################################################carrefour0504
    ######################################################pxmart0504
    collection = client.rawData.pxmart
    pxmartData = list(collection.find(queryElements))
    for dien in pxmartData:
        dien.pop("_id")
    ######################################################pxmart0504
    ######################################################Wow
    ##################################################第一次跑不執行
    TWLocs = [i for i in TWLocs if ('NconStore_Analyze' in i and
              i['NconStore_Analyze'] >0)]
    ##################################################第一次跑不執行
    allN=len(TWLocs)
    print("有{}筆資料要分析".format(allN))
    radius=500
    n = 0
    
    
    for TWLoc in TWLocs:
        score=0
        
        n += 1
        if n % 100 == 0:
            e=time.time()
            print("已完成{}%分析-{}項,花費{}秒".format(round(n/allN,4)*100,n,round(e-b)))
        if n % 2000 == 0:
            gc.collect()
            client = pymongo.mongo_client.MongoClient("localhost", 27017, username='j122085', password='850605')
            collection = client.rawData.taiwanInfoStoneTwo
            
            ids=["{}_{}".format(i['lat'],i['lng']) for i in TWLocs if i.get("NconStore_Analyze",0)>0]
            datas=[i for i in TWLocs if i.get("NconStore_Analyze",0)>0]
            operations=[UpdateOne({"_id":idn},{'$set':data},upsert=True) for idn ,data in zip(ids,datas)]
            try:
                collection.bulk_write(operations ,ordered=False)
            except Exception as er:
                print(er)
            client.close()

        TWLoc["areaRadius_Analyze"] = radius

        
        
       

        #############################################################0523Score
        
        

        TWLoc["NconStore_Analyze"] = len([dien['name'] for dien in conStoreData if "lng" in dien and haversine(lng1=float(dien["lng"]),
                                                                                lat1=float(dien["lat"]),
                                                                                lng2=TWLoc["lng"],
                                                                                lat2=TWLoc["lat"]) <= radius])
        if TWLoc["NconStore_Analyze"]>12:
            score=score+2
        elif TWLoc["NconStore_Analyze"]>4:
            score=score+1
            
        if TWLoc["NconStore_Analyze"]==0:
            TWLoc["score"]=score
            continue
            
            
        TWLoc["NbusStation_Analyze"] = len([dien['stationName'] for dien in busData if "lng" in dien and haversine(lng1=dien["lng"],
                                                                                lat1=dien["lat"],
                                                                                lng2=TWLoc["lng"],
                                                                                lat2=TWLoc["lat"]) <= 500])#0326 change radius
        if TWLoc["NbusStation_Analyze"]>11:
            score=score+2
        elif TWLoc["NbusStation_Analyze"]>4:
            score=score+1
        
        
    #         conStoreData
        TWLoc["Nstar_Analyze"] = len([dien['name'] for dien in ipeendata 
                                if '星巴' in dien['name'] 
                                and haversine(lng1=dien["lng"],
                                              lat1=dien["lat"],
                                              lng2=TWLoc["lng"],
                                              lat2=TWLoc["lat"]) <= radius])
        TWLoc["Nmc_Analyze"] = len([dien['name'] for dien in ipeendata 
                                if '麥當' in dien['name'] 
                                and haversine(lng1=dien["lng"],
                                              lat1=dien["lat"],
                                              lng2=TWLoc["lng"],
                                              lat2=TWLoc["lat"]) <= radius])
        TWLoc["Nken_Analyze"] = len([dien['name'] for dien in ipeendata 
                                if '肯德' in dien['name'] 
                                and haversine(lng1=dien["lng"],
                                              lat1=dien["lat"],
                                              lng2=TWLoc["lng"],
                                              lat2=TWLoc["lat"]) <= radius])
        TWLoc["Nwa_Analyze"] = len([dien['name'] for dien in ipeendata 
                                if '瓦城泰' in dien['name'] 
                                and haversine(lng1=dien["lng"],
                                              lat1=dien["lat"],
                                              lng2=TWLoc["lng"],
                                              lat2=TWLoc["lat"]) <= radius])
        
        if TWLoc["Nstar_Analyze"]+TWLoc["Nmc_Analyze"]+TWLoc["Nken_Analyze"]+TWLoc["Nwa_Analyze"]>2:
            score=score+2
        elif TWLoc["Nstar_Analyze"]+TWLoc["Nmc_Analyze"]+TWLoc["Nken_Analyze"]+TWLoc["Nwa_Analyze"]>0:
            score=score+1
        
        TWLoc["Nwatson_Analyze"] = len([dien for dien in watsonsData
                                          if haversine(lng1=float(dien["lng"]),
                                                       lat1=float(dien["lat"]),
                                                       lng2=TWLoc["lng"],
                                                       lat2=TWLoc["lat"]) <= radius])
        TWLoc["Npxmart_Analyze"] = len([dien for dien in pxmartData
                                          if haversine(lng1=float(dien["lng"]),
                                                       lat1=float(dien["lat"]),
                                                       lng2=TWLoc["lng"],
                                                       lat2=TWLoc["lat"]) <= radius])
        
        if TWLoc["Nwatson_Analyze"]+TWLoc["Npxmart_Analyze"]>2:
            score=score+2
        elif TWLoc["Nwatson_Analyze"]+TWLoc["Npxmart_Analyze"]>0:
            score=score+1
            
        
        
        
        
        rangeCost = 1.4

        simDien = [dien['bigstyle'] for dien in ipeendata if haversine(lng1=dien["lng"],
                                                                       lat1=dien["lat"],
                                                                       lng2=TWLoc["lng"],
                                                                       lat2=TWLoc["lat"]) <= 500
                   and dien['averagecost'] < ((240) * rangeCost)
                   and dien['averagecost'] > ((240) / rangeCost)]
        # stoneTwoCost==240
        TWLoc["NsimCostDien"] = len(simDien)
        # print(simDien)
        # print(wowDien['Called'])
        if TWLoc["NsimCostDien"]>29:
            score=score+2
        elif TWLoc["NsimCostDien"]>11:
            score=score+1
        
        
        
            
            
        TWLoc["score"]=score
        
        dienHuman = sum([dien['weight'] for dien in Nhumandata if haversine(lng1=dien["lng"],
                                                                            lat1=dien["lat"],
                                                                            lng2=TWLoc["lng"],
                                                                            lat2=TWLoc["lat"]) <= radius and 'weight' in dien])
        TWLoc['Nhuman_Analyze'] = dienHuman

        #############################################################0523Score
        
        
        
    e = time.time()
    print(e-b)


#     ids=[data.pop("_id") for data in TWLocs]
#     operations=[UpdateOne({"_id":idn},{'$set':data},upsert=True) for idn ,data in zip(ids,TWLocs)]
#     try:
#         collection.bulk_write(operations ,ordered=False)
#     except Exception as er:
#         print(er)

#     alldata=list(collection.find({}))

#     client.close()
    client = pymongo.mongo_client.MongoClient("192.168.1.113", 27017, username='j122085', password='850605')
    collection = client.rawData.taiwanInfoStoneTwo
    ids=["{}_{}".format(i['lat'],i['lng']) for i in TWLocs]
    operations=[UpdateOne({"_id":idn},{'$set':data},upsert=True) for idn ,data in zip(ids,TWLocs)]
    try:
        collection.bulk_write(operations ,ordered=False)
    except Exception as er:
        print(er)
    client.close()
    
    e = time.time()
    print(e-b)
    
    
    mailTo(title="StoneTwoSuccess",mailAdds=["andy.yuan@wowprime.com"],message="分析完畢_耗時{}秒".format(e-b),whoSend='StoneTwo')
except Exception as er:
    errorMsg=str(er)+"出錯位置:"+str(sys.exc_info()[2].tb_lineno)
    mailTo(title="StoneTwoFail",mailAdds=["andy.yuan@wowprime.com"],message=errorMsg,whoSend='StoneTwo')

# %%
len(list(collection.find({'score':{"$gt":0}})))

# %%
len(TWLocs)

# %%
client = pymongo.mongo_client.MongoClient("192.168.1.113", 27017, username='j122085', password='850605')
collection = client.rawData.taiwanInfoStoneTwo

# %%
TWLocs=[i for i in list(collection.find()) if i['NconStore_Analyze']>0]

import pandas as pd
df=pd.DataFrame(TWLocs)
f = pd.ExcelWriter(r'D:\outputXLS\stone2location.xlsx')
df.to_excel(f,header=True)
f.save()

# %% [markdown]
# # 500M for hot7

# %%
import json
import pymongo
from pymongo import UpdateOne
import numpy
import math
from math import radians, cos, sin, asin, sqrt
from collections import Counter
import time
import sys
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.message import EmailMessage
import smtplib
import gc
gc.enable() 



def haversine(lng1, lat1, lng2, lat2):
    # 将十进制度数转化为弧度
    lng1, lat1, lng2, lat2 = map(radians, [lng1, lat1, lng2, lat2])
    # haversine公式
    dlng = lng2 - lng1
    dlat = lat2 - lat1
    a = sin(dlat / 2) ** 2 + cos(lat1) * cos(lat2) * sin(dlng / 2) ** 2
    c = 2 * asin(sqrt(a))
    r = 6371  # 地球平均半径，单位为公里
    return c * r * 1000


b=time.time()
def mailTo(title,mailAdds,message,whoSend='taiwanInfoHot7'):
    msg = MIMEMultipart()    
    sender = whoSend
    subject = title
    body = message
    msg['From'] = sender
    msg['To'] = ','.join(mailAdds)
    msg['Subject'] = subject
    msg.attach(MIMEText(body, 'plain'))
    text=msg.as_string()
    #print text
    # Send the message via our SMTP server
    s = smtplib.SMTP('192.168.2.1',25)
    s.sendmail(sender,mailAdds, text)
    s.quit()  

mailTo(title="taiwanInfoHot7begin",mailAdds=["andy.yuan@wowprime.com"],message="分析開始")
try:
    ######################################################第一次跑用stoneTwo來篩選沒超商的點
    b=time.time()
    client = pymongo.mongo_client.MongoClient("localhost", 27017, username='j122085', password='850605')
#     collectionTaiwan = client.rawData.taiwanInfoStoneTwo
    collectionTaiwan = client.rawData.taiwanInfoHot7
    ##################################################第一次跑不執行
    TWLocs=list(collectionTaiwan.find({}, {'_id': False}))
    ##################################################第一次跑不執行
    
    ######################################################IPEEN
    # collection = client.rawData.wowprimeipeen
    collection = client.rawData.ipeenInfo
    ipeendata = list(collection.find({}, {'_id': False}))
    ipeendata = [dien for dien in ipeendata if dien['status'] == "正常營業"
                 and dien['lat'] > 18
                 and dien['lat'] < 27
                 and dien['lng'] < 125
                 and dien['lng'] > 117
                 and dien['bigadd'] != 0
                 and dien['smalladd'] != 0
                 and dien['averagecost'] < 250]

    ######################################################IPEEN
    ######################################################conStore0320
    collection = client.rawData.conStore
    conStoreData = list(collection.find({}, {'_id': False}))
    ######################################################conStore0320
    ######################################################Watsons
    collection = client.rawData.Watsons
    watsonsData = list(collection.find({}, {'_id': False}))
    ######################################################Watsons
    ######################################################carrefour0504
    collection = client.rawData.carrefour
    carrefourData = list(collection.find({}, {'_id': False}))
    ######################################################carrefour0504
    ######################################################pxmart0504
    collection = client.rawData.pxmart
    pxmartData = list(collection.find({}, {'_id': False}))
    ######################################################pxmart0504
    ######################################################Clinic0531
    collection = client.rawData.infoClinic
    clinicData = list(collection.find({}, {'_id': False}))
    ######################################################Clinic0531
    ######################################################Tstore0531
    collection = client.rawData.info3Store
    tStoreData = list(collection.find({}, {'_id': False}))
    ######################################################Tstore0531
    ##################################################第一次跑先去除latlng以外的資訊
#     TWLocs = [{"lat":i["lat"],"lng":i["lng"]} for i in TWLocs if ('NconStore_Analyze' in i and
#               i['NconStore_Analyze'] >0)]
    TWLocs = [i for i in TWLocs if ('NconStore_Analyze' in i and
              i['NconStore_Analyze'] >0)]
    ##################################################第一次跑先去除latlng以外的資訊
    allN=len(TWLocs)
    print("有{}筆資料要分析".format(allN))
    radius=500
    n = 0

    for TWLoc in TWLocs:
        score=0
        n += 1
        if n % 50 == 0:
            e=time.time()
            print("已完成{}%分析-{}項,花費{}秒".format(round(n/allN,4)*100,n,round(e-b)))
        if n % 2000 == 0:
            gc.collect()
            client = pymongo.mongo_client.MongoClient("localhost", 27017, username='j122085', password='850605')
            collection = client.rawData.taiwanInfoHot7
            
            ids=["{}_{}".format(i['lat'],i['lng']) for i in TWLocs if i.get("NconStore_Analyze",0)>0]
            datas=[i for i in TWLocs if i.get("NconStore_Analyze",0)>0]
            operations=[UpdateOne({"_id":idn},{'$set':data},upsert=True) for idn ,data in zip(ids,datas)]
            try:
                collection.bulk_write(operations ,ordered=False)
            except Exception as er:
                print(er)
            client.close()

        TWLoc["areaRadius_Analyze"] = radius
        #############################################################0523Score

        TWLoc["NconStore_Analyze"] = len([dien['name'] for dien in conStoreData if "lng" in dien and haversine(lng1=float(dien["lng"]),
                                                                                lat1=float(dien["lat"]),
                                                                                lng2=TWLoc["lng"],
                                                                                lat2=TWLoc["lat"]) <= radius])
            
        
        TWLoc["Nwatson_Analyze"] = len([dien for dien in watsonsData
                                          if haversine(lng1=float(dien["lng"]),
                                                       lat1=float(dien["lat"]),
                                                       lng2=TWLoc["lng"],
                                                       lat2=TWLoc["lat"]) <= radius])
        TWLoc["Npxmart_Analyze"] = len([dien for dien in pxmartData
                                          if haversine(lng1=float(dien["lng"]),
                                                       lat1=float(dien["lat"]),
                                                       lng2=TWLoc["lng"],
                                                       lat2=TWLoc["lat"]) <= radius])
        
            
        TWLoc["NclinicData_Analyze"] = len([dien for dien in clinicData
                                  if haversine(lng1=float(dien["lng"]),
                                               lat1=float(dien["lat"]),
                                               lng2=TWLoc["lng"],
                                               lat2=TWLoc["lat"]) <= radius])
        
        TWLoc["NtStore_Analyze"] = len([dien for dien in tStoreData
                                  if haversine(lng1=float(dien["lng"]),
                                               lat1=float(dien["lat"]),
                                               lng2=TWLoc["lng"],
                                               lat2=TWLoc["lat"]) <= radius])

        rangeCost = 1.4

        simDien = [dien['smallstyle'] for dien in ipeendata if haversine(lng1=dien["lng"],
                                                                       lat1=dien["lat"],
                                                                       lng2=TWLoc["lng"],
                                                                       lat2=TWLoc["lat"]) <= 500
                   and dien['averagecost'] < 250
                   and dien['smallstyle']=="鐵板燒"]
        
        TWLoc["NsimCostDien"] = len(simDien)

        dapu = len([dien['smallstyle'] for dien in ipeendata if haversine(lng1=dien["lng"],
                                                                       lat1=dien["lat"],
                                                                       lng2=TWLoc["lng"],
                                                                       lat2=TWLoc["lat"]) <= 500
                   and "大埔平" in dien['name']])
        
        TWLoc["NDapu_analyze"] = dapu
        

        

        #############################################################0523Score
    for i in TWLocs:
        score=0
        if i['NclinicData_Analyze']>20:
            score+=2
        elif i['NclinicData_Analyze']>9:
            score+=1
        if i['NconStore_Analyze']>11:
            score+=2
        elif i['NconStore_Analyze']>5:
            score+=1
        if i['Npxmart_Analyze']+i['Nwatson_Analyze']>2:
            score+=2
        elif i['Npxmart_Analyze']+i['Nwatson_Analyze']>0:
            score+=1

        if i['NsimCostDien']>3:
            score+=3
        elif i['NsimCostDien']>2:
            score+=2
        elif i['NsimCostDien']>1:
            score+=1
        if i['NtStore_Analyze']+i["NDapu_analyze"]>0:
            score+=1
        i['score']=score
        
    
    e = time.time()
    print(e-b)


#     client.close()
    client = pymongo.mongo_client.MongoClient("localhost", 27017, username='j122085', password='850605')
    collection = client.rawData.taiwanInfoHot7
    ids=["{}_{}".format(i['lat'],i['lng']) for i in TWLocs]
    operations=[UpdateOne({"_id":idn},{'$set':data},upsert=True) for idn ,data in zip(ids,TWLocs)]
    try:
        collection.bulk_write(operations ,ordered=False)
    except Exception as er\
        print(er)
    client.close()
    
    e = time.time()
    print(e-b)
    
    
    mailTo(title="taiwanInfoHot7Success",mailAdds=["andy.yuan@wowprime.com"],message="分析完畢_耗時{}秒".format(e-b))
except Exception as er:
    errorMsg=str(er)+"出錯位置:"+str(sys.exc_info()[2].tb_lineno)
    mailTo(title="taiwanInfoHot7Fail",mailAdds=["andy.yuan@wowprime.com"],message=errorMsg)
# Out:
# 有49103筆資料要分析
# 已完成0.1%分析-50項,花費43秒
# 已完成0.2%分析-100項,花費84秒
# 已完成0.31%分析-150項,花費123秒
# 已完成0.41000000000000003%分析-200項,花費162秒
# 已完成0.51%分析-250項,花費201秒
# 已完成0.61%分析-300項,花費242秒
# 已完成0.7100000000000001%分析-350項,花費285秒
# 已完成0.8099999999999999%分析-400項,花費325秒
# 已完成0.9199999999999999%分析-450項,花費367秒
# 已完成1.02%分析-500項,花費409秒
# 已完成1.1199999999999999%分析-550項,花費450秒
# 已完成1.22%分析-600項,花費489秒
# 已完成1.32%分析-650項,花費529秒
# 已完成1.43%分析-700項,花費570秒
# 已完成1.53%分析-750項,花費612秒
# 已完成1.63%分析-800項,花費653秒
# 已完成1.73%分析-850項,花費693秒
# 已完成1.83%分析-900項,花費732秒
# 已完成1.9300000000000002%分析-950項,花費772秒
# 已完成2.04%分析-1000項,花費811秒
# 已完成2.1399999999999997%分析-1050項,花費850秒
# 已完成2.2399999999999998%分析-1100項,花費889秒
# 已完成2.34%分析-1150項,花費929秒
# 已完成2.44%分析-1200項,花費968秒
# 已完成2.55%分析-1250項,花費1008秒
# 已完成2.65%分析-1300項,花費1047秒
# 已完成2.75%分析-1350項,花費1086秒
# 已完成2.85%分析-1400項,花費1125秒
# 已完成2.9499999999999997%分析-1450項,花費1165秒
# 已完成3.05%分析-1500項,花費1204秒
# 已完成3.16%分析-1550項,花費1243秒
# 已完成3.26%分析-1600項,花費1283秒
# 已完成3.36%分析-1650項,花費1322秒
# 已完成3.46%分析-1700項,花費1361秒
# 已完成3.56%分析-1750項,花費1400秒
# 已完成3.6700000000000004%分析-1800項,花費1440秒
# 已完成3.7699999999999996%分析-1850項,花費1479秒
# 已完成3.8699999999999997%分析-1900項,花費1519秒
# 已完成3.9699999999999998%分析-1950項,花費1558秒
# 已完成4.07%分析-2000項,花費1597秒
# 已完成4.17%分析-2050項,花費1641秒
# 已完成4.279999999999999%分析-2100項,花費1681秒
# 已完成4.38%分析-2150項,花費1720秒
# 已完成4.4799999999999995%分析-2200項,花費1760秒
# 已完成4.58%分析-2250項,花費1799秒
# 已完成4.68%分析-2300項,花費1838秒
# 已完成4.79%分析-2350項,花費1878秒
# 已完成4.89%分析-2400項,花費1917秒
# 已完成4.99%分析-2450項,花費1957秒
# 已完成5.09%分析-2500項,花費1996秒
# 已完成5.19%分析-2550項,花費2035秒
# 已完成5.29%分析-2600項,花費2075秒
# 已完成5.4%分析-2650項,花費2114秒
# 已完成5.5%分析-2700項,花費2153秒
# 已完成5.6000000000000005%分析-2750項,花費2193秒
# 已完成5.7%分析-2800項,花費2232秒
# 已完成5.800000000000001%分析-2850項,花費2271秒
# 已完成5.91%分析-2900項,花費2310秒
# 已完成6.01%分析-2950項,花費2349秒
# 已完成6.11%分析-3000項,花費2388秒
# 已完成6.21%分析-3050項,花費2428秒
# 已完成6.3100000000000005%分析-3100項,花費2468秒
# 已完成6.419999999999999%分析-3150項,花費2507秒
# 已完成6.52%分析-3200項,花費2546秒
# 已完成6.619999999999999%分析-3250項,花費2585秒
# 已完成6.72%分析-3300項,花費2625秒
# 已完成6.819999999999999%分析-3350項,花費2664秒
# 已完成6.92%分析-3400項,花費2703秒
# 已完成7.03%分析-3450項,花費2743秒
# 已完成7.13%分析-3500項,花費2782秒
# 已完成7.23%分析-3550項,花費2821秒
# 已完成7.33%分析-3600項,花費2860秒
# 已完成7.430000000000001%分析-3650項,花費2899秒
# 已完成7.539999999999999%分析-3700項,花費2939秒
# 已完成7.64%分析-3750項,花費2978秒
# 已完成7.739999999999999%分析-3800項,花費3017秒
# 已完成7.84%分析-3850項,花費3056秒
# 已完成7.9399999999999995%分析-3900項,花費3095秒
# 已完成8.04%分析-3950項,花費3134秒
# 已完成8.15%分析-4000項,花費3174秒
# 已完成8.25%分析-4050項,花費3218秒
# 已完成8.35%分析-4100項,花費3257秒
# 已完成8.450000000000001%分析-4150項,花費3296秒
# 已完成8.55%分析-4200項,花費3336秒
# 已完成8.66%分析-4250項,花費3375秒
# 已完成8.76%分析-4300項,花費3414秒
# 已完成8.86%分析-4350項,花費3454秒
# 已完成8.959999999999999%分析-4400項,花費3493秒
# 已完成9.06%分析-4450項,花費3532秒
# 已完成9.16%分析-4500項,花費3571秒
# 已完成9.27%分析-4550項,花費3611秒
# 已完成9.370000000000001%分析-4600項,花費3650秒
# 已完成9.47%分析-4650項,花費3689秒
# 已完成9.569999999999999%分析-4700項,花費3728秒
# 已完成9.67%分析-4750項,花費3767秒
# 已完成9.78%分析-4800項,花費3807秒
# 已完成9.879999999999999%分析-4850項,花費3846秒
# 已完成9.98%分析-4900項,花費3885秒
# 已完成10.08%分析-4950項,花費3924秒
# 已完成10.18%分析-5000項,花費3964秒
# 已完成10.280000000000001%分析-5050項,花費4003秒
# 已完成10.39%分析-5100項,花費4042秒
# 已完成10.489999999999998%分析-5150項,花費4082秒
# 已完成10.59%分析-5200項,花費4121秒
# 已完成10.69%分析-5250項,花費4161秒
# 已完成10.79%分析-5300項,花費4200秒
# 已完成10.9%分析-5350項,花費4239秒
# 已完成11.0%分析-5400項,花費4278秒
# 已完成11.1%分析-5450項,花費4317秒
# 已完成11.200000000000001%分析-5500項,花費4357秒
# 已完成11.3%分析-5550項,花費4396秒
# 已完成11.4%分析-5600項,花費4435秒
# 已完成11.51%分析-5650項,花費4475秒
# 已完成11.61%分析-5700項,花費4514秒
# 已完成11.709999999999999%分析-5750項,花費4553秒
# 已完成11.81%分析-5800項,花費4593秒
# 已完成11.91%分析-5850項,花費4635秒
# 已完成12.02%分析-5900項,花費4679秒
# 已完成12.120000000000001%分析-5950項,花費4723秒
# 已完成12.22%分析-6000項,花費4764秒
# 已完成12.32%分析-6050項,花費4811秒
# 已完成12.42%分析-6100項,花費4855秒
# 已完成12.520000000000001%分析-6150項,花費4898秒
# 已完成12.629999999999999%分析-6200項,花費4943秒
# 已完成12.73%分析-6250項,花費4988秒
# 已完成12.83%分析-6300項,花費5032秒
# 已完成12.93%分析-6350項,花費5072秒
# 已完成13.03%分析-6400項,花費5113秒
# 已完成13.139999999999999%分析-6450項,花費5156秒
# 已完成13.239999999999998%分析-6500項,花費5199秒
# 已完成13.34%分析-6550項,花費5243秒
# 已完成13.44%分析-6600項,花費5285秒
# 已完成13.54%分析-6650項,花費5326秒
# 已完成13.639999999999999%分析-6700項,花費5371秒
# 已完成13.750000000000002%分析-6750項,花費5412秒
# 已完成13.850000000000001%分析-6800項,花費5453秒
# 已完成13.950000000000001%分析-6850項,花費5496秒
# 已完成14.05%分析-6900項,花費5538秒
# 已完成14.149999999999999%分析-6950項,花費5579秒
# 已完成14.26%分析-7000項,花費5620秒
# 已完成14.360000000000001%分析-7050項,花費5661秒
# 已完成14.46%分析-7100項,花費5703秒
# 已完成14.56%分析-7150項,花費5744秒
# 已完成14.66%分析-7200項,花費5784秒
# 已完成14.760000000000002%分析-7250項,花費5825秒
# 已完成14.87%分析-7300項,花費5865秒
# 已完成14.97%分析-7350項,花費5907秒
# 已完成15.07%分析-7400項,花費5947秒
# 已完成15.17%分析-7450項,花費5990秒
# 已完成15.27%分析-7500項,花費6031秒
# 已完成15.379999999999999%分析-7550項,花費6070秒
# 已完成15.479999999999999%分析-7600項,花費6111秒
# 已完成15.58%分析-7650項,花費6151秒
# 已完成15.68%分析-7700項,花費6191秒
# 已完成15.78%分析-7750項,花費6231秒
# 已完成15.879999999999999%分析-7800項,花費6271秒
# 已完成15.989999999999998%分析-7850項,花費6312秒
# 已完成16.09%分析-7900項,花費6352秒
# 已完成16.189999999999998%分析-7950項,花費6392秒
# 已完成16.29%分析-8000項,花費6435秒
# 已完成16.39%分析-8050項,花費6479秒
# 已完成16.5%分析-8100項,花費6522秒
# 已完成16.6%分析-8150項,花費6564秒
# 已完成16.7%分析-8200項,花費6609秒
# 已完成16.8%分析-8250項,花費6652秒
# 已完成16.900000000000002%分析-8300項,花費6695秒
# 已完成17.01%分析-8350項,花費6740秒
# 已完成17.11%分析-8400項,花費6783秒
# 已完成17.21%分析-8450項,花費6825秒
# 已完成17.31%分析-8500項,花費6869秒
# 已完成17.41%分析-8550項,花費6911秒
# 已完成17.51%分析-8600項,花費6956秒
# 已完成17.62%分析-8650項,花費6996秒
# 已完成17.72%分析-8700項,花費7036秒
# 已完成17.82%分析-8750項,花費7076秒
# 已完成17.919999999999998%分析-8800項,花費7117秒
# 已完成18.02%分析-8850項,花費7157秒
# 已完成18.13%分析-8900項,花費7198秒
# 已完成18.23%分析-8950項,花費7238秒
# 已完成18.33%分析-9000項,花費7278秒
# 已完成18.43%分析-9050項,花費7319秒
# 已完成18.529999999999998%分析-9100項,花費7359秒
# 已完成18.63%分析-9150項,花費7399秒
# 已完成18.740000000000002%分析-9200項,花費7439秒
# 已完成18.84%分析-9250項,花費7482秒
# 已完成18.94%分析-9300項,花費7524秒
# 已完成19.040000000000003%分析-9350項,花費7566秒
# 已完成19.139999999999997%分析-9400項,花費7609秒
# 已完成19.25%分析-9450項,花費7651秒
# 已完成19.35%分析-9500項,花費7691秒
# 已完成19.45%分析-9550項,花費7732秒
# 已完成19.55%分析-9600項,花費7774秒
# 已完成19.650000000000002%分析-9650項,花費7816秒
# 已完成19.75%分析-9700項,花費7855秒
# 已完成19.86%分析-9750項,花費7895秒
# 已完成19.96%分析-9800項,花費7934秒
# 已完成20.06%分析-9850項,花費7974秒
# 已完成20.16%分析-9900項,花費8013秒
# 已完成20.26%分析-9950項,花費8052秒
# 已完成20.369999999999997%分析-10000項,花費8092秒
# 已完成20.47%分析-10050項,花費8136秒
# 已完成20.57%分析-10100項,花費8175秒
# 已完成20.669999999999998%分析-10150項,花費8215秒
# 已完成20.77%分析-10200項,花費8254秒
# 已完成20.87%分析-10250項,花費8294秒
# 已完成20.979999999999997%分析-10300項,花費8333秒
# 已完成21.08%分析-10350項,花費8373秒
# 已完成21.18%分析-10400項,花費8412秒
# 已完成21.279999999999998%分析-10450項,花費8452秒
# 已完成21.38%分析-10500項,花費8493秒
# 已完成21.490000000000002%分析-10550項,花費8533秒
# 已完成21.59%分析-10600項,花費8574秒
# 已完成21.69%分析-10650項,花費8614秒
# 已完成21.790000000000003%分析-10700項,花費8655秒
# 已完成21.89%分析-10750項,花費8695秒
# 已完成21.990000000000002%分析-10800項,花費8736秒
# 已完成22.1%分析-10850項,花費8776秒
# 已完成22.2%分析-10900項,花費8817秒
# 已完成22.3%分析-10950項,花費8858秒
# 已完成22.400000000000002%分析-11000項,花費8899秒
# 已完成22.5%分析-11050項,花費8944秒
# 已完成22.61%分析-11100項,花費8984秒
# 已完成22.71%分析-11150項,花費9026秒
# 已完成22.81%分析-11200項,花費9067秒
# 已完成22.91%分析-11250項,花費9109秒
# 已完成23.01%分析-11300項,花費9151秒
# 已完成23.11%分析-11350項,花費9197秒
# 已完成23.22%分析-11400項,花費9237秒
# 已完成23.32%分析-11450項,花費9278秒
# 已完成23.419999999999998%分析-11500項,花費9320秒
# 已完成23.52%分析-11550項,花費9361秒
# 已完成23.62%分析-11600項,花費9402秒
# 已完成23.73%分析-11650項,花費9446秒
# 已完成23.830000000000002%分析-11700項,花費9492秒
# 已完成23.93%分析-11750項,花費9536秒
# 已完成24.03%分析-11800項,花費9577秒
# 已完成24.13%分析-11850項,花費9620秒
# 已完成24.23%分析-11900項,花費9661秒
# 已完成24.34%分析-11950項,花費9702秒
# 已完成24.44%分析-12000項,花費9743秒
# 已完成24.54%分析-12050項,花費9788秒
# 已完成24.64%分析-12100項,花費9829秒
# 已完成24.740000000000002%分析-12150項,花費9872秒
# 已完成24.85%分析-12200項,花費9914秒
# 已完成24.95%分析-12250項,花費9955秒
# 已完成25.05%分析-12300項,花費9996秒
# 已完成25.15%分析-12350項,花費10037秒
# 已完成25.25%分析-12400項,花費10079秒
# 已完成25.35%分析-12450項,花費10121秒
# 已完成25.46%分析-12500項,花費10163秒
# 已完成25.56%分析-12550項,花費10203秒
# 已完成25.66%分析-12600項,花費10248秒
# 已完成25.759999999999998%分析-12650項,花費10289秒
# 已完成25.86%分析-12700項,花費10331秒
# 已完成25.97%分析-12750項,花費10373秒
# 已完成26.07%分析-12800項,花費10413秒
# 已完成26.169999999999998%分析-12850項,花費10455秒
# 已完成26.27%分析-12900項,花費10495秒
# 已完成26.369999999999997%分析-12950項,花費10535秒
# 已完成26.47%分析-13000項,花費10575秒
# 已完成26.58%分析-13050項,花費10616秒
# 已完成26.68%分析-13100項,花費10657秒
# 已完成26.779999999999998%分析-13150項,花費10697秒
# 已完成26.88%分析-13200項,花費10737秒
# 已完成26.979999999999997%分析-13250項,花費10779秒
# 已完成27.089999999999996%分析-13300項,花費10820秒
# 已完成27.189999999999998%分析-13350項,花費10860秒
# 已完成27.29%分析-13400項,花費10905秒
# 已完成27.389999999999997%分析-13450項,花費10950秒
# 已完成27.49%分析-13500項,花費10993秒
# 已完成27.6%分析-13550項,花費11034秒
# 已完成27.700000000000003%分析-13600項,花費11076秒
# 已完成27.800000000000004%分析-13650項,花費11119秒
# 已完成27.900000000000002%分析-13700項,花費11160秒
# 已完成28.000000000000004%分析-13750項,花費11201秒
# 已完成28.1%分析-13800項,花費11240秒
# 已完成28.21%分析-13850項,花費11280秒
# 已完成28.310000000000002%分析-13900項,花費11320秒
# 已完成28.410000000000004%分析-13950項,花費11360秒
# 已完成28.51%分析-14000項,花費11399秒
# 已完成28.610000000000003%分析-14050項,花費11443秒
# 已完成28.720000000000002%分析-14100項,花費11484秒
# 已完成28.82%分析-14150項,花費11524秒
# 已完成28.92%分析-14200項,花費11566秒
# 已完成29.020000000000003%分析-14250項,花費11611秒
# 已完成29.12%分析-14300項,花費11652秒
# 已完成29.220000000000002%分析-14350項,花費11692秒
# 已完成29.330000000000002%分析-14400項,花費11732秒
# 已完成29.43%分析-14450項,花費11771秒
# 已完成29.53%分析-14500項,花費11811秒
# 已完成29.630000000000003%分析-14550項,花費11850秒
# 已完成29.73%分析-14600項,花費11889秒
# 已完成29.84%分析-14650項,花費11929秒
# 已完成29.94%分析-14700項,花費11968秒
# 已完成30.04%分析-14750項,花費12008秒
# 已完成30.14%分析-14800項,花費12047秒
# 已完成30.240000000000002%分析-14850項,花費12087秒
# 已完成30.34%分析-14900項,花費12126秒
# 已完成30.45%分析-14950項,花費12165秒
# 已完成30.55%分析-15000項,花費12205秒
# 已完成30.65%分析-15050項,花費12244秒
# 已完成30.75%分析-15100項,花費12283秒
# 已完成30.85%分析-15150項,花費12323秒
# 已完成30.959999999999997%分析-15200項,花費12362秒
# 已完成31.06%分析-15250項,花費12401秒
# 已完成31.16%分析-15300項,花費12440秒
# 已完成31.259999999999998%分析-15350項,花費12479秒
# 已完成31.36%分析-15400項,花費12519秒
# 已完成31.46%分析-15450項,花費12559秒
# 已完成31.569999999999997%分析-15500項,花費12599秒
# 已完成31.669999999999998%分析-15550項,花費12638秒
# 已完成31.77%分析-15600項,花費12678秒
# 已完成31.869999999999997%分析-15650項,花費12718秒
# 已完成31.97%分析-15700項,花費12764秒
# 已完成32.08%分析-15750項,花費12803秒
# 已完成32.18%分析-15800項,花費12845秒
# 已完成32.28%分析-15850項,花費12887秒
# 已完成32.379999999999995%分析-15900項,花費12927秒
# 已完成32.48%分析-15950項,花費12969秒
# 已完成32.58%分析-16000項,花費13010秒
# 已完成32.690000000000005%分析-16050項,花費13055秒
# 已完成32.79%分析-16100項,花費13097秒
# 已完成32.89%分析-16150項,花費13139秒
# 已完成32.99%分析-16200項,花費13182秒
# 已完成33.09%分析-16250項,花費13221秒
# 已完成33.2%分析-16300項,花費13260秒
# 已完成33.300000000000004%分析-16350項,花費13300秒
# 已完成33.4%分析-16400項,花費13339秒
# 已完成33.5%分析-16450項,花費13378秒
# 已完成33.6%分析-16500項,花費13418秒
# 已完成33.7%分析-16550項,花費13460秒
# 已完成33.81%分析-16600項,花費13500秒
# 已完成33.910000000000004%分析-16650項,花費13540秒
# 已完成34.01%分析-16700項,花費13579秒
# 已完成34.11%分析-16750項,花費13620秒
# 已完成34.21%分析-16800項,花費13661秒
# 已完成34.32%分析-16850項,花費13703秒
# 已完成34.42%分析-16900項,花費13743秒
# 已完成34.52%分析-16950項,花費13783秒
# 已完成34.62%分析-17000項,花費13823秒
# 已完成34.72%分析-17050項,花費13862秒
# 已完成34.82%分析-17100項,花費13903秒
# 已完成34.93%分析-17150項,花費13945秒
# 已完成35.03%分析-17200項,花費13985秒
# 已完成35.13%分析-17250項,花費14025秒
# 已完成35.23%分析-17300項,花費14065秒
# 已完成35.33%分析-17350項,花費14105秒
# 已完成35.44%分析-17400項,花費14145秒
# 已完成35.54%分析-17450項,花費14184秒
# 已完成35.64%分析-17500項,花費14224秒
# 已完成35.74%分析-17550項,花費14265秒
# 已完成35.839999999999996%分析-17600項,花費14304秒
# 已完成35.94%分析-17650項,花費14344秒
# 已完成36.05%分析-17700項,花費14383秒
# 已完成36.15%分析-17750項,花費14423秒
# 已完成36.25%分析-17800項,花費14463秒
# 已完成36.35%分析-17850項,花費14502秒
# 已完成36.449999999999996%分析-17900項,花費14542秒
# 已完成36.559999999999995%分析-17950項,花費14581秒
# 已完成36.66%分析-18000項,花費14621秒
# 已完成36.76%分析-18050項,花費14665秒
# 已完成36.86%分析-18100項,花費14704秒
# 已完成36.96%分析-18150項,花費14744秒
# 已完成37.059999999999995%分析-18200項,花費14784秒
# 已完成37.169999999999995%分析-18250項,花費14824秒
# 已完成37.269999999999996%分析-18300項,花費14866秒
# 已完成37.37%分析-18350項,花費14907秒
# 已完成37.47%分析-18400項,花費14948秒
# 已完成37.57%分析-18450項,花費14988秒
# 已完成37.68%分析-18500項,花費15028秒
# 已完成37.78%分析-18550項,花費15068秒
# 已完成37.88%分析-18600項,花費15108秒
# 已完成37.980000000000004%分析-18650項,花費15151秒
# 已完成38.080000000000005%分析-18700項,花費15190秒
# 已完成38.190000000000005%分析-18750項,花費15231秒
# 已完成38.29%分析-18800項,花費15276秒
# 已完成38.39%分析-18850項,花費15316秒
# 已完成38.49%分析-18900項,花費15356秒
# 已完成38.59%分析-18950項,花費15397秒
# 已完成38.690000000000005%分析-19000項,花費15437秒
# 已完成38.800000000000004%分析-19050項,花費15478秒
# 已完成38.9%分析-19100項,花費15519秒
# 已完成39.0%分析-19150項,花費15560秒
# 已完成39.1%分析-19200項,花費15600秒
# 已完成39.2%分析-19250項,花費15640秒
# 已完成39.31%分析-19300項,花費15680秒
# 已完成39.410000000000004%分析-19350項,花費15720秒
# 已完成39.51%分析-19400項,花費15760秒
# 已完成39.61%分析-19450項,花費15799秒
# 已完成39.71%分析-19500項,花費15839秒
# 已完成39.81%分析-19550項,花費15878秒
# 已完成39.92%分析-19600項,花費15918秒
# 已完成40.02%分析-19650項,花費15958秒
# 已完成40.12%分析-19700項,花費15998秒
# 已完成40.22%分析-19750項,花費16037秒
# 已完成40.32%分析-19800項,花費16084秒
# 已完成40.43%分析-19850項,花費16126秒
# 已完成40.53%分析-19900項,花費16166秒
# 已完成40.63%分析-19950項,花費16208秒
# 已完成40.73%分析-20000項,花費16250秒
# 已完成40.83%分析-20050項,花費16297秒
# 已完成40.93%分析-20100項,花費16341秒
# 已完成41.04%分析-20150項,花費16385秒
# 已完成41.14%分析-20200項,花費16425秒
# 已完成41.24%分析-20250項,花費16465秒
# 已完成41.339999999999996%分析-20300項,花費16505秒
# 已完成41.44%分析-20350項,花費16545秒
# 已完成41.55%分析-20400項,花費16584秒
# 已完成41.65%分析-20450項,花費16625秒
# 已完成41.75%分析-20500項,花費16665秒
# 已完成41.85%分析-20550項,花費16705秒
# 已完成41.949999999999996%分析-20600項,花費16745秒
# 已完成42.05%分析-20650項,花費16784秒
# 已完成42.16%分析-20700項,花費16824秒
# 已完成42.26%分析-20750項,花費16864秒
# 已完成42.36%分析-20800項,花費16903秒
# 已完成42.46%分析-20850項,花費16943秒
# 已完成42.559999999999995%分析-20900項,花費16982秒
# 已完成42.67%分析-20950項,花費17022秒
# 已完成42.77%分析-21000項,花費17062秒
# 已完成42.870000000000005%分析-21050項,花費17102秒
# 已完成42.970000000000006%分析-21100項,花費17142秒
# 已完成43.07%分析-21150項,花費17181秒
# 已完成43.169999999999995%分析-21200項,花費17221秒
# 已完成43.28%分析-21250項,花費17261秒
# 已完成43.38%分析-21300項,花費17301秒
# 已完成43.480000000000004%分析-21350項,花費17340秒
# 已完成43.580000000000005%分析-21400項,花費17380秒
# 已完成43.68%分析-21450項,花費17420秒
# 已完成43.79%分析-21500項,花費17460秒
# 已完成43.89%分析-21550項,花費17499秒
# 已完成43.99%分析-21600項,花費17538秒
# 已完成44.09%分析-21650項,花費17579秒
# 已完成44.190000000000005%分析-21700項,花費17622秒
# 已完成44.29%分析-21750項,花費17668秒
# 已完成44.4%分析-21800項,花費17709秒
# 已完成44.5%分析-21850項,花費17748秒
# 已完成44.6%分析-21900項,花費17789秒
# 已完成44.7%分析-21950項,花費17829秒
# 已完成44.800000000000004%分析-22000項,花費17869秒
# 已完成44.91%分析-22050項,花費17914秒
# 已完成45.01%分析-22100項,花費17960秒
# 已完成45.11%分析-22150項,花費18004秒
# 已完成45.21%分析-22200項,花費18045秒
# 已完成45.31%分析-22250項,花費18087秒
# 已完成45.410000000000004%分析-22300項,花費18129秒
# 已完成45.519999999999996%分析-22350項,花費18171秒
# 已完成45.62%分析-22400項,花費18212秒
# 已完成45.72%分析-22450項,花費18254秒
# 已完成45.82%分析-22500項,花費18296秒
# 已完成45.92%分析-22550項,花費18338秒
# 已完成46.03%分析-22600項,花費18381秒
# 已完成46.129999999999995%分析-22650項,花費18423秒
# 已完成46.23%分析-22700項,花費18465秒
# 已完成46.33%分析-22750項,花費18506秒
# 已完成46.43%分析-22800項,花費18548秒
# 已完成46.53%分析-22850項,花費18588秒
# 已完成46.64%分析-22900項,花費18627秒
# 已完成46.739999999999995%分析-22950項,花費18667秒
# 已完成46.839999999999996%分析-23000項,花費18706秒
# 已完成46.94%分析-23050項,花費18745秒
# 已完成47.04%分析-23100項,花費18784秒
# 已完成47.15%分析-23150項,花費18824秒
# 已完成47.25%分析-23200項,花費18864秒
# 已完成47.349999999999994%分析-23250項,花費18904秒
# 已完成47.449999999999996%分析-23300項,花費18943秒
# 已完成47.55%分析-23350項,花費18983秒
# 已完成47.65%分析-23400項,花費19023秒
# 已完成47.760000000000005%分析-23450項,花費19063秒
# 已完成47.86%分析-23500項,花費19103秒
# 已完成47.96%分析-23550項,花費19143秒
# 已完成48.06%分析-23600項,花費19182秒
# 已完成48.16%分析-23650項,花費19221秒
# 已完成48.27%分析-23700項,花費19261秒
# 已完成48.370000000000005%分析-23750項,花費19300秒
# 已完成48.47%分析-23800項,花費19340秒
# 已完成48.57%分析-23850項,花費19379秒
# 已完成48.67%分析-23900項,花費19418秒
# 已完成48.78%分析-23950項,花費19458秒
# 已完成48.88%分析-24000項,花費19497秒
# 已完成48.980000000000004%分析-24050項,花費19541秒
# 已完成49.08%分析-24100項,花費19581秒
# 已完成49.18%分析-24150項,花費19620秒
# 已完成49.28%分析-24200項,花費19660秒
# 已完成49.39%分析-24250項,花費19699秒
# 已完成49.49%分析-24300項,花費19738秒
# 已完成49.59%分析-24350項,花費19777秒
# 已完成49.69%分析-24400項,花費19816秒
# 已完成49.79%分析-24450項,花費19855秒
# 已完成49.9%分析-24500項,花費19894秒
# 已完成50.0%分析-24550項,花費19934秒
# 已完成50.1%分析-24600項,花費19973秒
# 已完成50.2%分析-24650項,花費20012秒
# 已完成50.3%分析-24700項,花費20051秒
# 已完成50.4%分析-24750項,花費20090秒
# 已完成50.51%分析-24800項,花費20129秒
# 已完成50.61%分析-24850項,花費20168秒
# 已完成50.71%分析-24900項,花費20208秒
# 已完成50.81%分析-24950項,花費20247秒
# 已完成50.91%分析-25000項,花費20286秒
# 已完成51.019999999999996%分析-25050項,花費20325秒
# 已完成51.12%分析-25100項,花費20364秒
# 已完成51.22%分析-25150項,花費20403秒
# 已完成51.32%分析-25200項,花費20442秒
# 已完成51.42%分析-25250項,花費20483秒
# 已完成51.519999999999996%分析-25300項,花費20524秒
# 已完成51.629999999999995%分析-25350項,花費20565秒
# 已完成51.73%分析-25400項,花費20609秒
# 已完成51.83%分析-25450項,花費20653秒
# 已完成51.93%分析-25500項,花費20696秒
# 已完成52.03%分析-25550項,花費20737秒
# 已完成52.14%分析-25600項,花費20777秒
# 已完成52.239999999999995%分析-25650項,花費20819秒
# 已完成52.339999999999996%分析-25700項,花費20860秒
# 已完成52.44%分析-25750項,花費20900秒
# 已完成52.54%分析-25800項,花費20942秒
# 已完成52.64%分析-25850項,花費20983秒
# 已完成52.75%分析-25900項,花費21024秒
# 已完成52.849999999999994%分析-25950項,花費21069秒
# 已完成52.949999999999996%分析-26000項,花費21110秒
# 已完成53.05%分析-26050項,花費21155秒
# 已完成53.15%分析-26100項,花費21195秒
# 已完成53.26%分析-26150項,花費21235秒
# 已完成53.36%分析-26200項,花費21275秒
# 已完成53.459999999999994%分析-26250項,花費21315秒
# 已完成53.559999999999995%分析-26300項,花費21359秒
# 已完成53.66%分析-26350項,花費21403秒
# 已完成53.76%分析-26400項,花費21446秒
# 已完成53.87%分析-26450項,花費21487秒
# 已完成53.97%分析-26500項,花費21527秒
# 已完成54.06999999999999%分析-26550項,花費21567秒
# 已完成54.169999999999995%分析-26600項,花費21609秒
# 已完成54.269999999999996%分析-26650項,花費21650秒
# 已完成54.379999999999995%分析-26700項,花費21691秒
# 已完成54.48%分析-26750項,花費21732秒
# 已完成54.58%分析-26800項,花費21772秒
# 已完成54.67999999999999%分析-26850項,花費21813秒
# 已完成54.779999999999994%分析-26900項,花費21853秒
# 已完成54.879999999999995%分析-26950項,花費21893秒
# 已完成54.99000000000001%分析-27000項,花費21933秒
# 已完成55.089999999999996%分析-27050項,花費21973秒
# 已完成55.19%分析-27100項,花費22012秒
# 已完成55.28999999999999%分析-27150項,花費22052秒
# 已完成55.38999999999999%分析-27200項,花費22094秒
# 已完成55.50000000000001%分析-27250項,花費22137秒
# 已完成55.60000000000001%分析-27300項,花費22179秒
# 已完成55.7%分析-27350項,花費22224秒
# 已完成55.800000000000004%分析-27400項,花費22264秒
# 已完成55.900000000000006%分析-27450項,花費22305秒
# 已完成56.00000000000001%分析-27500項,花費22345秒
# 已完成56.11000000000001%分析-27550項,花費22384秒
# 已完成56.21000000000001%分析-27600項,花費22424秒
# 已完成56.31%分析-27650項,花費22463秒
# 已完成56.410000000000004%分析-27700項,花費22502秒
# 已完成56.510000000000005%分析-27750項,花費22542秒
# 已完成56.620000000000005%分析-27800項,花費22584秒
# 已完成56.720000000000006%分析-27850項,花費22623秒
# 已完成56.82000000000001%分析-27900項,花費22663秒
# 已完成56.92%分析-27950項,花費22702秒
# 已完成57.02%分析-28000項,花費22744秒
# 已完成57.120000000000005%分析-28050項,花費22792秒
# 已完成57.230000000000004%分析-28100項,花費22834秒
# 已完成57.330000000000005%分析-28150項,花費22874秒
# 已完成57.43000000000001%分析-28200項,花費22914秒
# 已完成57.53%分析-28250項,花費22952秒
# 已完成57.63%分析-28300項,花費22991秒
# 已完成57.74%分析-28350項,花費23030秒
# 已完成57.84%分析-28400項,花費23069秒
# 已完成57.940000000000005%分析-28450項,花費23108秒
# 已完成58.040000000000006%分析-28500項,花費23147秒
# 已完成58.14%分析-28550項,花費23186秒
# 已完成58.24%分析-28600項,花費23225秒
# 已完成58.35%分析-28650項,花費23264秒
# 已完成58.45%分析-28700項,花費23303秒
# 已完成58.550000000000004%分析-28750項,花費23342秒
# 已完成58.650000000000006%分析-28800項,花費23381秒
# 已完成58.75%分析-28850項,花費23420秒
# 已完成58.86%分析-28900項,花費23459秒
# 已完成58.96%分析-28950項,花費23499秒
# 已完成59.06%分析-29000項,花費23538秒
# 已完成59.160000000000004%分析-29050項,花費23577秒
# 已完成59.260000000000005%分析-29100項,花費23617秒
# 已完成59.37%分析-29150項,花費23657秒
# 已完成59.47%分析-29200項,花費23696秒
# 已完成59.57%分析-29250項,花費23736秒
# 已完成59.67%分析-29300項,花費23776秒
# 已完成59.77%分析-29350項,花費23815秒
# 已完成59.870000000000005%分析-29400項,花費23855秒
# 已完成59.98%分析-29450項,花費23895秒
# 已完成60.08%分析-29500項,花費23934秒
# 已完成60.18%分析-29550項,花費23974秒
# 已完成60.28%分析-29600項,花費24015秒
# 已完成60.38%分析-29650項,花費24056秒
# 已完成60.49%分析-29700項,花費24096秒
# 已完成60.589999999999996%分析-29750項,花費24136秒
# 已完成60.69%分析-29800項,花費24175秒
# 已完成60.79%分析-29850項,花費24215秒
# 已完成60.89%分析-29900項,花費24254秒
# 已完成60.99%分析-29950項,花費24294秒
# 已完成61.1%分析-30000項,花費24333秒
# 已完成61.199999999999996%分析-30050項,花費24378秒
# 已完成61.3%分析-30100項,花費24418秒
# 已完成61.4%分析-30150項,花費24458秒
# 已完成61.5%分析-30200項,花費24498秒
# 已完成61.61%分析-30250項,花費24543秒
# 已完成61.71%分析-30300項,花費24584秒
# 已完成61.809999999999995%分析-30350項,花費24625秒
# 已完成61.91%分析-30400項,花費24665秒
# 已完成62.01%分析-30450項,花費24706秒
# 已完成62.11%分析-30500項,花費24747秒
# 已完成62.22%分析-30550項,花費24789秒
# 已完成62.32%分析-30600項,花費24830秒
# 已完成62.419999999999995%分析-30650項,花費24872秒
# 已完成62.519999999999996%分析-30700項,花費24911秒
# 已完成62.62%分析-30750項,花費24951秒
# 已完成62.73%分析-30800項,花費24990秒
# 已完成62.83%分析-30850項,花費25029秒
# 已完成62.93%分析-30900項,花費25069秒
# 已完成63.029999999999994%分析-30950項,花費25109秒
# 已完成63.129999999999995%分析-31000項,花費25148秒
# 已完成63.23%分析-31050項,花費25189秒
# 已完成63.339999999999996%分析-31100項,花費25230秒
# 已完成63.44%分析-31150項,花費25271秒
# 已完成63.54%分析-31200項,花費25310秒
# 已完成63.63999999999999%分析-31250項,花費25350秒
# 已完成63.739999999999995%分析-31300項,花費25389秒
# 已完成63.849999999999994%分析-31350項,花費25429秒
# 已完成63.949999999999996%分析-31400項,花費25468秒
# 已完成64.05%分析-31450項,花費25508秒
# 已完成64.14999999999999%分析-31500項,花費25547秒
# 已完成64.25%分析-31550項,花費25589秒
# 已完成64.35%分析-31600項,花費25630秒
# 已完成64.46%分析-31650項,花費25670秒
# 已完成64.56%分析-31700項,花費25710秒
# 已完成64.66%分析-31750項,花費25750秒
# 已完成64.75999999999999%分析-31800項,花費25790秒
# 已完成64.86%分析-31850項,花費25830秒
# 已完成64.97%分析-31900項,花費25869秒
# 已完成65.07%分析-31950項,花費25909秒
# 已完成65.16999999999999%分析-32000項,花費25948秒
# 已完成65.27%分析-32050項,花費25992秒
# 已完成65.36999999999999%分析-32100項,花費26032秒
# 已完成65.47%分析-32150項,花費26071秒
# 已完成65.58%分析-32200項,花費26111秒
# 已完成65.68%分析-32250項,花費26150秒
# 已完成65.78%分析-32300項,花費26190秒
# 已完成65.88000000000001%分析-32350項,花費26229秒
# 已完成65.98%分析-32400項,花費26268秒
# 已完成66.09%分析-32450項,花費26307秒
# 已完成66.19%分析-32500項,花費26346秒
# 已完成66.29%分析-32550項,花費26385秒
# 已完成66.39%分析-32600項,花費26424秒
# 已完成66.49000000000001%分析-32650項,花費26463秒
# 已完成66.59%分析-32700項,花費26503秒
# 已完成66.7%分析-32750項,花費26542秒
# 已完成66.8%分析-32800項,花費26581秒
# 已完成66.9%分析-32850項,花費26620秒
# 已完成67.0%分析-32900項,花費26659秒
# 已完成67.10000000000001%分析-32950項,花費26698秒
# 已完成67.21000000000001%分析-33000項,花費26737秒
# 已完成67.31%分析-33050項,花費26776秒
# 已完成67.41%分析-33100項,花費26815秒
# 已完成67.51%分析-33150項,花費26854秒
# 已完成67.61%分析-33200項,花費26893秒
# 已完成67.71000000000001%分析-33250項,花費26932秒
# 已完成67.82000000000001%分析-33300項,花費26971秒
# 已完成67.92%分析-33350項,花費27010秒
# 已完成68.02%分析-33400項,花費27049秒
# 已完成68.12%分析-33450項,花費27088秒
# 已完成68.22%分析-33500項,花費27126秒
# 已完成68.33%分析-33550項,花費27165秒
# 已完成68.43%分析-33600項,花費27204秒
# 已完成68.53%分析-33650項,花費27243秒
# 已完成68.63%分析-33700項,花費27282秒
# 已完成68.73%分析-33750項,花費27321秒
# 已完成68.83%分析-33800項,花費27360秒
# 已完成68.94%分析-33850項,花費27399秒
# 已完成69.04%分析-33900項,花費27438秒
# 已完成69.14%分析-33950項,花費27477秒
# 已完成69.24%分析-34000項,花費27516秒
# 已完成69.34%分析-34050項,花費27559秒
# 已完成69.45%分析-34100項,花費27598秒
# 已完成69.55%分析-34150項,花費27637秒
# 已完成69.65%分析-34200項,花費27676秒
# 已完成69.75%分析-34250項,花費27715秒
# 已完成69.85%分析-34300項,花費27754秒
# 已完成69.95%分析-34350項,花費27793秒
# 已完成70.06%分析-34400項,花費27832秒
# 已完成70.16%分析-34450項,花費27871秒
# 已完成70.26%分析-34500項,花費27910秒
# 已完成70.36%分析-34550項,花費27948秒
# 已完成70.46%分析-34600項,花費27987秒
# 已完成70.57%分析-34650項,花費28026秒
# 已完成70.67%分析-34700項,花費28065秒
# 已完成70.77%分析-34750項,花費28104秒
# 已完成70.87%分析-34800項,花費28143秒
# 已完成70.97%分析-34850項,花費28182秒
# 已完成71.08%分析-34900項,花費28221秒
# 已完成71.17999999999999%分析-34950項,花費28259秒
# 已完成71.28%分析-35000項,花費28298秒
# 已完成71.38%分析-35050項,花費28337秒
# 已完成71.48%分析-35100項,花費28376秒
# 已完成71.58%分析-35150項,花費28415秒
# 已完成71.69%分析-35200項,花費28454秒
# 已完成71.78999999999999%分析-35250項,花費28493秒
# 已完成71.89%分析-35300項,花費28532秒
# 已完成71.99%分析-35350項,花費28571秒
# 已完成72.09%分析-35400項,花費28610秒
# 已完成72.2%分析-35450項,花費28649秒
# 已完成72.3%分析-35500項,花費28688秒
# 已完成72.39999999999999%分析-35550項,花費28727秒
# 已完成72.5%分析-35600項,花費28766秒
# 已完成72.6%分析-35650項,花費28805秒
# 已完成72.7%分析-35700項,花費28844秒
# 已完成72.81%分析-35750項,花費28883秒
# 已完成72.91%分析-35800項,花費28922秒
# 已完成73.00999999999999%分析-35850項,花費28961秒
# 已完成73.11%分析-35900項,花費29000秒
# 已完成73.21%分析-35950項,花費29039秒
# 已完成73.32%分析-36000項,花費29078秒
# 已完成73.42%分析-36050項,花費29122秒
# 已完成73.52%分析-36100項,花費29161秒
# 已完成73.61999999999999%分析-36150項,花費29200秒
# 已完成73.72%分析-36200項,花費29239秒
# 已完成73.82%分析-36250項,花費29278秒
# 已完成73.92999999999999%分析-36300項,花費29317秒
# 已完成74.03%分析-36350項,花費29356秒
# 已完成74.13%分析-36400項,花費29396秒
# 已完成74.22999999999999%分析-36450項,花費29434秒
# 已完成74.33%分析-36500項,花費29473秒
# 已完成74.44%分析-36550項,花費29512秒
# 已完成74.53999999999999%分析-36600項,花費29551秒
# 已完成74.64%分析-36650項,花費29590秒
# 已完成74.74%分析-36700項,花費29629秒
# 已完成74.83999999999999%分析-36750項,花費29668秒
# 已完成74.94%分析-36800項,花費29707秒
# 已完成75.05%分析-36850項,花費29746秒
# 已完成75.14999999999999%分析-36900項,花費29785秒
# 已完成75.25%分析-36950項,花費29823秒
# 已完成75.35%分析-37000項,花費29862秒
# 已完成75.44999999999999%分析-37050項,花費29901秒
# 已完成75.56%分析-37100項,花費29940秒
# 已完成75.66000000000001%分析-37150項,花費29979秒
# 已完成75.76%分析-37200項,花費30018秒
# 已完成75.86%分析-37250項,花費30056秒
# 已完成75.96000000000001%分析-37300項,花費30095秒
# 已完成76.06%分析-37350項,花費30135秒
# 已完成76.17%分析-37400項,花費30174秒
# 已完成76.27000000000001%分析-37450項,花費30213秒
# 已完成76.37%分析-37500項,花費30252秒
# 已完成76.47%分析-37550項,花費30291秒
# 已完成76.57000000000001%分析-37600項,花費30330秒
# 已完成76.68%分析-37650項,花費30369秒
# 已完成76.78%分析-37700項,花費30408秒
# 已完成76.88000000000001%分析-37750項,花費30447秒
# 已完成76.98%分析-37800項,花費30486秒
# 已完成77.08%分析-37850項,花費30525秒
# 已完成77.18%分析-37900項,花費30565秒
# 已完成77.29%分析-37950項,花費30604秒
# 已完成77.39%分析-38000項,花費30643秒
# 已完成77.49000000000001%分析-38050項,花費30687秒
# 已完成77.59%分析-38100項,花費30725秒
# 已完成77.69%分析-38150項,花費30764秒
# 已完成77.8%分析-38200項,花費30803秒
# 已完成77.9%分析-38250項,花費30842秒
# 已完成78.0%分析-38300項,花費30881秒
# 已完成78.10000000000001%分析-38350項,花費30920秒
# 已完成78.2%分析-38400項,花費30959秒
# 已完成78.3%分析-38450項,花費30997秒
# 已完成78.41%分析-38500項,花費31036秒
# 已完成78.51%分析-38550項,花費31075秒
# 已完成78.61%分析-38600項,花費31114秒
# 已完成78.71000000000001%分析-38650項,花費31153秒
# 已完成78.81%分析-38700項,花費31192秒
# 已完成78.92%分析-38750項,花費31231秒
# 已完成79.02%分析-38800項,花費31270秒
# 已完成79.12%分析-38850項,花費31309秒
# 已完成79.22%分析-38900項,花費31348秒
# 已完成79.32000000000001%分析-38950項,花費31387秒
# 已完成79.42%分析-39000項,花費31426秒
# 已完成79.53%分析-39050項,花費31464秒
# 已完成79.63%分析-39100項,花費31503秒
# 已完成79.73%分析-39150項,花費31542秒
# 已完成79.83%分析-39200項,花費31581秒
# 已完成79.93%分析-39250項,花費31620秒
# 已完成80.04%分析-39300項,花費31659秒
# 已完成80.14%分析-39350項,花費31698秒
# 已完成80.24%分析-39400項,花費31737秒
# 已完成80.34%分析-39450項,花費31776秒
# 已完成80.44%分析-39500項,花費31814秒
# 已完成80.54%分析-39550項,花費31853秒
# 已完成80.65%分析-39600項,花費31892秒
# 已完成80.75%分析-39650項,花費31931秒
# 已完成80.85%分析-39700項,花費31970秒
# 已完成80.95%分析-39750項,花費32009秒
# 已完成81.05%分析-39800項,花費32048秒
# 已完成81.16%分析-39850項,花費32087秒
# 已完成81.26%分析-39900項,花費32126秒
# 已完成81.36%分析-39950項,花費32165秒
# 已完成81.46%分析-40000項,花費32204秒
# 已完成81.56%分析-40050項,花費32247秒
# 已完成81.67%分析-40100項,花費32286秒
# 已完成81.77%分析-40150項,花費32325秒
# 已完成81.87%分析-40200項,花費32364秒
# 已完成81.97%分析-40250項,花費32402秒
# 已完成82.07%分析-40300項,花費32441秒
# 已完成82.17%分析-40350項,花費32480秒
# 已完成82.28%分析-40400項,花費32519秒
# 已完成82.38%分析-40450項,花費32557秒
# 已完成82.48%分析-40500項,花費32596秒
# 已完成82.58%分析-40550項,花費32635秒
# 已完成82.67999999999999%分析-40600項,花費32675秒
# 已完成82.78999999999999%分析-40650項,花費32713秒
# 已完成82.89%分析-40700項,花費32752秒
# 已完成82.99%分析-40750項,花費32791秒
# 已完成83.09%分析-40800項,花費32830秒
# 已完成83.19%分析-40850項,花費32868秒
# 已完成83.28999999999999%分析-40900項,花費32907秒
# 已完成83.39999999999999%分析-40950項,花費32946秒
# 已完成83.5%分析-41000項,花費32985秒
# 已完成83.6%分析-41050項,花費33024秒
# 已完成83.7%分析-41100項,花費33063秒
# 已完成83.8%分析-41150項,花費33102秒
# 已完成83.91%分析-41200項,花費33141秒
# 已完成84.00999999999999%分析-41250項,花費33180秒
# 已完成84.11%分析-41300項,花費33219秒
# 已完成84.21%分析-41350項,花費33258秒
# 已完成84.31%分析-41400項,花費33296秒
# 已完成84.41%分析-41450項,花費33335秒
# 已完成84.52%分析-41500項,花費33374秒
# 已完成84.61999999999999%分析-41550項,花費33413秒
# 已完成84.72%分析-41600項,花費33451秒
# 已完成84.82%分析-41650項,花費33490秒
# 已完成84.92%分析-41700項,花費33529秒
# 已完成85.03%分析-41750項,花費33568秒
# 已完成85.13%分析-41800項,花費33607秒
# 已完成85.22999999999999%分析-41850項,花費33646秒
# 已完成85.33%分析-41900項,花費33684秒
# 已完成85.42999999999999%分析-41950項,花費33723秒
# 已完成85.53%分析-42000項,花費33762秒
# 已完成85.64%分析-42050項,花費33806秒
# 已完成85.74000000000001%分析-42100項,花費33845秒
# 已完成85.84%分析-42150項,花費33883秒
# 已完成85.94000000000001%分析-42200項,花費33922秒
# 已完成86.04%分析-42250項,花費33961秒
# 已完成86.15%分析-42300項,花費34000秒
# 已完成86.25%分析-42350項,花費34038秒
# 已完成86.35000000000001%分析-42400項,花費34077秒
# 已完成86.45%分析-42450項,花費34116秒
# 已完成86.55000000000001%分析-42500項,花費34155秒
# 已完成86.65%分析-42550項,花費34194秒
# 已完成86.76%分析-42600項,花費34233秒
# 已完成86.86%分析-42650項,花費34271秒
# 已完成86.96000000000001%分析-42700項,花費34310秒
# 已完成87.06%分析-42750項,花費34348秒
# 已完成87.16000000000001%分析-42800項,花費34387秒
# 已完成87.27000000000001%分析-42850項,花費34426秒
# 已完成87.37%分析-42900項,花費34464秒
# 已完成87.47%分析-42950項,花費34503秒
# 已完成87.57000000000001%分析-43000項,花費34542秒
# 已完成87.67%分析-43050項,花費34581秒
# 已完成87.77000000000001%分析-43100項,花費34619秒
# 已完成87.88%分析-43150項,花費34658秒
# 已完成87.98%分析-43200項,花費34697秒
# 已完成88.08%分析-43250項,花費34735秒
# 已完成88.18%分析-43300項,花費34774秒
# 已完成88.28%分析-43350項,花費34813秒
# 已完成88.39%分析-43400項,花費34852秒
# 已完成88.49000000000001%分析-43450項,花費34891秒
# 已完成88.59%分析-43500項,花費34930秒
# 已完成88.69%分析-43550項,花費34968秒
# 已完成88.79%分析-43600項,花費35007秒
# 已完成88.89%分析-43650項,花費35046秒
# 已完成89.0%分析-43700項,花費35085秒
# 已完成89.1%分析-43750項,花費35123秒
# 已完成89.2%分析-43800項,花費35162秒
# 已完成89.3%分析-43850項,花費35201秒
# 已完成89.4%分析-43900項,花費35240秒
# 已完成89.51%分析-43950項,花費35279秒
# 已完成89.61%分析-44000項,花費35317秒
# 已完成89.71000000000001%分析-44050項,花費35361秒
# 已完成89.81%分析-44100項,花費35400秒
# 已完成89.91%分析-44150項,花費35438秒
# 已完成90.01%分析-44200項,花費35477秒
# 已完成90.12%分析-44250項,花費35516秒
# 已完成90.22%分析-44300項,花費35554秒
# 已完成90.32%分析-44350項,花費35593秒
# 已完成90.42%分析-44400項,花費35632秒
# 已完成90.52%分析-44450項,花費35671秒
# 已完成90.63%分析-44500項,花費35709秒
# 已完成90.73%分析-44550項,花費35748秒
# 已完成90.83%分析-44600項,花費35787秒
# 已完成90.93%分析-44650項,花費35825秒
# 已完成91.03%分析-44700項,花費35864秒
# 已完成91.13%分析-44750項,花費35903秒
# 已完成91.24%分析-44800項,花費35941秒
# 已完成91.34%分析-44850項,花費35980秒
# 已完成91.44%分析-44900項,花費36019秒
# 已完成91.53999999999999%分析-44950項,花費36057秒
# 已完成91.64%分析-45000項,花費36096秒
# 已完成91.75%分析-45050項,花費36134秒
# 已完成91.85%分析-45100項,花費36173秒
# 已完成91.95%分析-45150項,花費36211秒
# 已完成92.05%分析-45200項,花費36250秒
# 已完成92.15%分析-45250項,花費36289秒
# 已完成92.25999999999999%分析-45300項,花費36328秒
# 已完成92.36%分析-45350項,花費36366秒
# 已完成92.46%分析-45400項,花費36405秒
# 已完成92.56%分析-45450項,花費36444秒
# 已完成92.66%分析-45500項,花費36482秒
# 已完成92.75999999999999%分析-45550項,花費36521秒
# 已完成92.86999999999999%分析-45600項,花費36560秒
# 已完成92.97%分析-45650項,花費36599秒
# 已完成93.07%分析-45700項,花費36638秒
# 已完成93.17%分析-45750項,花費36677秒
# 已完成93.27%分析-45800項,花費36716秒
# 已完成93.38%分析-45850項,花費36755秒
# 已完成93.47999999999999%分析-45900項,花費36793秒
# 已完成93.58%分析-45950項,花費36832秒
# 已完成93.67999999999999%分析-46000項,花費36871秒
# 已完成93.78%分析-46050項,花費36915秒
# 已完成93.88%分析-46100項,花費36954秒
# 已完成93.99%分析-46150項,花費36992秒
# 已完成94.08999999999999%分析-46200項,花費37030秒
# 已完成94.19%分析-46250項,花費37069秒
# 已完成94.28999999999999%分析-46300項,花費37108秒
# 已完成94.39%分析-46350項,花費37147秒
# 已完成94.5%分析-46400項,花費37185秒
# 已完成94.6%分析-46450項,花費37224秒
# 已完成94.69999999999999%分析-46500項,花費37262秒
# 已完成94.8%分析-46550項,花費37301秒
# 已完成94.89999999999999%分析-46600項,花費37339秒
# 已完成95.0%分析-46650項,花費37378秒
# 已完成95.11%分析-46700項,花費37416秒
# 已完成95.21%分析-46750項,花費37455秒
# 已完成95.30999999999999%分析-46800項,花費37494秒
# 已完成95.41%分析-46850項,花費37532秒
# 已完成95.50999999999999%分析-46900項,花費37571秒
# 已完成95.62%分析-46950項,花費37609秒
# 已完成95.72%分析-47000項,花費37648秒
# 已完成95.82000000000001%分析-47050項,花費37687秒
# 已完成95.92%分析-47100項,花費37726秒
# 已完成96.02000000000001%分析-47150項,花費37764秒
# 已完成96.12%分析-47200項,花費37803秒
# 已完成96.23%分析-47250項,花費37842秒
# 已完成96.33%分析-47300項,花費37881秒
# 已完成96.43%分析-47350項,花費37919秒
# 已完成96.53%分析-47400項,花費37958秒
# 已完成96.63000000000001%分析-47450項,花費37997秒
# 已完成96.74000000000001%分析-47500項,花費38036秒
# 已完成96.84%分析-47550項,花費38074秒
# 已完成96.94%分析-47600項,花費38113秒
# 已完成97.04%分析-47650項,花費38152秒
# 已完成97.14%分析-47700項,花費38190秒
# 已完成97.24000000000001%分析-47750項,花費38229秒
# 已完成97.35000000000001%分析-47800項,花費38268秒
# 已完成97.45%分析-47850項,花費38307秒
# 已完成97.55%分析-47900項,花費38346秒
# 已完成97.65%分析-47950項,花費38384秒
# 已完成97.75%分析-48000項,花費38423秒
# 已完成97.86%分析-48050項,花費38467秒
# 已完成97.96000000000001%分析-48100項,花費38505秒
# 已完成98.06%分析-48150項,花費38544秒
# 已完成98.16%分析-48200項,花費38583秒
# 已完成98.26%分析-48250項,花費38622秒
# 已完成98.36%分析-48300項,花費38661秒
# 已完成98.47%分析-48350項,花費38699秒
# 已完成98.57000000000001%分析-48400項,花費38738秒
# 已完成98.67%分析-48450項,花費38777秒
# 已完成98.77%分析-48500項,花費38816秒
# 已完成98.87%分析-48550項,花費38854秒
# 已完成98.98%分析-48600項,花費38893秒
# 已完成99.08%分析-48650項,花費38932秒
# 已完成99.18%分析-48700項,花費38971秒
# 已完成99.28%分析-48750項,花費39010秒
# 已完成99.38%分析-48800項,花費39049秒
# 已完成99.48%分析-48850項,花費39088秒
# 已完成99.59%分析-48900項,花費39126秒
# 已完成99.69%分析-48950項,花費39165秒
# 已完成99.79%分析-49000項,花費39204秒
# 已完成99.89%分析-49050項,花費39243秒
# 已完成99.99%分析-49100項,花費39281秒
# 39284.56391501427
# 39289.78391480446

# %%
for i in TWLocs:
    score=0
    if i['NclinicData_Analyze']>20:
        score+=2
    elif i['NclinicData_Analyze']>9:
        score+=1
    if i['NconStore_Analyze']>11:
        score+=2
    elif i['NconStore_Analyze']>5:
        score+=1
    if i['Npxmart_Analyze']+i['Nwatson_Analyze']>2:
        score+=2
    elif i['Npxmart_Analyze']+i['Nwatson_Analyze']>0:
        score+=1

    if i['NsimCostDien']>3:
        score+=3
    elif i['NsimCostDien']>2:
        score+=2
    elif i['NsimCostDien']>1:
        score+=1
    if i['NtStore_Analyze']+i["NDapu_analyze"]>0:
        score+=1
    i['score']=score


# e = time.time()
# print(e-b)


# #     client.close()
# client = pymongo.mongo_client.MongoClient("192.168.1.113", 27017, username='j122085', password='850605')
# collection = client.rawData.taiwanInfoHot7
# ids=["{}_{}".format(i['lat'],i['lng']) for i in TWLocs]
# operations=[UpdateOne({"_id":idn},{'$set':data},upsert=True) for idn ,data in zip(ids,TWLocs)]
# try:
#     collection.bulk_write(operations ,ordered=False)
# except Exception as er:
#     print(er)
# client.close()

# %%
# client = pymongo.mongo_client.MongoClient("localhost", 27017, username='j122085', password='850605')
# collection = client.rawData.taiwanInfoHot7
# hot7Data=list(collection.find({},{"_id":False}))

# %%
# import pandas as pd
# df=pd.DataFrame(hot7Data)
# f = pd.ExcelWriter(r'D:\outputXLS\outputHot7-3.xlsx')
# df.to_excel(f,header=True)
# f.save()

# %% [markdown]
# # 備份ServerData到本機

# %%
import pymongo
from pymongo import UpdateOne
client = pymongo.mongo_client.MongoClient("192.168.1.113", 27017, username='j122085', password='850605')
db=client.rawData

client2 = pymongo.mongo_client.MongoClient("localhost", 27017, username='j122085', password='850605')
db2=client2.rawData
for j in db.collection_names():
    datas=list(db[j].find())
    ids=[i.pop("_id") for i in datas]
    operations=[UpdateOne({"_id":idn},{'$set':data},upsert=True) for idn ,data in zip(ids,datas)]
    try:
        db2[j].bulk_write(operations ,ordered=False)
    except Exception as er:
        print(er)
client.close()
# Out:
# batch op errors occurred
# batch op errors occurred
