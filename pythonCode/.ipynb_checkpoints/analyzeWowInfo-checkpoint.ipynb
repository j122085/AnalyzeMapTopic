# %%
import json
import pymongo
from math import radians, cos, sin, asin, sqrt
import numpy
import math
from collections import Counter

# %%
def haversine(lng1, lat1, lng2, lat2):
    # 将十进制度数转化为弧度
    lng1, lat1, lng2, lat2 = map(radians, [lng1, lat1, lng2, lat2])
    # haversine公式
    dlng = lng2 - lng1
    dlat = lat2 - lat1
    a = sin(dlat / 2) ** 2 + cos(lat1) * cos(lat2) * sin(dlng / 2) ** 2
    c = 2 * asin(sqrt(a))
    r = 6371  # 地球平均半径，单位为公里
    return c * r * 1000

# %%
queryElements={}
client = pymongo.mongo_client.MongoClient("localhost", 27017,username='j122085',password='850605')
db=client.rawData
db.collection_names()
# Out:
# ['Watsons',
#  'busData',
#  'HRdata104',
#  'wowprimediendata',
#  'info591',
#  'departmentStore',
#  'websites591',
#  'taiwanInfo',
#  'smallStyleCount',
#  'addressCoordinate',
#  'Nhuman',
#  'ipeenWebsite',
#  'bigStyleCount',
#  'ipeenInfo',
#  'conStore',
#  'testDB',
#  'CostPower']

# %%
# collection = client.rawData.wowprimeipeen
collection = client.rawData.ipeenInfo
ipeendata = list(collection.find(queryElements))
client.close()
ipeendata = [dien for dien in ipeendata if dien['status'] == "正常營業"
                                         and dien['lat'] > 18
                                         and dien['lat'] < 27
                                         and dien['lng'] < 125
                                         and dien['lng'] > 117
                                         and dien['bigadd'] != 0
                                         and dien['smalladd'] != 0
                                         and dien['averagecost']<8000]

for dien in ipeendata:
    dien["id"] = dien.pop("_id")
ipeendata[3]
# Out:
# {'Ncomment': 118,
#  'address': '台北市信義區忠孝東路五段10號10樓',
#  'averagecost': 1210,
#  'bigadd': '台北市',
#  'bigstyle': 'buffet自助餐',
#  'collecount': 739,
#  'comments': ['http://www.ipeen.com.tw/comment/1360256',
#   'http://www.ipeen.com.tw/comment/1260569',
#   'http://www.ipeen.com.tw/comment/1241048',
#   'http://www.ipeen.com.tw/comment/1197122',
#   'http://www.ipeen.com.tw/comment/1186946'],
#  'id': 95584,
#  'ipeenscore': 45,
#  'lat': 25.040763368711964,
#  'lng': 121.56571445244984,
#  'name': '台北W飯店 - the kitchen table 西餐廳',
#  'reviewdate': '2016/09/01',
#  'smalladd': '信義區',
#  'smallstyle': '複合式',
#  'status': '正常營業',
#  'tele': '0277038887',
#  'url': 'http://www.ipeen.com.tw/shop/95584',
#  'viewcount': 8987274}

# %%
client = pymongo.mongo_client.MongoClient("localhost", 27017,username='j122085',password='850605')
collection = client.rawData.HRdata104
hr104data = list(collection.find(queryElements))
client.close()
hr104data = [dien for dien in hr104data if dien['LAT'] > 18
             and dien['LAT'] < 27
             and dien['SAL_MONTH_LOW'] > 18000
             and dien['SAL_MONTH_LOW'] < 100000
             and dien['SAL_MONTH_HIGH'] > 18000
             and dien['SAL_MONTH_HIGH'] < 200000
             and dien['LON'] < 125
             and dien['LON'] > 117
             and dien['bigadd'] != 0
             and dien['smalladd'] != 0]



for dien in hr104data:
    dien["lat"] = dien.pop("LAT")
    dien["lng"] = dien.pop("LON")
    del dien["_id"]
hr104data[5]
# Out:
# {'APPEAR_DATE': '20180222',
#  'DESCRIPTION': '陶板屋台北重慶南店\n誠    徵：大廳計時人員\n工作內容：協助現場顧客服務、外場營運協助等。\n工作時段：(依營運需求彈性排班,工作時間面試詳洽)\n\n◎ 全日班-1名\n(10:30~14:30 及 17:00~22:00)\n◎ 假日班-1名\n(10:30~14:30 及 17:00~22:00) \n◎ 早班-1名\n(10:30~14:30)\n◎ 晚班-1名\n(17:00~22:00)\n\n學/經 歷：高中職以上,具服務熱忱。',
#  'J': '4460426b56363f5631323a6344543618638704226443640212121211f382b2625381j52',
#  'JOB': '陶板屋台北重慶南店-大廳計時人員',
#  'JOBCAT_DESCRIPT': '餐飲服務生',
#  'JOB_ADDRESS': '重慶南路一段58號2樓',
#  'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#  'NAME': '王品餐飲股份有限公司',
#  'SAL_MONTH_HIGH': 26400,
#  'SAL_MONTH_LOW': 24800,
#  'bigadd': '台北市',
#  'bigstyle': '咖啡、簡餐、茶',
#  'lat': 25.043903,
#  'lng': 121.513078,
#  'smalladd': '中正區'}

# %%
client = pymongo.mongo_client.MongoClient("localhost", 27017,username='j122085',password='850605')
collection = client.rawData.Nhuman
Nhumandata = list(collection.find(queryElements))
client.close()
for dien in Nhumandata:
    dien["weight"] = int(dien.pop("Nhuman"))
    dien["add"] = dien.pop("_id")
Nhumandata[5]
# Out:
# {'add': '新北市板橋區新興里',
#  'bigadd': '新北市',
#  'lat': 25.0076421,
#  'lng': 121.4549022,
#  'smalladd': '板橋區',
#  'weight': 3337}

# %%
client = pymongo.mongo_client.MongoClient("localhost", 27017,username='j122085',password='850605')
collection = client.rawData.CostPower
CostPowerdata = list(collection.find(queryElements))
client.close()
for dien in CostPowerdata:
    dien["weight"] = int(dien.pop('costPower'))
    dien["add"] = dien.pop("_id")
CostPowerdata[5]
# Out:
# {'add': '臺北市士林區舊佳里',
#  'bigadd': '台北市',
#  'lat': 25.0973296,
#  'lng': 121.5248678,
#  'smalladd': '士林區',
#  'weight': 68}

# %%
client = pymongo.mongo_client.MongoClient("localhost", 27017,username='j122085',password='850605')
collection = client.rawData.busData
busData = list(collection.find(queryElements))
client.close()
busData[5]
# ['busData',
#  'HRdata104',
#  'wowprimediendata',
#  'departmentStore',
#  'smallStyleCount',
#  'addressCoordinate',
#  'Nhuman',
#  'ipeenWebsite',
#  'bigStyleCount',
#  'ipeenInfo',
#  'conStore',
#  'testDB',
#  'CostPower']
# Out:
# {'_id': '東新國小',
#  'bigCity': '臺北市',
#  'lat': 25.05746843,
#  'lng': 121.6020404,
#  'stationName': '東新國小'}

# %%
client = pymongo.mongo_client.MongoClient("localhost", 27017,username='j122085',password='850605')
collection = client.rawData.conStore
busData = list(collection.find(queryElements))
client.close()
busData[5]
# Out:
# {'_id': '高雄市前鎮區草衙里后安路１４６',
#  'add': '高雄市前鎮區草衙里后安路１４６',
#  'bigadd': '高雄市',
#  'lat': '25.086368784991',
#  'lng': '121.52553924517',
#  'name': '統一超商股份有限公司',
#  'smalladd': '前鎮區'}

# %%
client = pymongo.mongo_client.MongoClient("localhost", 27017, username='j122085', password='850605')
collection = client.rawData.wowprimediendata
wowDiensData = list(collection.find({'CloseDate':'None',"lat": {"$gt": 1}}))
wowDiensData=[dien for dien in wowDiensData if "A" not in dien['StoreNo'] and dien['StoreNo'][0]!='3']
wowDiensData[0]
# Out:
# {'Address': '新北市新店區民權路86號2樓',
#  'AreaManager': '王至誠',
#  'Called': '原燒',
#  'CareerName': '原燒事業處',
#  'CareerNo': '102',
#  'Chef': '郭炳志',
#  'CloseDate': 'None',
#  'CodeId': 'F',
#  'CorporationId': '27492204',
#  'Corporation_ch': '原燒新店民權分公司',
#  'CreateDate': '2018-02-02 08:46:12.987000',
#  'ItemName': '百貨點',
#  'Manager': '吳憲政',
#  'NbusStation_Analyze': 10,
#  'NconStore_Analyze': 133,
#  'NcostData_Analyze': 27,
#  'Nhuman_Analyze': 243950,
#  'Njob_Analyze': 103,
#  'Nken_Analyze': 2,
#  'Nmc_Analyze': 5,
#  'Nstar_Analyze': 5,
#  'Nwa_Analyze': 1,
#  'Phone': '02-22191613',
#  'PlaceNo': '33',
#  'StoreName': '新店民權',
#  'StoreNo': '10202',
#  '_id': '10202',
#  'areaRadius_Analyze': 2000,
#  'avgCost_Analyze': 121.0,
#  'avgDailyCustomer': 143,
#  'avgDailyMeal': 119,
#  'avgDailyNet': 93184,
#  'avgSalary_Analyze': 29884.0,
#  'bigadd': '新北市',
#  'costPower_Analyze': 49.0,
#  'income': '5000000',
#  'lastYearRevenue': 33066877,
#  'lat': 24.9832568,
#  'lng': 121.5370956,
#  'mostStyle_Analyze': '中式料理',
#  'smalladd': '新店區'}

# %%
x=[]
queryDien=input("請輸入品牌名稱:")
radius=int(input("半徑範圍(公尺):"))
if queryDien!="":
    wowData=[i for i in wowDiensData if i['Called']==queryDien]
else:
    wowData=wowDiensData
    queryDien="全品牌"
print("有{}筆資料要分析".format(len(wowData)))
n=0
# Out:
# 請輸入品牌名稱:
# 半徑範圍(公尺):2000
# 有276筆資料要分析

# %%
wowDien=wowData[0]
wowDien
# Out:
# {'Address': '新北市新店區民權路86號2樓',
#  'AreaManager': '王至誠',
#  'Called': '原燒',
#  'CareerName': '原燒事業處',
#  'CareerNo': '102',
#  'Chef': '郭炳志',
#  'CloseDate': 'None',
#  'CodeId': 'F',
#  'CorporationId': '27492204',
#  'Corporation_ch': '原燒新店民權分公司',
#  'CreateDate': '2018-02-02 08:46:12.987000',
#  'ItemName': '百貨點',
#  'Manager': '吳憲政',
#  'NbusStation_Analyze': 10,
#  'NconStore_Analyze': 133,
#  'NcostData_Analyze': 27,
#  'Nhuman_Analyze': 243950,
#  'Njob_Analyze': 103,
#  'Nken_Analyze': 2,
#  'Nmc_Analyze': 5,
#  'Nstar_Analyze': 5,
#  'Nwa_Analyze': 1,
#  'Phone': '02-22191613',
#  'PlaceNo': '33',
#  'StoreName': '新店民權',
#  'StoreNo': '10202',
#  '_id': '10202',
#  'areaRadius_Analyze': 2000,
#  'avgCost_Analyze': 121.0,
#  'avgDailyCustomer': 143,
#  'avgDailyMeal': 119,
#  'avgDailyNet': 93184,
#  'avgSalary_Analyze': 29884.0,
#  'bigadd': '新北市',
#  'costPower_Analyze': 49.0,
#  'income': '5000000',
#  'lastYearRevenue': 33066877,
#  'lat': 24.9832568,
#  'lng': 121.5370956,
#  'mostStyle_Analyze': '中式料理',
#  'smalladd': '新店區'}

# %%
rangeCost=1.3
NsimCostDien=len([dien['averagecost'] for dien in ipeendata if haversine(lng1=dien["lng"],
                                                                 lat1=dien["lat"],
                                                                 lng2=wowDien["lng"],
                                                                 lat2=wowDien["lat"]) <= radius
                                                and dien['averagecost']<(wowDien['avgDailyNet']/wowDien['avgDailyCustomer'])*rangeCost
                                                and dien['averagecost']>(wowDien['avgDailyNet']/wowDien['avgDailyCustomer'])/rangeCost] )
NsimCostDien
# Out:
# 47

# %%
x=650
y=1.4
round(x*y),round(x/y)
# Out:
# (910, 464)

# %%
wowDien['avgDailyNet']/wowDien['avgDailyCustomer']
# Out:
# 651.6363636363636

# %%
[dien['averagecost'] for dien in ipeendata if haversine(lng1=dien["lng"],
                                                                 lat1=dien["lat"],
                                                                 lng2=wowDien["lng"],
                                                                 lat2=wowDien["lat"]) <= radius
                                                and dien['averagecost']<(wowDien['avgDailyNet']/wowDien['avgDailyCustomer'])*rangeCost
                                                and dien['averagecost']>(wowDien['avgDailyNet']/wowDien['avgDailyCustomer'])/rangeCost]
# Out:
# [709,
#  495,
#  594,
#  502,
#  696,
#  600,
#  727,
#  552,
#  537,
#  595,
#  530,
#  790,
#  687,
#  534,
#  617,
#  475,
#  600,
#  806,
#  628,
#  484,
#  600,
#  503,
#  729,
#  475,
#  560,
#  622,
#  480,
#  616,
#  591,
#  600,
#  503,
#  472,
#  520,
#  743,
#  470,
#  483,
#  600,
#  682,
#  533,
#  554,
#  573,
#  728,
#  700,
#  500,
#  485,
#  500,
#  500]

# %%
wowDiensData

# %%
set([i['Called'] for i in wowDiensData])
# Out:
# {'CooK BEEF!',
#  'hot 7',
#  'ita義塔',
#  '乍牛',
#  '其他事業處',
#  '原燒',
#  '品田牧場',
#  '夏慕尼',
#  '沐越',
#  '王品',
#  '石二鍋',
#  '聚',
#  '舒果',
#  '舒果新加坡',
#  '莆田',
#  '蔬果截切配送中心',
#  '藝奇',
#  '陶板屋',
#  '青花驕',
#  '麻佬大',
#  'ＴＡＳＴｙ'}

# %%
    
mapType={'CooK BEEF!':'異國料理',
 'hot 7':'燒烤類',
 'ita義塔':'異國料理',
 '乍牛':'日式料理',
 '原燒':'燒烤類',
 '品田牧場':'日式料理',
 '夏慕尼':'燒烤類',
 '沐越':'亞洲料理',
 '王品':'異國料理',
 '石二鍋':'鍋類',
 '聚':'鍋類',
 '舒果':'素食',
 '莆田':'亞洲料理',
 '藝奇':'日式料理',
 '陶板屋':'日式料理',
 '青花驕':'鍋類',
 '麻佬大':'小吃',
 'ＴＡＳＴｙ':'異國料理'}

# %%
import numpy
import math
from collections import Counter
x=[]
queryDien=input("請輸入品牌名稱:")
radius=int(input("半徑範圍(公尺):"))
if queryDien!="":
    wowData=[i for i in wowDiensData if i['Called']==queryDien]
else:
    wowData=wowDiensData
    queryDien="全品牌"
print("有{}筆資料要分析".format(len(wowData)))
n=0
for wowDien in wowData:
    n+=1
    if n%30==0:
        print("已完成{}項分析".format(n))
    y={}
    y['店代號']=wowDien["_id"]
    y["事業處"]=wowDien['Called']
    y["分店名"]=wowDien['StoreName']
    y["地址"]=wowDien['Address']
    y['電話']=wowDien['Phone']
#     y["區管理者"]=wowDien['AreaManager']
#     y["廚師"]=wowDien['Chef']
    try:
        y['每日均_營收淨額(ADS)']=wowDien['avgDailyNet']
        y['每日均_顧客量(ADGC)']=wowDien['avgDailyCustomer']
#         y['每日均_客量']=wowDien['avgDailyMeal']
    except:
        pass
    y["半徑範圍(公尺)"]=radius
    
    
    dienCostPower = round(numpy.mean([dien['weight'] for dien in CostPowerdata if haversine(lng1=dien["lng"],
                                                                 lat1=dien["lat"],
                                                                 lng2=wowDien["lng"],
                                                                 lat2=wowDien["lat"]) <= radius]))
    if not math.isnan(dienCostPower):
        y["消費力"]=dienCostPower
        
    y["消費力筆數"]=len([dien['weight'] for dien in CostPowerdata if haversine(lng1=dien["lng"],
                                                                 lat1=dien["lat"],
                                                                 lng2=wowDien["lng"],
                                                                 lat2=wowDien["lat"]) <= radius])
    
    
    dienHuman = sum([dien['weight'] for dien in Nhumandata if haversine(lng1=dien["lng"],
                                                                 lat1=dien["lat"],
                                                                 lng2=wowDien["lng"],
                                                                 lat2=wowDien["lat"]) <= radius])
    y['人口數']=dienHuman 
    
    
    
    avgSalary = round(numpy.mean([dien['SAL_MONTH_LOW']*1/3+dien['SAL_MONTH_HIGH']*2/3 for dien in hr104data if haversine(lng1=dien["lng"],
                                                                 lat1=dien["lat"],
                                                                 lng2=wowDien["lng"],
                                                                 lat2=wowDien["lat"]) <= radius]))
    if not math.isnan(avgSalary):
        y['餐飲業平均薪資(2/3最低+1/3最高)']=avgSalary 
        
    y['餐飲業徵才筆數']=len([dien['SAL_MONTH_LOW']*1/3+dien['SAL_MONTH_HIGH']*2/3 for dien in hr104data if haversine(lng1=dien["lng"],
                                                                 lat1=dien["lat"],
                                                                 lng2=wowDien["lng"],
                                                                 lat2=wowDien["lat"]) <= radius])
    
    
    avgCost = round(numpy.mean([dien['averagecost'] for dien in ipeendata if haversine(lng1=dien["lng"],
                                                                 lat1=dien["lat"],
                                                                 lng2=wowDien["lng"],
                                                                 lat2=wowDien["lat"]) <= radius]))
    if not math.isnan(avgCost):
        y['餐飲業平均消費']=avgCost
    
    try:
        mostStyle=Counter([dien['bigstyle'] for dien in ipeendata if haversine(lng1=dien["lng"],
                                                                     lat1=dien["lat"],
                                                                     lng2=wowDien["lng"],
                                                                     lat2=wowDien["lat"]) <= radius]).most_common(1)[0][0]
    except:
        mostStyle=""
    y['最多品類']=mostStyle
    
    
    
    x.append(y)
# Out:
# 請輸入品牌名稱:
# 半徑範圍(公尺):2000
# 有281筆資料要分析
# 已完成30項分析
# D:\anaconda\lib\site-packages\numpy\core\fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# D:\anaconda\lib\site-packages\numpy\core\_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 已完成60項分析
# 已完成90項分析
# 已完成120項分析
# 已完成150項分析
# 已完成180項分析
# 已完成210項分析
# 已完成240項分析
# 已完成270項分析

# %%
import pandas as pd
df = pd.DataFrame(x)
df=df.reindex(columns=['店代號','事業處','分店名','地址','電話','半徑範圍(公尺)','每日均_營收淨額','每日均_顧客量','每日均_客量',
                       '消費力','消費力筆數','人口數','餐飲業平均薪資(2/3最低+1/3最高)','餐飲業徵才筆數','餐飲業平均消費','最多品類']) #,'區管理者',"廚師"
writer = pd.ExcelWriter('../data/'+queryDien+'.xlsx', engine='xlsxwriter')
df.to_excel(writer, sheet_name='Sheet1')
writer.save()
print("儲存完畢")
# Out:
# 儲存完畢

# %%
# Out:
#   File "<ipython-input-70-575abeff3f0a>", line 2
#     異國料理:[ita義塔,王品,ＴＡＳＴｙ,CooK BEEF!]
#                                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 直接存進mongo內

# %%
import json
import pymongo
from pymongo import UpdateOne
import numpy
import math
from math import radians, cos, sin, asin, sqrt
from collections import Counter
import time
import sys
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.message import EmailMessage
import smtplib

def haversine(lng1, lat1, lng2, lat2):
    # 将十进制度数转化为弧度
    lng1, lat1, lng2, lat2 = map(radians, [lng1, lat1, lng2, lat2])
    # haversine公式
    dlng = lng2 - lng1
    dlat = lat2 - lat1
    a = sin(dlat / 2) ** 2 + cos(lat1) * cos(lat2) * sin(dlng / 2) ** 2
    c = 2 * asin(sqrt(a))
    r = 6371  # 地球平均半径，单位为公里
    return c * r * 1000


b=time.time()
def mailTo(title,mailAdds,message,whoSend='AutoAddInsurance'):
    msg = MIMEMultipart()    
    sender = whoSend
    subject = title
    body = message
    msg['From'] = sender
    msg['To'] = ','.join(mailAdds)
    msg['Subject'] = subject
    msg.attach(MIMEText(body, 'plain'))
    text=msg.as_string()
    #print text
    # Send the message via our SMTP server
    s = smtplib.SMTP('192.168.2.1',25)
    s.sendmail(sender,mailAdds, text)
    s.quit()  

try:
    ######################################################IPEEN
    b=time.time()
    queryElements = {}
    client = pymongo.mongo_client.MongoClient("localhost", 27017, username='j122085', password='850605')
    # collection = client.rawData.wowprimeipeen
    collection = client.rawData.ipeenInfo
    ipeendata = list(collection.find(queryElements))
    ipeendata = [dien for dien in ipeendata if dien['status'] == "正常營業"
                 and dien['lat'] > 18
                 and dien['lat'] < 27
                 and dien['lng'] < 125
                 and dien['lng'] > 117
                 and dien['bigadd'] != 0
                 and dien['smalladd'] != 0
                 and dien['averagecost'] < 8000]

    for dien in ipeendata:
        dien["id"] = dien.pop("_id")
    ######################################################IPEEN
    ######################################################104
    collection = client.rawData.HRdata104
    hr104data = list(collection.find(queryElements))
    hr104data = [dien for dien in hr104data if dien['LAT'] > 18
                 and dien['LAT'] < 27
                 and dien['SAL_MONTH_LOW'] > 18000
                 and dien['SAL_MONTH_LOW'] < 100000
                 and dien['SAL_MONTH_HIGH'] > 18000
                 and dien['SAL_MONTH_HIGH'] < 200000
                 and dien['LON'] < 125
                 and dien['LON'] > 117
                 and dien['bigadd'] != 0
                 and dien['smalladd'] != 0]

    for dien in hr104data:
        dien["lat"] = dien.pop("LAT")
        dien["lng"] = dien.pop("LON")
        del dien["_id"]
    ######################################################104
    ######################################################Nhuman
    collection = client.rawData.Nhuman
    Nhumandata = list(collection.find(queryElements))
    for dien in Nhumandata:
        dien["weight"] = int(dien.pop("Nhuman"))
        dien["add"] = dien.pop("_id")
    ######################################################Nhuman
    ######################################################CostPower
    collection = client.rawData.CostPower
    CostPowerdata = list(collection.find(queryElements))
    for dien in CostPowerdata:
        dien["weight"] = int(dien.pop('costPower'))
        dien["add"] = dien.pop("_id")
    ######################################################CostPower
    ######################################################Bus0320
    collection = client.rawData.busData
    busData = list(collection.find(queryElements))
    for dien in busData:
        dien["add"] = dien.pop("_id")
    ######################################################Bus0320
    ######################################################conStore0320
    collection = client.rawData.conStore
    conStoreData = list(collection.find(queryElements))
    for dien in conStoreData:
        dien.pop("_id")
    ######################################################conStore0320
    ######################################################Watsons0420
    collection = client.rawData.Watsons
    watsonsData = list(collection.find(queryElements))
    for dien in watsonsData:
        dien.pop("_id")
    ######################################################Watsons0420
    ######################################################carrefour0504
    collection = client.rawData.carrefour
    carrefourData = list(collection.find(queryElements))
    for dien in carrefourData:
        dien.pop("_id")
    ######################################################carrefour0504
    ######################################################pxmart0504
    collection = client.rawData.pxmart
    pxmartData = list(collection.find(queryElements))
    for dien in pxmartData:
        dien.pop("_id")
    ######################################################pxmart0504
    
    
    
    
    ######################################################Wow
    collection = client.rawData.wowprimediendata
    wowDiensData = list(collection.find({'CloseDate': 'None', "lat": {"$gt": 1}}))
    wowDiensData = [dien for dien in wowDiensData if "A" not in dien['StoreNo'] and dien['StoreNo'][0] != '3']
    ######################################################Wow

    
    x = []
    queryDien = ""#input("請輸入品牌名稱:")
    radius = 2000#int(input("半徑範圍(公尺):"))
    if queryDien != "":
        wowDiensData = [i for i in wowDiensData if i['Called'] == queryDien]
    else:
        queryDien = "全品牌"
    print("有{}筆資料要分析".format(len(wowDiensData)))
    n = 0
    for wowDien in wowDiensData:
        n += 1
        if n % 15 == 0:
            print("已完成{}項分析".format(n))
        wowDien["areaRadius_Analyze"] = radius
        dienCostPower = round(numpy.mean([dien['weight'] for dien in CostPowerdata if haversine(lng1=dien["lng"],
                                                                                                lat1=dien["lat"],
                                                                                                lng2=wowDien["lng"],
                                                                                                lat2=wowDien[
                                                                                                    "lat"]) <= radius and 'weight' in dien]))

        if not math.isnan(dienCostPower):
            wowDien["costPower_Analyze"] = dienCostPower
        wowDien["NcostData_Analyze"] = len([dien['weight'] for dien in CostPowerdata if haversine(lng1=dien["lng"],
                                                                                lat1=dien["lat"],
                                                                                lng2=wowDien["lng"],
                                                                                lat2=wowDien["lat"]) <= radius and 'weight' in dien])
        
        dienHuman = sum([dien['weight'] for dien in Nhumandata if haversine(lng1=dien["lng"],
                                                                            lat1=dien["lat"],
                                                                            lng2=wowDien["lng"],
                                                                            lat2=wowDien["lat"]) <= radius and 'weight' in dien])
        wowDien['Nhuman_Analyze'] = dienHuman

        avgSalary = round(numpy.mean(
            [dien['SAL_MONTH_LOW'] * 1 / 3 + dien['SAL_MONTH_HIGH'] * 2 / 3 for dien in hr104data if
             haversine(lng1=dien["lng"],
                       lat1=dien["lat"],
                       lng2=wowDien["lng"],
                       lat2=wowDien["lat"]) <= radius and 'SAL_MONTH_HIGH' in dien and 'SAL_MONTH_LOW' in dien]))
        if not math.isnan(avgSalary):
            wowDien['avgSalary_Analyze'] = avgSalary

        wowDien['Njob_Analyze'] = len([dien['SAL_MONTH_LOW'] * 1 / 3 + dien['SAL_MONTH_HIGH'] * 2 / 3 for dien in hr104data if
                            haversine(lng1=dien["lng"],
                                      lat1=dien["lat"],
                                      lng2=wowDien["lng"],
                                      lat2=wowDien["lat"]) <= radius and 'SAL_MONTH_HIGH' in dien  and 'SAL_MONTH_LOW' in dien])

        avgCost = round(numpy.mean([dien['averagecost'] for dien in ipeendata if haversine(lng1=dien["lng"],
                                                                                           lat1=dien["lat"],
                                                                                           lng2=wowDien["lng"],
                                                                                           lat2=wowDien[
                                                                                               "lat"]) <= radius and 'averagecost' in dien]))
        if not math.isnan(avgCost):
            wowDien['avgCost_Analyze'] = avgCost

        try:
            mostStyle = Counter([dien['bigstyle'] for dien in ipeendata if haversine(lng1=dien["lng"],
                                                                                     lat1=dien["lat"],
                                                                                     lng2=wowDien["lng"],
                                                                                     lat2=wowDien[
                                                                                         "lat"]) <= radius and 'bigstyle' in dien]).most_common(1)[0][0]
        except:
            mostStyle = ""
        wowDien['mostStyle_Analyze'] = mostStyle
        
        ###############################################################################################################0320
        wowDien["NbusStation_Analyze"] = len([dien['stationName'] for dien in busData if "lng" in dien and haversine(lng1=dien["lng"],
                                                                                lat1=dien["lat"],
                                                                                lng2=wowDien["lng"],
                                                                                lat2=wowDien["lat"]) <= 500])#0326 change radius
        
        wowDien["NconStore_Analyze"] = len([dien['name'] for dien in conStoreData if "lng" in dien and haversine(lng1=float(dien["lng"]),
                                                                                lat1=float(dien["lat"]),
                                                                                lng2=wowDien["lng"],
                                                                                lat2=wowDien["lat"]) <= radius])
#         conStoreData
        wowDien["Nstar_Analyze"] = len([dien['name'] for dien in ipeendata 
                                if '星巴' in dien['name'] 
                                and haversine(lng1=dien["lng"],
                                              lat1=dien["lat"],
                                              lng2=wowDien["lng"],
                                              lat2=wowDien["lat"]) <= radius])
        wowDien["Nmc_Analyze"] = len([dien['name'] for dien in ipeendata 
                                if '麥當' in dien['name'] 
                                and haversine(lng1=dien["lng"],
                                              lat1=dien["lat"],
                                              lng2=wowDien["lng"],
                                              lat2=wowDien["lat"]) <= radius])
        wowDien["Nken_Analyze"] = len([dien['name'] for dien in ipeendata 
                                if '肯德' in dien['name'] 
                                and haversine(lng1=dien["lng"],
                                              lat1=dien["lat"],
                                              lng2=wowDien["lng"],
                                              lat2=wowDien["lat"]) <= radius])
        wowDien["Nwa_Analyze"] = len([dien['name'] for dien in ipeendata 
                                if '瓦城泰' in dien['name'] 
                                and haversine(lng1=dien["lng"],
                                              lat1=dien["lat"],
                                              lng2=wowDien["lng"],
                                              lat2=wowDien["lat"]) <= radius])
        ################################################################################################################0320
        ########################
        mapType={'CooK BEEF!':'異國料理',
                 'hot 7':'燒烤類',
                 'ita義塔':'異國料理',
                 '乍牛':'日式料理',
                 '原燒':'燒烤類',
                 '品田牧場':'日式料理',
                 '夏慕尼':'燒烤類',
                 '沐越':'亞洲料理',
                 '王品':'異國料理',
                 '石二鍋':'鍋類',
                 '聚':'鍋類',
                 '舒果':'素食',
                 '莆田':'亞洲料理',
                 '藝奇':'日式料理',
                 '陶板屋':'日式料理',
                 '青花驕':'鍋類',
                 '麻佬大':'小吃',
                 'ＴＡＳＴｙ':'異國料理'}
        rangeCost=1.4
        
        
        simDien=[dien['bigstyle'] for dien in ipeendata if haversine(lng1=dien["lng"],
                                                                 lat1=dien["lat"],
                                                                 lng2=wowDien["lng"],
                                                                 lat2=wowDien["lat"]) <= 500
                                                and 'avgDailyNet' in wowDien
                                                and dien['bigstyle']==mapType[wowDien['Called']]
                                                and dien['averagecost']<((wowDien['avgDailyNet']/wowDien['avgDailyCustomer'])*rangeCost)
                                                and dien['averagecost']>((wowDien['avgDailyNet']/wowDien['avgDailyCustomer'])/rangeCost)] 
        wowDien["NsimCostDien"]=len(simDien)
#         print(simDien)
#         print(wowDien['Called'])
        
        wowDien["Nwatson_Analyze"] = len([dien for dien in watsonsData 
                                if  haversine(lng1=float(dien["lng"]),
                                              lat1=float(dien["lat"]),
                                              lng2=wowDien["lng"],
                                              lat2=wowDien["lat"]) <= radius])
        ########################
        #############0504
        wowDien["Ncarrefour_Analyze"] = len([dien for dien in carrefourData 
                                if  haversine(lng1=float(dien["lng"]),
                                              lat1=float(dien["lat"]),
                                              lng2=wowDien["lng"],
                                              lat2=wowDien["lat"]) <= radius])
        wowDien["Npxmart_Analyze"] = len([dien for dien in pxmartData 
                                if  haversine(lng1=float(dien["lng"]),
                                              lat1=float(dien["lat"]),
                                              lng2=wowDien["lng"],
                                              lat2=wowDien["lat"]) <= radius])
        #############0504
        
        
        
        
        
        
        e = time.time()
    print(e-b)

    collection = client.rawData.wowprimediendata
    ids=[data.pop("_id") for data in wowDiensData]
    operations=[UpdateOne({"_id":idn},{'$set':data},upsert=True) for idn ,data in zip(ids,wowDiensData)]
    try:
        collection.bulk_write(operations ,ordered=False)
    except Exception as er:
        print(er)

    alldata=list(collection.find({}))

    client.close()
    
    mailTo(title="analyzeWowDataSuccess",mailAdds=["andy.yuan@wowprime.com"],message="分析完畢_耗時{}秒".format(e-b),whoSend='analyzeWowData')
except Exception as er:
    errorMsg=str(er)+"出錯位置:"+str(sys.exc_info()[2].tb_lineno)
    mailTo(title="analyzeWowDataFail",mailAdds=["andy.yuan@wowprime.com"],message=errorMsg,whoSend='analyzeWowData')
# Out:
# 有276筆資料要分析
# 已完成15項分析
# 已完成30項分析
# D:\anaconda\lib\site-packages\numpy\core\fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# D:\anaconda\lib\site-packages\numpy\core\_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 已完成45項分析
# 已完成60項分析
# 已完成75項分析
# 已完成90項分析
# 已完成105項分析
# 已完成120項分析
# 已完成135項分析
# 已完成150項分析
# 已完成165項分析
# 已完成180項分析
# 已完成195項分析
# 已完成210項分析
# 已完成225項分析
# 已完成240項分析
# 已完成255項分析
# 已完成270項分析
# 453.3913345336914

# %%
[i['NsimCostDien'] for i in wowDiensData if i['Called']=="聚"]
# Out:
# [9, 19, 9, 21, 10, 9, 12, 0, 5, 2, 3, 4, 5, 3, 4, 0, 3, 6, 3, 3, 0, 0]

# %%
len([dien['averagecost'] for dien in ipeendata if haversine(lng1=dien["lng"],
                                                                 lat1=dien["lat"],
                                                                 lng2=wowDien["lng"],
                                                                 lat2=wowDien["lat"]) <= 500
                                                and 'avgDailyNet' in wowDien
                                                and dien['bigstyle']==mapType[wowDien['Called']]
                                                and dien['averagecost']<((wowDien['avgDailyNet']/wowDien['avgDailyCustomer'])*rangeCost)
                                                and dien['averagecost']>((wowDien['avgDailyNet']/wowDien['avgDailyCustomer'])/rangeCost)] )
# Out:
# 2

# %%
ipeendata
# Out:
# [{'Ncomment': 75,
#   'address': '台北市大安區仁愛路四段27巷3號',
#   'averagecost': 673,
#   'bigadd': '台北市',
#   'bigstyle': '中式料理',
#   'collecount': 719,
#   'comments': ['http://www.ipeen.com.tw/comment/1550133',
#    'http://www.ipeen.com.tw/comment/1531625',
#    'http://www.ipeen.com.tw/comment/1531118',
#    'http://www.ipeen.com.tw/comment/1531088',
#    'http://www.ipeen.com.tw/comment/1531070'],
#   'id': 597032,
#   'ipeenscore': 45,
#   'lat': 25.0388350068,
#   'lng': 121.54526991892999,
#   'name': '天下三絕',
#   'reviewdate': '2015/05/06',
#   'smalladd': '大安區',
#   'smallstyle': '麵食點心',
#   'status': '正常營業',
#   'tele': '0227416299',
#   'url': 'http://www.ipeen.com.tw/shop/597032',
#   'viewcount': 802226},
#  {'Ncomment': 78,
#   'address': '宜蘭縣頭城鎮外澳里8鄰石空路95號',
#   'averagecost': 147,
#   'bigadd': '宜蘭縣',
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 198,
#   'comments': ['http://www.ipeen.com.tw/comment/1341719',
#    'http://www.ipeen.com.tw/comment/1153943',
#    'http://www.ipeen.com.tw/comment/915108',
#    'http://www.ipeen.com.tw/comment/833080',
#    'http://www.ipeen.com.tw/comment/814882'],
#   'id': 81702,
#   'ipeenscore': 45,
#   'lat': 24.8845760044,
#   'lng': 121.83919400670003,
#   'name': 'Mr. Brown Café 伯朗咖啡館(頭城城堡咖啡一館)',
#   'reviewdate': '2016/04/05',
#   'smalladd': '頭城鎮',
#   'smallstyle': '複合式',
#   'status': '正常營業',
#   'tele': '0924020088',
#   'url': 'http://www.ipeen.com.tw/shop/81702',
#   'viewcount': 343792},
#  {'Ncomment': 114,
#   'address': '桃園市大溪區中央路127號',
#   'averagecost': 285,
#   'bigadd': '桃園市',
#   'bigstyle': '烘焙、甜點、零食',
#   'collecount': 205,
#   'comments': ['http://www.ipeen.com.tw/comment/1519751',
#    'http://www.ipeen.com.tw/comment/1396433',
#    'http://www.ipeen.com.tw/comment/1343069',
#    'http://www.ipeen.com.tw/comment/1341326',
#    'http://www.ipeen.com.tw/comment/1338308'],
#   'id': 57264,
#   'ipeenscore': 45,
#   'lat': 24.88233901646,
#   'lng': 121.28699301204999,
#   'name': '杏芳食品',
#   'reviewdate': '2012/06/20',
#   'smalladd': '大溪區',
#   'smallstyle': '西點烘焙、麵包',
#   'status': '正常營業',
#   'tele': '033881689',
#   'url': 'http://www.ipeen.com.tw/shop/57264',
#   'viewcount': 276567},
#  {'Ncomment': 118,
#   'address': '台北市信義區忠孝東路五段10號10樓',
#   'averagecost': 1210,
#   'bigadd': '台北市',
#   'bigstyle': 'buffet自助餐',
#   'collecount': 739,
#   'comments': ['http://www.ipeen.com.tw/comment/1360256',
#    'http://www.ipeen.com.tw/comment/1260569',
#    'http://www.ipeen.com.tw/comment/1241048',
#    'http://www.ipeen.com.tw/comment/1197122',
#    'http://www.ipeen.com.tw/comment/1186946'],
#   'id': 95584,
#   'ipeenscore': 45,
#   'lat': 25.040763368711964,
#   'lng': 121.56571445244984,
#   'name': '台北W飯店 - the kitchen table 西餐廳',
#   'reviewdate': '2016/09/01',
#   'smalladd': '信義區',
#   'smallstyle': '複合式',
#   'status': '正常營業',
#   'tele': '0277038887',
#   'url': 'http://www.ipeen.com.tw/shop/95584',
#   'viewcount': 8987274},
#  {'Ncomment': 64,
#   'address': '台中市西區向上路一段8-5號',
#   'averagecost': 275,
#   'bigadd': '台中市',
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 598,
#   'comments': ['http://www.ipeen.com.tw/comment/1035080',
#    'http://www.ipeen.com.tw/comment/1029082',
#    'http://www.ipeen.com.tw/comment/1023128',
#    'http://www.ipeen.com.tw/comment/1019820',
#    'http://www.ipeen.com.tw/comment/1019618'],
#   'id': 976516,
#   'ipeenscore': 50,
#   'lat': 24.14682516517948,
#   'lng': 120.66865922818629,
#   'name': 'Naissance 米之朵甜點房',
#   'reviewdate': '2015/07/21',
#   'smalladd': '西區',
#   'smallstyle': '複合式',
#   'status': '正常營業',
#   'tele': '0423027087',
#   'url': 'http://www.ipeen.com.tw/shop/976516',
#   'viewcount': 14626639},
#  {'Ncomment': 84,
#   'address': '台北市大同區南京西路18巷6弄8號',
#   'averagecost': 247,
#   'bigadd': '台北市',
#   'bigstyle': '日式料理',
#   'collecount': 2351,
#   'comments': ['http://www.ipeen.com.tw/comment/1104278',
#    'http://www.ipeen.com.tw/comment/1080329',
#    'http://www.ipeen.com.tw/comment/1054318',
#    'http://www.ipeen.com.tw/comment/969952',
#    'http://www.ipeen.com.tw/comment/933848'],
#   'id': 66586,
#   'ipeenscore': 45,
#   'lat': 25.05196500071,
#   'lng': 121.51969900889,
#   'name': '平成十九日式料理',
#   'reviewdate': '2016/03/27',
#   'smalladd': '大同區',
#   'smallstyle': '生魚片、壽司專賣',
#   'status': '正常營業',
#   'tele': '0225596510',
#   'url': 'http://www.ipeen.com.tw/shop/66586',
#   'viewcount': 508120},
#  {'Ncomment': 90,
#   'address': '高雄市左營區大中二路333號',
#   'averagecost': 0,
#   'bigadd': '高雄市',
#   'bigstyle': '烘焙、甜點、零食',
#   'collecount': 123,
#   'comments': ['http://www.ipeen.com.tw/comment/1025176',
#    'http://www.ipeen.com.tw/comment/972938',
#    'http://www.ipeen.com.tw/comment/972178',
#    'http://www.ipeen.com.tw/comment/968364',
#    'http://www.ipeen.com.tw/comment/965406'],
#   'id': 979156,
#   'ipeenscore': 50,
#   'lat': 22.67934400648,
#   'lng': 120.31255111799999,
#   'name': '九品元 芝麻可可',
#   'reviewdate': '2014/11/04',
#   'smalladd': '左營區',
#   'smallstyle': '中式糕餅',
#   'status': '正常營業',
#   'tele': '073436933',
#   'url': 'http://www.ipeen.com.tw/shop/979156',
#   'viewcount': 9741589},
#  {'Ncomment': 138,
#   'address': '台北市大安區忠孝東路四段98號11樓',
#   'averagecost': 872,
#   'bigadd': '台北市',
#   'bigstyle': '燒烤類',
#   'collecount': 663,
#   'comments': ['http://www.ipeen.com.tw/comment/1555668',
#    'http://www.ipeen.com.tw/comment/1549437',
#    'http://www.ipeen.com.tw/comment/1478345',
#    'http://www.ipeen.com.tw/comment/1455371',
#    'http://www.ipeen.com.tw/comment/1452119'],
#   'id': 600598,
#   'ipeenscore': 45,
#   'lat': 25.04150840463,
#   'lng': 121.54610510091001,
#   'name': '好客 酒吧燒烤(忠孝店)',
#   'reviewdate': '2016/03/27',
#   'smalladd': '大安區',
#   'smallstyle': '火烤兩吃',
#   'status': '正常營業',
#   'tele': '0287728832',
#   'url': 'http://www.ipeen.com.tw/shop/600598',
#   'viewcount': 11721879},
#  {'Ncomment': 71,
#   'address': '台北市信義區松仁路105號B1',
#   'averagecost': 2295,
#   'bigadd': '台北市',
#   'bigstyle': '異國料理',
#   'collecount': 1408,
#   'comments': ['http://www.ipeen.com.tw/comment/1471283',
#    'http://www.ipeen.com.tw/comment/1314149',
#    'http://www.ipeen.com.tw/comment/1041090',
#    'http://www.ipeen.com.tw/comment/991448',
#    'http://www.ipeen.com.tw/comment/957022'],
#   'id': 88582,
#   'ipeenscore': 50,
#   'lat': 25.03565200516,
#   'lng': 121.56871301306,
#   'name': 'Lawry’s 勞瑞斯牛肋排餐廳',
#   'reviewdate': '2017/02/06',
#   'smalladd': '信義區',
#   'smallstyle': '美式料理',
#   'status': '正常營業',
#   'tele': '0227298555',
#   'url': 'http://www.ipeen.com.tw/shop/88582',
#   'viewcount': 16088740},
#  {'Ncomment': 52,
#   'address': '台中市西屯區福科路839號',
#   'averagecost': 439,
#   'bigadd': '台中市',
#   'bigstyle': '鍋類',
#   'collecount': 947,
#   'comments': ['http://www.ipeen.com.tw/comment/826964',
#    'http://www.ipeen.com.tw/comment/583478',
#    'http://www.ipeen.com.tw/comment/582934',
#    'http://www.ipeen.com.tw/comment/582928',
#    'http://www.ipeen.com.tw/comment/579226'],
#   'id': 110811,
#   'ipeenscore': 50,
#   'lat': 24.187115125522336,
#   'lng': 120.60802203569611,
#   'name': '臥龍城巴蜀麻辣燙-麻辣火鍋專賣(原爭紅麻辣火鍋)',
#   'reviewdate': '2017/10/19',
#   'smalladd': '西屯區',
#   'smallstyle': '麻辣火鍋',
#   'status': '正常營業',
#   'tele': '0424614128',
#   'url': 'http://www.ipeen.com.tw/shop/110811',
#   'viewcount': 14418670},
#  {'Ncomment': 71,
#   'address': '台北市信義區莊敬路391巷7號',
#   'averagecost': 104,
#   'bigadd': '台北市',
#   'bigstyle': '早餐',
#   'collecount': 1433,
#   'comments': ['http://www.ipeen.com.tw/comment/1464191',
#    'http://www.ipeen.com.tw/comment/1287470',
#    'http://www.ipeen.com.tw/comment/1109645',
#    'http://www.ipeen.com.tw/comment/1088633',
#    'http://www.ipeen.com.tw/comment/1066532'],
#   'id': 49644,
#   'ipeenscore': 45,
#   'lat': 25.0284340112,
#   'lng': 121.56573001663,
#   'name': '陳根找茶',
#   'reviewdate': '2012/10/08',
#   'smalladd': '信義區',
#   'smallstyle': '西式早餐',
#   'status': '正常營業',
#   'tele': '0227253696',
#   'url': 'http://www.ipeen.com.tw/shop/49644',
#   'viewcount': 304717},
#  {'Ncomment': 54,
#   'address': '台北市中山區南京東路三段89巷5-4號',
#   'averagecost': 142,
#   'bigadd': '台北市',
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 1117,
#   'comments': ['http://www.ipeen.com.tw/comment/1524713',
#    'http://www.ipeen.com.tw/comment/1453610',
#    'http://www.ipeen.com.tw/comment/1447163',
#    'http://www.ipeen.com.tw/comment/1430552',
#    'http://www.ipeen.com.tw/comment/1379264'],
#   'id': 590826,
#   'ipeenscore': 45,
#   'lat': 25.05301581793,
#   'lng': 121.54088441079,
#   'name': 'LOCO FOOD 樂口福咖啡',
#   'reviewdate': '2016/03/27',
#   'smalladd': '中山區',
#   'smallstyle': '複合式',
#   'status': '正常營業',
#   'tele': '0225068917',
#   'url': 'http://www.ipeen.com.tw/shop/590826',
#   'viewcount': 190150},
#  {'Ncomment': 56,
#   'address': '新北市汐止區汐萬路三段350巷7號',
#   'averagecost': 1154,
#   'bigadd': '新北市',
#   'bigstyle': '中式料理',
#   'collecount': 833,
#   'comments': ['http://www.ipeen.com.tw/comment/1436522',
#    'http://www.ipeen.com.tw/comment/1070597',
#    'http://www.ipeen.com.tw/comment/955380',
#    'http://www.ipeen.com.tw/comment/869022',
#    'http://www.ipeen.com.tw/comment/764574'],
#   'id': 7731,
#   'ipeenscore': 45,
#   'lat': 25.125879007560002,
#   'lng': 121.62617601232,
#   'name': '食養山房',
#   'reviewdate': '2015/04/04',
#   'smalladd': '汐止區',
#   'smallstyle': '台菜餐廳',
#   'status': '正常營業',
#   'tele': '0226462266',
#   'url': 'http://www.ipeen.com.tw/shop/7731',
#   'viewcount': 480268},
#  {'Ncomment': 77,
#   'address': '新北市中和區中和路246號',
#   'averagecost': 303,
#   'bigadd': '新北市',
#   'bigstyle': '燒烤類',
#   'collecount': 462,
#   'comments': ['http://www.ipeen.com.tw/comment/1549950',
#    'http://www.ipeen.com.tw/comment/1544381',
#    'http://www.ipeen.com.tw/comment/1523414',
#    'http://www.ipeen.com.tw/comment/1456763',
#    'http://www.ipeen.com.tw/comment/1356788'],
#   'id': 635218,
#   'ipeenscore': 45,
#   'lat': 24.99969378300008,
#   'lng': 121.50719182675164,
#   'name': '小惡魔炭燒牛排',
#   'reviewdate': '2014/03/11',
#   'smalladd': '中和區',
#   'smallstyle': '炭烤串燒',
#   'status': '正常營業',
#   'tele': '0222482766',
#   'url': 'http://www.ipeen.com.tw/shop/635218',
#   'viewcount': 2170479},
#  {'Ncomment': 55,
#   'address': '台北市大安區安和路一段49巷10號',
#   'averagecost': 1478,
#   'bigadd': '台北市',
#   'bigstyle': '異國料理',
#   'collecount': 1056,
#   'comments': ['http://www.ipeen.com.tw/comment/1124528',
#    'http://www.ipeen.com.tw/comment/1050130',
#    'http://www.ipeen.com.tw/comment/966108',
#    'http://www.ipeen.com.tw/comment/964888',
#    'http://www.ipeen.com.tw/comment/939516'],
#   'id': 16577,
#   'ipeenscore': 45,
#   'lat': 25.03843200608,
#   'lng': 121.55155401316999,
#   'name': '雅室牛排館',
#   'reviewdate': '2015/06/03',
#   'smalladd': '大安區',
#   'smallstyle': '法式料理',
#   'status': '正常營業',
#   'tele': '0227753011',
#   'url': 'http://www.ipeen.com.tw/shop/16577',
#   'viewcount': 343172},
#  {'Ncomment': 168,
#   'address': '新北市新莊區中正路1號3樓',
#   'averagecost': 161,
#   'bigadd': '新北市',
#   'bigstyle': '異國料理',
#   'collecount': 159,
#   'comments': ['http://www.ipeen.com.tw/comment/1496651',
#    'http://www.ipeen.com.tw/comment/1451282',
#    'http://www.ipeen.com.tw/comment/1365674',
#    'http://www.ipeen.com.tw/comment/1074176',
#    'http://www.ipeen.com.tw/comment/1009042'],
#   'id': 31744,
#   'ipeenscore': 45,
#   'lat': 25.04157369949059,
#   'lng': 121.46477939138364,
#   'name': 'IKEA瑞典餐廳(新莊店)',
#   'reviewdate': '2012/10/23',
#   'smalladd': '新莊區',
#   'smallstyle': '北歐料理',
#   'status': '正常營業',
#   'tele': '0222765388',
#   'url': 'http://www.ipeen.com.tw/shop/31744',
#   'viewcount': 651667},
#  {'Ncomment': 84,
#   'address': '台北市大安區延吉街137巷6-2號',
#   'averagecost': 206,
#   'bigadd': '台北市',
#   'bigstyle': '中式料理',
#   'collecount': 1053,
#   'comments': ['http://www.ipeen.com.tw/comment/1135841',
#    'http://www.ipeen.com.tw/comment/1105325',
#    'http://www.ipeen.com.tw/comment/1094957',
#    'http://www.ipeen.com.tw/comment/1045226',
#    'http://www.ipeen.com.tw/comment/1030218'],
#   'id': 6633,
#   'ipeenscore': 45,
#   'lat': 25.041918607099998,
#   'lng': 121.55481471111995,
#   'name': 'Hong Kong 茶水攤',
#   'reviewdate': '2015/04/05',
#   'smalladd': '大安區',
#   'smallstyle': '粵菜 港式飲茶',
#   'status': '正常營業',
#   'tele': '0227725252',
#   'url': 'http://www.ipeen.com.tw/shop/6633',
#   'viewcount': 570022},
#  {'Ncomment': 57,
#   'address': '台北市大安區仁愛路四段27巷6號-1',
#   'averagecost': 342,
#   'bigadd': '台北市',
#   'bigstyle': '異國料理',
#   'collecount': 1645,
#   'comments': ['http://www.ipeen.com.tw/comment/1459751',
#    'http://www.ipeen.com.tw/comment/1255505',
#    'http://www.ipeen.com.tw/comment/1032408',
#    'http://www.ipeen.com.tw/comment/1005964',
#    'http://www.ipeen.com.tw/comment/845900'],
#   'id': 94031,
#   'ipeenscore': 45,
#   'lat': 25.038841001970003,
#   'lng': 121.54508200107999,
#   'name': 'M ONE Cafe',
#   'reviewdate': '2011/04/10',
#   'smalladd': '大安區',
#   'smallstyle': '美式料理',
#   'status': '正常營業',
#   'tele': '0287732136',
#   'url': 'http://www.ipeen.com.tw/shop/94031',
#   'viewcount': 256814},
#  {'Ncomment': 95,
#   'address': '新竹縣竹北市文平路302號',
#   'averagecost': 128,
#   'bigadd': '新竹縣',
#   'bigstyle': '烘焙、甜點、零食',
#   'collecount': 148,
#   'comments': ['http://www.ipeen.com.tw/comment/999322',
#    'http://www.ipeen.com.tw/comment/831994',
#    'http://www.ipeen.com.tw/comment/765946',
#    'http://www.ipeen.com.tw/comment/737072',
#    'http://www.ipeen.com.tw/comment/689192'],
#   'id': 36511,
#   'ipeenscore': 45,
#   'lat': 24.83132401922,
#   'lng': 121.00985300832001,
#   'name': '均鎂糕餅公司',
#   'reviewdate': '2015/05/25',
#   'smalladd': '竹北市',
#   'smallstyle': '西點烘焙、麵包',
#   'status': '正常營業',
#   'tele': '035528898',
#   'url': 'http://www.ipeen.com.tw/shop/36511',
#   'viewcount': 420167},
#  {'Ncomment': 73,
#   'address': '台北市大安區敦化南路二段265巷7號1樓',
#   'averagecost': 954,
#   'bigadd': '台北市',
#   'bigstyle': '鍋類',
#   'collecount': 751,
#   'comments': ['http://www.ipeen.com.tw/comment/1391477',
#    'http://www.ipeen.com.tw/comment/993786',
#    'http://www.ipeen.com.tw/comment/955988',
#    'http://www.ipeen.com.tw/comment/955874',
#    'http://www.ipeen.com.tw/comment/955596'],
#   'id': 948242,
#   'ipeenscore': 50,
#   'lat': 25.025476012760002,
#   'lng': 121.54956000172,
#   'name': '香聚鍋The Dainties',
#   'reviewdate': '2016/03/27',
#   'smalladd': '大安區',
#   'smallstyle': '涮涮鍋',
#   'status': '正常營業',
#   'tele': '0227382258',
#   'url': 'http://www.ipeen.com.tw/shop/948242',
#   'viewcount': 14507092},
#  {'Ncomment': 97,
#   'address': '台北市松山區敦化北路100號B2',
#   'averagecost': 163,
#   'bigadd': '台北市',
#   'bigstyle': '異國料理',
#   'collecount': 109,
#   'comments': ['http://www.ipeen.com.tw/comment/1060132',
#    'http://www.ipeen.com.tw/comment/1004088',
#    'http://www.ipeen.com.tw/comment/982668',
#    'http://www.ipeen.com.tw/comment/939530',
#    'http://www.ipeen.com.tw/comment/907540'],
#   'id': 17010,
#   'ipeenscore': 45,
#   'lat': 25.05233900419,
#   'lng': 121.54859801604997,
#   'name': 'IKEA瑞典餐廳(敦北店)',
#   'reviewdate': '2016/04/05',
#   'smalladd': '松山區',
#   'smallstyle': '其他異國料理',
#   'status': '正常營業',
#   'tele': '0227168900',
#   'url': 'http://www.ipeen.com.tw/shop/17010',
#   'viewcount': 401166},
#  {'Ncomment': 49,
#   'address': '台北市中山區中山北路二段36巷33號',
#   'averagecost': 339,
#   'bigadd': '台北市',
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 1036,
#   'comments': ['http://www.ipeen.com.tw/comment/1219898',
#    'http://www.ipeen.com.tw/comment/993430',
#    'http://www.ipeen.com.tw/comment/989982',
#    'http://www.ipeen.com.tw/comment/972788',
#    'http://www.ipeen.com.tw/comment/951590'],
#   'id': 121923,
#   'ipeenscore': 45,
#   'lat': 25.05437201599,
#   'lng': 121.52087000616,
#   'name': '疊疊樂',
#   'reviewdate': '2016/03/27',
#   'smalladd': '中山區',
#   'smallstyle': '複合式',
#   'status': '正常營業',
#   'tele': '0225670687',
#   'url': 'http://www.ipeen.com.tw/shop/121923',
#   'viewcount': 1281791},
#  {'Ncomment': 59,
#   'address': '台北市南港區經貿二路66-2號1樓',
#   'averagecost': 1640,
#   'bigadd': '台北市',
#   'bigstyle': '日式料理',
#   'collecount': 590,
#   'comments': ['http://www.ipeen.com.tw/comment/1013638',
#    'http://www.ipeen.com.tw/comment/992202',
#    'http://www.ipeen.com.tw/comment/957568',
#    'http://www.ipeen.com.tw/comment/873740',
#    'http://www.ipeen.com.tw/comment/867188'],
#   'id': 145009,
#   'ipeenscore': 50,
#   'lat': 25.05755223717201,
#   'lng': 121.61624781594931,
#   'name': '高樂餐飲-鐵板料理 與 小高玉迴轉壽司',
#   'reviewdate': '2014/08/20',
#   'smalladd': '南港區',
#   'smallstyle': '其他日式料理',
#   'status': '正常營業',
#   'tele': '0227868077',
#   'url': 'http://www.ipeen.com.tw/shop/145009',
#   'viewcount': 16297233},
#  {'Ncomment': 115,
#   'address': '台北市信義區基隆路一段159號B1',
#   'averagecost': 1575,
#   'bigadd': '台北市',
#   'bigstyle': '日式料理',
#   'collecount': 390,
#   'comments': ['http://www.ipeen.com.tw/comment/1136591',
#    'http://www.ipeen.com.tw/comment/1134194',
#    'http://www.ipeen.com.tw/comment/1102253',
#    'http://www.ipeen.com.tw/comment/1093865',
#    'http://www.ipeen.com.tw/comment/1082741'],
#   'id': 155233,
#   'ipeenscore': 50,
#   'lat': 25.042059017059998,
#   'lng': 121.56496301595,
#   'name': '宸料理頂級日式料理',
#   'reviewdate': '2016/04/05',
#   'smalladd': '信義區',
#   'smallstyle': '綜合日式料理',
#   'status': '正常營業',
#   'tele': '0227657688',
#   'url': 'http://www.ipeen.com.tw/shop/155233',
#   'viewcount': 13161948},
#  {'Ncomment': 69,
#   'address': '台北市大安區樂利路11巷30、32號',
#   'averagecost': 617,
#   'bigadd': '台北市',
#   'bigstyle': '主題特色餐廳',
#   'collecount': 2314,
#   'comments': ['http://www.ipeen.com.tw/comment/1050822',
#    'http://www.ipeen.com.tw/comment/1000624',
#    'http://www.ipeen.com.tw/comment/984360',
#    'http://www.ipeen.com.tw/comment/979166',
#    'http://www.ipeen.com.tw/comment/978124'],
#   'id': 6925,
#   'ipeenscore': 45,
#   'lat': 25.0282440032,
#   'lng': 121.5524410197,
#   'name': 'The Villa Herbs restaurant(樂利店)',
#   'reviewdate': '2017/09/01',
#   'smalladd': '大安區',
#   'smallstyle': '酒吧 Lounge Bar',
#   'status': '正常營業',
#   'tele': '0227323255',
#   'url': 'http://www.ipeen.com.tw/shop/6925',
#   'viewcount': 9424847},
#  {'Ncomment': 65,
#   'address': '台北市大安區和平東路一段55巷5號(建議從75巷進去比較好找)',
#   'averagecost': 388,
#   'bigadd': '台北市',
#   'bigstyle': '鍋類',
#   'collecount': 941,
#   'comments': ['http://www.ipeen.com.tw/comment/1015482',
#    'http://www.ipeen.com.tw/comment/994758',
#    'http://www.ipeen.com.tw/comment/974752',
#    'http://www.ipeen.com.tw/comment/966536',
#    'http://www.ipeen.com.tw/comment/853776'],
#   'id': 7188,
#   'ipeenscore': 45,
#   'lat': 25.027928013409998,
#   'lng': 121.52455301901,
#   'name': '勵進餐廳(台電員工餐廳)',
#   'reviewdate': '2016/04/05',
#   'smalladd': '大安區',
#   'smallstyle': '其他鍋類',
#   'status': '正常營業',
#   'tele': '0223934780',
#   'url': 'http://www.ipeen.com.tw/shop/7188',
#   'viewcount': 793548},
#  {'Ncomment': 106,
#   'address': '台北市信義區松壽路20號2樓(威秀影城)',
#   'averagecost': 214,
#   'bigadd': '台北市',
#   'bigstyle': '日式料理',
#   'collecount': 464,
#   'comments': ['http://www.ipeen.com.tw/comment/1127255',
#    'http://www.ipeen.com.tw/comment/1015862',
#    'http://www.ipeen.com.tw/comment/967576',
#    'http://www.ipeen.com.tw/comment/658064',
#    'http://www.ipeen.com.tw/comment/635132'],
#   'id': 43587,
#   'ipeenscore': 45,
#   'lat': 25.03563600988,
#   'lng': 121.56709900267,
#   'name': 'らあめん花月嵐拉麵(信義威秀店)',
#   'reviewdate': '2016/04/05',
#   'smalladd': '信義區',
#   'smallstyle': '日式麵食專賣',
#   'status': '正常營業',
#   'tele': '0227292128',
#   'url': 'http://www.ipeen.com.tw/shop/43587',
#   'viewcount': 356705},
#  {'Ncomment': 307,
#   'address': '台北市中山區南京西路12巷13弄9號',
#   'averagecost': 275,
#   'bigadd': '台北市',
#   'bigstyle': '異國料理',
#   'collecount': 3000,
#   'comments': ['http://www.ipeen.com.tw/comment/1414229',
#    'http://www.ipeen.com.tw/comment/1373510',
#    'http://www.ipeen.com.tw/comment/1281026',
#    'http://www.ipeen.com.tw/comment/1243895',
#    'http://www.ipeen.com.tw/comment/1041714'],
#   'id': 67012,
#   'ipeenscore': 45,
#   'lat': 25.051715000850002,
#   'lng': 121.52191300095004,
#   'name': '螺絲瑪莉 Rose Mary',
#   'reviewdate': '2016/03/27',
#   'smalladd': '中山區',
#   'smallstyle': '義式料理',
#   'status': '正常營業',
#   'tele': '0225219822',
#   'url': 'http://www.ipeen.com.tw/shop/67012',
#   'viewcount': 2483800},
#  {'Ncomment': 127,
#   'address': '宜蘭縣羅東鎮中正北路109號',
#   'averagecost': 40,
#   'bigadd': '宜蘭縣',
#   'bigstyle': '小吃',
#   'collecount': 385,
#   'comments': ['http://www.ipeen.com.tw/comment/1096526',
#    'http://www.ipeen.com.tw/comment/1076438',
#    'http://www.ipeen.com.tw/comment/1060092',
#    'http://www.ipeen.com.tw/comment/1032578',
#    'http://www.ipeen.com.tw/comment/1029396'],
#   'id': 33031,
#   'ipeenscore': 45,
#   'lat': 24.68247700856,
#   'lng': 121.77127401067001,
#   'name': '林場肉羹',
#   'reviewdate': '2015/12/10',
#   'smalladd': '羅東鎮',
#   'smallstyle': '其他小吃',
#   'status': '正常營業',
#   'tele': '039552736',
#   'url': 'http://www.ipeen.com.tw/shop/33031',
#   'viewcount': 275009},
#  {'Ncomment': 72,
#   'address': '台北市大安區忠孝東路四段223巷10弄8號',
#   'averagecost': 309,
#   'bigadd': '台北市',
#   'bigstyle': '異國料理',
#   'collecount': 1064,
#   'comments': ['http://www.ipeen.com.tw/comment/976352',
#    'http://www.ipeen.com.tw/comment/688736',
#    'http://www.ipeen.com.tw/comment/687186',
#    'http://www.ipeen.com.tw/comment/678024',
#    'http://www.ipeen.com.tw/comment/667168'],
#   'id': 38484,
#   'ipeenscore': 45,
#   'lat': 25.041953606036213,
#   'lng': 121.55337917724492,
#   'name': 'FORKERS佛客漢堡(忠孝店)',
#   'reviewdate': '2014/07/11',
#   'smalladd': '大安區',
#   'smallstyle': '美式料理',
#   'status': '正常營業',
#   'tele': '0227719285',
#   'url': 'http://www.ipeen.com.tw/shop/38484',
#   'viewcount': 4503461},
#  {'Ncomment': 70,
#   'address': '台北市信義區忠孝東路五段15巷14號',
#   'averagecost': 567,
#   'bigadd': '台北市',
#   'bigstyle': '中式料理',
#   'collecount': 600,
#   'comments': ['http://www.ipeen.com.tw/comment/1055832',
#    'http://www.ipeen.com.tw/comment/799806',
#    'http://www.ipeen.com.tw/comment/738972',
#    'http://www.ipeen.com.tw/comment/717022',
#    'http://www.ipeen.com.tw/comment/598652'],
#   'id': 3776,
#   'ipeenscore': 45,
#   'lat': 25.041792019040003,
#   'lng': 121.56547101641,
#   'name': '宋廚北方菜館',
#   'reviewdate': '2015/04/02',
#   'smalladd': '信義區',
#   'smallstyle': '北京菜',
#   'status': '正常營業',
#   'tele': '0227644788',
#   'url': 'http://www.ipeen.com.tw/shop/3776',
#   'viewcount': 440615},
#  {'Ncomment': 84,
#   'address': '台中市西區明義街52號',
#   'averagecost': 319,
#   'bigadd': '台中市',
#   'bigstyle': '烘焙、甜點、零食',
#   'collecount': 822,
#   'comments': ['http://www.ipeen.com.tw/comment/1402673',
#    'http://www.ipeen.com.tw/comment/1243952',
#    'http://www.ipeen.com.tw/comment/1106870',
#    'http://www.ipeen.com.tw/comment/1068428',
#    'http://www.ipeen.com.tw/comment/1002274'],
#   'id': 141365,
#   'ipeenscore': 45,
#   'lat': 24.1552250071,
#   'lng': 120.66054200475001,
#   'name': '小梗甜點咖啡',
#   'reviewdate': '2016/08/10',
#   'smalladd': '西區',
#   'smallstyle': '西點烘焙、麵包',
#   'status': '正常營業',
#   'tele': '0423198852',
#   'url': 'http://www.ipeen.com.tw/shop/141365',
#   'viewcount': 222797},
#  {'Ncomment': 76,
#   'address': '台中市南屯區公益路二段25號',
#   'averagecost': 312,
#   'bigadd': '台中市',
#   'bigstyle': '鍋類',
#   'collecount': 756,
#   'comments': ['http://www.ipeen.com.tw/comment/1216142',
#    'http://www.ipeen.com.tw/comment/1168460',
#    'http://www.ipeen.com.tw/comment/1062452',
#    'http://www.ipeen.com.tw/comment/956002',
#    'http://www.ipeen.com.tw/comment/920722'],
#   'id': 47432,
#   'ipeenscore': 45,
#   'lat': 24.15070300093,
#   'lng': 120.65166601023,
#   'name': '八錢鍋物',
#   'reviewdate': '2015/06/14',
#   'smalladd': '南屯區',
#   'smallstyle': '其他鍋類',
#   'status': '正常營業',
#   'tele': '0423191768',
#   'url': 'http://www.ipeen.com.tw/shop/47432',
#   'viewcount': 464421},
#  {'Ncomment': 64,
#   'address': '台北市大安區敦化南路二段63巷53弄7號',
#   'averagecost': 1116,
#   'bigadd': '台北市',
#   'bigstyle': '燒烤類',
#   'collecount': 904,
#   'comments': ['http://www.ipeen.com.tw/comment/1214456',
#    'http://www.ipeen.com.tw/comment/919498',
#    'http://www.ipeen.com.tw/comment/909600',
#    'http://www.ipeen.com.tw/comment/906172',
#    'http://www.ipeen.com.tw/comment/902062'],
#   'id': 108951,
#   'ipeenscore': 50,
#   'lat': 25.03114401219,
#   'lng': 121.55168500735,
#   'name': '油花炭火燒肉專門店',
#   'reviewdate': '2016/03/27',
#   'smalladd': '大安區',
#   'smallstyle': '炭烤串燒',
#   'status': '正常營業',
#   'tele': '0227555200',
#   'url': 'http://www.ipeen.com.tw/shop/108951',
#   'viewcount': 24595031},
#  {'Ncomment': 69,
#   'address': '台中市西區公益路36號',
#   'averagecost': 545,
#   'bigadd': '台中市',
#   'bigstyle': '主題特色餐廳',
#   'collecount': 826,
#   'comments': ['http://www.ipeen.com.tw/comment/1016384',
#    'http://www.ipeen.com.tw/comment/1011142',
#    'http://www.ipeen.com.tw/comment/1004586',
#    'http://www.ipeen.com.tw/comment/1001686',
#    'http://www.ipeen.com.tw/comment/990098'],
#   'id': 578076,
#   'ipeenscore': 50,
#   'lat': 24.150956006090002,
#   'lng': 120.66857301396999,
#   'name': '路德威手工啤酒餐廳',
#   'reviewdate': '2014/11/12',
#   'smalladd': '西區',
#   'smallstyle': '啤酒屋',
#   'status': '正常營業',
#   'tele': '0423288686',
#   'url': 'http://www.ipeen.com.tw/shop/578076',
#   'viewcount': 8441116},
#  {'Ncomment': 95,
#   'address': '新北市板橋區文化路一段219-6號',
#   'averagecost': 624,
#   'bigadd': '新北市',
#   'bigstyle': '燒烤類',
#   'collecount': 688,
#   'comments': ['http://www.ipeen.com.tw/comment/1007394',
#    'http://www.ipeen.com.tw/comment/808292',
#    'http://www.ipeen.com.tw/comment/609784',
#    'http://www.ipeen.com.tw/comment/527094',
#    'http://www.ipeen.com.tw/comment/496036'],
#   'id': 39054,
#   'ipeenscore': 45,
#   'lat': 25.01734640203,
#   'lng': 121.46375251199005,
#   'name': '燒肉天國(板橋店)',
#   'reviewdate': '2015/12/04',
#   'smalladd': '板橋區',
#   'smallstyle': '日式燒肉',
#   'status': '正常營業',
#   'tele': '0222726988',
#   'url': 'http://www.ipeen.com.tw/shop/39054',
#   'viewcount': 3638342},
#  {'Ncomment': 113,
#   'address': '台中市東區十甲路247-1號',
#   'averagecost': 263,
#   'bigadd': '台中市',
#   'bigstyle': '烘焙、甜點、零食',
#   'collecount': 319,
#   'comments': ['http://www.ipeen.com.tw/comment/1003100',
#    'http://www.ipeen.com.tw/comment/979314',
#    'http://www.ipeen.com.tw/comment/899482',
#    'http://www.ipeen.com.tw/comment/890366',
#    'http://www.ipeen.com.tw/comment/874312'],
#   'id': 39073,
#   'ipeenscore': 45,
#   'lat': 24.14473501477,
#   'lng': 120.70440001950001,
#   'name': '一森手工烘焙坊(十甲旗艦店)',
#   'reviewdate': '2010/04/26',
#   'smalladd': '東區',
#   'smallstyle': '西點烘焙、麵包',
#   'status': '正常營業',
#   'tele': '0422111159',
#   'url': 'http://www.ipeen.com.tw/shop/39073',
#   'viewcount': 5584592},
#  {'Ncomment': 65,
#   'address': '台北市萬華區漢中街127號5樓',
#   'averagecost': 601,
#   'bigadd': '台北市',
#   'bigstyle': '燒烤類',
#   'collecount': 408,
#   'comments': ['http://www.ipeen.com.twhttp://content.ipeen.com.tw/tastenews/926',
#    'http://www.ipeen.com.tw/comment/1055092',
#    'http://www.ipeen.com.tw/comment/1054912',
#    'http://www.ipeen.com.tw/comment/1371974',
#    'http://www.ipeen.com.tw/comment/1364549',
#    'http://www.ipeen.com.tw/comment/1357895'],
#   'id': 992146,
#   'ipeenscore': 50,
#   'lat': 25.04201260546,
#   'lng': 121.50757871926007,
#   'name': '我!就厲害(西門珍饌店)',
#   'reviewdate': '2017/04/28',
#   'smalladd': '萬華區',
#   'smallstyle': '火烤兩吃',
#   'status': '正常營業',
#   'tele': '0223315527',
#   'url': 'http://www.ipeen.com.tw/shop/992146',
#   'viewcount': 24478029},
#  {'Ncomment': 64,
#   'address': '台北市大安區浦城街13巷26號',
#   'averagecost': 335,
#   'bigadd': '台北市',
#   'bigstyle': '亞洲料理',
#   'collecount': 674,
#   'comments': ['http://www.ipeen.com.tw/comment/1186952',
#    'http://www.ipeen.com.tw/comment/1066738',
#    'http://www.ipeen.com.tw/comment/1041542',
#    'http://www.ipeen.com.tw/comment/935554',
#    'http://www.ipeen.com.tw/comment/934898'],
#   'id': 10317,
#   'ipeenscore': 45,
#   'lat': 25.02436701902,
#   'lng': 121.52787600002,
#   'name': '印渡風情印度餐廳(師大一店)',
#   'reviewdate': '2013/08/06',
#   'smalladd': '大安區',
#   'smallstyle': '印度料理',
#   'status': '正常營業',
#   'tele': '0223633054',
#   'url': 'http://www.ipeen.com.tw/shop/10317',
#   'viewcount': 5015512},
#  {'Ncomment': 79,
#   'address': '台北市大安區新生南路三段82號',
#   'averagecost': 66,
#   'bigadd': '台北市',
#   'bigstyle': '冰品、飲料、甜湯',
#   'collecount': 677,
#   'comments': ['http://www.ipeen.com.tw/comment/1302224',
#    'http://www.ipeen.com.tw/comment/1046612',
#    'http://www.ipeen.com.tw/comment/952968',
#    'http://www.ipeen.com.tw/comment/845122',
#    'http://www.ipeen.com.tw/comment/810302'],
#   'id': 22268,
#   'ipeenscore': 45,
#   'lat': 25.01896301324,
#   'lng': 121.53352300466,
#   'name': '臺一牛奶大王',
#   'reviewdate': '2015/04/24',
#   'smalladd': '大安區',
#   'smallstyle': '剉冰、豆花',
#   'status': '正常營業',
#   'tele': '0223634341',
#   'url': 'http://www.ipeen.com.tw/shop/22268',
#   'viewcount': 380922},
#  {'Ncomment': 115,
#   'address': '花蓮縣花蓮市復興街110巷2號',
#   'averagecost': 27,
#   'bigadd': '花蓮縣',
#   'bigstyle': '中式料理',
#   'collecount': 591,
#   'comments': ['http://www.ipeen.com.tw/comment/1014056',
#    'http://www.ipeen.com.tw/comment/1010566',
#    'http://www.ipeen.com.tw/comment/1003762',
#    'http://www.ipeen.com.tw/comment/987058',
#    'http://www.ipeen.com.tw/comment/965858'],
#   'id': 40429,
#   'ipeenscore': 45,
#   'lat': 23.982386005280002,
#   'lng': 121.60606801562999,
#   'name': '老牌炸蛋蔥油餅',
#   'reviewdate': '2016/10/13',
#   'smalladd': '花蓮市',
#   'smallstyle': '麵食點心',
#   'status': '正常營業',
#   'tele': '0955282038',
#   'url': 'http://www.ipeen.com.tw/shop/40429',
#   'viewcount': 321636},
#  {'Ncomment': 58,
#   'address': '台北市大安區敦化南路一段177巷21號',
#   'averagecost': 328,
#   'bigadd': '台北市',
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 866,
#   'comments': ['http://www.ipeen.com.tw/comment/1486079',
#    'http://www.ipeen.com.tw/comment/1021902',
#    'http://www.ipeen.com.tw/comment/942732',
#    'http://www.ipeen.com.tw/comment/856070',
#    'http://www.ipeen.com.tw/comment/775584'],
#   'id': 108117,
#   'ipeenscore': 45,
#   'lat': 25.043134015649997,
#   'lng': 121.55051800586,
#   'name': 'StayReal Café by Gabee',
#   'reviewdate': '2016/11/29',
#   'smalladd': '大安區',
#   'smallstyle': '咖啡專賣',
#   'status': '正常營業',
#   'tele': '0227318011',
#   'url': 'http://www.ipeen.com.tw/shop/108117',
#   'viewcount': 212438},
#  {'Ncomment': 51,
#   'address': '台北市大安區杭州南路二段25巷1號',
#   'averagecost': 228,
#   'bigadd': '台北市',
#   'bigstyle': '中式料理',
#   'collecount': 1065,
#   'comments': ['http://www.ipeen.com.tw/comment/1211384',
#    'http://www.ipeen.com.tw/comment/911220',
#    'http://www.ipeen.com.tw/comment/836412',
#    'http://www.ipeen.com.tw/comment/836270',
#    'http://www.ipeen.com.tw/comment/782868'],
#   'id': 23158,
#   'ipeenscore': 45,
#   'lat': 25.033859013649998,
#   'lng': 121.52386100611,
#   'name': '盛園絲瓜小籠湯包',
#   'reviewdate': '2016/04/27',
#   'smalladd': '大安區',
#   'smallstyle': '麵食點心',
#   'status': '正常營業',
#   'tele': '0223582253',
#   'url': 'http://www.ipeen.com.tw/shop/23158',
#   'viewcount': 300674},
#  {'Ncomment': 73,
#   'address': '台北市中正區忠孝西路一段38號2樓',
#   'averagecost': 971,
#   'bigadd': '台北市',
#   'bigstyle': 'buffet自助餐',
#   'collecount': 459,
#   'comments': ['http://www.ipeen.com.tw/comment/1337522',
#    'http://www.ipeen.com.tw/comment/1163222',
#    'http://www.ipeen.com.tw/comment/1106189',
#    'http://www.ipeen.com.tw/comment/1088978',
#    'http://www.ipeen.com.tw/comment/979802'],
#   'id': 987250,
#   'ipeenscore': 45,
#   'lat': 25.04625850734,
#   'lng': 121.51642180726,
#   'name': '台北凱撒大飯店(Checkers自助式餐廳)',
#   'reviewdate': '2018/01/13',
#   'smalladd': '中正區',
#   'smallstyle': '複合式',
#   'status': '正常營業',
#   'tele': '0223115151',
#   'url': 'http://www.ipeen.com.tw/shop/987250',
#   'viewcount': 224579},
#  {'Ncomment': 46,
#   'address': '台南市中西區正興街80號',
#   'averagecost': 127,
#   'bigadd': '台南市',
#   'bigstyle': '冰品、飲料、甜湯',
#   'collecount': 1314,
#   'comments': ['http://www.ipeen.com.tw/comment/1371278',
#    'http://www.ipeen.com.tw/comment/1100249',
#    'http://www.ipeen.com.tw/comment/1095938',
#    'http://www.ipeen.com.tw/comment/1018836',
#    'http://www.ipeen.com.tw/comment/926112'],
#   'id': 615220,
#   'ipeenscore': 45,
#   'lat': 22.99451200854,
#   'lng': 120.19718900435,
#   'name': '泰成水果店',
#   'reviewdate': '2014/03/07',
#   'smalladd': '中西區',
#   'smallstyle': '果汁',
#   'status': '正常營業',
#   'tele': '062281794',
#   'url': 'http://www.ipeen.com.tw/shop/615220',
#   'viewcount': 257981},
#  {'Ncomment': 79,
#   'address': '台北市萬華區成都路27巷19號',
#   'averagecost': 280,
#   'bigadd': '台北市',
#   'bigstyle': '中式料理',
#   'collecount': 1018,
#   'comments': ['http://www.ipeen.com.tw/comment/896294',
#    'http://www.ipeen.com.tw/comment/715724',
#    'http://www.ipeen.com.tw/comment/707830',
#    'http://www.ipeen.com.tw/comment/697638',
#    'http://www.ipeen.com.tw/comment/669048'],
#   'id': 6462,
#   'ipeenscore': 45,
#   'lat': 25.04317401766,
#   'lng': 121.50692701824,
#   'name': '維多利亞茶餐廳',
#   'reviewdate': '2015/04/05',
#   'smalladd': '萬華區',
#   'smallstyle': '粵菜 港式飲茶',
#   'status': '正常營業',
#   'tele': '0223826388',
#   'url': 'http://www.ipeen.com.tw/shop/6462',
#   'viewcount': 423670},
#  {'Ncomment': 194,
#   'address': '台北市中山區長安東路二段174-1號2樓',
#   'averagecost': 575,
#   'bigadd': '台北市',
#   'bigstyle': '鍋類',
#   'collecount': 1172,
#   'comments': ['http://www.ipeen.com.tw/comment/764836',
#    'http://www.ipeen.com.tw/comment/762508',
#    'http://www.ipeen.com.tw/comment/610694',
#    'http://www.ipeen.com.tw/comment/1262810',
#    'http://www.ipeen.com.tw/comment/1100411'],
#   'id': 43734,
#   'ipeenscore': 45,
#   'lat': 25.04814701028,
#   'lng': 121.54024900925,
#   'name': '私宅打邊爐(長安店)',
#   'reviewdate': '2016/08/29',
#   'smalladd': '中山區',
#   'smallstyle': '麻辣火鍋',
#   'status': '正常營業',
#   'tele': '0287725728',
#   'url': 'http://www.ipeen.com.tw/shop/43734',
#   'viewcount': 12560318},
#  {'Ncomment': 76,
#   'address': '台北市南港區經貿二路66號2樓-2',
#   'averagecost': 465,
#   'bigadd': '台北市',
#   'bigstyle': '中式料理',
#   'collecount': 624,
#   'comments': ['http://www.ipeen.com.tw/comment/903962',
#    'http://www.ipeen.com.tw/comment/878424',
#    'http://www.ipeen.com.tw/comment/859868',
#    'http://www.ipeen.com.tw/comment/859534',
#    'http://www.ipeen.com.tw/comment/857790'],
#   'id': 479588,
#   'ipeenscore': 50,
#   'lat': 25.0572974128,
#   'lng': 121.61647031525,
#   'name': '餡老滿(南港旗艦店)',
#   'reviewdate': '2015/04/22',
#   'smalladd': '南港區',
#   'smallstyle': '北京菜',
#   'status': '正常營業',
#   'tele': '0227893423',
#   'url': 'http://www.ipeen.com.tw/shop/479588',
#   'viewcount': 12306429},
#  {'Ncomment': 74,
#   'address': '台中市南屯區惠文路587號',
#   'averagecost': 1707,
#   'bigadd': '台中市',
#   'bigstyle': '異國料理',
#   'collecount': 546,
#   'comments': ['http://www.ipeen.com.tw/comment/1526996',
#    'http://www.ipeen.com.tw/comment/1507670',
#    'http://www.ipeen.com.tw/comment/1495001',
#    'http://www.ipeen.com.tw/comment/1476215',
#    'http://www.ipeen.com.tw/comment/1465328'],
#   'id': 44309,
#   'ipeenscore': 50,
#   'lat': 24.14930701034,
#   'lng': 120.64362201751999,
#   'name': 'LAFETE法月當代法式料理餐廳',
#   'reviewdate': '2009/06/09',
#   'smalladd': '南屯區',
#   'smallstyle': '法式料理',
#   'status': '正常營業',
#   'tele': '0422521680',
#   'url': 'http://www.ipeen.com.tw/shop/44309',
#   'viewcount': 338717},
#  {'Ncomment': 71,
#   'address': '台北市大安區仁愛路四段345巷4弄4號1樓',
#   'averagecost': 706,
#   'bigadd': '台北市',
#   'bigstyle': '主題特色餐廳',
#   'collecount': 2058,
#   'comments': ['http://www.ipeen.com.tw/comment/1026188',
#    'http://www.ipeen.com.tw/comment/1016884',
#    'http://www.ipeen.com.tw/comment/1004000',
#    'http://www.ipeen.com.tw/comment/925566',
#    'http://www.ipeen.com.tw/comment/921258'],
#   'id': 584085,
#   'ipeenscore': 45,
#   'lat': 25.038828010809997,
#   'lng': 121.55386601895,
#   'name': '鬍子餐酒',
#   'reviewdate': '2013/12/03',
#   'smalladd': '大安區',
#   'smallstyle': '其它主題餐廳',
#   'status': '正常營業',
#   'tele': '0287739292',
#   'url': 'http://www.ipeen.com.tw/shop/584085',
#   'viewcount': 380782},
#  {'Ncomment': 74,
#   'address': '新北市泰山區泰林路一段28-28號',
#   'averagecost': 502,
#   'bigadd': '新北市',
#   'bigstyle': '燒烤類',
#   'collecount': 344,
#   'comments': ['http://www.ipeen.com.tw/comment/993498',
#    'http://www.ipeen.com.tw/comment/991862',
#    'http://www.ipeen.com.tw/comment/989186',
#    'http://www.ipeen.com.tw/comment/984162',
#    'http://www.ipeen.com.tw/comment/982682'],
#   'id': 132057,
#   'ipeenscore': 45,
#   'lat': 25.05094790082,
#   'lng': 121.4398780155,
#   'name': '鑽木取火日式燒肉(新莊泰林店)',
#   'reviewdate': '2015/12/31',
#   'smalladd': '泰山區',
#   'smallstyle': '日式燒肉',
#   'status': '正常營業',
#   'tele': '0222972666',
#   'url': 'http://www.ipeen.com.tw/shop/132057',
#   'viewcount': 26190339},
#  {'Ncomment': 92,
#   'address': '台北市大安區通化街26-4號2樓(湳山戲院售票口旁)',
#   'averagecost': 184,
#   'bigadd': '台北市',
#   'bigstyle': '烘焙、甜點、零食',
#   'collecount': 1395,
#   'comments': ['http://www.ipeen.com.tw/comment/945108',
#    'http://www.ipeen.com.tw/comment/944106',
#    'http://www.ipeen.com.tw/comment/928826',
#    'http://www.ipeen.com.tw/comment/919142',
#    'http://www.ipeen.com.tw/comment/918306'],
#   'id': 600302,
#   'ipeenscore': 50,
#   'lat': 25.03166791584,
#   'lng': 121.55428351015999,
#   'name': 'Le Petit Waffle蕾蓓蒂比利時鬆餅專賣店',
#   'reviewdate': '2016/04/25',
#   'smalladd': '大安區',
#   'smallstyle': '休閒零食',
#   'status': '正常營業',
#   'tele': '0227085495',
#   'url': 'http://www.ipeen.com.tw/shop/600302',
#   'viewcount': 3520731},
#  {'Ncomment': 140,
#   'address': '台中市西區美村路一段158號',
#   'averagecost': 115,
#   'bigadd': '台中市',
#   'bigstyle': '主題特色餐廳',
#   'collecount': 836,
#   'comments': ['http://www.ipeen.com.tw/comment/1580745',
#    'http://www.ipeen.com.tw/comment/855212',
#    'http://www.ipeen.com.tw/comment/796104',
#    'http://www.ipeen.com.tw/comment/696016',
#    'http://www.ipeen.com.tw/comment/583640'],
#   'id': 134025,
#   'ipeenscore': 45,
#   'lat': 24.15059341135835,
#   'lng': 120.66146424275348,
#   'name': 'K5樂活冰品館(台中旗艦店)',
#   'reviewdate': '2014/04/10',
#   'smalladd': '西區',
#   'smallstyle': '食補藥膳餐廳',
#   'status': '正常營業',
#   'tele': '0423013949',
#   'url': 'http://www.ipeen.com.tw/shop/134025',
#   'viewcount': 5835588},
#  {'Ncomment': 110,
#   'address': '苗栗縣大湖鄉十份33號',
#   'averagecost': 376,
#   'bigadd': '苗栗縣',
#   'bigstyle': '主題特色餐廳',
#   'collecount': 413,
#   'comments': ['http://www.ipeen.com.tw/comment/1581879',
#    'http://www.ipeen.com.tw/comment/1574679',
#    'http://www.ipeen.com.tw/comment/1377200',
#    'http://www.ipeen.com.tw/comment/1224095',
#    'http://www.ipeen.com.tw/comment/1185791'],
#   'id': 42472,
#   'ipeenscore': 45,
#   'lat': 24.34937000448,
#   'lng': 120.77857881425999,
#   'name': '天空之城(天堂古堡)',
#   'reviewdate': '2017/01/17',
#   'smalladd': '大湖鄉',
#   'smallstyle': '景觀餐廳',
#   'status': '正常營業',
#   'tele': '037951815',
#   'url': 'http://www.ipeen.com.tw/shop/42472',
#   'viewcount': 648460},
#  {'Ncomment': 71,
#   'address': '台北市萬華區廣州街168號',
#   'averagecost': 68,
#   'bigadd': '台北市',
#   'bigstyle': '冰品、飲料、甜湯',
#   'collecount': 485,
#   'comments': ['http://www.ipeen.com.tw/comment/1483895',
#    'http://www.ipeen.com.tw/comment/1065306',
#    'http://www.ipeen.com.tw/comment/1044250',
#    'http://www.ipeen.com.tw/comment/1020626',
#    'http://www.ipeen.com.tw/comment/990734'],
#   'id': 8327,
#   'ipeenscore': 45,
#   'lat': 25.0366320129,
#   'lng': 121.49892200338999,
#   'name': '龍都冰果室',
#   'reviewdate': '2015/04/06',
#   'smalladd': '萬華區',
#   'smallstyle': '剉冰、豆花',
#   'status': '正常營業',
#   'tele': '0223083223',
#   'url': 'http://www.ipeen.com.tw/shop/8327',
#   'viewcount': 187143},
#  {'Ncomment': 75,
#   'address': '宜蘭縣羅東鎮民生路130號',
#   'averagecost': 31,
#   'bigadd': '宜蘭縣',
#   'bigstyle': '小吃',
#   'collecount': 495,
#   'comments': ['http://www.ipeen.com.tw/comment/1506995',
#    'http://www.ipeen.com.tw/comment/1196768',
#    'http://www.ipeen.com.tw/comment/1094063',
#    'http://www.ipeen.com.tw/comment/1056922',
#    'http://www.ipeen.com.tw/comment/1046334'],
#   'id': 1007950,
#   'ipeenscore': 45,
#   'lat': 24.67775710079,
#   'lng': 121.76695401163994,
#   'name': '義豐蔥油派',
#   'reviewdate': '2015/03/11',
#   'smalladd': '羅東鎮',
#   'smallstyle': '其他小吃',
#   'status': '正常營業',
#   'tele': '039573018',
#   'url': 'http://www.ipeen.com.tw/shop/1007950',
#   'viewcount': 172785},
#  {'Ncomment': 73,
#   'address': '台北市萬華區峨眉街36號',
#   'averagecost': 306,
#   'bigadd': '台北市',
#   'bigstyle': '日式料理',
#   'collecount': 377,
#   'comments': ['http://www.ipeen.com.tw/comment/1412339',
#    'http://www.ipeen.com.tw/comment/1382345',
#    'http://www.ipeen.com.tw/comment/1373759',
#    'http://www.ipeen.com.tw/comment/1373495',
#    'http://www.ipeen.com.tw/comment/1371131'],
#   'id': 23525,
#   'ipeenscore': 45,
#   'lat': 25.04351800253,
#   'lng': 121.50664801734004,
#   'name': '美觀園',
#   'reviewdate': '2017/04/28',
#   'smalladd': '萬華區',
#   'smallstyle': '綜合日式料理',
#   'status': '正常營業',
#   'tele': '0223317000',
#   'url': 'http://www.ipeen.com.tw/shop/23525',
#   'viewcount': 11973328},
#  {'Ncomment': 85,
#   'address': '台北市中山區南京東路一段19號',
#   'averagecost': 407,
#   'bigadd': '台北市',
#   'bigstyle': '異國料理',
#   'collecount': 550,
#   'comments': ['http://www.ipeen.com.tw/comment/1132532',
#    'http://www.ipeen.com.tw/comment/1107767',
#    'http://www.ipeen.com.tw/comment/985510',
#    'http://www.ipeen.com.tw/comment/980134',
#    'http://www.ipeen.com.tw/comment/979054'],
#   'id': 16551,
#   'ipeenscore': 45,
#   'lat': 25.052375012120002,
#   'lng': 121.5239060007,
#   'name': 'Vegas Fresh Cafe 義達餐廳(原Vegas Vegas維加斯美式餐廳)',
#   'reviewdate': '2015/12/22',
#   'smalladd': '中山區',
#   'smallstyle': '美式料理',
#   'status': '正常營業',
#   'tele': '0225416788',
#   'url': 'http://www.ipeen.com.tw/shop/16551',
#   'viewcount': 9051411},
#  {'Ncomment': 74,
#   'address': '台中市西屯區朝富路252號',
#   'averagecost': 294,
#   'bigadd': '台中市',
#   'bigstyle': '異國料理',
#   'collecount': 900,
#   'comments': ['http://www.ipeen.com.tw/comment/1512152',
#    'http://www.ipeen.com.tw/comment/1160576',
#    'http://www.ipeen.com.tw/comment/855960',
#    'http://www.ipeen.com.tw/comment/815978',
#    'http://www.ipeen.com.tw/comment/812936'],
#   'id': 585583,
#   'ipeenscore': 50,
#   'lat': 24.163586211840002,
#   'lng': 120.63562620009,
#   'name': 'Burger Joint 7分So 漢堡 早午餐專賣(朝富店)',
#   'reviewdate': '2015/03/17',
#   'smalladd': '西屯區',
#   'smallstyle': '美式料理',
#   'status': '正常營業',
#   'tele': '0422523309',
#   'url': 'http://www.ipeen.com.tw/shop/585583',
#   'viewcount': 5407754},
#  {'Ncomment': 61,
#   'address': '台北市大安區杭州南路二段17號',
#   'averagecost': 230,
#   'bigadd': '台北市',
#   'bigstyle': '中式料理',
#   'collecount': 788,
#   'comments': ['http://www.ipeen.com.tw/comment/1459046',
#    'http://www.ipeen.com.tw/comment/1189940',
#    'http://www.ipeen.com.tw/comment/1059114',
#    'http://www.ipeen.com.tw/comment/948268',
#    'http://www.ipeen.com.tw/comment/943122'],
#   'id': 35407,
#   'ipeenscore': 45,
#   'lat': 25.03410101885,
#   'lng': 121.52372700020999,
#   'name': '杭州小籠湯包(一店)',
#   'reviewdate': '2015/05/23',
#   'smalladd': '大安區',
#   'smallstyle': '麵食點心',
#   'status': '正常營業',
#   'tele': '0223931757',
#   'url': 'http://www.ipeen.com.tw/shop/35407',
#   'viewcount': 215008},
#  {'Ncomment': 126,
#   'address': '高雄市新興區中正四路31號',
#   'averagecost': 246,
#   'bigadd': '高雄市',
#   'bigstyle': '烘焙、甜點、零食',
#   'collecount': 317,
#   'comments': ['http://www.ipeen.com.tw/comment/1370279',
#    'http://www.ipeen.com.tw/comment/1075037',
#    'http://www.ipeen.com.tw/comment/1061662',
#    'http://www.ipeen.com.tw/comment/1061600',
#    'http://www.ipeen.com.tw/comment/1057578'],
#   'id': 76080,
#   'ipeenscore': 50,
#   'lat': 22.63075250156,
#   'lng': 120.30072230304997,
#   'name': '高雄不二家',
#   'reviewdate': '2016/07/11',
#   'smalladd': '新興區',
#   'smallstyle': '西點烘焙、麵包',
#   'status': '正常營業',
#   'tele': '072319666',
#   'url': 'http://www.ipeen.com.tw/shop/76080',
#   'viewcount': 4217642},
#  {'Ncomment': 164,
#   'address': '台北市大同區長安西路33號',
#   'averagecost': 337,
#   'bigadd': '台北市',
#   'bigstyle': '異國料理',
#   'collecount': 2277,
#   'comments': ['http://www.ipeen.com.tw/comment/1489124',
#    'http://www.ipeen.com.tw/comment/1483535',
#    'http://www.ipeen.com.tw/comment/1474262',
#    'http://www.ipeen.com.tw/comment/1469828',
#    'http://www.ipeen.com.tw/comment/1432763'],
#   'id': 141337,
#   'ipeenscore': 45,
#   'lat': 25.05037601933,
#   'lng': 121.51975500827001,
#   'name': '蘑菇森林義大利麵坊',
#   'reviewdate': '2017/04/28',
#   'smalladd': '大同區',
#   'smallstyle': '義式料理',
#   'status': '正常營業',
#   'tele': '0225509092',
#   'url': 'http://www.ipeen.com.tw/shop/141337',
#   'viewcount': 14080745},
#  {'Ncomment': 82,
#   'address': '台北市萬華區昆明街96巷4號2樓',
#   'averagecost': 304,
#   'bigadd': '台北市',
#   'bigstyle': '異國料理',
#   'collecount': 1488,
#   'comments': ['http://www.ipeen.com.twhttp://content.ipeen.com.tw/tastenews/62',
#    'http://www.ipeen.com.tw/comment/1418615',
#    'http://www.ipeen.com.tw/comment/1418609',
#    'http://www.ipeen.com.tw/comment/1277240',
#    'http://www.ipeen.com.tw/comment/1155920',
#    'http://www.ipeen.com.tw/comment/1143242'],
#   'id': 926202,
#   'ipeenscore': 45,
#   'lat': 25.04467981178,
#   'lng': 121.50504560882001,
#   'name': '1861 caffe',
#   'reviewdate': '2017/04/28',
#   'smalladd': '萬華區',
#   'smallstyle': '義式料理',
#   'status': '正常營業',
#   'tele': '0223820177',
#   'url': 'http://www.ipeen.com.tw/shop/926202',
#   'viewcount': 35305224},
#  {'Ncomment': 61,
#   'address': '台北市大安區忠孝東路四段289號B1',
#   'averagecost': 645,
#   'bigadd': '台北市',
#   'bigstyle': '鍋類',
#   'collecount': 1665,
#   'comments': ['http://www.ipeen.com.tw/comment/1348031',
#    'http://www.ipeen.com.tw/comment/1347410',
#    'http://www.ipeen.com.tw/comment/1297589',
#    'http://www.ipeen.com.tw/comment/1292300',
#    'http://www.ipeen.com.tw/comment/1291400'],
#   'id': 712324,
#   'ipeenscore': 45,
#   'lat': 25.04170101131,
#   'lng': 121.55471400108999,
#   'name': '醉麻辣',
#   'reviewdate': '2016/04/12',
#   'smalladd': '大安區',
#   'smallstyle': '麻辣火鍋',
#   'status': '正常營業',
#   'tele': '0277112789',
#   'url': 'http://www.ipeen.com.tw/shop/712324',
#   'viewcount': 5341991},
#  {'Ncomment': 57,
#   'address': '台北市大安區延吉街294號',
#   'averagecost': 202,
#   'bigadd': '台北市',
#   'bigstyle': '日式料理',
#   'collecount': 1936,
#   'comments': ['http://www.ipeen.com.tw/comment/1344869',
#    'http://www.ipeen.com.tw/comment/1048344',
#    'http://www.ipeen.com.tw/comment/1030844',
#    'http://www.ipeen.com.tw/comment/1008000',
#    'http://www.ipeen.com.tw/comment/998764'],
#   'id': 628558,
#   'ipeenscore': 45,
#   'lat': 25.03332001483,
#   'lng': 121.55725400714006,
#   'name': '寅樂屋 Torarakuya-Taipei',
#   'reviewdate': '2014/02/11',
#   'smalladd': '大安區',
#   'smallstyle': '其他日式料理',
#   'status': '正常營業',
#   'tele': '0223257874',
#   'url': 'http://www.ipeen.com.tw/shop/628558',
#   'viewcount': 137454},
#  {'Ncomment': 246,
#   'address': '台中市中區中山路20號',
#   'averagecost': 171,
#   'bigadd': '台中市',
#   'bigstyle': '主題特色餐廳',
#   'collecount': 1220,
#   'comments': ['http://www.ipeen.com.tw/comment/1258208',
#    'http://www.ipeen.com.tw/comment/1243334',
#    'http://www.ipeen.com.tw/comment/1150727',
#    'http://www.ipeen.com.tw/comment/1109213',
#    'http://www.ipeen.com.tw/comment/1067000'],
#   'id': 141715,
#   'ipeenscore': 45,
#   'lat': 24.13781101447,
#   'lng': 120.6833570038,
#   'name': '宮原眼科',
#   'reviewdate': '2013/08/06',
#   'smalladd': '中區',
#   'smallstyle': '懷舊主題',
#   'status': '正常營業',
#   'tele': '0422271927',
#   'url': 'http://www.ipeen.com.tw/shop/141715',
#   'viewcount': 1280543},
#  {'Ncomment': 89,
#   'address': '台北市內湖區瑞光路316巷58號',
#   'averagecost': 534,
#   'bigadd': '台北市',
#   'bigstyle': '異國料理',
#   'collecount': 871,
#   'comments': ['http://www.ipeen.com.tw/comment/1555872',
#    'http://www.ipeen.com.tw/comment/1467686',
#    'http://www.ipeen.com.tw/comment/1234055',
#    'http://www.ipeen.com.tw/comment/1194833',
#    'http://www.ipeen.com.tw/comment/1155863'],
#   'id': 942500,
#   'ipeenscore': 50,
#   'lat': 25.07579980173,
#   'lng': 121.57331471511,
#   'name': 'Mastro Cafe',
#   'reviewdate': '2016/03/27',
#   'smalladd': '內湖區',
#   'smallstyle': '美式料理',
#   'status': '正常營業',
#   'tele': '0287523558',
#   'url': 'http://www.ipeen.com.tw/shop/942500',
#   'viewcount': 4878848},
#  {'Ncomment': 85,
#   'address': '台北市中山區松江路129-4號1樓',
#   'averagecost': 623,
#   'bigadd': '台北市',
#   'bigstyle': '鍋類',
#   'collecount': 739,
#   'comments': ['http://www.ipeen.com.tw/comment/1511408',
#    'http://www.ipeen.com.tw/comment/1500833',
#    'http://www.ipeen.com.tw/comment/1217174',
#    'http://www.ipeen.com.tw/comment/1049076',
#    'http://www.ipeen.com.tw/comment/1034816'],
#   'id': 663462,
#   'ipeenscore': 45,
#   'lat': 25.0539150057,
#   'lng': 121.53339100013994,
#   'name': '辛殿麻辣鍋(松江南京店)',
#   'reviewdate': '2016/03/27',
#   'smalladd': '中山區',
#   'smallstyle': '麻辣火鍋',
#   'status': '正常營業',
#   'tele': '0225037667',
#   'url': 'http://www.ipeen.com.tw/shop/663462',
#   'viewcount': 10719783},
#  {'Ncomment': 122,
#   'address': '台北市大安區羅斯福路三段245號2樓',
#   'averagecost': 493,
#   'bigadd': '台北市',
#   'bigstyle': '異國料理',
#   'collecount': 353,
#   'comments': ['http://www.ipeen.com.tw/comment/914462',
#    'http://www.ipeen.com.tw/comment/875668',
#    'http://www.ipeen.com.tw/comment/728296',
#    'http://www.ipeen.com.tw/comment/716218',
#    'http://www.ipeen.com.tw/comment/712590'],
#   'id': 73732,
#   'ipeenscore': 45,
#   'lat': 25.0193320166,
#   'lng': 121.52999600912,
#   'name': '洋旗牛排餐廳',
#   'reviewdate': '2016/03/27',
#   'smalladd': '大安區',
#   'smallstyle': '義式料理',
#   'status': '正常營業',
#   'tele': '0223672559',
#   'url': 'http://www.ipeen.com.tw/shop/73732',
#   'viewcount': 3872589},
#  {'Ncomment': 92,
#   'address': '台中市北屯區崇德路二段101號1F',
#   'averagecost': 365,
#   'bigadd': '台中市',
#   'bigstyle': '日式料理',
#   'collecount': 261,
#   'comments': ['http://www.ipeen.com.tw/comment/699624',
#    'http://www.ipeen.com.tw/comment/465824',
#    'http://www.ipeen.com.tw/comment/459356',
#    'http://www.ipeen.com.tw/comment/458356',
#    'http://www.ipeen.com.tw/comment/458274'],
#   'id': 91956,
#   'ipeenscore': 50,
#   'lat': 24.17104801386,
#   'lng': 120.68520400784,
#   'name': '勝博殿日式炸豬排(台中崇德旗艦店)',
#   'reviewdate': '2016/04/05',
#   'smalladd': '北屯區',
#   'smallstyle': '日式豬排專賣',
#   'status': '正常營業',
#   'tele': '0422312538',
#   'url': 'http://www.ipeen.com.tw/shop/91956',
# ...
#    'http://www.ipeen.com.tw/comment/609888',
#    'http://www.ipeen.com.tw/comment/602642',
#    'http://www.ipeen.com.tw/comment/377103'],
#   'id': 19699,
#   'ipeenscore': 45,
#   'lat': 25.01112101587,
#   'lng': 121.51447501557,
#   'name': '麒麟閣火鍋店',
#   'othername': 0,
#   'reviewdate': '2015/04/23',
#   'smalladd': '永和區',
#   'smallstyle': '其他鍋類',
#   'status': '正常營業',
#   'tele': '0229249259',
#   'url': 'http://www.ipeen.com.tw/shop/19699',
#   'viewcount': 205863},
#  {'Ncomment': 43,
#   'address': '台北市中山區松江路128號1樓',
#   'averagecost': 679,
#   'bigadd': '台北市',
#   'bigstyle': '中式料理',
#   'collecount': 285,
#   'comments': ['http://www.ipeen.com.tw/comment/1096094',
#    'http://www.ipeen.com.tw/comment/1063100',
#    'http://www.ipeen.com.tw/comment/1036894',
#    'http://www.ipeen.com.tw/comment/985944',
#    'http://www.ipeen.com.tw/comment/975732'],
#   'id': 617568,
#   'ipeenscore': 45,
#   'lat': 25.052834830159142,
#   'lng': 121.53284948573163,
#   'name': '滿穗台菜餐廳',
#   'othername': 0,
#   'reviewdate': '2015/12/22',
#   'smalladd': '中山區',
#   'smallstyle': '台菜餐廳',
#   'status': '正常營業',
#   'tele': '0225412020',
#   'url': 'http://www.ipeen.com.tw/shop/617568',
#   'viewcount': 7512214},
#  {'Ncomment': 44,
#   'address': '高雄市鳥松區球場路63號(近本館路)',
#   'averagecost': 319,
#   'bigadd': '高雄市',
#   'bigstyle': '烘焙、甜點、零食',
#   'collecount': 175,
#   'comments': ['http://www.ipeen.com.twhttp://content.ipeen.com.tw/tastenews/602',
#    'http://www.ipeen.com.tw/comment/1287035',
#    'http://www.ipeen.com.tw/comment/1284374',
#    'http://www.ipeen.com.tw/comment/995110',
#    'http://www.ipeen.com.tw/comment/995014',
#    'http://www.ipeen.com.tw/comment/987800'],
#   'id': 580163,
#   'ipeenscore': 45,
#   'lat': 22.656123972609997,
#   'lng': 120.33669304608,
#   'name': '火星糖(球場路門市)',
#   'othername': '球場路門市',
#   'reviewdate': '2016/04/05',
#   'smalladd': '鳥松區',
#   'smallstyle': '休閒零食',
#   'status': '正常營業',
#   'tele': '073702775',
#   'url': 'http://www.ipeen.com.tw/shop/580163',
#   'viewcount': 6996497},
#  {'Ncomment': 32,
#   'address': '台中市西區精誠五街4號',
#   'averagecost': 343,
#   'bigadd': '台中市',
#   'bigstyle': '異國料理',
#   'collecount': 433,
#   'comments': ['http://www.ipeen.com.tw/comment/1266893',
#    'http://www.ipeen.com.tw/comment/1066740',
#    'http://www.ipeen.com.tw/comment/958126',
#    'http://www.ipeen.com.tw/comment/956304',
#    'http://www.ipeen.com.tw/comment/937944'],
#   'id': 1022258,
#   'ipeenscore': 45,
#   'lat': 24.15568231167,
#   'lng': 120.65657301943,
#   'name': 'KATZ 卡司複合式餐廳',
#   'othername': 0,
#   'reviewdate': '2016/05/30',
#   'smalladd': '西區',
#   'smallstyle': '其他異國料理',
#   'status': '正常營業',
#   'tele': '0423267355',
#   'url': 'http://www.ipeen.com.tw/shop/1022258',
#   'viewcount': 3254607},
#  {'Ncomment': 52,
#   'address': '台中市中區自由路二段25號',
#   'averagecost': 270,
#   'bigadd': '台中市',
#   'bigstyle': '烘焙、甜點、零食',
#   'collecount': 109,
#   'comments': ['http://www.ipeen.com.tw/comment/1397933',
#    'http://www.ipeen.com.tw/comment/1397930',
#    'http://www.ipeen.com.tw/comment/1395260',
#    'http://www.ipeen.com.tw/comment/1395257',
#    'http://www.ipeen.com.tw/comment/1394435'],
#   'id': 37680,
#   'ipeenscore': 45,
#   'lat': 24.138881795565144,
#   'lng': 120.68119116179399,
#   'name': '太陽堂老店',
#   'othername': 0,
#   'reviewdate': '2016/12/27',
#   'smalladd': '中區',
#   'smallstyle': '中式糕餅',
#   'status': '正常營業',
#   'tele': '0422200012',
#   'url': 'http://www.ipeen.com.tw/shop/37680',
#   'viewcount': 4490923},
#  {'Ncomment': 37,
#   'address': '台南市中西區南門路67號2樓',
#   'averagecost': 196,
#   'bigadd': '台南市',
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 525,
#   'comments': ['http://www.ipeen.com.tw/comment/924252',
#    'http://www.ipeen.com.tw/comment/793604',
#    'http://www.ipeen.com.tw/comment/723744',
#    'http://www.ipeen.com.tw/comment/676724',
#    'http://www.ipeen.com.tw/comment/666160'],
#   'id': 10492,
#   'ipeenscore': 45,
#   'lat': 22.989722017080002,
#   'lng': 120.20486501450999,
#   'name': '窄門咖啡',
#   'othername': 0,
#   'reviewdate': '2016/06/24',
#   'smalladd': '中西區',
#   'smallstyle': '咖啡專賣',
#   'status': '正常營業',
#   'tele': '062110508',
#   'url': 'http://www.ipeen.com.tw/shop/10492',
#   'viewcount': 151291},
#  {'Ncomment': 30,
#   'address': '台北市大安區敦化南路一段190巷16號',
#   'averagecost': 381,
#   'bigadd': '台北市',
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 630,
#   'comments': ['http://www.ipeen.com.tw/comment/1332584',
#    'http://www.ipeen.com.tw/comment/1199237',
#    'http://www.ipeen.com.tw/comment/973644',
#    'http://www.ipeen.com.tw/comment/935970',
#    'http://www.ipeen.com.tw/comment/882420'],
#   'id': 958360,
#   'ipeenscore': 45,
#   'lat': 25.04252800706,
#   'lng': 121.54769800244996,
#   'name': 'Caldo Cafe(咖朵二店)',
#   'othername': '咖朵二店',
#   'reviewdate': '2014/06/18',
#   'smalladd': '大安區',
#   'smallstyle': '咖啡專賣',
#   'status': '正常營業',
#   'tele': '0227218895',
#   'url': 'http://www.ipeen.com.tw/shop/958360',
#   'viewcount': 59179},
#  {'Ncomment': 41,
#   'address': '台南市中西區永福路二段68號',
#   'averagecost': 161,
#   'bigadd': '台南市',
#   'bigstyle': '日式料理',
#   'collecount': 493,
#   'comments': ['http://www.ipeen.com.tw/comment/791530',
#    'http://www.ipeen.com.tw/comment/750152',
#    'http://www.ipeen.com.tw/comment/727546',
#    'http://www.ipeen.com.tw/comment/715764',
#    'http://www.ipeen.com.tw/comment/710140'],
#   'id': 44319,
#   'ipeenscore': 45,
#   'lat': 22.99332101349,
#   'lng': 120.20104000208,
#   'name': '橋北屋日本家庭料理(永福店)',
#   'othername': '永福店',
#   'reviewdate': '2016/04/26',
#   'smalladd': '中西區',
#   'smallstyle': '其他日式料理',
#   'status': '正常營業',
#   'tele': '062280946',
#   'url': 'http://www.ipeen.com.tw/shop/44319',
#   'viewcount': 229921},
#  {'Ncomment': 49,
#   'address': '台北市內湖區內湖路一段300號',
#   'averagecost': 230,
#   'bigadd': '台北市',
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 347,
#   'comments': ['http://www.ipeen.com.tw/comment/1532087',
#    'http://www.ipeen.com.tw/comment/1000740',
#    'http://www.ipeen.com.tw/comment/970850',
#    'http://www.ipeen.com.tw/comment/966006',
#    'http://www.ipeen.com.tw/comment/962740'],
#   'id': 946534,
#   'ipeenscore': 45,
#   'lat': 25.081933614729998,
#   'lng': 121.56854670577007,
#   'name': '貳樓餐廳 Second Floor Cafe(西湖店)',
#   'othername': '西湖店',
#   'reviewdate': '2016/04/03',
#   'smalladd': '內湖區',
#   'smallstyle': '複合式',
#   'status': '正常營業',
#   'tele': '0227997922',
#   'url': 'http://www.ipeen.com.tw/shop/946534',
#   'viewcount': 88020},
#  {'Ncomment': 32,
#   'address': '台北市大同區南京西路25巷2-1號',
#   'averagecost': 752,
#   'bigadd': '台北市',
#   'bigstyle': '燒烤類',
#   'collecount': 549,
#   'comments': ['http://www.ipeen.com.tw/comment/1075013',
#    'http://www.ipeen.com.tw/comment/920770',
#    'http://www.ipeen.com.tw/comment/915168',
#    'http://www.ipeen.com.tw/comment/801344',
#    'http://www.ipeen.com.tw/comment/748100'],
#   'id': 8678,
#   'ipeenscore': 45,
#   'lat': 25.05317101971,
#   'lng': 121.52019600346,
#   'name': '乾杯(中山店)',
#   'othername': '中山店',
#   'reviewdate': '2017/05/06',
#   'smalladd': '大同區',
#   'smallstyle': '日式燒肉',
#   'status': '正常營業',
#   'tele': '0225556110',
#   'url': 'http://www.ipeen.com.tw/shop/8678',
#   'viewcount': 310931},
#  {'Ncomment': 42,
#   'address': '台北市文山區興隆路一段167號',
#   'averagecost': 341,
#   'bigadd': '台北市',
#   'bigstyle': '中式料理',
#   'collecount': 280,
#   'comments': ['http://www.ipeen.com.tw/comment/735666',
#    'http://www.ipeen.com.tw/comment/701812',
#    'http://www.ipeen.com.tw/comment/199637',
#    'http://www.ipeen.com.tw/comment/197832',
#    'http://www.ipeen.com.tw/comment/158826'],
#   'id': 22773,
#   'ipeenscore': 45,
#   'lat': 25.00141700851,
#   'lng': 121.542737019,
#   'name': '福利餐廳',
#   'othername': 0,
#   'reviewdate': '2015/04/25',
#   'smalladd': '文山區',
#   'smallstyle': '四川菜',
#   'status': '正常營業',
#   'tele': '0229356298',
#   'url': 'http://www.ipeen.com.tw/shop/22773',
#   'viewcount': 357302},
#  {'Ncomment': 41,
#   'address': '台北市內湖區港墘路127巷7號',
#   'averagecost': 134,
#   'bigadd': '台北市',
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 354,
#   'comments': ['http://www.ipeen.com.tw/comment/982900',
#    'http://www.ipeen.com.tw/comment/909718',
#    'http://www.ipeen.com.tw/comment/831370',
#    'http://www.ipeen.com.tw/comment/827606',
#    'http://www.ipeen.com.tw/comment/825352'],
#   'id': 997662,
#   'ipeenscore': 45,
#   'lat': 25.077875560847612,
#   'lng': 121.57649774086016,
#   'name': 'Waffle Please 比利時列日鬆餅專賣店(內湖店)',
#   'othername': '內湖店',
#   'reviewdate': '2016/03/27',
#   'smalladd': '內湖區',
#   'smallstyle': '複合式',
#   'status': '正常營業',
#   'tele': '0287510762',
#   'url': 'http://www.ipeen.com.tw/shop/997662',
#   'viewcount': 1418975},
#  {'Ncomment': 39,
#   'address': '台北市松山區民生東路五段137巷4弄31號',
#   'averagecost': 404,
#   'bigadd': '台北市',
#   'bigstyle': '鍋類',
#   'collecount': 318,
#   'comments': ['http://www.ipeen.com.tw/comment/1021468',
#    'http://www.ipeen.com.tw/comment/1013526',
#    'http://www.ipeen.com.tw/comment/980716',
#    'http://www.ipeen.com.tw/comment/893128',
#    'http://www.ipeen.com.tw/comment/782414'],
#   'id': 88645,
#   'ipeenscore': 45,
#   'lat': 25.05993001367,
#   'lng': 121.56265600739,
#   'name': '好食多涮涮屋(民生店)',
#   'othername': '民生店',
#   'reviewdate': '2016/03/27',
#   'smalladd': '松山區',
#   'smallstyle': '其他鍋類',
#   'status': '正常營業',
#   'tele': '0227608370',
#   'url': 'http://www.ipeen.com.tw/shop/88645',
#   'viewcount': 147317},
#  {'Ncomment': 27,
#   'address': '新北市板橋區中山路一段161號33樓',
#   'averagecost': 505,
#   'bigadd': '新北市',
#   'bigstyle': '主題特色餐廳',
#   'collecount': 1124,
#   'comments': ['http://www.ipeen.com.tw/comment/866312',
#    'http://www.ipeen.com.tw/comment/830388',
#    'http://www.ipeen.com.tw/comment/719576',
#    'http://www.ipeen.com.tw/comment/719446',
#    'http://www.ipeen.com.tw/comment/697726'],
#   'id': 586111,
#   'ipeenscore': 45,
#   'lat': 25.0122349136,
#   'lng': 121.46554101710001,
#   'name': 'ARTCO典藏33觀景餐廳',
#   'othername': 0,
#   'reviewdate': '2013/09/16',
#   'smalladd': '板橋區',
#   'smallstyle': '景觀餐廳',
#   'status': '正常營業',
#   'tele': '0229550633',
#   'url': 'http://www.ipeen.com.tw/shop/586111',
#   'viewcount': 263019},
#  {'Ncomment': 48,
#   'address': '台北市南港區南港路一段201號',
#   'averagecost': 159,
#   'bigadd': '台北市',
#   'bigstyle': '中式料理',
#   'collecount': 284,
#   'comments': ['http://www.ipeen.com.tw/comment/1357379',
#    'http://www.ipeen.com.tw/comment/1274801',
#    'http://www.ipeen.com.tw/comment/1268804',
#    'http://www.ipeen.com.tw/comment/1162166',
#    'http://www.ipeen.com.tw/comment/916054'],
#   'id': 53263,
#   'ipeenscore': 45,
#   'lat': 25.05505401223,
#   'lng': 121.61171901188,
#   'name': '南港 北大荒水餃店',
#   'othername': 0,
#   'reviewdate': '2016/12/21',
#   'smalladd': '南港區',
#   'smallstyle': '麵食點心',
#   'status': '正常營業',
#   'tele': '0227880455',
#   'url': 'http://www.ipeen.com.tw/shop/53263',
#   'viewcount': 152597},
#  {'Ncomment': 22,
#   'address': '台北市松山區民生東路四段56巷1弄3號',
#   'averagecost': 272,
#   'bigadd': '台北市',
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 1422,
#   'comments': ['http://www.ipeen.com.tw/comment/886860',
#    'http://www.ipeen.com.tw/comment/759090',
#    'http://www.ipeen.com.tw/comment/747634',
#    'http://www.ipeen.com.tw/comment/700062',
#    'http://www.ipeen.com.tw/comment/698756'],
#   'id': 920770,
#   'ipeenscore': 45,
#   'lat': 25.05760791015,
#   'lng': 121.55181601441004,
#   'name': '民生工寓coffee essential',
#   'othername': 0,
#   'reviewdate': '2014/04/28',
#   'smalladd': '松山區',
#   'smallstyle': '咖啡專賣',
#   'status': '正常營業',
#   'tele': '0287121220',
#   'url': 'http://www.ipeen.com.tw/shop/920770',
#   'viewcount': 75614},
#  {'Ncomment': 34,
#   'address': '台中市西屯區文心路三段93-1號',
#   'averagecost': 795,
#   'bigadd': '台中市',
#   'bigstyle': '日式料理',
#   'collecount': 403,
#   'comments': ['http://www.ipeen.com.tw/comment/1572813',
#    'http://www.ipeen.com.tw/comment/1543277',
#    'http://www.ipeen.com.tw/comment/1503617',
#    'http://www.ipeen.com.tw/comment/1402625',
#    'http://www.ipeen.com.tw/comment/1342010'],
#   'id': 958862,
#   'ipeenscore': 50,
#   'lat': 24.16715100767,
#   'lng': 120.65267800923999,
#   'name': '將軍府',
#   'othername': 0,
#   'reviewdate': '2015/02/11',
#   'smalladd': '西屯區',
#   'smallstyle': '居酒屋',
#   'status': '正常營業',
#   'tele': '0423177243',
#   'url': 'http://www.ipeen.com.tw/shop/958862',
#   'viewcount': 4429821},
#  {'Ncomment': 45,
#   'address': '台北市大安區忠孝東路四段98號6樓(Bistro98)',
#   'averagecost': 542,
#   'bigadd': '台北市',
#   'bigstyle': '亞洲料理',
#   'collecount': 321,
#   'comments': ['http://www.ipeen.com.tw/comment/1502093',
#    'http://www.ipeen.com.tw/comment/1166543',
#    'http://www.ipeen.com.tw/comment/1036432',
#    'http://www.ipeen.com.tw/comment/1028456',
#    'http://www.ipeen.com.tw/comment/943798'],
#   'id': 627400,
#   'ipeenscore': 45,
#   'lat': 25.04137001975,
#   'lng': 121.5462920114,
#   'name': '饗泰多泰式餐廳',
#   'othername': 0,
#   'reviewdate': '2016/04/05',
#   'smalladd': '大安區',
#   'smallstyle': '泰式料理',
#   'status': '正常營業',
#   'tele': '0287729838',
#   'url': 'http://www.ipeen.com.tw/shop/627400',
#   'viewcount': 2258030},
#  {'Ncomment': 56,
#   'address': '台北市大安區光復南路612號',
#   'averagecost': 1248,
#   'bigadd': '台北市',
#   'bigstyle': '異國料理',
#   'collecount': 95,
#   'comments': ['http://www.ipeen.com.tw/comment/1483409',
#    'http://www.ipeen.com.tw/comment/1308428',
#    'http://www.ipeen.com.tw/comment/1284653',
#    'http://www.ipeen.com.tw/comment/685390',
#    'http://www.ipeen.com.tw/comment/592410'],
#   'id': 16759,
#   'ipeenscore': 45,
#   'lat': 25.032399005040002,
#   'lng': 121.55732901745,
#   'name': '王品牛排(台北光復南店)',
#   'othername': '台北光復南店',
#   'reviewdate': '2017/05/04',
#   'smalladd': '大安區',
#   'smallstyle': '美式料理',
#   'status': '正常營業',
#   'tele': '0223253478',
#   'url': 'http://www.ipeen.com.tw/shop/16759',
#   'viewcount': 240397},
#  {'Ncomment': 45,
#   'address': '台中市大甲區文曲路586巷10號',
#   'averagecost': 368,
#   'bigadd': '台中市',
#   'bigstyle': '鍋類',
#   'collecount': 282,
#   'comments': ['http://www.ipeen.com.tw/comment/457136',
#    'http://www.ipeen.com.tw/comment/424934',
#    'http://www.ipeen.com.tw/comment/359250',
#    'http://www.ipeen.com.tw/comment/352859',
#    'http://www.ipeen.com.tw/comment/352009'],
#   'id': 123301,
#   'ipeenscore': 45,
#   'lat': 24.34087501629,
#   'lng': 120.61500400288,
#   'name': '大甲鍋神庭園日式涮涮鍋',
#   'othername': 0,
#   'reviewdate': '2017/10/24',
#   'smalladd': '大甲區',
#   'smallstyle': '涮涮鍋',
#   'status': '正常營業',
#   'tele': '0426863355',
#   'url': 'http://www.ipeen.com.tw/shop/123301',
#   'viewcount': 816390},
#  {'Ncomment': 49,
#   'address': '苗栗縣三義鄉雙潭村13鄰崩山下1-9號',
#   'averagecost': 720,
#   'bigadd': '苗栗縣',
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 163,
#   'comments': ['http://www.ipeen.com.tw/comment/1436615',
#    'http://www.ipeen.com.tw/comment/749432',
#    'http://www.ipeen.com.tw/comment/743978',
#    'http://www.ipeen.com.tw/comment/725852',
#    'http://www.ipeen.com.tw/comment/716906'],
#   'id': 25294,
#   'ipeenscore': 45,
#   'lat': 24.3793568239467,
#   'lng': 120.77363543746274,
#   'name': '卓也小屋養生館(卓也小屋民宿)',
#   'othername': 0,
#   'reviewdate': '2015/04/26',
#   'smalladd': '三義鄉',
#   'smallstyle': '複合式',
#   'status': '正常營業',
#   'tele': '037879198',
#   'url': 'http://www.ipeen.com.tw/shop/25294',
#   'viewcount': 212927},
#  {'Ncomment': 51,
#   'address': '台中市西區大忠南街82巷10號',
#   'averagecost': 209,
#   'bigadd': '台中市',
#   'bigstyle': '其他美食',
#   'collecount': 16,
#   'comments': ['http://www.ipeen.com.tw/comment/1052438',
#    'http://www.ipeen.com.tw/comment/1046752',
#    'http://www.ipeen.com.tw/comment/1046392',
#    'http://www.ipeen.com.tw/comment/1046348',
#    'http://www.ipeen.com.tw/comment/1044370'],
#   'id': 88095,
#   'ipeenscore': 45,
#   'lat': 24.138650817280002,
#   'lng': 120.65546911243,
#   'name': '饗城食品(常溫方便菜系列)',
#   'othername': 0,
#   'reviewdate': '2016/04/29',
#   'smalladd': '西區',
#   'smallstyle': '其他美食',
#   'status': '正常營業',
#   'tele': '0966762900',
#   'url': 'http://www.ipeen.com.tw/shop/88095',
#   'viewcount': 4289829},
#  {'Ncomment': 47,
#   'address': '新北市板橋區實踐路30號',
#   'averagecost': 340,
#   'bigadd': '新北市',
#   'bigstyle': '亞洲料理',
#   'collecount': 154,
#   'comments': ['http://www.ipeen.com.tw/comment/1324073',
#    'http://www.ipeen.com.tw/comment/1240799',
#    'http://www.ipeen.com.tw/comment/1206098',
#    'http://www.ipeen.com.tw/comment/1198637',
#    'http://www.ipeen.com.tw/comment/1191140'],
#   'id': 1055732,
#   'ipeenscore': 45,
#   'lat': 25.00716590077,
#   'lng': 121.46340800028,
#   'name': 'OMAYA春川炒雞(板橋店)',
#   'othername': '板橋店',
#   'reviewdate': '2016/02/05',
#   'smalladd': '板橋區',
#   'smallstyle': '韓式料理',
#   'status': '正常營業',
#   'tele': '0229597877',
#   'url': 'http://www.ipeen.com.tw/shop/1055732',
#   'viewcount': 3022866},
#  ...]

# %%
# Out:
# [{'Ncomment': 37,
#   'address': '台中市南屯區公益路二段387號',
#   'averagecost': 659,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 1053,
#   'comments': ['http://www.ipeen.com.tw/comment/733822',
#    'http://www.ipeen.com.tw/comment/730168',
#    'http://www.ipeen.com.tw/comment/687294',
#    'http://www.ipeen.com.tw/comment/584468',
#    'http://www.ipeen.com.tw/comment/528464'],
#   'id': 54180,
#   'ipeenscore': 45,
#   'lat': 24.15130065819473,
#   'lng': 120.64156990234083,
#   'name': '羊角日式炭火燒肉吃到飽',
#   'reviewdate': '2016/08/11',
#   'smalladd': '南屯區',
#   'smallstyle': '炭烤串燒',
#   'status': '正常營業',
#   'tele': '0422523355',
#   'url': 'http://www.ipeen.com.tw/shop/54180',
#   'viewcount': 5421546},
#  {'Ncomment': 42,
#   'address': '台中市西屯區太原路一段255號',
#   'averagecost': 885,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 134,
#   'comments': ['http://www.ipeen.com.twhttp://content.ipeen.com.tw/tastenews/698',
#    'http://www.ipeen.com.tw/comment/1582680',
#    'http://www.ipeen.com.tw/comment/1558245',
#    'http://www.ipeen.com.tw/comment/1558233',
#    'http://www.ipeen.com.tw/comment/1558227',
#    'http://www.ipeen.com.tw/comment/1557981'],
#   'id': 1074904,
#   'ipeenscore': 45,
#   'lat': 24.163928103112525,
#   'lng': 120.66301367418228,
#   'name': '雲火日式燒肉',
#   'othername': 0,
#   'reviewdate': '2017/06/12',
#   'smalladd': '西屯區',
#   'smallstyle': '日式燒肉',
#   'status': '正常營業',
#   'tele': '0423110071',
#   'url': 'http://www.ipeen.com.tw/shop/1074904',
#   'viewcount': 2116127},
#  {'Ncomment': 31,
#   'address': '台中市南屯區公益路二段631號',
#   'averagecost': 468,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 183,
#   'comments': ['http://www.ipeen.com.tw/comment/1272566',
#    'http://www.ipeen.com.tw/comment/1199396',
#    'http://www.ipeen.com.tw/comment/1135052',
#    'http://www.ipeen.com.tw/comment/1095224',
#    'http://www.ipeen.com.tw/comment/1060528'],
#   'id': 1022168,
#   'ipeenscore': 45,
#   'lat': 24.15080380833,
#   'lng': 120.63366600977001,
#   'name': 'リ味館生鮮水產，現烤海鮮',
#   'othername': 0,
#   'reviewdate': '2016/04/05',
#   'smalladd': '南屯區',
#   'smallstyle': '炭烤串燒',
#   'status': '正常營業',
#   'tele': '0920808651',
#   'url': 'http://www.ipeen.com.tw/shop/1022168',
#   'viewcount': 4300922},
#  {'Ncomment': 24,
#   'address': '台中市南屯區東興路二段340號',
#   'averagecost': 542,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 412,
#   'comments': ['http://www.ipeen.com.tw/comment/939348',
#    'http://www.ipeen.com.tw/comment/920278',
#    'http://www.ipeen.com.tw/comment/869200',
#    'http://www.ipeen.com.tw/comment/809306',
#    'http://www.ipeen.com.tw/comment/736954'],
#   'id': 2903,
#   'ipeenscore': 45,
#   'lat': 24.144775014929998,
#   'lng': 120.65318800267,
#   'name': '澄川黃鶴洞燒肉之丘(創始店)',
#   'othername': '創始店',
#   'reviewdate': '2016/05/11',
#   'smalladd': '南屯區',
#   'smallstyle': '韓式燒肉',
#   'status': '正常營業',
#   'tele': '0424737865',
#   'url': 'http://www.ipeen.com.tw/shop/2903',
#   'viewcount': 329511},
#  {'Ncomment': 26,
#   'address': '台中市南屯區黎明路二段382號',
#   'averagecost': 558,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 282,
#   'comments': ['http://www.ipeen.com.tw/comment/1567614',
#    'http://www.ipeen.com.tw/comment/1513601',
#    'http://www.ipeen.com.tw/comment/1036714',
#    'http://www.ipeen.com.tw/comment/1035760',
#    'http://www.ipeen.com.tw/comment/1000300'],
#   'id': 580913,
#   'ipeenscore': 45,
#   'lat': 24.151002433972206,
#   'lng': 120.63524723360979,
#   'name': '森森燒肉(原:小匠屋)',
#   'othername': 0,
#   'reviewdate': '2017/06/06',
#   'smalladd': '南屯區',
#   'smallstyle': '日式燒肉',
#   'status': '正常營業',
#   'tele': '0422582302',
#   'url': 'http://www.ipeen.com.tw/shop/580913',
#   'viewcount': 161392},
#  {'Ncomment': 30,
#   'address': '台中市西區忠明南路229號',
#   'averagecost': 555,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 68,
#   'comments': ['http://www.ipeen.com.tw/comment/1468298',
#    'http://www.ipeen.com.tw/comment/1420148',
#    'http://www.ipeen.com.tw/comment/1412951',
#    'http://www.ipeen.com.tw/comment/1404404',
#    'http://www.ipeen.com.tw/comment/1334621'],
#   'id': 1023560,
#   'ipeenscore': 45,
#   'lat': 24.147948212659998,
#   'lng': 120.65759581383,
#   'name': '店小二串燒燒肉',
#   'othername': 0,
#   'reviewdate': '2016/01/28',
#   'smalladd': '西區',
#   'smallstyle': '炭烤串燒',
#   'status': '正常營業',
#   'tele': '0423055225',
#   'url': 'http://www.ipeen.com.tw/shop/1023560',
#   'viewcount': 36752},
#  {'Ncomment': 23,
#   'address': '台中市南屯區公益路二段836號',
#   'averagecost': 795,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 136,
#   'comments': ['http://www.ipeen.com.tw/comment/1333370',
#    'http://www.ipeen.com.tw/comment/1297424',
#    'http://www.ipeen.com.tw/comment/1161845',
#    'http://www.ipeen.com.tw/comment/1155125',
#    'http://www.ipeen.com.tw/comment/1151936'],
#   'id': 1069068,
#   'ipeenscore': 45,
#   'lat': 24.151427018600003,
#   'lng': 120.62828280446999,
#   'name': '紅巢燒肉工房(公益旗艦店)',
#   'othername': '公益旗艦店',
#   'reviewdate': '2017/10/19',
#   'smalladd': '南屯區',
#   'smallstyle': '日式燒肉',
#   'status': '正常營業',
#   'tele': '0422559258',
#   'url': 'http://www.ipeen.com.tw/shop/1069068',
#   'viewcount': 1539152},
#  {'Ncomment': 17,
#   'address': '台中市西屯區朝富二街20號',
#   'averagecost': 875,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 260,
#   'comments': ['http://www.ipeen.com.tw/comment/914536',
#    'http://www.ipeen.com.tw/comment/736354',
#    'http://www.ipeen.com.tw/comment/515124',
#    'http://www.ipeen.com.tw/comment/389223',
#    'http://www.ipeen.com.tw/comment/363096'],
#   'id': 44089,
#   'ipeenscore': 45,
#   'lat': 24.16809885154209,
#   'lng': 120.63671830792737,
#   'name': '匠屋燒肉(朝馬店)',
#   'othername': '朝馬店',
#   'reviewdate': '2014/06/09',
#   'smalladd': '西屯區',
#   'smallstyle': '日式燒肉',
#   'status': '正常營業',
#   'tele': '0422524758',
#   'url': 'http://www.ipeen.com.tw/shop/44089',
#   'viewcount': 185055},
#  {'Ncomment': 12,
#   'address': '台中市西屯區大安街23號',
#   'averagecost': 697,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 504,
#   'comments': ['http://www.ipeen.com.tw/comment/1117553',
#    'http://www.ipeen.com.tw/comment/1035076',
#    'http://www.ipeen.com.tw/comment/941160',
#    'http://www.ipeen.com.tw/comment/855358',
#    'http://www.ipeen.com.tw/comment/833138'],
#   'id': 987024,
#   'ipeenscore': 45,
#   'lat': 24.157088904810003,
#   'lng': 120.65337000397,
#   'name': '狂人肉鋪',
#   'othername': 0,
#   'reviewdate': '2014/11/19',
#   'smalladd': '西屯區',
#   'smallstyle': '韓式燒肉',
#   'status': '正常營業',
#   'tele': '0423292332',
#   'url': 'http://www.ipeen.com.tw/shop/987024',
#   'viewcount': 147792},
#  {'Ncomment': 22,
#   'address': '台中市西屯區市政北一路1 號2樓',
#   'averagecost': 825,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 24,
#   'comments': ['http://www.ipeen.com.tw/comment/1498127',
#    'http://www.ipeen.com.tw/comment/1107308',
#    'http://www.ipeen.com.tw/comment/1072250',
#    'http://www.ipeen.com.tw/comment/1070642',
#    'http://www.ipeen.com.tw/comment/1065184'],
#   'id': 1018232,
#   'ipeenscore': 45,
#   'lat': 24.156851901419998,
#   'lng': 120.64648491279,
#   'name': '原燒優質原味燒肉(台中市政北店)',
#   'othername': '台中市政北店',
#   'reviewdate': '2016/06/07',
#   'smalladd': '西屯區市',
#   'smallstyle': '日式燒肉',
#   'status': '正常營業',
#   'tele': '0422586886',
#   'url': 'http://www.ipeen.com.tw/shop/1018232',
#   'viewcount': 1019208},
#  {'Ncomment': 17,
#   'address': '台中市西區精誠三街2號',
#   'averagecost': 760,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 261,
#   'comments': ['http://www.ipeen.com.tw/comment/1473455',
#    'http://www.ipeen.com.tw/comment/473354',
#    'http://www.ipeen.com.tw/comment/317157',
#    'http://www.ipeen.com.tw/comment/187589',
#    'http://www.ipeen.com.tw/comment/142136'],
#   'id': 56341,
#   'ipeenscore': 45,
#   'lat': 24.157037008859998,
#   'lng': 120.65721100092,
#   'name': '乾杯(台中精誠店)',
#   'othername': '台中精誠店',
#   'reviewdate': '2014/04/14',
#   'smalladd': '西區',
#   'smallstyle': '日式燒肉',
#   'status': '正常營業',
#   'tele': '0423102978',
#   'url': 'http://www.ipeen.com.tw/shop/56341',
#   'viewcount': 148915},
#  {'Ncomment': 22,
#   'address': '台中市西屯區文心路一段436號',
#   'averagecost': 681,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 62,
#   'comments': ['http://www.ipeen.com.tw/comment/1245092',
#    'http://www.ipeen.com.tw/comment/1082042',
#    'http://www.ipeen.com.tw/comment/360972',
#    'http://www.ipeen.com.tw/comment/166599',
#    'http://www.ipeen.com.tw/comment/160009'],
#   'id': 1073734,
#   'ipeenscore': 45,
#   'lat': 24.150410409650593,
#   'lng': 120.64716224543336,
#   'name': '屋馬燒肉(文心店)',
#   'othername': '文心店',
#   'reviewdate': '2016/06/07',
#   'smalladd': '西屯區',
#   'smallstyle': '日式燒肉',
#   'status': '正常營業',
#   'tele': '0423106699',
#   'url': 'http://www.ipeen.com.tw/shop/1073734',
#   'viewcount': 282973},
#  {'Ncomment': 17,
#   'address': '台中市南屯區文心路一段546號',
#   'averagecost': 740,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 49,
#   'comments': ['http://www.ipeen.com.tw/comment/1514870',
#    'http://www.ipeen.com.tw/comment/1385957',
#    'http://www.ipeen.com.tw/comment/1336835',
#    'http://www.ipeen.com.tw/comment/1320833',
#    'http://www.ipeen.com.tw/comment/1301030'],
#   'id': 1129298,
#   'ipeenscore': 45,
#   'lat': 24.15484271568,
#   'lng': 120.64700201914,
#   'name': '燒肉眾 精緻炭火燒肉(台中文心店)',
#   'othername': '台中文心店',
#   'reviewdate': '2017/03/22',
#   'smalladd': '南屯區',
#   'smallstyle': '日式燒肉',
#   'status': '正常營業',
#   'tele': '0423290288',
#   'url': 'http://www.ipeen.com.tw/shop/1129298',
#   'viewcount': 2736260},
#  {'Ncomment': 11,
#   'address': '台中市西區美村路一段177號',
#   'averagecost': 581,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 63,
#   'comments': ['http://www.ipeen.com.tw/comment/805646',
#    'http://www.ipeen.com.tw/comment/725466',
#    'http://www.ipeen.com.tw/comment/679264',
#    'http://www.ipeen.com.tw/comment/572164',
#    'http://www.ipeen.com.tw/comment/449788'],
#   'id': 65837,
#   'ipeenscore': 35,
#   'lat': 24.15056501542,
#   'lng': 120.66187900579,
#   'name': '日月燒烤',
#   'othername': 0,
#   'reviewdate': '2012/03/23',
#   'smalladd': '西區',
#   'smallstyle': '炭烤串燒',
#   'status': '正常營業',
#   'tele': '0423017717',
#   'url': 'http://www.ipeen.com.tw/shop/65837',
#   'viewcount': 104355},
#  {'Ncomment': 8,
#   'address': '台中市西屯區朝富路38號',
#   'averagecost': 672,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 107,
#   'comments': ['http://www.ipeen.com.tw/comment/974238',
#    'http://www.ipeen.com.tw/comment/922448',
#    'http://www.ipeen.com.tw/comment/921868',
#    'http://www.ipeen.com.tw/comment/900980',
#    'http://www.ipeen.com.tw/comment/1307690'],
#   'id': 1031004,
#   'ipeenscore': 40,
#   'lat': 24.16691491019,
#   'lng': 120.63758700621,
#   'name': '笨豬跳韓式烤肉 Bungy Jump Korean  BBQ',
#   'othername': 0,
#   'reviewdate': '2015/08/15',
#   'smalladd': '西屯區',
#   'smallstyle': '韓式燒肉',
#   'status': '正常營業',
#   'tele': 0,
#   'url': 'http://www.ipeen.com.tw/shop/1031004',
#   'viewcount': 27249},
#  {'Ncomment': 6,
#   'address': '台中市西屯區東興路三段372號',
#   'averagecost': 559,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 163,
#   'comments': ['http://www.ipeen.com.tw/comment/500726',
#    'http://www.ipeen.com.tw/comment/483670',
#    'http://www.ipeen.com.tw/comment/480502',
#    'http://www.ipeen.com.tw/comment/476018',
#    'http://www.ipeen.com.tw/comment/1040282'],
#   'id': 14844,
#   'ipeenscore': 45,
#   'lat': 24.15751900474,
#   'lng': 120.65525000003,
#   'name': '太郎燒肉',
#   'othername': 0,
#   'reviewdate': '2015/04/15',
#   'smalladd': '西屯區',
#   'smallstyle': '炭烤串燒',
#   'status': '正常營業',
#   'tele': '0423199077',
#   'url': 'http://www.ipeen.com.tw/shop/14844',
#   'viewcount': 43376},
#  {'Ncomment': 9,
#   'address': '台中市南屯區東興路二段217號',
#   'averagecost': 660,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 50,
#   'comments': ['http://www.ipeen.com.tw/comment/1454372',
#    'http://www.ipeen.com.tw/comment/1429307',
#    'http://www.ipeen.com.tw/comment/1178303',
#    'http://www.ipeen.com.tw/comment/925836',
#    'http://www.ipeen.com.tw/comment/908990'],
#   'id': 945054,
#   'ipeenscore': 45,
#   'lat': 24.14209101497,
#   'lng': 120.65279800812007,
#   'name': '燄鐵板燒(東興旗艦店)',
#   'othername': '東興旗艦店',
#   'reviewdate': '2014/06/27',
#   'smalladd': '南屯區',
#   'smallstyle': '鐵板燒',
#   'status': '正常營業',
#   'tele': '0424752555',
#   'url': 'http://www.ipeen.com.tw/shop/945054',
#   'viewcount': 23930},
#  {'Ncomment': 10,
#   'address': '台中市西區臺灣大道二段315號',
#   'averagecost': 825,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 2,
#   'comments': ['http://www.ipeen.com.tw/comment/1558263',
#    'http://www.ipeen.com.tw/comment/1558095',
#    'http://www.ipeen.com.tw/comment/1550751',
#    'http://www.ipeen.com.tw/comment/1538885',
#    'http://www.ipeen.com.tw/comment/1531403'],
#   'id': 1231085,
#   'ipeenscore': 45,
#   'lat': 24.1537757,
#   'lng': 120.6652143,
#   'name': '澄居烤物燒肉',
#   'othername': 0,
#   'reviewdate': '2017/10/25',
#   'smalladd': '西區',
#   'smallstyle': '日式燒肉',
#   'status': '正常營業',
#   'tele': '0423265302',
#   'url': 'http://www.ipeen.com.tw/shop/1231085',
#   'viewcount': 5328},
#  {'Ncomment': 6,
#   'address': '台中市西區向上北路159號',
#   'averagecost': 699,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 93,
#   'comments': ['http://www.ipeen.com.tw/comment/747776',
#    'http://www.ipeen.com.tw/comment/442054',
#    'http://www.ipeen.com.tw/comment/397006',
#    'http://www.ipeen.com.tw/comment/385793',
#    'http://www.ipeen.com.tw/comment/257676'],
#   'id': 116959,
#   'ipeenscore': 45,
#   'lat': 24.147940426818856,
#   'lng': 120.66228710264255,
#   'name': '匠屋燒肉(勤美店)',
#   'othername': '勤美店',
#   'reviewdate': '2014/06/12',
#   'smalladd': '西區',
#   'smallstyle': '日式燒肉',
#   'status': '正常營業',
#   'tele': '0423022666',
#   'url': 'http://www.ipeen.com.tw/shop/116959',
#   'viewcount': 47180},
#  {'Ncomment': 7,
#   'address': '台中市西屯區漢口路二段148號',
#   'averagecost': 491,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 43,
#   'comments': ['http://www.ipeen.com.tw/comment/969264',
#    'http://www.ipeen.com.tw/comment/606108',
#    'http://www.ipeen.com.tw/comment/310563',
#    'http://www.ipeen.com.tw/comment/538658',
#    'http://www.ipeen.com.tw/comment/536260'],
#   'id': 32531,
#   'ipeenscore': 45,
#   'lat': 24.16571801087,
#   'lng': 120.66330300751,
#   'name': '石頭日式炭火燒肉(台中漢口館總店)',
#   'othername': '台中漢口館總店',
#   'reviewdate': '2017/08/04',
#   'smalladd': '西屯區',
#   'smallstyle': '炭烤串燒',
#   'status': '正常營業',
#   'tele': '0423175757',
#   'url': 'http://www.ipeen.com.tw/shop/32531',
#   'viewcount': 82914},
#  {'Ncomment': 5,
#   'address': '台中市南屯區大觀路41號',
#   'averagecost': 551,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 82,
#   'comments': ['http://www.ipeen.com.tw/comment/885796',
#    'http://www.ipeen.com.tw/comment/525442',
#    'http://www.ipeen.com.tw/comment/303159',
#    'http://www.ipeen.com.tw/comment/787554',
#    'http://www.ipeen.com.tw/comment/478688'],
#   'id': 140739,
#   'ipeenscore': 45,
#   'lat': 24.14564600123,
#   'lng': 120.64215501575,
#   'name': '傑夫の燒肉',
#   'othername': 0,
#   'reviewdate': '2016/04/05',
#   'smalladd': '南屯區',
#   'smallstyle': '炭烤串燒',
#   'status': '正常營業',
#   'tele': '0423860398',
#   'url': 'http://www.ipeen.com.tw/shop/140739',
#   'viewcount': 41398},
#  {'Ncomment': 6,
#   'address': '台中市西區臺灣大道二段459號14樓(廣三SOGO14F)',
#   'averagecost': 778,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 22,
#   'comments': ['http://www.ipeen.com.tw/comment/1172495',
#    'http://www.ipeen.com.tw/comment/1016332',
#    'http://www.ipeen.com.tw/comment/949182',
#    'http://www.ipeen.com.tw/comment/922392',
#    'http://www.ipeen.com.tw/comment/1197953'],
#   'id': 1037172,
#   'ipeenscore': 45,
#   'lat': 24.15546901452,
#   'lng': 120.66188801356,
#   'name': '牛角日本燒肉專門店(台中廣三SOGO店)',
#   'othername': '台中廣三SOGO店',
#   'reviewdate': '2017/05/04',
#   'smalladd': '西區',
#   'smallstyle': '日式燒肉',
#   'status': '正常營業',
#   'tele': '0423287151',
#   'url': 'http://www.ipeen.com.tw/shop/1037172',
#   'viewcount': 10062},
#  {'Ncomment': 4,
#   'address': '台中市西區明義街74號',
#   'averagecost': 675,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 51,
#   'comments': ['http://www.ipeen.com.tw/comment/927958',
#    'http://www.ipeen.com.tw/comment/647142',
#    'http://www.ipeen.com.tw/comment/339777',
#    'http://www.ipeen.com.tw/comment/302817'],
#   'id': 14857,
#   'ipeenscore': 45,
#   'lat': 24.15578000608,
#   'lng': 120.65949100941,
#   'name': '匠屋燒肉(明義店)',
#   'othername': '明義店',
#   'reviewdate': '2015/04/10',
#   'smalladd': '西區',
#   'smallstyle': '炭烤串燒',
#   'status': '正常營業',
#   'tele': '0423287703',
#   'url': 'http://www.ipeen.com.tw/shop/14857',
#   'viewcount': 21080},
#  {'Ncomment': 6,
#   'address': '雲林縣斗六市中堅西路722號',
#   'averagecost': 463,
#   'bigadd': '雲林縣',
#   'bigstyle': '燒烤類',
#   'collecount': 1,
#   'comments': ['http://www.ipeen.com.tw/comment/1351400',
#    'http://www.ipeen.com.tw/comment/1324676',
#    'http://www.ipeen.com.tw/comment/1138988',
#    'http://www.ipeen.com.tw/comment/1447742',
#    'http://www.ipeen.com.tw/comment/1280453'],
#   'id': 1093067,
#   'ipeenscore': 45,
#   'lat': 24.15903000334,
#   'lng': 120.6617560165,
#   'name': '石記-鐵町心作鐵板料理',
#   'othername': 0,
#   'reviewdate': '2016/09/02',
#   'smalladd': '斗六市',
#   'smallstyle': '鐵板燒',
#   'status': '正常營業',
#   'tele': '055332616',
#   'url': 'http://www.ipeen.com.tw/shop/1093067',
#   'viewcount': 5949},
#  {'Ncomment': 4,
#   'address': '台中市西屯區臺灣大道二段111號10樓',
#   'averagecost': 676,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 61,
#   'comments': ['http://www.ipeen.com.tw/comment/589034',
#    'http://www.ipeen.com.tw/comment/913684',
#    'http://www.ipeen.com.tw/comment/765430',
#    'http://www.ipeen.com.tw/comment/658246'],
#   'id': 928394,
#   'ipeenscore': 45,
#   'lat': 24.16449800661,
#   'lng': 120.64706900468,
#   'name': '兩班家 韓式碳烤',
#   'othername': 0,
#   'reviewdate': '2014/08/05',
#   'smalladd': '西屯區',
#   'smallstyle': '韓式燒肉',
#   'status': '正常營業',
#   'tele': 0,
#   'url': 'http://www.ipeen.com.tw/shop/928394',
#   'viewcount': 13683},
#  {'Ncomment': 5,
#   'address': '台中市西區精誠路265號',
#   'averagecost': 666,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 5,
#   'comments': ['http://www.ipeen.com.tw/comment/1380263',
#    'http://www.ipeen.com.tw/comment/1190897',
#    'http://www.ipeen.com.tw/comment/1079417',
#    'http://www.ipeen.com.tw/comment/1162211',
#    'http://www.ipeen.com.tw/comment/1159706'],
#   'id': 1067594,
#   'ipeenscore': 40,
#   'lat': 24.14673110353,
#   'lng': 120.65516321091,
#   'name': '鳥樂 串燒日本料理 Toriraku',
#   'othername': 0,
#   'reviewdate': '2016/04/29',
#   'smalladd': '西區',
#   'smallstyle': '炭烤串燒',
#   'status': '正常營業',
#   'tele': '0424735350',
#   'url': 'http://www.ipeen.com.tw/shop/1067594',
#   'viewcount': 4553},
#  {'Ncomment': 4,
#   'address': '台中市西屯區西屯路二段272號之12',
#   'averagecost': 500,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 10,
#   'comments': ['http://www.ipeen.com.tw/comment/952298',
#    'http://www.ipeen.com.tw/comment/937174',
#    'http://www.ipeen.com.tw/comment/924424',
#    'http://www.ipeen.com.tw/comment/897650'],
#   'id': 1026112,
#   'ipeenscore': 45,
#   'lat': 24.1744384163,
#   'lng': 120.64453880544,
#   'name': '炫牛碳燒牛排館',
#   'othername': 0,
#   'reviewdate': '2015/07/10',
#   'smalladd': '西屯區',
#   'smallstyle': '炭烤串燒',
#   'status': '正常營業',
#   'tele': '0424523999',
#   'url': 'http://www.ipeen.com.tw/shop/1026112',
#   'viewcount': 8118},
#  {'Ncomment': 4,
#   'address': '台中市西屯區臺灣大道三段251號11樓',
#   'averagecost': 737,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 26,
#   'comments': ['http://www.ipeen.com.tw/comment/410922',
#    'http://www.ipeen.com.tw/comment/692328',
#    'http://www.ipeen.com.tw/comment/673934',
#    'http://www.ipeen.com.tw/comment/434738'],
#   'id': 119875,
#   'ipeenscore': 35,
#   'lat': 24.165286968310802,
#   'lng': 120.64406929054395,
#   'name': '八道藏創作鐵板料理',
#   'othername': 0,
#   'reviewdate': '2013/10/03',
#   'smalladd': '西屯區',
#   'smallstyle': '鐵板燒',
#   'status': '正常營業',
#   'tele': '0422522606',
#   'url': 'http://www.ipeen.com.tw/shop/119875',
#   'viewcount': 22461},
#  {'Ncomment': 2,
#   'address': '台中市西屯區臺灣大道三段251號11樓(台中大遠百南棟11F)',
#   'averagecost': 704,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 4,
#   'comments': ['http://www.ipeen.com.tw/comment/1366070',
#    'http://www.ipeen.com.tw/comment/1296527'],
#   'id': 1155950,
#   'ipeenscore': 40,
#   'lat': 24.164863112080003,
#   'lng': 120.64471690733001,
#   'name': '牛角日本燒肉專門店(台中大遠百店)',
#   'othername': '台中大遠百店',
#   'reviewdate': '2017/03/04',
#   'smalladd': '西屯區',
#   'smallstyle': '日式燒肉',
#   'status': '正常營業',
#   'tele': '0422542623',
#   'url': 'http://www.ipeen.com.tw/shop/1155950',
#   'viewcount': 13348},
#  {'Ncomment': 1,
#   'address': '台中市西屯區寧夏路98號',
#   'averagecost': 500,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 18,
#   'comments': ['http://www.ipeen.com.tw/comment/1561767'],
#   'id': 137903,
#   'ipeenscore': 40,
#   'lat': 24.16594900227,
#   'lng': 120.66208300166,
#   'name': '西原家備長炭串料理',
#   'othername': 0,
#   'reviewdate': '2013/07/31',
#   'smalladd': '西屯區',
#   'smallstyle': '炭烤串燒',
#   'status': '正常營業',
#   'tele': '0423168688',
#   'url': 'http://www.ipeen.com.tw/shop/137903',
#   'viewcount': 133385},
#  {'Ncomment': 2,
#   'address': '台中市西區中興街279號2樓',
#   'averagecost': 748,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 10,
#   'comments': ['http://www.ipeen.com.tw/comment/1086245',
#    'http://www.ipeen.com.tw/comment/1077011'],
#   'id': 1073492,
#   'ipeenscore': 40,
#   'lat': 24.15881901647,
#   'lng': 120.66165001124999,
#   'name': '勻淨法式無煙燒肉',
#   'othername': 0,
#   'reviewdate': '2016/06/06',
#   'smalladd': '西區',
#   'smallstyle': '日式燒肉',
#   'status': '正常營業',
#   'tele': '0423282228',
#   'url': 'http://www.ipeen.com.tw/shop/1073492',
#   'viewcount': 7532},
#  {'Ncomment': 1,
#   'address': '台中市西屯區何厝街36號',
#   'averagecost': 667,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 11,
#   'comments': ['http://www.ipeen.com.tw/comment/831614'],
#   'id': 962944,
#   'ipeenscore': 0,
#   'lat': 24.16182701343,
#   'lng': 120.65444941132,
#   'name': '蝦城鹽烤',
#   'othername': 0,
#   'reviewdate': '2014/12/04',
#   'smalladd': '西屯區',
#   'smallstyle': '炭烤串燒',
#   'status': '正常營業',
#   'tele': '0939058012',
#   'url': 'http://www.ipeen.com.tw/shop/962944',
#   'viewcount': 9478},
#  {'Ncomment': 3,
#   'address': '台中市南屯區公益路二段929號',
#   'averagecost': 708,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 4,
#   'comments': ['http://www.ipeen.com.tw/comment/1571160',
#    'http://www.ipeen.com.tw/comment/1541795',
#    'http://www.ipeen.com.tw/comment/1486847'],
#   'id': 1192985,
#   'ipeenscore': 0,
#   'lat': 24.1512211,
#   'lng': 120.628625,
#   'name': '杕鐵板燒',
#   'othername': 0,
#   'reviewdate': '2017/06/05',
#   'smalladd': '南屯區',
#   'smallstyle': '鐵板燒',
#   'status': '正常營業',
#   'tele': '0423805222',
#   'url': 'http://www.ipeen.com.tw/shop/1192985',
#   'viewcount': 3284},
#  {'Ncomment': 0,
#   'address': '台中市西屯區河南路三段120號1樓',
#   'averagecost': 790,
#   'bigadd': '台中市',
#   'bigstyle': '燒烤類',
#   'collecount': 6,
#   'comments': [],
#   'id': 1045654,
#   'ipeenscore': 35,
#   'lat': 24.16408260447,
#   'lng': 120.63812760291,
#   'name': '牧島燒肉專門店(老虎城店)',
#   'othername': '老虎城店',
#   'reviewdate': '2015/11/25',
#   'smalladd': '西屯區',
#   'smallstyle': '日式燒肉',
#   'status': '正常營業',
#   'tele': '0422595915',
#   'url': 'http://www.ipeen.com.tw/shop/1045654',
#   'viewcount': 4380}]

# %%
wowDien
# Out:
# {'Address': '台中市西屯區台灣大道四段1038號',
#  'AreaManager': '徐怡靜',
#  'Called': '聚',
#  'CareerName': '聚鍋事業處',
#  'CareerNo': '104',
#  'Chef': '許金隆',
#  'CloseDate': 'None',
#  'CodeId': 'B',
#  'CorporationId': '72494262',
#  'Corporation_ch': '聚鍋台中東海店',
#  'CreateDate': '2018-02-02 10:45:12.190000',
#  'ItemName': 'None',
#  'Manager': '王仁森',
#  'NbusStation_Analyze': 9,
#  'NconStore_Analyze': 30,
#  'NcostData_Analyze': 9,
#  'Nhuman_Analyze': 63580,
#  'Njob_Analyze': 71,
#  'Nken_Analyze': 1,
#  'Nmc_Analyze': 3,
#  'NsimCostDien': 47,
#  'Nstar_Analyze': 1,
#  'Nwa_Analyze': 0,
#  'Phone': '',
#  'PlaceNo': '',
#  'StoreName': '台中東海店',
#  'StoreNo': '10438',
#  '_id': '10438',
#  'areaRadius_Analyze': 2000,
#  'avgCost_Analyze': 120.0,
#  'avgSalary_Analyze': 27287.0,
#  'bigadd': '台中市',
#  'costPower_Analyze': 61.0,
#  'lat': 24.1833807,
#  'lng': 120.6154146,
#  'mostStyle_Analyze': '中式料理',
#  'smalladd': '西屯區'}

# %%
wowDiensData
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6f2a5a6585ab> in <module>()
# ----> 1 wowDiensData
#
# NameError: name 'wowDiensData' is not defined

# %% [markdown]
# # 以下試玩回歸

# %%
import pymongo
client = pymongo.mongo_client.MongoClient("localhost", 27017,username='j122085',password='850605')
collections=client.rawData.wowprimediendata
data=list(collections.find({}))

# %%
data=[i for i in data if i['CloseDate']=="None" 
      and "A" not in i['StoreNo'] 
      and "B" not in i['StoreNo'] 
      and i['StoreNo'][0]!='3' 
      and i['StoreNo'][:2]!='19' 
      and i['StoreNo'][:2]!='41'
      and i['Called']!='曼咖啡'
      and i['Called']!='泰國陶板屋'
      and i['Called']!='新創事業處'
      and i['Called']!='美國原燒'
     ]

# %%
print(set([i['Called'] for i in data]))
data[2]
# Out:
# {'聚', 'ＴＡＳＴｙ', '陶板屋', '莆田', '青花驕', '石二鍋', '夏慕尼', '舒果', '藝奇', 'ita義塔', '乍牛', '沐越', 'hot 7', '王品', 'CooK BEEF!', '麻佬大', '品田牧場', '原燒'}
# {'Address': '新北市板橋區館前東路96號1樓',
#  'AreaManager': '王至誠',
#  'Called': '原燒',
#  'CareerName': '原燒事業處',
#  'CareerNo': '102',
#  'Chef': '鄭伊浚',
#  'CloseDate': 'None',
#  'CodeId': 'F',
#  'CorporationId': '41486956',
#  'Corporation_ch': '原燒板橋館前東店',
#  'CreateDate': '2018-02-02 08:46:13.233000',
#  'ItemName': '百貨點',
#  'Manager': '吳憲政',
#  'NbusStation_Analyze': 165,
#  'NconStore_Analyze': 221,
#  'NcostData_Analyze': 48,
#  'Nhuman_Analyze': 404374,
#  'Njob_Analyze': 240,
#  'Nken_Analyze': 3,
#  'Nmc_Analyze': 6,
#  'Nstar_Analyze': 8,
#  'Nwa_Analyze': 3,
#  'Phone': '02-29598558',
#  'PlaceNo': '30',
#  'StoreName': '板橋館前東',
#  'StoreNo': '10204',
#  '_id': '10204',
#  'areaRadius_Analyze': 2000,
#  'avgCost_Analyze': 136.0,
#  'avgDailyCustomer': 157,
#  'avgDailyMeal': 134,
#  'avgDailyNet': 105236,
#  'avgSalary_Analyze': 29591.0,
#  'bigadd': '新北市',
#  'costPower_Analyze': 54.0,
#  'lastYearRevenue': 40378431,
#  'lat': 25.0074218,
#  'lng': 121.4624007,
#  'mostStyle_Analyze': '小吃',
#  'smalladd': '板橋區'}

# %%
data[5]
# Out:
# {'Address': '桃園市復興路190、190之1、192、194號',
#  'AreaManager': '王至誠',
#  'Called': '原燒',
#  'CareerName': '原燒事業處',
#  'CareerNo': '102',
#  'Chef': '鄭信宏',
#  'CloseDate': 'None',
#  'CodeId': 'H',
#  'CorporationId': '28144133',
#  'Corporation_ch': '原燒桃園復興分公司',
#  'CreateDate': '2018-02-02 08:46:13.747000',
#  'ItemName': '百貨點',
#  'Manager': '吳憲政',
#  'NcostData_Analyze': 33,
#  'Nhuman_Analyze': 189479,
#  'Njob_Analyze': 124,
#  'Phone': '03-3357957',
#  'PlaceNo': '39',
#  'StoreName': '桃園復興',
#  'StoreNo': '10207',
#  '_id': '10207',
#  'areaRadius_Analyze': 2000,
#  'avgCost_Analyze': 130.0,
#  'avgDailyCustomer': 123,
#  'avgDailyMeal': 105,
#  'avgDailyNet': 82705,
#  'avgSalary_Analyze': 27436.0,
#  'bigadd': '桃園市',
#  'costPower_Analyze': 59.0,
#  'lastYearRevenue': 30180943,
#  'lat': 24.9536959,
#  'lng': 121.223226,
#  'mostStyle_Analyze': '小吃',
#  'smalladd': '桃園區'}

# %%
{i['Corporation_ch']:{'營收':i['avgDailyNet'],'消費力':i['costPower_Analyze']} for i in data if 'avgDailyNet' in i and i['avgDailyNet']>200000 }
# Out:
# {'夏慕尼台中大隆分公司': {'消費力': 75.0, '營收': 204141},
#  '夏慕尼台中文心分公司': {'消費力': 65.0, '營收': 227544},
#  '夏慕尼台北中山北分公司': {'消費力': 71.0, '營收': 332748},
#  '夏慕尼台北忠孝東': {'消費力': 73.0, '營收': 222255},
#  '夏慕尼板橋民生分公司': {'消費力': 54.0, '營收': 271042},
#  '夏慕尼高雄五福分公司': {'消費力': 50.0, '營收': 321154},
#  '陶板屋板橋捷運新埔店': {'消費力': 56.0, '營收': 215205},
#  '青花驕台北中山北店': {'消費力': 71.0, '營收': 258175}}

# %%
import scipy.stats as stats
import pandas as pd
getCov=[]
for called in set([i['Called'] for i in data]):
    x={}
    yearRevenueList=[i['avgDailyNet'] for i in data if 'avgDailyNet' in i 
                     and 'costPower_Analyze' in i 
                     and i['NcostData_Analyze']>20
                     and i['Called']==called]
    costPowerList=[i['costPower_Analyze'] for i in data if 'avgDailyNet' in i 
                   and 'costPower_Analyze' in i 
                   and i['NcostData_Analyze']>20
                   and i['Called']==called]
    x['品牌']=called
    x['資料筆數']=str(len(costPowerList))
    x['ADS_vs_消費力_相關係數']=round(stats.pearsonr(yearRevenueList,costPowerList)[0],3)
    getCov.append(x)
    
    
df=pd.DataFrame(getCov)

writer = pd.ExcelWriter('output.xlsx')
df.to_excel(writer,'Sheet1')
writer.save()
# Out:
# D:\anaconda\lib\site-packages\scipy\stats\stats.py:3021: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den
# D:\anaconda\lib\site-packages\scipy\stats\stats.py:5277: RuntimeWarning: invalid value encountered in less
#   x = np.where(x < 1.0, x, 1.0)  # if x > 1 then return 1.0

# %%
get_median

# %%
df
# Out:
#     ADS_vs_消費力_相關係數          品牌 資料筆數
# 0               NaN          沐越    1
# 1            -0.180          莆田    3
# 2               NaN         青花驕    1
# 3            -0.351          王品   12
# 4             0.120         夏慕尼   12
# 5             0.180         陶板屋   19
# 6             0.621  CooK BEEF!    5
# 7             0.212          原燒   14
# 8             0.621          乍牛    3
# 9             1.000       ita義塔    2
# 10            0.250       ＴＡＳＴｙ   23
# 11            0.008        品田牧場   13
# 12            0.937         麻佬大    4
# 13            0.028       hot 7   12
# 14            0.077           聚   12
# 15            0.043          舒果    4
# 16            0.080          藝奇    7
# 17            0.174         石二鍋   29

# %%
import numpy as np
data_X=np.array(yearRevenueList)
data_Y=np.array(costPowerList)
print(data_X)
print(data_Y)
print(len(data_X))
# Out:
# [ 60028  54633  49622  61390  67790  54921  62109  79851  67139  75638
#   81458  59061  71132  87087  48298  84731  77290  72316  75306  47185
#  123342  74531  43618  70125  91334  62908  98753  92606 103459  88629
#  110596  78406  99119  85834  90324  74970  74060  85775  75499  68740
#   87353  73802  88105]
# [49. 72. 79. 56. 56. 53. 42. 62. 54. 74. 70. 46. 54. 71. 65. 55. 47. 65.
#  50. 63. 63. 51. 61. 51. 57. 55. 80. 43. 54. 58. 56. 57. 52. 59. 53. 53.
#  51. 54. 57. 51. 52. 53. 76.]
# 43

# %%
numpy.corrcoef(data_X,data_Y)
# Out:
# array([[1.        , 0.00338317],
#        [0.00338317, 1.        ]])

# %%
import scipy.stats as stats
stats.pearsonr(data_X,data_Y)
# Out:
# (0.003383169118087708, 0.9828218847065735)

# %%
from sympy import *
num = len(data_X)
def linear_regression(X, Y):
    a, b = symbols('a b')
    residual = 0
    #residualSum 求殘差

    for i in range(num):
        residual += (Y[i] - (a * X[i] + b)) ** 2

    #展開觀看方程式內容

    print (expand(residual))
    #對a微分

    f1 = diff(residual, a)
    #對b微分

    f2 = diff(residual, b)
    print (f1)
    print (f2)
    #求聯立方程式的解

    res = solve([f1, f2], [a, b])
    return res[a], res[b]

a, b = linear_regression(data_X, data_Y)
# Out:
# 338681220738817876*a**2 + 16509122932*a*b - 970929454388.0*a + 250*b**2 - 29406.0*b + 889275.0
# 677362441477635752*a + 16509122932*b - 970929454388.0
# 16509122932*a + 500*b - 29406.0

# %%
b
# Out:
# 58.8132690736243

# %%
a
# Out:
# -3.84355253007993e-11

# %%
yearRevenueList=[i['avgDailyNet'] for i in data if 'avgDailyNet' in i 
                 and 'costPower_Analyze' in i 
                 and i['NcostData_Analyze']>10]
costPowerList=[i['costPower_Analyze'] for i in data if 'avgDailyNet' in i 
               and 'costPower_Analyze' in i 
               and i['NcostData_Analyze']>10]
import numpy as np
data_X=np.array(yearRevenueList)
data_Y=np.array(costPowerList)

import matplotlib.pyplot as plt
plt.plot(data_X, data_Y, 'rx')
plt.show()

# %%
from __future__ import division
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import math


x = data_X
y = data_Y
theta = np.zeros((2,1))

#scatterplot of data with option to save figure.
def scatterPlot(x,y,yp=None,savePng=False):
	plt.xlabel('Population of City in 10,000s')
	plt.ylabel('Profit in $10,000s')
	plt.scatter(x, y, marker='x')
	if yp != None:
		plt.plot(x,yp)
	if savePng==false:
		plt.show()
	else:
		name = raw_input('Name Figure File: ')
		plt.savefig(name+'.png')


scatterPlot(x,y)

#linear regression implementation using libraries
(m,b) = np.polyfit(x,y,1)
print ('Slope is ' + str(m))
print ('Y intercept is ' + str(b))
yp = np.polyval([m,b],x)
scatterPlot(x,y,yp)
# Out:
# Slope is 0.0010539741378557173
# Y intercept is 54.976139372404546
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-138-0870297d9384> in <module>()
#      31 print ('Y intercept is ' + str(b))
#      32 yp = np.polyval([m,b],x)
# ---> 33 scatterPlot(x,y,yp)
#
# <ipython-input-138-0870297d9384> in scatterPlot(x, y, yp, savePng)
#      15         plt.ylabel('Profit in $10,000s')
#      16         plt.scatter(x, y, marker='x')
# ---> 17         if yp != None:
#      18                 plt.plot(x,yp)
#      19         if savePng==false:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
from __future__ import division
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import math

#read data into array
# data = np.genfromtxt('ex1data1.txt',delimiter=',')
x=data_X
y=data_Y
m=y.size
a=ones(m,2)


def cost(x, y, theta=np.zeros((2,1))):
    """Computes the cost of linear regression
    theta = parameter for linear regression
    x and y are the data points
    This is done to monitor the cost of gradient descent"""
    m = len(x)
    J = 1/(2*m) * sum((x.dot(theta).flatten()- y)**2)
    return J


def gradientDesc(x, y, theta=np.zeros((2,1)), alpha=.01,iterations=1500):
    """"Gradient Descent implementation of 
    linear regression with one variable"""
    m = y.size
    J = []
    for numbers in range(iterations):
        a = theta[0][0] - alpha*(1/m)*sum((x.dot(theta).flatten() - y)*x[:,0])
        b = theta[1][0] - alpha*(1/m)*sum((x.dot(theta).flatten() - y)*x[:,1])
        theta[0][0],theta[1][0]=a,b
        print (theta[0][0])
        print (theta[1][0])
        J.append(cost(x,y,theta))
        print ('Cost: ' + str(J[-1]))
    return theta

#scatterplot of data with option to save figure.
def scatterPlot(x,y,yp=None,savePng=False):
    plt.xlabel('Population of City in 10,000s')
    plt.ylabel('Profit in $10,000s')
    plt.scatter(x, y, marker='x')
    if yp != None:
        plt.plot(x,yp)
    if savePng==false:
        plt.show()
    else:
        name = raw_input('Name Figure File: ')
        plt.savefig(name+'.png')

# %%
scatterPlot(x,y)
