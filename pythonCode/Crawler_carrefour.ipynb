# %%
headerstr='''Accept: application/json, text/javascript, */*; q=0.01
Accept-Encoding: gzip, deflate, br
Accept-Language: zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7
Cache-Control: no-cache
Connection: keep-alive
Cookie: _ga=GA1.3.207086480.1524637160; _gid=GA1.3.1652140068.1524637160
Host: www.carrefour.com.tw
Pragma: no-cache
Referer: https://www.carrefour.com.tw/store.html
User-Agent: Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.181 Safari/537.36
X-Requested-With: XMLHttpRequest'''

headers={i.split(":")[0].strip():i.split(":")[1].strip() for i in headerstr.split("\n")}
headers
# Out:
# {'Accept': 'application/json, text/javascript, */*; q=0.01',
#  'Accept-Encoding': 'gzip, deflate, br',
#  'Accept-Language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7',
#  'Cache-Control': 'no-cache',
#  'Connection': 'keep-alive',
#  'Cookie': '_ga=GA1.3.207086480.1524637160; _gid=GA1.3.1652140068.1524637160',
#  'Host': 'www.carrefour.com.tw',
#  'Pragma': 'no-cache',
#  'Referer': 'https',
#  'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.181 Safari/537.36',
#  'X-Requested-With': 'XMLHttpRequest'}

# %%
import requests
res=requests.get("https://www.carrefour.com.tw/api/Store",headers=headers)

# %%
carrefourDatasO=json.loads(res.text)['result']

# %%
carrefourDatasO[0]

carrefourDatas=[]
for i in carrefourDatasO:
    carrefourData={}
    carrefourData['name']="家樂福"+i['分店中文名稱']
    carrefourData['lat']=i['Latitude']
    carrefourData['lng']=i['Longitude']
    carrefourData['address']=i['地址']
    carrefourData['bigadd']=i['縣市']
    carrefourData['smalladd']=i['區']
    carrefourData['tele']=i['電話號碼']
    carrefourDatas.append(carrefourData)

# %%
carrefourDatas
# Out:
# [{'address': '濟南路2段46號B1',
#   'bigadd': '台北市',
#   'lat': 25.0403671,
#   'lng': 121.530579,
#   'name': '家樂福台北濟南',
#   'smalladd': '中正區',
#   'tele': '02-23211262'},
#  {'address': '重慶北路二段171號',
#   'bigadd': '台北市',
#   'lat': 25.0595646,
#   'lng': 121.513779,
#   'name': '家樂福重慶店',
#   'smalladd': '大同區',
#   'tele': '(02)2553-7389'},
#  {'address': '樂群三路218號',
#   'bigadd': '台北市',
#   'lat': 25.0824471,
#   'lng': 121.558037,
#   'name': '家樂福大直店',
#   'smalladd': '中山區',
#   'tele': '(02)8509-5577'},
#  {'address': '三民路160號',
#   'bigadd': '台北市',
#   'lat': 25.0615635,
#   'lng': 121.563316,
#   'name': '家樂福三民店',
#   'smalladd': '松山區',
#   'tele': '(02)2767-0702'},
#  {'address': '桂林路1號',
#   'bigadd': '台北市',
#   'lat': 25.0378418,
#   'lng': 121.506172,
#   'name': '家樂福桂林店',
#   'smalladd': '萬華區',
#   'tele': '(02)2388-9887'},
#  {'address': '東興路45號B1',
#   'bigadd': '台北市',
#   'lat': 25.0476589,
#   'lng': 121.566368,
#   'name': '家樂福東興店',
#   'smalladd': '信義區',
#   'tele': '(02)8768-1111'},
#  {'address': '德行西路47號',
#   'bigadd': '台北市',
#   'lat': 25.1052933,
#   'lng': 121.522507,
#   'name': '家樂福天母店',
#   'smalladd': '士林區',
#   'tele': '(02)2833-8042'},
#  {'address': '中山北路七段113號',
#   'bigadd': '台北市',
#   'lat': 25.1224,
#   'lng': 121.531647,
#   'name': '家樂福天母中北店',
#   'smalladd': '士林區',
#   'tele': '(02)2871-2126'},
#  {'address': '忠誠路二段188號',
#   'bigadd': '台北市',
#   'lat': 25.1164436,
#   'lng': 121.533073,
#   'name': '家樂福士林忠誠',
#   'smalladd': '士林區',
#   'tele': '02-28755015'},
#  {'address': '中和街366號B1',
#   'bigadd': '台北市',
#   'lat': 25.1417618,
#   'lng': 121.499245,
#   'name': '家樂福北投店',
#   'smalladd': '北投區',
#   'tele': '(02)2896-3000'},
#  {'address': '東湖路69號B1',
#   'bigadd': '台北市',
#   'lat': 25.0686741,
#   'lng': 121.614441,
#   'name': '家樂福內湖東湖店',
#   'smalladd': '內湖區',
#   'tele': '02-26320558'},
#  {'address': '民善街88號(民權大橋旁)',
#   'bigadd': '台北市',
#   'lat': 25.06111,
#   'lng': 121.574883,
#   'name': '家樂福內湖店',
#   'smalladd': '內湖區',
#   'tele': '(02)8790-5000'},
#  {'address': '內湖路一段155號',
#   'bigadd': '台北市',
#   'lat': 25.0836239,
#   'lng': 121.561119,
#   'name': '家樂福台北內湖1',
#   'smalladd': '內湖區',
#   'tele': '02-26585955'},
#  {'address': '南港路二段20巷5號B1-1',
#   'bigadd': '台北市',
#   'lat': 25.0539341,
#   'lng': 121.605537,
#   'name': '家樂福南港店',
#   'smalladd': '南港區',
#   'tele': '(02)2788-2550'},
#  {'address': '中正路302號',
#   'bigadd': '新北市',
#   'lat': 25.0207176,
#   'lng': 121.455223,
#   'name': '家樂福板橋中正店',
#   'smalladd': '板橋區',
#   'tele': '02-29605886'},
#  {'address': '府中路 126 號 1 樓',
#   'bigadd': '新北市',
#   'lat': 25.0095444,
#   'lng': 121.45488,
#   'name': '家樂福府中店',
#   'smalladd': '板橋區',
#   'tele': '(02)2272-9000'},
#  {'address': '三民路二段31號B1',
#   'bigadd': '新北市',
#   'lat': 25.0179768,
#   'lng': 121.4794,
#   'name': '家樂福板橋店',
#   'smalladd': '板橋區',
#   'tele': '(02)2964-2988'},
#  {'address': '文化路二段313號B1',
#   'bigadd': '新北市',
#   'lat': 25.0297356,
#   'lng': 121.469688,
#   'name': '家樂福板橋文化',
#   'smalladd': '板橋區',
#   'tele': '02-22565121'},
#  {'address': '新台五路一段99號B1',
#   'bigadd': '新北市',
#   'lat': 25.06097,
#   'lng': 121.646652,
#   'name': '家樂福汐科店',
#   'smalladd': '汐止區',
#   'tele': '(02)2697-1098'},
#  {'address': '中興路三段1號',
#   'bigadd': '新北市',
#   'lat': 24.97608,
#   'lng': 121.546661,
#   'name': '家樂福新店店',
#   'smalladd': '新店區',
#   'tele': '(02)8919-3333'},
#  {'address': '中和路499-1號',
#   'bigadd': '新北市',
#   'lat': 25.0022545,
#   'lng': 121.51059,
#   'name': '家樂福永和永安店',
#   'smalladd': '永和區',
#   'tele': '(02)2232-7755'},
#  {'address': '中山路二段295號B1',
#   'bigadd': '新北市',
#   'lat': 25.0018749,
#   'lng': 121.4958,
#   'name': '家樂福中和店',
#   'smalladd': '中和區',
#   'tele': '(02)8245-5566'},
#  {'address': '景平路353號B1',
#   'bigadd': '新北市',
#   'lat': 24.99338,
#   'lng': 121.504791,
#   'name': '家樂福景安店',
#   'smalladd': '中和區',
#   'tele': '(02)2240-9628'},
#  {'address': '明德路一段67號',
#   'bigadd': '新北市',
#   'lat': 24.98404,
#   'lng': 121.465523,
#   'name': '家樂福土城福益店',
#   'smalladd': '土城區',
#   'tele': '(02)2261-6611'},
#  {'address': '青雲路152號B1',
#   'bigadd': '新北市',
#   'lat': 24.9834576,
#   'lng': 121.459213,
#   'name': '家樂福土城店',
#   'smalladd': '土城區',
#   'tele': '(02)2265-6001'},
#  {'address': '大雅路288號B1',
#   'bigadd': '新北市',
#   'lat': 24.94774,
#   'lng': 121.379967,
#   'name': '家樂福北大店',
#   'smalladd': '樹林區',
#   'tele': '(02)3501-6879'},
#  {'address': '大安路118號',
#   'bigadd': '新北市',
#   'lat': 24.9971485,
#   'lng': 121.421341,
#   'name': '家樂福樹林店',
#   'smalladd': '樹林區',
#   'tele': '(02)2681-0000'},
#  {'address': '五華街282號',
#   'bigadd': '新北市',
#   'lat': 25.0878754,
#   'lng': 121.486778,
#   'name': '家樂福蘆洲店',
#   'smalladd': '三重區',
#   'tele': '(02)8287-9000'},
#  {'address': '重新路五段654號',
#   'bigadd': '新北市',
#   'lat': 25.04325,
#   'lng': 121.467766,
#   'name': '家樂福重新店',
#   'smalladd': '三重區',
#   'tele': '(02)2999-5000'},
#  {'address': '中平路108號B1',
#   'bigadd': '新北市',
#   'lat': 25.0459023,
#   'lng': 121.444931,
#   'name': '家樂福中平店',
#   'smalladd': '新莊區',
#   'tele': '(02)8992-5678'},
#  {'address': '雙鳳路59號',
#   'bigadd': '新北市',
#   'lat': 25.02726,
#   'lng': 121.415855,
#   'name': '家樂福新莊丹鳳店',
#   'smalladd': '新莊區',
#   'tele': '02-2901-5908'},
#  {'address': '中港路336號',
#   'bigadd': '新北市',
#   'lat': 25.04601,
#   'lng': 121.451492,
#   'name': '家樂福新莊中港',
#   'smalladd': '新莊區',
#   'tele': '02-29985052'},
#  {'address': '文化二路一段 559 號 B1',
#   'bigadd': '新北市',
#   'lat': 25.07716,
#   'lng': 121.374725,
#   'name': '家樂福林口店',
#   'smalladd': '林口區',
#   'tele': '(02)2602-5858'},
#  {'address': '光華路200號',
#   'bigadd': '新北市',
#   'lat': 25.0819626,
#   'lng': 121.46331,
#   'name': '家樂福蘆洲光華店',
#   'smalladd': '蘆洲區',
#   'tele': '02-2288-9268'},
#  {'address': '中山北路二段383號',
#   'bigadd': '新北市',
#   'lat': 25.1853,
#   'lng': 121.44442,
#   'name': '家樂福淡新店',
#   'smalladd': '淡水區',
#   'tele': '(02)8631-8880'},
#  {'address': '民權路二段38巷2號B2',
#   'bigadd': '宜蘭縣',
#   'lat': 24.7538967,
#   'lng': 121.75029,
#   'name': '家樂福宜蘭店',
#   'smalladd': '宜蘭市',
#   'tele': '(03)936-1188'},
#  {'address': '南大路286號',
#   'bigadd': '新竹市',
#   'lat': 24.7992153,
#   'lng': 120.971542,
#   'name': '家樂福新竹南大店',
#   'smalladd': '東區',
#   'tele': '03-5617768'},
#  {'address': '光明六路89號1F',
#   'bigadd': '新竹縣',
#   'lat': 24.8270473,
#   'lng': 121.009727,
#   'name': '家樂福竹北店',
#   'smalladd': '竹北市',
#   'tele': '0800 500 505'},
#  {'address': '中山東路二段510號',
#   'bigadd': '桃園市',
#   'lat': 24.9465923,
#   'lng': 121.24617,
#   'name': '家樂福中壢店',
#   'smalladd': '中壢區',
#   'tele': '0800-688-388'},
#  {'address': '中華路二段501號',
#   'bigadd': '桃園市',
#   'lat': 24.9631062,
#   'lng': 121.233864,
#   'name': '家樂福中原店',
#   'smalladd': '中壢區',
#   'tele': '(03)433-4601'},
#  {'address': '中華路一段450號',
#   'bigadd': '桃園市',
#   'lat': 24.97177,
#   'lng': 121.2536,
#   'name': '家樂福內壢店',
#   'smalladd': '中壢區',
#   'tele': '(03)452-6000'},
#  {'address': '中北路111號',
#   'bigadd': '桃園市',
#   'lat': 24.9569645,
#   'lng': 121.236137,
#   'name': '家樂福中壢中北店',
#   'smalladd': '中壢區',
#   'tele': '03-4162176'},
#  {'address': '坤慶路1號',
#   'bigadd': '桃園市',
#   'lat': 24.9025269,
#   'lng': 121.2119,
#   'name': '家樂福平鎮店',
#   'smalladd': '平鎮區',
#   'tele': '03-469-0288'},
#  {'address': '春日路1593號',
#   'bigadd': '桃園市',
#   'lat': 25.024,
#   'lng': 121.305931,
#   'name': '家樂福桃園店',
#   'smalladd': '桃園區',
#   'tele': '(03)356-6611'},
#  {'address': '大興路1號',
#   'bigadd': '桃園市',
#   'lat': 25.0152035,
#   'lng': 121.308449,
#   'name': '家樂福桃園大興',
#   'smalladd': '桃園區',
#   'tele': '03-3250172'},
#  {'address': '龍安街137號',
#   'bigadd': '桃園市',
#   'lat': 24.99078,
#   'lng': 121.279526,
#   'name': '家樂福桃園龍安店',
#   'smalladd': '桃園區',
#   'tele': '03-3698550'},
#  {'address': '經國路369號',
#   'bigadd': '桃園市',
#   'lat': 25.0162029,
#   'lng': 121.305359,
#   'name': '家樂福經國店',
#   'smalladd': '桃園區',
#   'tele': '(03)316-0676'},
#  {'address': '中正路836號',
#   'bigadd': '桃園市',
#   'lat': 25.0099354,
#   'lng': 121.301346,
#   'name': '家樂福桃園中正店',
#   'smalladd': '桃園區',
#   'tele': '(03)358-1259'},
#  {'address': '南平路168號',
#   'bigadd': '桃園市',
#   'lat': 25.0198746,
#   'lng': 121.302208,
#   'name': '家樂福桃園南平店',
#   'smalladd': '桃園區',
#   'tele': '03-3163799'},
#  {'address': '介壽路一段728號B2',
#   'bigadd': '桃園市',
#   'lat': 24.9644718,
#   'lng': 121.300255,
#   'name': '家樂福八德店',
#   'smalladd': '八德區',
#   'tele': '03-3611385'},
#  {'address': '桃園街118號B1',
#   'bigadd': '桃園市',
#   'lat': 25.0481,
#   'lng': 121.2907,
#   'name': '家樂福南竹店',
#   'smalladd': '蘆竹區',
#   'tele': '(03)212-2077'},
#  {'address': '民族街106號',
#   'bigadd': '苗栗縣',
#   'lat': 24.68641,
#   'lng': 120.878563,
#   'name': '家樂福民族店',
#   'smalladd': '竹南鎮',
#   'tele': '(037)461-138'},
#  {'address': '國華路599號',
#   'bigadd': '苗栗縣',
#   'lat': 24.5741386,
#   'lng': 120.817406,
#   'name': '家樂福苗栗店',
#   'smalladd': '苗栗市',
#   'tele': '(037)333-000'},
#  {'address': '復興路4段186號B1',
#   'bigadd': '台中市',
#   'lat': 24.1366119,
#   'lng': 120.687584,
#   'name': '家樂福德安店',
#   'smalladd': '東區',
#   'tele': '(04)2223-6677'},
#  {'address': '中清路一段595號',
#   'bigadd': '台中市',
#   'lat': 24.1695843,
#   'lng': 120.671379,
#   'name': '家樂福台中中清2',
#   'smalladd': '北區',
#   'tele': '(04)2292-1598'},
#  {'address': '崇德路一段635號',
#   'bigadd': '台中市',
#   'lat': 24.1678352,
#   'lng': 120.684914,
#   'name': '家樂福崇德店',
#   'smalladd': '北區',
#   'tele': '(04)2237-2710'},
#  {'address': '漢口路四段295號',
#   'bigadd': '台中市',
#   'lat': 24.1673126,
#   'lng': 120.680244,
#   'name': '家樂福台中漢口店',
#   'smalladd': '北區',
#   'tele': '(04)2236-0276'},
#  {'address': '進化路379號',
#   'bigadd': '台中市',
#   'lat': 24.154665,
#   'lng': 120.692039,
#   'name': '家樂福台中進化',
#   'smalladd': '北區',
#   'tele': '04-23602158'},
#  {'address': '昌平路一段105-1號',
#   'bigadd': '台中市',
#   'lat': 24.17332,
#   'lng': 120.690331,
#   'name': '家樂福昌平店',
#   'smalladd': '北屯區',
#   'tele': '(04)2243- 6058'},
#  {'address': '平田里13鄰興安路一段288號',
#   'bigadd': '台中市',
#   'lat': 24.1733265,
#   'lng': 120.69136,
#   'name': '家樂福台中興安店',
#   'smalladd': '北屯區',
#   'tele': '04-22420200'},
#  {'address': '青海路二段207-18號',
#   'bigadd': '台中市',
#   'lat': 24.16967,
#   'lng': 120.645912,
#   'name': '家樂福青海店',
#   'smalladd': '西屯區',
#   'tele': '(04)2707-3866'},
#  {'address': '中清路三段436號',
#   'bigadd': '台中市',
#   'lat': 24.207058,
#   'lng': 120.6524,
#   'name': '家樂福中清店',
#   'smalladd': '西屯區',
#   'tele': '(04)2426-2555'},
#  {'address': '南屯路二段270之1號',
#   'bigadd': '台中市',
#   'lat': 24.13734,
#   'lng': 120.646332,
#   'name': '家樂福台中南屯店',
#   'smalladd': '南屯區',
#   'tele': '(04)2475-0568'},
#  {'address': '大墩路533號B1',
#   'bigadd': '台中市',
#   'lat': 24.1490841,
#   'lng': 120.649536,
#   'name': '家樂福大墩店',
#   'smalladd': '南屯區',
#   'tele': '(04)2310-8467'},
#  {'address': '文心路一段521號',
#   'bigadd': '台中市',
#   'lat': 24.15412,
#   'lng': 120.646721,
#   'name': '家樂福文心店',
#   'smalladd': '南屯區',
#   'tele': '(04)2254-3355'},
#  {'address': '大墩十一街730號',
#   'bigadd': '台中市',
#   'lat': 24.14861,
#   'lng': 120.632851,
#   'name': '家樂福台中大墩11',
#   'smalladd': '南屯區',
#   'tele': '04-22528128'},
#  {'address': '新城里環中東路三段567號',
#   'bigadd': '台中市',
#   'lat': 20.04561,
#   'lng': 127.056885,
#   'name': '家樂福太平環中店',
#   'smalladd': '太平區',
#   'tele': '(04)2391-6018'},
#  {'address': '中平七街70號',
#   'bigadd': '台中市',
#   'lat': 24.1253185,
#   'lng': 120.719765,
#   'name': '家樂福太平店',
#   'smalladd': '太平區',
#   'tele': '(04)2277-8068'},
#  {'address': '中興路二段309巷2號',
#   'bigadd': '台中市',
#   'lat': 24.0952415,
#   'lng': 120.687874,
#   'name': '家樂福大里內新店',
#   'smalladd': '大里區',
#   'tele': '(04)2485-2689'},
#  {'address': '豐南街118號',
#   'bigadd': '台中市',
#   'lat': 24.24056,
#   'lng': 120.715279,
#   'name': '家樂福豐南店',
#   'smalladd': '豐原區',
#   'tele': '(04)2528-0897'},
#  {'address': '成功路500號',
#   'bigadd': '台中市',
#   'lat': 24.2521,
#   'lng': 120.706,
#   'name': '家樂福豐原店',
#   'smalladd': '豐原區',
#   'tele': '(04)2526-5151'},
#  {'address': '光華路336號',
#   'bigadd': '台中市',
#   'lat': 24.24243,
#   'lng': 120.565178,
#   'name': '家樂福沙鹿店',
#   'smalladd': '沙鹿區',
#   'tele': '(04)266-52300'},
#  {'address': '蔣公路295號',
#   'bigadd': '台中市',
#   'lat': 24.34784,
#   'lng': 120.617447,
#   'name': '家樂福大甲蔣公店',
#   'smalladd': '大甲區',
#   'tele': '04-26870392'},
#  {'address': '金馬路二段321號',
#   'bigadd': '彰化縣',
#   'lat': 24.09452,
#   'lng': 120.542412,
#   'name': '家樂福彰化店',
#   'smalladd': '彰化市',
#   'tele': '(047)367-397'},
#  {'address': '大同路一段455號1樓之2',
#   'bigadd': '彰化縣',
#   'lat': 23.9653,
#   'lng': 120.577026,
#   'name': '家樂福員林大同店',
#   'smalladd': '員林市',
#   'tele': '(04)835-1299'},
#  {'address': '三和三路21號',
#   'bigadd': '南投縣',
#   'lat': 23.9059715,
#   'lng': 120.6892,
#   'name': '家樂福南投店',
#   'smalladd': '南投市',
#   'tele': '(049) 2245-318'},
#  {'address': '和平里4鄰中山街210號',
#   'bigadd': '南投縣',
#   'lat': 23.97812,
#   'lng': 120.682892,
#   'name': '家樂福草屯店',
#   'smalladd': '草屯鎮',
#   'tele': '049-232-0700'},
#  {'address': '信義路1029號',
#   'bigadd': '南投縣',
#   'lat': 23.97096,
#   'lng': 120.956421,
#   'name': '家樂福埔里店',
#   'smalladd': '埔里鎮',
#   'tele': '(049)2912-088'},
#  {'address': '忠孝路346巷21號',
#   'bigadd': '嘉義市',
#   'lat': 23.4896755,
#   'lng': 120.45536,
#   'name': '家樂福北門店',
#   'smalladd': '東區忠',
#   'tele': '(05)277-2289'},
#  {'address': '博愛路二段461號',
#   'bigadd': '嘉義市',
#   'lat': 23.4714279,
#   'lng': 120.431038,
#   'name': '家樂福嘉義店',
#   'smalladd': '西區博',
#   'tele': '(05)235-3606'},
#  {'address': '立新街96號',
#   'bigadd': '雲林縣',
#   'lat': 23.7051125,
#   'lng': 120.426918,
#   'name': '家樂福虎尾店',
#   'smalladd': '虎尾鎮',
#   'tele': '(05)6331089'},
#  {'address': '雲林路二段297號',
#   'bigadd': '雲林縣',
#   'lat': 23.7019119,
#   'lng': 120.529877,
#   'name': '家樂福斗六店',
#   'smalladd': '斗六市',
#   'tele': '(05)537-5500'},
#  {'address': '西門路一段701號1樓',
#   'bigadd': '台南市',
#   'lat': 22.9879017,
#   'lng': 120.1973,
#   'name': '家樂福台南西門店',
#   'smalladd': '中西區',
#   'tele': '06-220-1858'},
#  {'address': '中華西路2段16號',
#   'bigadd': '台南市',
#   'lat': 22.9882584,
#   'lng': 120.1871,
#   'name': '家樂福安平店',
#   'smalladd': '中西區',
#   'tele': '(06)295-7588'},
#  {'address': '中華東路三段277號',
#   'bigadd': '台南市',
#   'lat': 22.97456,
#   'lng': 120.222595,
#   'name': '家樂福台南中華東店',
#   'smalladd': '東區',
#   'tele': '06-2600621'},
#  {'address': '裕農路766號',
#   'bigadd': '台南是',
#   'lat': 22.9890327,
#   'lng': 120.238136,
#   'name': '家樂福台南裕農店',
#   'smalladd': '東區',
#   'tele': '06-3315595'},
#  {'address': '莊敬路118號1樓',
#   'bigadd': '台南市',
#   'lat': 0.0,
#   'lng': 0.0,
#   'name': '家樂福莊敬店',
#   'smalladd': '東區',
#   'tele': '(06)236-9528'},
#  {'address': '開元路501號',
#   'bigadd': '台南市',
#   'lat': 23.00767,
#   'lng': 120.220833,
#   'name': '家樂福台南開元店',
#   'smalladd': '北區',
#   'tele': '06-2093057'},
#  {'address': '北安路一段167號',
#   'bigadd': '台南市',
#   'lat': 23.0176144,
#   'lng': 120.208595,
#   'name': '家樂福便利購北安店',
#   'smalladd': '北區',
#   'tele': '06-2518022'},
#  {'address': '中山南路696號',
#   'bigadd': '台南市',
#   'lat': 23.0202084,
#   'lng': 120.244316,
#   'name': '家樂福永康二王店',
#   'smalladd': '永康區',
#   'tele': '(06)201-6398'},
#  {'address': '中華二路350號B1-1-8',
#   'bigadd': '台南市',
#   'lat': 23.008707,
#   'lng': 120.231285,
#   'name': '家樂福中華店',
#   'smalladd': '永康區',
#   'tele': '(06)275-6050'},
#  {'address': '中正南路358號',
#   'bigadd': '台南市',
#   'lat': 23.0328,
#   'lng': 120.228477,
#   'name': '家樂福中正店',
#   'smalladd': '永康區',
#   'tele': '(06)253-8481'},
#  {'address': '中山路711號',
#   'bigadd': '台南市',
#   'lat': 22.9726028,
#   'lng': 120.247131,
#   'name': '家樂福仁德店',
#   'smalladd': '仁德區',
#   'tele': '(06)249-6666'},
#  {'address': '健康路251號',
#   'bigadd': '台南市',
#   'lat': 23.3191147,
#   'lng': 120.311958,
#   'name': '家樂福新營店',
#   'smalladd': '新營區',
#   'tele': '(06)656-9435'},
#  {'address': '中華五路1111號',
#   'bigadd': '高雄市',
#   'lat': 22.6059341,
#   'lng': 120.304504,
#   'name': '家樂福成功店',
#   'smalladd': '前鎮區',
#   'tele': '(07)536-9828'},
#  {'address': '光華二路157號',
#   'bigadd': '高雄市',
#   'lat': 22.611021,
#   'lng': 120.317184,
#   'name': '家樂福光華店',
#   'smalladd': '前鎮區',
#   'tele': '(07)330-6189'},
#  {'address': '河東路356號',
#   'bigadd': '高雄市',
#   'lat': 22.63365,
#   'lng': 120.286064,
#   'name': '家樂福愛河店',
#   'smalladd': '三民區',
#   'tele': '(07)272-5066'},
#  {'address': '大順二路849號',
#   'bigadd': '高雄市',
#   'lat': 22.6531773,
#   'lng': 120.318985,
#   'name': '家樂福鼎山店',
#   'smalladd': '三民區',
#   'tele': '(07)394-5588'},
#  {'address': '建工路497號',
#   'bigadd': '高雄市',
#   'lat': 22.650034,
#   'lng': 120.3247,
#   'name': '家樂福三民建工店',
#   'smalladd': '三民區',
#   'tele': '07-3808236'},
#  {'address': '鼎山街259號',
#   'bigadd': '高雄市',
#   'lat': 22.6593189,
#   'lng': 120.319824,
#   'name': '家樂福鼎金店',
#   'smalladd': '三民區',
#   'tele': '07-3803017'},
#  {'address': '澄清路635號',
#   'bigadd': '高雄市',
#   'lat': 22.6438084,
#   'lng': 120.346024,
#   'name': '家樂福澄清店',
#   'smalladd': '三民區',
#   'tele': '(07)394-3858'},
#  {'address': '藍田路288號',
#   'bigadd': '高雄市',
#   'lat': 22.72773,
#   'lng': 120.290787,
#   'name': '家樂福楠梓店',
#   'smalladd': '楠梓區',
#   'tele': '(07)591-1899'},
#  {'address': '益群路50號',
#   'bigadd': '高雄市',
#   'lat': 22.7249565,
#   'lng': 120.296913,
#   'name': '家樂福楠梓益群店',
#   'smalladd': '楠梓區',
#   'tele': '07-3011317'},
#  {'address': '宏平路411號',
#   'bigadd': '高雄市',
#   'lat': 22.5697117,
#   'lng': 120.358109,
#   'name': '家樂福高雄小港店',
#   'smalladd': '小港區',
#   'tele': '07-801-2597'},
#  {'address': '文川路323號',
#   'bigadd': '高雄市',
#   'lat': 22.6845856,
#   'lng': 120.3124,
#   'name': '家樂福重和店',
#   'smalladd': '左營區',
#   'tele': '07-3411855'},
#  {'address': '自由三路250號',
#   'bigadd': '高雄市',
#   'lat': 22.6717968,
#   'lng': 120.313919,
#   'name': '家樂福左營自由店',
#   'smalladd': '左營區',
#   'tele': '(07)3418908'},
#  {'address': '自由二路150號',
#   'bigadd': '高雄市',
#   'lat': 22.66209,
#   'lng': 120.3088,
#   'name': '家樂福左營自由二店',
#   'smalladd': '左營區',
#   'tele': '07-5562238'},
#  {'address': '南屏路369號',
#   'bigadd': '高雄市',
#   'lat': 22.668169,
#   'lng': 120.297539,
#   'name': '家樂福左營南屏店',
#   'smalladd': '左營區',
#   'tele': '07-5223536'},
#  {'address': '岡山路288號',
#   'bigadd': '高雄市',
#   'lat': 22.79323,
#   'lng': 120.296036,
#   'name': '家樂福高雄岡山店',
#   'smalladd': '岡山區',
#   'tele': '07-621-7627'},
#  {'address': '中山西路236號',
#   'bigadd': '高雄市',
#   'lat': 22.6280975,
#   'lng': 120.347885,
#   'name': '家樂福鳳山店',
#   'smalladd': '鳳山區',
#   'tele': '(07)740-1789'},
#  {'address': '林森路291號',
#   'bigadd': '高雄市',
#   'lat': 22.5963326,
#   'lng': 120.3371,
#   'name': '家樂福五甲店',
#   'smalladd': '鳳山區',
#   'tele': '(07)713-8508'},
#  {'address': '仁愛路188號',
#   'bigadd': '屏東縣',
#   'lat': 22.68272,
#   'lng': 120.497963,
#   'name': '家樂福屏東店',
#   'smalladd': '屏東市',
#   'tele': '(08)738-0310'},
#  {'address': '自由路618號',
#   'bigadd': '屏東縣',
#   'lat': 22.68336,
#   'lng': 120.482346,
#   'name': '家樂福屏東自由店',
#   'smalladd': '屏東市',
#   'tele': '08-7663568'},
#  {'address': '正氣路300之1號',
#   'bigadd': '台東縣',
#   'lat': 22.7548656,
#   'lng': 121.148888,
#   'name': '家樂福台東店',
#   'smalladd': '台東市',
#   'tele': '(089)333-258'},
#  {'address': '嘉里路15號B1',
#   'bigadd': '花蓮縣',
#   'lat': 24.0154743,
#   'lng': 121.610611,
#   'name': '家樂福花蓮店',
#   'smalladd': '新城鄉',
#   'tele': '(03)826-7979'}]

# %%
import requests
import pymongo
from pymongo import UpdateOne
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.message import EmailMessage
import smtplib
import json

def mailTo(title,mailAdds,message,whoSend='Crawler591Info'):
    msg = MIMEMultipart()    
    sender = whoSend
    subject = title
    body = message
    msg['From'] = sender
    msg['To'] = ','.join(mailAdds)
    msg['Subject'] = subject
    msg.attach(MIMEText(body, 'plain'))
    text=msg.as_string()
    #print text
    # Send the message via our SMTP server
    s = smtplib.SMTP('192.168.2.1',25)
    s.sendmail(sender,mailAdds, text)
    s.quit()  



try:
    headerstr='''Accept: application/json, text/javascript, */*; q=0.01
    Accept-Encoding: gzip, deflate, br
    Accept-Language: zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7
    Cache-Control: no-cache
    Connection: keep-alive
    Cookie: _ga=GA1.3.207086480.1524637160; _gid=GA1.3.1652140068.1524637160
    Host: www.carrefour.com.tw
    Pragma: no-cache
    Referer: https://www.carrefour.com.tw/store.html
    User-Agent: Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.181 Safari/537.36
    X-Requested-With: XMLHttpRequest'''

    headers={i.split(":")[0].strip():i.split(":")[1].strip() for i in headerstr.split("\n")}
    res=requests.get("https://www.carrefour.com.tw/api/Store",headers=headers)
    carrefourDatasO=json.loads(res.text)['result']
    carrefourDatas=[]
    for i in carrefourDatasO:
        carrefourData={}
        carrefourData['name']="家樂福"+i['分店中文名稱']
        carrefourData['lat']=i['Latitude']
        carrefourData['lng']=i['Longitude']
        carrefourData['address']=i['地址']
        carrefourData['bigadd']=i['縣市']
        carrefourData['smalladd']=i['區']
        carrefourData['tele']=i['電話號碼']
        carrefourData['_id']=carrefourData['name']
        carrefourDatas.append(carrefourData)
    Client=pymongo.MongoClient('localhost',27017,username='j122085',password='850605')
    collection=Client.rawData.carrefour
    ids=[i.pop("_id") for i in carrefourDatas]
    writeList=[UpdateOne({"_id":idn},{"$set":data},upsert=True) for idn,data in zip(ids,carrefourDatas)]
    try:
        collection.bulk_write(writeList,ordered=False)
    except Exception as er:
        print(er)

    mailTo("CrawlerCarrefour",["andy.yuan@wowprime.com"],"finish")
except Exception as er:
    mailTo("CrawlerCarrefour",["andy.yuan@wowprime.com"],"loss error:"+str(er))

# %%
list(collection.find({}))
# Out:
# [{'_id': '家樂福台北濟南',
#   'address': '濟南路2段46號B1',
#   'bigadd': '台北市',
#   'lat': 25.0403671,
#   'lng': 121.530579,
#   'name': '家樂福台北濟南',
#   'smalladd': '中正區',
#   'tele': '02-23211262'},
#  {'_id': '家樂福重慶店',
#   'address': '重慶北路二段171號',
#   'bigadd': '台北市',
#   'lat': 25.0595646,
#   'lng': 121.513779,
#   'name': '家樂福重慶店',
#   'smalladd': '大同區',
#   'tele': '(02)2553-7389'},
#  {'_id': '家樂福大直店',
#   'address': '樂群三路218號',
#   'bigadd': '台北市',
#   'lat': 25.0824471,
#   'lng': 121.558037,
#   'name': '家樂福大直店',
#   'smalladd': '中山區',
#   'tele': '(02)8509-5577'},
#  {'_id': '家樂福三民店',
#   'address': '三民路160號',
#   'bigadd': '台北市',
#   'lat': 25.0615635,
#   'lng': 121.563316,
#   'name': '家樂福三民店',
#   'smalladd': '松山區',
#   'tele': '(02)2767-0702'},
#  {'_id': '家樂福桂林店',
#   'address': '桂林路1號',
#   'bigadd': '台北市',
#   'lat': 25.0378418,
#   'lng': 121.506172,
#   'name': '家樂福桂林店',
#   'smalladd': '萬華區',
#   'tele': '(02)2388-9887'},
#  {'_id': '家樂福東興店',
#   'address': '東興路45號B1',
#   'bigadd': '台北市',
#   'lat': 25.0476589,
#   'lng': 121.566368,
#   'name': '家樂福東興店',
#   'smalladd': '信義區',
#   'tele': '(02)8768-1111'},
#  {'_id': '家樂福天母店',
#   'address': '德行西路47號',
#   'bigadd': '台北市',
#   'lat': 25.1052933,
#   'lng': 121.522507,
#   'name': '家樂福天母店',
#   'smalladd': '士林區',
#   'tele': '(02)2833-8042'},
#  {'_id': '家樂福天母中北店',
#   'address': '中山北路七段113號',
#   'bigadd': '台北市',
#   'lat': 25.1224,
#   'lng': 121.531647,
#   'name': '家樂福天母中北店',
#   'smalladd': '士林區',
#   'tele': '(02)2871-2126'},
#  {'_id': '家樂福士林忠誠',
#   'address': '忠誠路二段188號',
#   'bigadd': '台北市',
#   'lat': 25.1164436,
#   'lng': 121.533073,
#   'name': '家樂福士林忠誠',
#   'smalladd': '士林區',
#   'tele': '02-28755015'},
#  {'_id': '家樂福北投店',
#   'address': '中和街366號B1',
#   'bigadd': '台北市',
#   'lat': 25.1417618,
#   'lng': 121.499245,
#   'name': '家樂福北投店',
#   'smalladd': '北投區',
#   'tele': '(02)2896-3000'},
#  {'_id': '家樂福內湖東湖店',
#   'address': '東湖路69號B1',
#   'bigadd': '台北市',
#   'lat': 25.0686741,
#   'lng': 121.614441,
#   'name': '家樂福內湖東湖店',
#   'smalladd': '內湖區',
#   'tele': '02-26320558'},
#  {'_id': '家樂福內湖店',
#   'address': '民善街88號(民權大橋旁)',
#   'bigadd': '台北市',
#   'lat': 25.06111,
#   'lng': 121.574883,
#   'name': '家樂福內湖店',
#   'smalladd': '內湖區',
#   'tele': '(02)8790-5000'},
#  {'_id': '家樂福台北內湖1',
#   'address': '內湖路一段155號',
#   'bigadd': '台北市',
#   'lat': 25.0836239,
#   'lng': 121.561119,
#   'name': '家樂福台北內湖1',
#   'smalladd': '內湖區',
#   'tele': '02-26585955'},
#  {'_id': '家樂福南港店',
#   'address': '南港路二段20巷5號B1-1',
#   'bigadd': '台北市',
#   'lat': 25.0539341,
#   'lng': 121.605537,
#   'name': '家樂福南港店',
#   'smalladd': '南港區',
#   'tele': '(02)2788-2550'},
#  {'_id': '家樂福板橋中正店',
#   'address': '中正路302號',
#   'bigadd': '新北市',
#   'lat': 25.0207176,
#   'lng': 121.455223,
#   'name': '家樂福板橋中正店',
#   'smalladd': '板橋區',
#   'tele': '02-29605886'},
#  {'_id': '家樂福府中店',
#   'address': '府中路 126 號 1 樓',
#   'bigadd': '新北市',
#   'lat': 25.0095444,
#   'lng': 121.45488,
#   'name': '家樂福府中店',
#   'smalladd': '板橋區',
#   'tele': '(02)2272-9000'},
#  {'_id': '家樂福板橋店',
#   'address': '三民路二段31號B1',
#   'bigadd': '新北市',
#   'lat': 25.0179768,
#   'lng': 121.4794,
#   'name': '家樂福板橋店',
#   'smalladd': '板橋區',
#   'tele': '(02)2964-2988'},
#  {'_id': '家樂福板橋文化',
#   'address': '文化路二段313號B1',
#   'bigadd': '新北市',
#   'lat': 25.0297356,
#   'lng': 121.469688,
#   'name': '家樂福板橋文化',
#   'smalladd': '板橋區',
#   'tele': '02-22565121'},
#  {'_id': '家樂福汐科店',
#   'address': '新台五路一段99號B1',
#   'bigadd': '新北市',
#   'lat': 25.06097,
#   'lng': 121.646652,
#   'name': '家樂福汐科店',
#   'smalladd': '汐止區',
#   'tele': '(02)2697-1098'},
#  {'_id': '家樂福新店店',
#   'address': '中興路三段1號',
#   'bigadd': '新北市',
#   'lat': 24.97608,
#   'lng': 121.546661,
#   'name': '家樂福新店店',
#   'smalladd': '新店區',
#   'tele': '(02)8919-3333'},
#  {'_id': '家樂福永和永安店',
#   'address': '中和路499-1號',
#   'bigadd': '新北市',
#   'lat': 25.0022545,
#   'lng': 121.51059,
#   'name': '家樂福永和永安店',
#   'smalladd': '永和區',
#   'tele': '(02)2232-7755'},
#  {'_id': '家樂福中和店',
#   'address': '中山路二段295號B1',
#   'bigadd': '新北市',
#   'lat': 25.0018749,
#   'lng': 121.4958,
#   'name': '家樂福中和店',
#   'smalladd': '中和區',
#   'tele': '(02)8245-5566'},
#  {'_id': '家樂福景安店',
#   'address': '景平路353號B1',
#   'bigadd': '新北市',
#   'lat': 24.99338,
#   'lng': 121.504791,
#   'name': '家樂福景安店',
#   'smalladd': '中和區',
#   'tele': '(02)2240-9628'},
#  {'_id': '家樂福土城福益店',
#   'address': '明德路一段67號',
#   'bigadd': '新北市',
#   'lat': 24.98404,
#   'lng': 121.465523,
#   'name': '家樂福土城福益店',
#   'smalladd': '土城區',
#   'tele': '(02)2261-6611'},
#  {'_id': '家樂福土城店',
#   'address': '青雲路152號B1',
#   'bigadd': '新北市',
#   'lat': 24.9834576,
#   'lng': 121.459213,
#   'name': '家樂福土城店',
#   'smalladd': '土城區',
#   'tele': '(02)2265-6001'},
#  {'_id': '家樂福北大店',
#   'address': '大雅路288號B1',
#   'bigadd': '新北市',
#   'lat': 24.94774,
#   'lng': 121.379967,
#   'name': '家樂福北大店',
#   'smalladd': '樹林區',
#   'tele': '(02)3501-6879'},
#  {'_id': '家樂福樹林店',
#   'address': '大安路118號',
#   'bigadd': '新北市',
#   'lat': 24.9971485,
#   'lng': 121.421341,
#   'name': '家樂福樹林店',
#   'smalladd': '樹林區',
#   'tele': '(02)2681-0000'},
#  {'_id': '家樂福蘆洲店',
#   'address': '五華街282號',
#   'bigadd': '新北市',
#   'lat': 25.0878754,
#   'lng': 121.486778,
#   'name': '家樂福蘆洲店',
#   'smalladd': '三重區',
#   'tele': '(02)8287-9000'},
#  {'_id': '家樂福重新店',
#   'address': '重新路五段654號',
#   'bigadd': '新北市',
#   'lat': 25.04325,
#   'lng': 121.467766,
#   'name': '家樂福重新店',
#   'smalladd': '三重區',
#   'tele': '(02)2999-5000'},
#  {'_id': '家樂福中平店',
#   'address': '中平路108號B1',
#   'bigadd': '新北市',
#   'lat': 25.0459023,
#   'lng': 121.444931,
#   'name': '家樂福中平店',
#   'smalladd': '新莊區',
#   'tele': '(02)8992-5678'},
#  {'_id': '家樂福新莊丹鳳店',
#   'address': '雙鳳路59號',
#   'bigadd': '新北市',
#   'lat': 25.02726,
#   'lng': 121.415855,
#   'name': '家樂福新莊丹鳳店',
#   'smalladd': '新莊區',
#   'tele': '02-2901-5908'},
#  {'_id': '家樂福新莊中港',
#   'address': '中港路336號',
#   'bigadd': '新北市',
#   'lat': 25.04601,
#   'lng': 121.451492,
#   'name': '家樂福新莊中港',
#   'smalladd': '新莊區',
#   'tele': '02-29985052'},
#  {'_id': '家樂福林口店',
#   'address': '文化二路一段 559 號 B1',
#   'bigadd': '新北市',
#   'lat': 25.07716,
#   'lng': 121.374725,
#   'name': '家樂福林口店',
#   'smalladd': '林口區',
#   'tele': '(02)2602-5858'},
#  {'_id': '家樂福蘆洲光華店',
#   'address': '光華路200號',
#   'bigadd': '新北市',
#   'lat': 25.0819626,
#   'lng': 121.46331,
#   'name': '家樂福蘆洲光華店',
#   'smalladd': '蘆洲區',
#   'tele': '02-2288-9268'},
#  {'_id': '家樂福淡新店',
#   'address': '中山北路二段383號',
#   'bigadd': '新北市',
#   'lat': 25.1853,
#   'lng': 121.44442,
#   'name': '家樂福淡新店',
#   'smalladd': '淡水區',
#   'tele': '(02)8631-8880'},
#  {'_id': '家樂福宜蘭店',
#   'address': '民權路二段38巷2號B2',
#   'bigadd': '宜蘭縣',
#   'lat': 24.7538967,
#   'lng': 121.75029,
#   'name': '家樂福宜蘭店',
#   'smalladd': '宜蘭市',
#   'tele': '(03)936-1188'},
#  {'_id': '家樂福新竹南大店',
#   'address': '南大路286號',
#   'bigadd': '新竹市',
#   'lat': 24.7992153,
#   'lng': 120.971542,
#   'name': '家樂福新竹南大店',
#   'smalladd': '東區',
#   'tele': '03-5617768'},
#  {'_id': '家樂福竹北店',
#   'address': '光明六路89號1F',
#   'bigadd': '新竹縣',
#   'lat': 24.8270473,
#   'lng': 121.009727,
#   'name': '家樂福竹北店',
#   'smalladd': '竹北市',
#   'tele': '0800 500 505'},
#  {'_id': '家樂福中壢店',
#   'address': '中山東路二段510號',
#   'bigadd': '桃園市',
#   'lat': 24.9465923,
#   'lng': 121.24617,
#   'name': '家樂福中壢店',
#   'smalladd': '中壢區',
#   'tele': '0800-688-388'},
#  {'_id': '家樂福中原店',
#   'address': '中華路二段501號',
#   'bigadd': '桃園市',
#   'lat': 24.9631062,
#   'lng': 121.233864,
#   'name': '家樂福中原店',
#   'smalladd': '中壢區',
#   'tele': '(03)433-4601'},
#  {'_id': '家樂福內壢店',
#   'address': '中華路一段450號',
#   'bigadd': '桃園市',
#   'lat': 24.97177,
#   'lng': 121.2536,
#   'name': '家樂福內壢店',
#   'smalladd': '中壢區',
#   'tele': '(03)452-6000'},
#  {'_id': '家樂福中壢中北店',
#   'address': '中北路111號',
#   'bigadd': '桃園市',
#   'lat': 24.9569645,
#   'lng': 121.236137,
#   'name': '家樂福中壢中北店',
#   'smalladd': '中壢區',
#   'tele': '03-4162176'},
#  {'_id': '家樂福平鎮店',
#   'address': '坤慶路1號',
#   'bigadd': '桃園市',
#   'lat': 24.9025269,
#   'lng': 121.2119,
#   'name': '家樂福平鎮店',
#   'smalladd': '平鎮區',
#   'tele': '03-469-0288'},
#  {'_id': '家樂福桃園店',
#   'address': '春日路1593號',
#   'bigadd': '桃園市',
#   'lat': 25.024,
#   'lng': 121.305931,
#   'name': '家樂福桃園店',
#   'smalladd': '桃園區',
#   'tele': '(03)356-6611'},
#  {'_id': '家樂福桃園大興',
#   'address': '大興路1號',
#   'bigadd': '桃園市',
#   'lat': 25.0152035,
#   'lng': 121.308449,
#   'name': '家樂福桃園大興',
#   'smalladd': '桃園區',
#   'tele': '03-3250172'},
#  {'_id': '家樂福桃園龍安店',
#   'address': '龍安街137號',
#   'bigadd': '桃園市',
#   'lat': 24.99078,
#   'lng': 121.279526,
#   'name': '家樂福桃園龍安店',
#   'smalladd': '桃園區',
#   'tele': '03-3698550'},
#  {'_id': '家樂福經國店',
#   'address': '經國路369號',
#   'bigadd': '桃園市',
#   'lat': 25.0162029,
#   'lng': 121.305359,
#   'name': '家樂福經國店',
#   'smalladd': '桃園區',
#   'tele': '(03)316-0676'},
#  {'_id': '家樂福桃園中正店',
#   'address': '中正路836號',
#   'bigadd': '桃園市',
#   'lat': 25.0099354,
#   'lng': 121.301346,
#   'name': '家樂福桃園中正店',
#   'smalladd': '桃園區',
#   'tele': '(03)358-1259'},
#  {'_id': '家樂福桃園南平店',
#   'address': '南平路168號',
#   'bigadd': '桃園市',
#   'lat': 25.0198746,
#   'lng': 121.302208,
#   'name': '家樂福桃園南平店',
#   'smalladd': '桃園區',
#   'tele': '03-3163799'},
#  {'_id': '家樂福八德店',
#   'address': '介壽路一段728號B2',
#   'bigadd': '桃園市',
#   'lat': 24.9644718,
#   'lng': 121.300255,
#   'name': '家樂福八德店',
#   'smalladd': '八德區',
#   'tele': '03-3611385'},
#  {'_id': '家樂福南竹店',
#   'address': '桃園街118號B1',
#   'bigadd': '桃園市',
#   'lat': 25.0481,
#   'lng': 121.2907,
#   'name': '家樂福南竹店',
#   'smalladd': '蘆竹區',
#   'tele': '(03)212-2077'},
#  {'_id': '家樂福民族店',
#   'address': '民族街106號',
#   'bigadd': '苗栗縣',
#   'lat': 24.68641,
#   'lng': 120.878563,
#   'name': '家樂福民族店',
#   'smalladd': '竹南鎮',
#   'tele': '(037)461-138'},
#  {'_id': '家樂福苗栗店',
#   'address': '國華路599號',
#   'bigadd': '苗栗縣',
#   'lat': 24.5741386,
#   'lng': 120.817406,
#   'name': '家樂福苗栗店',
#   'smalladd': '苗栗市',
#   'tele': '(037)333-000'},
#  {'_id': '家樂福德安店',
#   'address': '復興路4段186號B1',
#   'bigadd': '台中市',
#   'lat': 24.1366119,
#   'lng': 120.687584,
#   'name': '家樂福德安店',
#   'smalladd': '東區',
#   'tele': '(04)2223-6677'},
#  {'_id': '家樂福台中中清2',
#   'address': '中清路一段595號',
#   'bigadd': '台中市',
#   'lat': 24.1695843,
#   'lng': 120.671379,
#   'name': '家樂福台中中清2',
#   'smalladd': '北區',
#   'tele': '(04)2292-1598'},
#  {'_id': '家樂福崇德店',
#   'address': '崇德路一段635號',
#   'bigadd': '台中市',
#   'lat': 24.1678352,
#   'lng': 120.684914,
#   'name': '家樂福崇德店',
#   'smalladd': '北區',
#   'tele': '(04)2237-2710'},
#  {'_id': '家樂福台中漢口店',
#   'address': '漢口路四段295號',
#   'bigadd': '台中市',
#   'lat': 24.1673126,
#   'lng': 120.680244,
#   'name': '家樂福台中漢口店',
#   'smalladd': '北區',
#   'tele': '(04)2236-0276'},
#  {'_id': '家樂福台中進化',
#   'address': '進化路379號',
#   'bigadd': '台中市',
#   'lat': 24.154665,
#   'lng': 120.692039,
#   'name': '家樂福台中進化',
#   'smalladd': '北區',
#   'tele': '04-23602158'},
#  {'_id': '家樂福昌平店',
#   'address': '昌平路一段105-1號',
#   'bigadd': '台中市',
#   'lat': 24.17332,
#   'lng': 120.690331,
#   'name': '家樂福昌平店',
#   'smalladd': '北屯區',
#   'tele': '(04)2243- 6058'},
#  {'_id': '家樂福台中興安店',
#   'address': '平田里13鄰興安路一段288號',
#   'bigadd': '台中市',
#   'lat': 24.1733265,
#   'lng': 120.69136,
#   'name': '家樂福台中興安店',
#   'smalladd': '北屯區',
#   'tele': '04-22420200'},
#  {'_id': '家樂福青海店',
#   'address': '青海路二段207-18號',
#   'bigadd': '台中市',
#   'lat': 24.16967,
#   'lng': 120.645912,
#   'name': '家樂福青海店',
#   'smalladd': '西屯區',
#   'tele': '(04)2707-3866'},
#  {'_id': '家樂福中清店',
#   'address': '中清路三段436號',
#   'bigadd': '台中市',
#   'lat': 24.207058,
#   'lng': 120.6524,
#   'name': '家樂福中清店',
#   'smalladd': '西屯區',
#   'tele': '(04)2426-2555'},
#  {'_id': '家樂福台中南屯店',
#   'address': '南屯路二段270之1號',
#   'bigadd': '台中市',
#   'lat': 24.13734,
#   'lng': 120.646332,
#   'name': '家樂福台中南屯店',
#   'smalladd': '南屯區',
#   'tele': '(04)2475-0568'},
#  {'_id': '家樂福大墩店',
#   'address': '大墩路533號B1',
#   'bigadd': '台中市',
#   'lat': 24.1490841,
#   'lng': 120.649536,
#   'name': '家樂福大墩店',
#   'smalladd': '南屯區',
#   'tele': '(04)2310-8467'},
#  {'_id': '家樂福文心店',
#   'address': '文心路一段521號',
#   'bigadd': '台中市',
#   'lat': 24.15412,
#   'lng': 120.646721,
#   'name': '家樂福文心店',
#   'smalladd': '南屯區',
#   'tele': '(04)2254-3355'},
#  {'_id': '家樂福台中大墩11',
#   'address': '大墩十一街730號',
#   'bigadd': '台中市',
#   'lat': 24.14861,
#   'lng': 120.632851,
#   'name': '家樂福台中大墩11',
#   'smalladd': '南屯區',
#   'tele': '04-22528128'},
#  {'_id': '家樂福太平環中店',
#   'address': '新城里環中東路三段567號',
#   'bigadd': '台中市',
#   'lat': 20.04561,
#   'lng': 127.056885,
#   'name': '家樂福太平環中店',
#   'smalladd': '太平區',
#   'tele': '(04)2391-6018'},
#  {'_id': '家樂福太平店',
#   'address': '中平七街70號',
#   'bigadd': '台中市',
#   'lat': 24.1253185,
#   'lng': 120.719765,
#   'name': '家樂福太平店',
#   'smalladd': '太平區',
#   'tele': '(04)2277-8068'},
#  {'_id': '家樂福大里內新店',
#   'address': '中興路二段309巷2號',
#   'bigadd': '台中市',
#   'lat': 24.0952415,
#   'lng': 120.687874,
#   'name': '家樂福大里內新店',
#   'smalladd': '大里區',
#   'tele': '(04)2485-2689'},
#  {'_id': '家樂福豐南店',
#   'address': '豐南街118號',
#   'bigadd': '台中市',
#   'lat': 24.24056,
#   'lng': 120.715279,
#   'name': '家樂福豐南店',
#   'smalladd': '豐原區',
#   'tele': '(04)2528-0897'},
#  {'_id': '家樂福豐原店',
#   'address': '成功路500號',
#   'bigadd': '台中市',
#   'lat': 24.2521,
#   'lng': 120.706,
#   'name': '家樂福豐原店',
#   'smalladd': '豐原區',
#   'tele': '(04)2526-5151'},
#  {'_id': '家樂福沙鹿店',
#   'address': '光華路336號',
#   'bigadd': '台中市',
#   'lat': 24.24243,
#   'lng': 120.565178,
#   'name': '家樂福沙鹿店',
#   'smalladd': '沙鹿區',
#   'tele': '(04)266-52300'},
#  {'_id': '家樂福大甲蔣公店',
#   'address': '蔣公路295號',
#   'bigadd': '台中市',
#   'lat': 24.34784,
#   'lng': 120.617447,
#   'name': '家樂福大甲蔣公店',
#   'smalladd': '大甲區',
#   'tele': '04-26870392'},
#  {'_id': '家樂福彰化店',
#   'address': '金馬路二段321號',
#   'bigadd': '彰化縣',
#   'lat': 24.09452,
#   'lng': 120.542412,
#   'name': '家樂福彰化店',
#   'smalladd': '彰化市',
#   'tele': '(047)367-397'},
#  {'_id': '家樂福員林大同店',
#   'address': '大同路一段455號1樓之2',
#   'bigadd': '彰化縣',
#   'lat': 23.9653,
#   'lng': 120.577026,
#   'name': '家樂福員林大同店',
#   'smalladd': '員林市',
#   'tele': '(04)835-1299'},
#  {'_id': '家樂福南投店',
#   'address': '三和三路21號',
#   'bigadd': '南投縣',
#   'lat': 23.9059715,
#   'lng': 120.6892,
#   'name': '家樂福南投店',
#   'smalladd': '南投市',
#   'tele': '(049) 2245-318'},
#  {'_id': '家樂福草屯店',
#   'address': '和平里4鄰中山街210號',
#   'bigadd': '南投縣',
#   'lat': 23.97812,
#   'lng': 120.682892,
#   'name': '家樂福草屯店',
#   'smalladd': '草屯鎮',
#   'tele': '049-232-0700'},
#  {'_id': '家樂福埔里店',
#   'address': '信義路1029號',
#   'bigadd': '南投縣',
#   'lat': 23.97096,
#   'lng': 120.956421,
#   'name': '家樂福埔里店',
#   'smalladd': '埔里鎮',
#   'tele': '(049)2912-088'},
#  {'_id': '家樂福北門店',
#   'address': '忠孝路346巷21號',
#   'bigadd': '嘉義市',
#   'lat': 23.4896755,
#   'lng': 120.45536,
#   'name': '家樂福北門店',
#   'smalladd': '東區忠',
#   'tele': '(05)277-2289'},
#  {'_id': '家樂福嘉義店',
#   'address': '博愛路二段461號',
#   'bigadd': '嘉義市',
#   'lat': 23.4714279,
#   'lng': 120.431038,
#   'name': '家樂福嘉義店',
#   'smalladd': '西區博',
#   'tele': '(05)235-3606'},
#  {'_id': '家樂福虎尾店',
#   'address': '立新街96號',
#   'bigadd': '雲林縣',
#   'lat': 23.7051125,
#   'lng': 120.426918,
#   'name': '家樂福虎尾店',
#   'smalladd': '虎尾鎮',
#   'tele': '(05)6331089'},
#  {'_id': '家樂福斗六店',
#   'address': '雲林路二段297號',
#   'bigadd': '雲林縣',
#   'lat': 23.7019119,
#   'lng': 120.529877,
#   'name': '家樂福斗六店',
#   'smalladd': '斗六市',
#   'tele': '(05)537-5500'},
#  {'_id': '家樂福台南西門店',
#   'address': '西門路一段701號1樓',
#   'bigadd': '台南市',
#   'lat': 22.9879017,
#   'lng': 120.1973,
#   'name': '家樂福台南西門店',
#   'smalladd': '中西區',
#   'tele': '06-220-1858'},
#  {'_id': '家樂福安平店',
#   'address': '中華西路2段16號',
#   'bigadd': '台南市',
#   'lat': 22.9882584,
#   'lng': 120.1871,
#   'name': '家樂福安平店',
#   'smalladd': '中西區',
#   'tele': '(06)295-7588'},
#  {'_id': '家樂福台南中華東店',
#   'address': '中華東路三段277號',
#   'bigadd': '台南市',
#   'lat': 22.97456,
#   'lng': 120.222595,
#   'name': '家樂福台南中華東店',
#   'smalladd': '東區',
#   'tele': '06-2600621'},
#  {'_id': '家樂福台南裕農店',
#   'address': '裕農路766號',
#   'bigadd': '台南是',
#   'lat': 22.9890327,
#   'lng': 120.238136,
#   'name': '家樂福台南裕農店',
#   'smalladd': '東區',
#   'tele': '06-3315595'},
#  {'_id': '家樂福莊敬店',
#   'address': '莊敬路118號1樓',
#   'bigadd': '台南市',
#   'lat': 0.0,
#   'lng': 0.0,
#   'name': '家樂福莊敬店',
#   'smalladd': '東區',
#   'tele': '(06)236-9528'},
#  {'_id': '家樂福台南開元店',
#   'address': '開元路501號',
#   'bigadd': '台南市',
#   'lat': 23.00767,
#   'lng': 120.220833,
#   'name': '家樂福台南開元店',
#   'smalladd': '北區',
#   'tele': '06-2093057'},
#  {'_id': '家樂福便利購北安店',
#   'address': '北安路一段167號',
#   'bigadd': '台南市',
#   'lat': 23.0176144,
#   'lng': 120.208595,
#   'name': '家樂福便利購北安店',
#   'smalladd': '北區',
#   'tele': '06-2518022'},
#  {'_id': '家樂福永康二王店',
#   'address': '中山南路696號',
#   'bigadd': '台南市',
#   'lat': 23.0202084,
#   'lng': 120.244316,
#   'name': '家樂福永康二王店',
#   'smalladd': '永康區',
#   'tele': '(06)201-6398'},
#  {'_id': '家樂福中華店',
#   'address': '中華二路350號B1-1-8',
#   'bigadd': '台南市',
#   'lat': 23.008707,
#   'lng': 120.231285,
#   'name': '家樂福中華店',
#   'smalladd': '永康區',
#   'tele': '(06)275-6050'},
#  {'_id': '家樂福中正店',
#   'address': '中正南路358號',
#   'bigadd': '台南市',
#   'lat': 23.0328,
#   'lng': 120.228477,
#   'name': '家樂福中正店',
#   'smalladd': '永康區',
#   'tele': '(06)253-8481'},
#  {'_id': '家樂福仁德店',
#   'address': '中山路711號',
#   'bigadd': '台南市',
#   'lat': 22.9726028,
#   'lng': 120.247131,
#   'name': '家樂福仁德店',
#   'smalladd': '仁德區',
#   'tele': '(06)249-6666'},
#  {'_id': '家樂福新營店',
#   'address': '健康路251號',
#   'bigadd': '台南市',
#   'lat': 23.3191147,
#   'lng': 120.311958,
#   'name': '家樂福新營店',
#   'smalladd': '新營區',
#   'tele': '(06)656-9435'},
#  {'_id': '家樂福成功店',
#   'address': '中華五路1111號',
#   'bigadd': '高雄市',
#   'lat': 22.6059341,
#   'lng': 120.304504,
#   'name': '家樂福成功店',
#   'smalladd': '前鎮區',
#   'tele': '(07)536-9828'},
#  {'_id': '家樂福光華店',
#   'address': '光華二路157號',
#   'bigadd': '高雄市',
#   'lat': 22.611021,
#   'lng': 120.317184,
#   'name': '家樂福光華店',
#   'smalladd': '前鎮區',
#   'tele': '(07)330-6189'},
#  {'_id': '家樂福愛河店',
#   'address': '河東路356號',
#   'bigadd': '高雄市',
#   'lat': 22.63365,
#   'lng': 120.286064,
#   'name': '家樂福愛河店',
#   'smalladd': '三民區',
#   'tele': '(07)272-5066'},
#  {'_id': '家樂福鼎山店',
#   'address': '大順二路849號',
#   'bigadd': '高雄市',
#   'lat': 22.6531773,
#   'lng': 120.318985,
#   'name': '家樂福鼎山店',
#   'smalladd': '三民區',
#   'tele': '(07)394-5588'},
#  {'_id': '家樂福三民建工店',
#   'address': '建工路497號',
#   'bigadd': '高雄市',
#   'lat': 22.650034,
#   'lng': 120.3247,
#   'name': '家樂福三民建工店',
#   'smalladd': '三民區',
#   'tele': '07-3808236'},
#  {'_id': '家樂福鼎金店',
#   'address': '鼎山街259號',
#   'bigadd': '高雄市',
#   'lat': 22.6593189,
#   'lng': 120.319824,
#   'name': '家樂福鼎金店',
#   'smalladd': '三民區',
#   'tele': '07-3803017'},
#  {'_id': '家樂福澄清店',
#   'address': '澄清路635號',
#   'bigadd': '高雄市',
#   'lat': 22.6438084,
#   'lng': 120.346024,
#   'name': '家樂福澄清店',
#   'smalladd': '三民區',
#   'tele': '(07)394-3858'},
#  {'_id': '家樂福楠梓店',
#   'address': '藍田路288號',
#   'bigadd': '高雄市',
#   'lat': 22.72773,
#   'lng': 120.290787,
#   'name': '家樂福楠梓店',
#   'smalladd': '楠梓區',
#   'tele': '(07)591-1899'},
#  {'_id': '家樂福楠梓益群店',
#   'address': '益群路50號',
#   'bigadd': '高雄市',
#   'lat': 22.7249565,
#   'lng': 120.296913,
#   'name': '家樂福楠梓益群店',
#   'smalladd': '楠梓區',
#   'tele': '07-3011317'},
#  {'_id': '家樂福高雄小港店',
#   'address': '宏平路411號',
#   'bigadd': '高雄市',
#   'lat': 22.5697117,
#   'lng': 120.358109,
#   'name': '家樂福高雄小港店',
#   'smalladd': '小港區',
#   'tele': '07-801-2597'},
#  {'_id': '家樂福重和店',
#   'address': '文川路323號',
#   'bigadd': '高雄市',
#   'lat': 22.6845856,
#   'lng': 120.3124,
#   'name': '家樂福重和店',
#   'smalladd': '左營區',
#   'tele': '07-3411855'},
#  {'_id': '家樂福左營自由店',
#   'address': '自由三路250號',
#   'bigadd': '高雄市',
#   'lat': 22.6717968,
#   'lng': 120.313919,
#   'name': '家樂福左營自由店',
#   'smalladd': '左營區',
#   'tele': '(07)3418908'},
#  {'_id': '家樂福左營自由二店',
#   'address': '自由二路150號',
#   'bigadd': '高雄市',
#   'lat': 22.66209,
#   'lng': 120.3088,
#   'name': '家樂福左營自由二店',
#   'smalladd': '左營區',
#   'tele': '07-5562238'},
#  {'_id': '家樂福左營南屏店',
#   'address': '南屏路369號',
#   'bigadd': '高雄市',
#   'lat': 22.668169,
#   'lng': 120.297539,
#   'name': '家樂福左營南屏店',
#   'smalladd': '左營區',
#   'tele': '07-5223536'},
#  {'_id': '家樂福高雄岡山店',
#   'address': '岡山路288號',
#   'bigadd': '高雄市',
#   'lat': 22.79323,
#   'lng': 120.296036,
#   'name': '家樂福高雄岡山店',
#   'smalladd': '岡山區',
#   'tele': '07-621-7627'},
#  {'_id': '家樂福鳳山店',
#   'address': '中山西路236號',
#   'bigadd': '高雄市',
#   'lat': 22.6280975,
#   'lng': 120.347885,
#   'name': '家樂福鳳山店',
#   'smalladd': '鳳山區',
#   'tele': '(07)740-1789'},
#  {'_id': '家樂福五甲店',
#   'address': '林森路291號',
#   'bigadd': '高雄市',
#   'lat': 22.5963326,
#   'lng': 120.3371,
#   'name': '家樂福五甲店',
#   'smalladd': '鳳山區',
#   'tele': '(07)713-8508'},
#  {'_id': '家樂福屏東店',
#   'address': '仁愛路188號',
#   'bigadd': '屏東縣',
#   'lat': 22.68272,
#   'lng': 120.497963,
#   'name': '家樂福屏東店',
#   'smalladd': '屏東市',
#   'tele': '(08)738-0310'},
#  {'_id': '家樂福屏東自由店',
#   'address': '自由路618號',
#   'bigadd': '屏東縣',
#   'lat': 22.68336,
#   'lng': 120.482346,
#   'name': '家樂福屏東自由店',
#   'smalladd': '屏東市',
#   'tele': '08-7663568'},
#  {'_id': '家樂福台東店',
#   'address': '正氣路300之1號',
#   'bigadd': '台東縣',
#   'lat': 22.7548656,
#   'lng': 121.148888,
#   'name': '家樂福台東店',
#   'smalladd': '台東市',
#   'tele': '(089)333-258'},
#  {'_id': '家樂福花蓮店',
#   'address': '嘉里路15號B1',
#   'bigadd': '花蓮縣',
#   'lat': 24.0154743,
#   'lng': 121.610611,
#   'name': '家樂福花蓮店',
#   'smalladd': '新城鄉',
#   'tele': '(03)826-7979'}]
